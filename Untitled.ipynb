# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Info/info.csv")
df
# Out:
#      Track ID      Genre Filename   Duration  Sample rate  \
# 0           1  classical    1.mp3  60.029388      44100.0
# 1          10  classical   10.mp3  60.029388      44100.0
# 2         100  classical  100.mp3  60.029388      44100.0
# 3          11  classical   11.mp3  60.029388      44100.0
# 4          12  classical   12.mp3  60.029388      44100.0
# ..        ...        ...      ...        ...          ...
# 395       395       rock   95.mp3  60.029388      44100.0
# 396       396       rock   96.mp3  60.029388      44100.0
# 397       397       rock   97.mp3  60.029388      44100.0
# 398       398       rock   98.mp3  60.029388      44100.0
# 399       399       rock   99.mp3  60.029388      44100.0
#
#      Max absolute amplitude  Mean absolute amplitude
# 0                  0.619064                 0.076574
# 1                  0.822159                 0.102358
# 2                  0.673553                 0.073789
# 3                  0.698700                 0.057149
# ...

# %%
df = df.drop(df[df["Duration" < 58.0].index)
# Out:
# 25.835102040816327 63
# 30.27591836734694 71
