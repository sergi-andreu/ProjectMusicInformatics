# %%
import numpy as np
import pandas as pd
import os

import tensorflow as tf
import tensorflow_addons as tfa

# %%
MFCCs = np.load("../preprocessing/MFCCs/MFCC.npy")
MFCCs = (MFCCs - np.nanmean(MFCCs))/np.nanstd(MFCCs)

# %%
info_songs = pd.read_csv("../Info/info.csv")
label_songs = pd.read_csv("../preprocessing/labels.csv")

# %%
# Retrieve emotions from the labels.csv file

emotions = ["amazement", "solemnity", "tenderness", "nostalgia", "calmness", 
            "power", "joyful_activation", "tension", "sadness"]

labels = label_songs[emotions]
labels = labels.to_numpy()

length_songs = pd.DataFrame(info_songs["Track ID"])
length_songs["Song length"] = info_songs["Duration"]*10
length_songs["Song length"] = length_songs["Song length"].astype(int)

# %%
n_data = len(length_songs)
idx = np.random.permutation(n_data)
length_songs = length_songs.reindex(idx)["Song length"].to_numpy()
MFCCs_raw = MFCCs[idx, :, :]
labels_raw = labels[idx]

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras import Input, layers
from tensorflow.keras import backend as K

sample_size = (20, 50, 1)

drop_out_rate = 0.4

# very simple keras Sequential model
input_tensor = Input(sample_size)
x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(input_tensor)
x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(x)
x = layers.Dropout(drop_out_rate)(x)
x = layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)
x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(x)
x = layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)
x = layers.Flatten()(x)
x = layers.Dense(20, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(drop_out_rate)(x)
#output_tensor = layers.Dense(9, activation="sigmoid")(x)
output_tensor = layers.Dense(9, activation="sigmoid")(x)

model_1 = tf.keras.Model(input_tensor, output_tensor)
model_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 20, 50, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 18, 48, 16)        160
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 46, 16)        2320
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 46, 16)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 7, 22, 16)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 20, 16)         2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 9, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 288)               0
# _________________________________________________________________
# dense (Dense)                (None, 20)                5780
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 20)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 189
# =================================================================
# Total params: 10,769
# Trainable params: 10,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = model_1

loss = "MSE"
#loss = "CosineSimilarity"
loss = "both"

if loss == "MSE":
    model.compile(optimizer="adam",
                  loss=tf.keras.losses.MeanSquaredError(),
                  metrics=["cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "CosineSimilarity":
    model.compile(optimizer="adam",
                  loss= tf.keras.losses.CosineSimilarity(),
                  metrics=["MSE", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "both":
    def custom_loss(y_true, y_pred):
        cos_sim = tf.keras.losses.CosineSimilarity() 
        MSE = tf.keras.losses.MeanSquaredError()
        
        return cos_sim(y_true, y_pred) + MSE(y_true, y_pred)
        
    model.compile(optimizer="adam",
                  loss= custom_loss,
                  metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])

# %%
def slice_accordingly(input_tensor, labels, size=sample_size):

    input_shape = (tf.shape(input_tensor).numpy())
    
    input_shape[1], input_shape[2] = size[0], size[1]
    size = input_shape
    
    sliced_tensor = tf.image.random_crop(input_tensor, size)
    
    nan_values, idx = tf.unique(tf.gather(tf.where(tf.math.is_nan(sliced_tensor)), 0, axis=1))
    nan_values = nan_values.numpy()
  
    msk = np.zeros((input_shape[0]), dtype=np.bool)
    msk[nan_values] = True
    msk = ~msk

    sliced_tensor = tf.boolean_mask(sliced_tensor, msk , axis=0)
    labels = tf.boolean_mask(labels , msk, axis=0)
    
    return sliced_tensor, labels

# %%
fraction_validation = 0.25
n_test = int(fraction_validation*len(labels))
n_train = len(labels) - n_test

train_features, train_labels, train_length = MFCCs_raw[:n_train], labels_raw[:n_train], length_songs[:n_train]
validation_features, validation_labels, validation_length = MFCCs_raw[n_train:], labels_raw[n_train:], length_songs[n_train:]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels, train_length))
validation_dataset = tf.data.Dataset.from_tensor_slices((validation_features, validation_labels, validation_length))

# %%
n_epochs = 10
batch_size = 50

history_df = pd.DataFrame()

for epoch in range(n_epochs):
    print("Epoch", epoch)
    train_ds = train_dataset.shuffle(n_train).batch(batch_size)
    val_ds = validation_dataset.shuffle(n_test).batch(n_test)
    
    x_val, y_val, length_val = next(iter(val_ds))
    x_val, y_val = slice_accordingly(x_val, y_val)
    
    for features, labels, lengths in train_ds:
        features, labels = slice_accordingly(features, labels)
        
        history = model.fit(features, labels,
                           validation_data=(x_val, y_val),verbose=1)
        history = pd.DataFrame(history.history)
        history_df = history_df.append(history)
# Out:
# Epoch 0
# 2/2 [==============================] - 3s 421ms/step - loss: -0.6167 - MSE: 0.1232 - cosine_similarity: 0.7399 - r_square: -4.2650 - val_loss: -0.6538 - val_MSE: 0.1108 - val_cosine_similarity: 0.7646 - val_r_square: -3.3311
# 2/2 [==============================] - 0s 120ms/step - loss: -0.6647 - MSE: 0.1079 - cosine_similarity: 0.7725 - r_square: -3.7034 - val_loss: -0.6581 - val_MSE: 0.1088 - val_cosine_similarity: 0.7669 - val_r_square: -3.1327
# 2/2 [==============================] - 0s 101ms/step - loss: -0.6892 - MSE: 0.0989 - cosine_similarity: 0.7881 - r_square: -3.9905 - val_loss: -0.6613 - val_MSE: 0.1071 - val_cosine_similarity: 0.7684 - val_r_square: -3.0100
# 2/2 [==============================] - 0s 117ms/step - loss: -0.6634 - MSE: 0.1025 - cosine_similarity: 0.7659 - r_square: -2.7993 - val_loss: -0.6668 - val_MSE: 0.1035 - val_cosine_similarity: 0.7703 - val_r_square: -2.8362
# 2/2 [==============================] - 0s 102ms/step - loss: -0.6608 - MSE: 0.1026 - cosine_similarity: 0.7634 - r_square: -3.2970 - val_loss: -0.6726 - val_MSE: 0.0996 - val_cosine_similarity: 0.7722 - val_r_square: -2.6496
# 2/2 [==============================] - 0s 101ms/step - loss: -0.6963 - MSE: 0.0859 - cosine_similarity: 0.7822 - r_square: -2.0864 - val_loss: -0.6788 - val_MSE: 0.0949 - val_cosine_similarity: 0.7737 - val_r_square: -2.4388
# Epoch 1
# 2/2 [==============================] - 0s 127ms/step - loss: -0.6738 - MSE: 0.0899 - cosine_similarity: 0.7637 - r_square: -2.3132 - val_loss: -0.6817 - val_MSE: 0.0924 - val_cosine_similarity: 0.7741 - val_r_square: -2.3374
# 2/2 [==============================] - 0s 117ms/step - loss: -0.6935 - MSE: 0.0847 - cosine_similarity: 0.7782 - r_square: -2.4033 - val_loss: -0.6853 - val_MSE: 0.0893 - val_cosine_similarity: 0.7747 - val_r_square: -2.2108
# 2/2 [==============================] - 0s 102ms/step - loss: -0.6981 - MSE: 0.0813 - cosine_similarity: 0.7794 - r_square: -2.0509 - val_loss: -0.6865 - val_MSE: 0.0879 - val_cosine_similarity: 0.7744 - val_r_square: -2.1769
# 2/2 [==============================] - 0s 115ms/step - loss: -0.6945 - MSE: 0.0761 - cosine_similarity: 0.7706 - r_square: -1.6039 - val_loss: -0.6858 - val_MSE: 0.0876 - val_cosine_similarity: 0.7734 - val_r_square: -2.1947
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7050 - MSE: 0.0768 - cosine_similarity: 0.7818 - r_square: -2.0448 - val_loss: -0.6872 - val_MSE: 0.0859 - val_cosine_similarity: 0.7731 - val_r_square: -2.1429
# 2/2 [==============================] - 0s 118ms/step - loss: -0.7046 - MSE: 0.0721 - cosine_similarity: 0.7767 - r_square: -1.9418 - val_loss: -0.6897 - val_MSE: 0.0835 - val_cosine_similarity: 0.7732 - val_r_square: -2.0592
# Epoch 2
# 2/2 [==============================] - 0s 111ms/step - loss: -0.7163 - MSE: 0.0714 - cosine_similarity: 0.7877 - r_square: -2.5431 - val_loss: -0.6967 - val_MSE: 0.0780 - val_cosine_similarity: 0.7746 - val_r_square: -1.8311
# 2/2 [==============================] - 0s 102ms/step - loss: -0.6914 - MSE: 0.0700 - cosine_similarity: 0.7614 - r_square: -1.3623 - val_loss: -0.6993 - val_MSE: 0.0757 - val_cosine_similarity: 0.7750 - val_r_square: -1.7422
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7108 - MSE: 0.0625 - cosine_similarity: 0.7733 - r_square: -1.2483 - val_loss: -0.7007 - val_MSE: 0.0744 - val_cosine_similarity: 0.7751 - val_r_square: -1.6951
# 2/2 [==============================] - 0s 117ms/step - loss: -0.7106 - MSE: 0.0657 - cosine_similarity: 0.7764 - r_square: -1.3704 - val_loss: -0.7022 - val_MSE: 0.0732 - val_cosine_similarity: 0.7754 - val_r_square: -1.6351
# 2/2 [==============================] - 0s 101ms/step - loss: -0.6929 - MSE: 0.0708 - cosine_similarity: 0.7636 - r_square: -1.8963 - val_loss: -0.7030 - val_MSE: 0.0726 - val_cosine_similarity: 0.7756 - val_r_square: -1.6058
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7016 - MSE: 0.0643 - cosine_similarity: 0.7658 - r_square: -1.3702 - val_loss: -0.7013 - val_MSE: 0.0737 - val_cosine_similarity: 0.7751 - val_r_square: -1.6603
# Epoch 3
# 2/2 [==============================] - 0s 112ms/step - loss: -0.6958 - MSE: 0.0692 - cosine_similarity: 0.7650 - r_square: -1.5742 - val_loss: -0.6993 - val_MSE: 0.0754 - val_cosine_similarity: 0.7746 - val_r_square: -1.7343
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7217 - MSE: 0.0627 - cosine_similarity: 0.7844 - r_square: -1.5234 - val_loss: -0.6979 - val_MSE: 0.0763 - val_cosine_similarity: 0.7742 - val_r_square: -1.7724
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7031 - MSE: 0.0695 - cosine_similarity: 0.7726 - r_square: -1.5893 - val_loss: -0.6983 - val_MSE: 0.0759 - val_cosine_similarity: 0.7742 - val_r_square: -1.7518
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7159 - MSE: 0.0684 - cosine_similarity: 0.7843 - r_square: -1.5635 - val_loss: -0.6990 - val_MSE: 0.0753 - val_cosine_similarity: 0.7743 - val_r_square: -1.7174
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7285 - MSE: 0.0595 - cosine_similarity: 0.7881 - r_square: -1.2225 - val_loss: -0.7008 - val_MSE: 0.0739 - val_cosine_similarity: 0.7747 - val_r_square: -1.6505
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7044 - MSE: 0.0641 - cosine_similarity: 0.7685 - r_square: -1.2472 - val_loss: -0.7033 - val_MSE: 0.0719 - val_cosine_similarity: 0.7752 - val_r_square: -1.5609
# Epoch 4
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7087 - MSE: 0.0681 - cosine_similarity: 0.7768 - r_square: -1.7083 - val_loss: -0.7052 - val_MSE: 0.0705 - val_cosine_similarity: 0.7757 - val_r_square: -1.4930
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7269 - MSE: 0.0566 - cosine_similarity: 0.7835 - r_square: -1.0303 - val_loss: -0.7070 - val_MSE: 0.0691 - val_cosine_similarity: 0.7761 - val_r_square: -1.4384
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7049 - MSE: 0.0604 - cosine_similarity: 0.7653 - r_square: -0.7573 - val_loss: -0.7093 - val_MSE: 0.0673 - val_cosine_similarity: 0.7766 - val_r_square: -1.3653
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7274 - MSE: 0.0580 - cosine_similarity: 0.7854 - r_square: -1.2365 - val_loss: -0.7106 - val_MSE: 0.0660 - val_cosine_similarity: 0.7766 - val_r_square: -1.3262
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7241 - MSE: 0.0529 - cosine_similarity: 0.7770 - r_square: -0.9524 - val_loss: -0.7100 - val_MSE: 0.0663 - val_cosine_similarity: 0.7763 - val_r_square: -1.3494
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7219 - MSE: 0.0558 - cosine_similarity: 0.7777 - r_square: -1.1611 - val_loss: -0.7077 - val_MSE: 0.0680 - val_cosine_similarity: 0.7757 - val_r_square: -1.4308
# Epoch 5
# 2/2 [==============================] - 0s 112ms/step - loss: -0.7420 - MSE: 0.0520 - cosine_similarity: 0.7941 - r_square: -1.0879 - val_loss: -0.7053 - val_MSE: 0.0698 - val_cosine_similarity: 0.7752 - val_r_square: -1.5057
# 2/2 [==============================] - 0s 118ms/step - loss: -0.6880 - MSE: 0.0666 - cosine_similarity: 0.7546 - r_square: -1.4441 - val_loss: -0.7047 - val_MSE: 0.0706 - val_cosine_similarity: 0.7753 - val_r_square: -1.5263
# 2/2 [==============================] - 0s 117ms/step - loss: -0.7223 - MSE: 0.0624 - cosine_similarity: 0.7847 - r_square: -1.2272 - val_loss: -0.7044 - val_MSE: 0.0709 - val_cosine_similarity: 0.7753 - val_r_square: -1.5306
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7077 - MSE: 0.0636 - cosine_similarity: 0.7714 - r_square: -1.5309 - val_loss: -0.7045 - val_MSE: 0.0710 - val_cosine_similarity: 0.7754 - val_r_square: -1.5255
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7151 - MSE: 0.0611 - cosine_similarity: 0.7762 - r_square: -1.0746 - val_loss: -0.7048 - val_MSE: 0.0708 - val_cosine_similarity: 0.7756 - val_r_square: -1.5073
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7248 - MSE: 0.0580 - cosine_similarity: 0.7827 - r_square: -1.2241 - val_loss: -0.7051 - val_MSE: 0.0704 - val_cosine_similarity: 0.7755 - val_r_square: -1.4839
# Epoch 6
# 2/2 [==============================] - 0s 114ms/step - loss: -0.7252 - MSE: 0.0582 - cosine_similarity: 0.7834 - r_square: -1.1310 - val_loss: -0.7033 - val_MSE: 0.0717 - val_cosine_similarity: 0.7750 - val_r_square: -1.5320
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7346 - MSE: 0.0573 - cosine_similarity: 0.7919 - r_square: -1.2140 - val_loss: -0.7050 - val_MSE: 0.0702 - val_cosine_similarity: 0.7752 - val_r_square: -1.4579
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7043 - MSE: 0.0617 - cosine_similarity: 0.7660 - r_square: -1.1299 - val_loss: -0.7072 - val_MSE: 0.0682 - val_cosine_similarity: 0.7755 - val_r_square: -1.3715
# 2/2 [==============================] - 0s 133ms/step - loss: -0.7146 - MSE: 0.0604 - cosine_similarity: 0.7750 - r_square: -0.9982 - val_loss: -0.7087 - val_MSE: 0.0669 - val_cosine_similarity: 0.7756 - val_r_square: -1.3194
# 2/2 [==============================] - 0s 118ms/step - loss: -0.7275 - MSE: 0.0540 - cosine_similarity: 0.7815 - r_square: -0.9992 - val_loss: -0.7080 - val_MSE: 0.0674 - val_cosine_similarity: 0.7755 - val_r_square: -1.3572
# 2/2 [==============================] - 0s 131ms/step - loss: -0.6986 - MSE: 0.0567 - cosine_similarity: 0.7553 - r_square: -1.0008 - val_loss: -0.7051 - val_MSE: 0.0697 - val_cosine_similarity: 0.7748 - val_r_square: -1.4748
# Epoch 7
# 2/2 [==============================] - 0s 116ms/step - loss: -0.7463 - MSE: 0.0522 - cosine_similarity: 0.7985 - r_square: -1.1386 - val_loss: -0.7047 - val_MSE: 0.0699 - val_cosine_similarity: 0.7746 - val_r_square: -1.5003
# 2/2 [==============================] - 0s 120ms/step - loss: -0.7060 - MSE: 0.0604 - cosine_similarity: 0.7664 - r_square: -1.0386 - val_loss: -0.7032 - val_MSE: 0.0710 - val_cosine_similarity: 0.7742 - val_r_square: -1.5602
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7161 - MSE: 0.0624 - cosine_similarity: 0.7785 - r_square: -1.3339 - val_loss: -0.7024 - val_MSE: 0.0715 - val_cosine_similarity: 0.7739 - val_r_square: -1.5933
# 2/2 [==============================] - 0s 102ms/step - loss: -0.6976 - MSE: 0.0632 - cosine_similarity: 0.7608 - r_square: -1.1232 - val_loss: -0.7026 - val_MSE: 0.0714 - val_cosine_similarity: 0.7740 - val_r_square: -1.5869
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7350 - MSE: 0.0524 - cosine_similarity: 0.7874 - r_square: -1.3798 - val_loss: -0.7043 - val_MSE: 0.0700 - val_cosine_similarity: 0.7743 - val_r_square: -1.5251
# 2/2 [==============================] - 0s 118ms/step - loss: -0.7192 - MSE: 0.0557 - cosine_similarity: 0.7749 - r_square: -1.2720 - val_loss: -0.7072 - val_MSE: 0.0677 - val_cosine_similarity: 0.7749 - val_r_square: -1.4247
# Epoch 8
# 2/2 [==============================] - 0s 109ms/step - loss: -0.7278 - MSE: 0.0583 - cosine_similarity: 0.7861 - r_square: -1.1583 - val_loss: -0.7104 - val_MSE: 0.0654 - val_cosine_similarity: 0.7758 - val_r_square: -1.3199
# 2/2 [==============================] - 0s 102ms/step - loss: -0.6979 - MSE: 0.0623 - cosine_similarity: 0.7603 - r_square: -1.4307 - val_loss: -0.7133 - val_MSE: 0.0633 - val_cosine_similarity: 0.7766 - val_r_square: -1.2214
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7274 - MSE: 0.0534 - cosine_similarity: 0.7808 - r_square: -0.7119 - val_loss: -0.7154 - val_MSE: 0.0617 - val_cosine_similarity: 0.7771 - val_r_square: -1.1486
# 2/2 [==============================] - 0s 119ms/step - loss: -0.7617 - MSE: 0.0486 - cosine_similarity: 0.8103 - r_square: -0.8980 - val_loss: -0.7171 - val_MSE: 0.0604 - val_cosine_similarity: 0.7776 - val_r_square: -1.0845
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7293 - MSE: 0.0491 - cosine_similarity: 0.7784 - r_square: -0.8053 - val_loss: -0.7173 - val_MSE: 0.0605 - val_cosine_similarity: 0.7778 - val_r_square: -1.0734
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7005 - MSE: 0.0563 - cosine_similarity: 0.7567 - r_square: -0.9655 - val_loss: -0.7164 - val_MSE: 0.0612 - val_cosine_similarity: 0.7776 - val_r_square: -1.0995
# Epoch 9
# 2/2 [==============================] - 0s 110ms/step - loss: -0.7271 - MSE: 0.0502 - cosine_similarity: 0.7773 - r_square: -0.9020 - val_loss: -0.7140 - val_MSE: 0.0627 - val_cosine_similarity: 0.7767 - val_r_square: -1.1671
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7120 - MSE: 0.0598 - cosine_similarity: 0.7718 - r_square: -1.0181 - val_loss: -0.7126 - val_MSE: 0.0638 - val_cosine_similarity: 0.7764 - val_r_square: -1.2163
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7520 - MSE: 0.0510 - cosine_similarity: 0.8030 - r_square: -0.9528 - val_loss: -0.7122 - val_MSE: 0.0642 - val_cosine_similarity: 0.7764 - val_r_square: -1.2327
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7261 - MSE: 0.0551 - cosine_similarity: 0.7812 - r_square: -0.9013 - val_loss: -0.7112 - val_MSE: 0.0652 - val_cosine_similarity: 0.7764 - val_r_square: -1.2756
# 2/2 [==============================] - 0s 118ms/step - loss: -0.7056 - MSE: 0.0612 - cosine_similarity: 0.7668 - r_square: -1.1824 - val_loss: -0.7110 - val_MSE: 0.0655 - val_cosine_similarity: 0.7765 - val_r_square: -1.2844
# 2/2 [==============================] - 0s 119ms/step - loss: -0.7280 - MSE: 0.0511 - cosine_similarity: 0.7792 - r_square: -0.9811 - val_loss: -0.7109 - val_MSE: 0.0656 - val_cosine_similarity: 0.7765 - val_r_square: -1.2902

# %%
# %matplotlib inline

metric = "cosine similarity" #Choose between 'loss', 'MSE', 'cosine similarity', 'r2'

import matplotlib.pyplot as plt
try: history_df = history_df.reset_index()
except: pass

metrics_dict = {"loss": ["loss", "val_loss"], "MSE": ["MSE", "val_MSE"], 
                "cosine similarity": ["cosine_similarity", "val_cosine_similarity"],
               "r2" : ["r_square", "val_r_square"]}

fig, ax = plt.subplots(figsize=(15,4),nrows=1, ncols=1)
ax.set_ylabel(f"{metric}")
ax.set_xlabel("Training time")
fig.suptitle(f"History of {metric} in training time")

train_plot = history_df.plot(y=metrics_dict[metric][0], use_index=True, ax=ax, label="Training")
val_plot = history_df.plot(y=metrics_dict[metric][1], use_index=True, ax=ax, label="Validation")

plt.show()

# %% [markdown]
# ## Evaluation of the results

# %%
val_ds = validation_dataset.shuffle(n_test).batch(n_test)
x_val, y_val, length_val = next(iter(val_ds))
x_val, y_val = slice_accordingly(x_val, y_val)
    

y_pred = model.predict(x_val)
y_true = y_val

# %%
def plot_epsilon_error(y_true, y_pred):
    
    N = len(y_true)
    
    cdf_abs_error = {}
    abs_error = np.abs(y_true - y_pred)
    
    fig, ax = plt.subplots(figsize=(12,6),nrows=1, ncols=2)
    ax[0].set_ylabel("Fraction of samples")
    ax[0].set_xlabel("Allowed absolute error")
    ax[0].set_title(f"CDF of the absolute error for different emotions")
    
    for i, emotion in enumerate(emotions):
        abs_error_emotion = np.sort(abs_error[:,i])
        X2 = np.sort(abs_error_emotion)
        F2 = np.array(range(N))/(float(N))
        
        cdf_abs_error[emotion] = [X2, F2]
        
        ax[0].plot(X2, F2, label=emotion)
        
    ax[0].legend()
    ax[0].grid()
    
    cdf_cosine_sim = {}
    cos_sim = np.array([np.dot(y_true[i], y_pred[i])/(np.linalg.norm(y_true[i])*np.linalg.norm(y_pred[i])) for i in range(N)])
    cos_error = 1-cos_sim
    
    X2 = np.sort(cos_error)
    F2 = np.array(range(N))/(float(N))

    ax[1].set_ylabel(f"Fraction of samples", rotation=-90, labelpad=15)
    ax[1].yaxis.set_label_position("right")
    ax[1].yaxis.tick_right()
    ax[1].set_xlabel("Allowed cosine error")
    ax[1].set_title(f"CDF of the cosine error")
    
    ax[1].plot(X2, F2)
    ax[1].grid()
    return cdf_abs_error

# %%
epsilon_error = plot_epsilon_error(y_true, y_pred)

x = epsilon_error["amazement"]
plt.show()

# %% [markdown]
# ## "Cross-validation"

# %%
def custom_loss(y_true, y_pred):
    cos_sim = tf.keras.losses.CosineSimilarity() 
    MSE = tf.keras.losses.MeanSquaredError()
        
    return cos_sim(y_true, y_pred) + MSE(y_true, y_pred)

# %%
from sklearn.model_selection import KFold


n_splits = 5
kf = KFold(n_splits=n_splits)

predictions_and_labels = {}


count = 0
for train_index, test_index in kf.split(MFCCs_raw):
    
    print(f"Training K-fold {1+count} of {n_splits}")

    train_features, train_labels = MFCCs_raw[train_index], labels_raw[train_index]
    validation_features, validation_labels = MFCCs_raw[test_index], labels_raw[test_index]

    train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels))
    validation_dataset = tf.data.Dataset.from_tensor_slices((validation_features, validation_labels))
    
    sample_size = (20, 50, 1)
    drop_out_rate = 0.4

    input_tensor = Input(sample_size)
    x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(input_tensor)
    x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(x)
    x = layers.Dropout(drop_out_rate)(x)
    x = layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)
    x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(x)
    x = layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)
    x = layers.Flatten()(x)
    x = layers.Dense(20, activation="relu")(x)
    x = layers.Flatten()(x)
    x = layers.Dropout(drop_out_rate)(x)
    output_tensor = layers.Dense(9, activation="sigmoid")(x)

    model = tf.keras.Model(input_tensor, output_tensor)
        
    model.compile(optimizer="adam",
                  loss= custom_loss,
                  metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
    n_epochs = 100
    batch_size = 50
    
    for epoch in range(n_epochs):
        train_ds = train_dataset.shuffle(n_train).batch(batch_size)
        for features, labels in train_ds:
            features, labels = slice_accordingly(features, labels)
            model.fit(features, labels, verbose=0)
            
    val_ds = validation_dataset.shuffle(n_test).batch(n_test)
    x_val, y_val = next(iter(val_ds))
    x_val, y_val = slice_accordingly(x_val, y_val)

            
    predictions_and_labels[count] = [model.predict(x_val), y_val]
    count = count+1
# Out:
# Training K-fold 1 of 5
# Training K-fold 2 of 5
# Training K-fold 3 of 5
# Training K-fold 4 of 5
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002BC1568FA60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Training K-fold 5 of 5
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002BC131A1598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
predictions = []
labels = []

for i in range(max(predictions_and_labels.keys())+1):
    predictions.append(predictions_and_labels[i][0])
    labels.append(predictions_and_labels[i][1])

predictions = np.concatenate(predictions)
labels = np.concatenate(labels)
epsilon_error = plot_epsilon_error(labels, predictions)

plt.show()

# %%
cos_sim = []
r2 = []
MSE = []

cos_sim_function = tf.keras.metrics.CosineSimilarity() 
MSE_function = tf.keras.metrics.MeanSquaredError()
r2_function = tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))

for i in range(max(predictions_and_labels.keys())+1):
    y_pred = predictions_and_labels[i][0]
    y_true = predictions_and_labels[i][1]
    
    cos_sim.append(cos_sim_function(y_true, y_pred).numpy())
    r2.append(r2_function(y_true, y_pred).numpy())
    MSE.append(MSE_function(y_true, y_pred).numpy())
    
print(f"The cosine similarity is approximately {100*np.mean(cos_sim):.2f}±{100*np.std(cos_sim):.2f}%")
print(f"The MSE is approximately {100*np.mean(MSE):.2f}±{100*np.std(MSE):.2f}%")
print(f"The R2 score is approximately {100*np.mean(r2):.2f}±{100*np.std(r2):.2f}%")
# Out:
# The cosine similarity is approximately 78.41±0.68%
# The MSE is approximately 3.85±0.10%
# The R2 score is approximately -22.17±2.40%
