# %%
import numpy as np
import pandas as pd
import os

import tensorflow as tf
import tensorflow_addons as tfa

# %%
MFCCs = np.load("../preprocessing/MFCCs/MFCC.npy")
MFCCs = (MFCCs - np.nanmean(MFCCs))/np.nanstd(MFCCs)

# %%
info_songs = pd.read_csv("../Info/info.csv")
label_songs = pd.read_csv("../preprocessing/labels.csv")

# %%
# Retrieve emotions from the labels.csv file

emotions = ["amazement", "solemnity", "tenderness", "nostalgia", "calmness", 
            "power", "joyful_activation", "tension", "sadness"]

labels = label_songs[emotions]
labels = labels.to_numpy()

length_songs = pd.DataFrame(info_songs["Track ID"])
length_songs["Song length"] = info_songs["Duration"]*10
length_songs["Song length"] = length_songs["Song length"].astype(int)

# %%
n_data = len(length_songs)
idx = np.random.permutation(n_data)
length_songs = length_songs.reindex(idx)["Song length"].to_numpy()
MFCCs_raw = MFCCs[idx, :, :]
labels_raw = labels[idx]

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras import Input, layers
from tensorflow.keras import backend as K

sample_size = (20, 50, 1)

drop_out_rate = 0.4

# very simple keras Sequential model
input_tensor = Input(sample_size)
x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(input_tensor)
x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(x)
x = layers.Dropout(drop_out_rate)(x)
x = layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)
x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(x)
x = layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)
x = layers.Flatten()(x)
x = layers.Dense(20, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(drop_out_rate)(x)
output_tensor = layers.Dense(9, activation="sigmoid")(x)

model_1 = tf.keras.Model(input_tensor, output_tensor)
model_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 20, 50, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 18, 48, 16)        160
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 46, 16)        2320
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 46, 16)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 7, 22, 16)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 20, 16)         2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 9, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 288)               0
# _________________________________________________________________
# dense (Dense)                (None, 20)                5780
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 20)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 189
# =================================================================
# Total params: 10,769
# Trainable params: 10,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = model_1

loss = "MSE"
#loss = "CosineSimilarity"
loss = "both"
loss = "KLDivergence"
loss = "RSquare"
loss = "LogCosh"

if loss == "MSE":
    model.compile(optimizer="adam",
                  loss=tf.keras.losses.MeanSquaredError(),
                  metrics=["cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "CosineSimilarity":
    model.compile(optimizer="adam",
                  loss= tf.keras.losses.CosineSimilarity(),
                  metrics=["MSE", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "both":
    def custom_loss(y_true, y_pred):
        cos_sim = tf.keras.losses.CosineSimilarity() 
        MSE = tf.keras.losses.MeanSquaredError()
        return cos_sim(y_true, y_pred) + MSE(y_true, y_pred)
    
    model.compile(optimizer="adam",
                loss= custom_loss,
                metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])

elif loss == "KLDivergence":
    model.compile(optimizer="adam",
                loss = tf.keras.losses.KLDivergence(),
                metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "RSquare":
    def rsquare_loss(y_true, y_pred):
        metric = tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))
        return -metric(y_true, y_pred)
    
    model.compile(optimizer="adam",
                loss = tf.keras.losses.KLDivergence(),
                metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "LogCosh":
    model.compile(optimizer="adam",
                loss =  tf.keras.losses.LogCosh(),
                metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])

# %%
def slice_accordingly(input_tensor, labels, size=sample_size):

    input_shape = (tf.shape(input_tensor).numpy())
    
    input_shape[1], input_shape[2] = size[0], size[1]
    size = input_shape
    
    sliced_tensor = tf.image.random_crop(input_tensor, size)
    
    nan_values, idx = tf.unique(tf.gather(tf.where(tf.math.is_nan(sliced_tensor)), 0, axis=1))
    nan_values = nan_values.numpy()
  
    msk = np.zeros((input_shape[0]), dtype=np.bool)
    msk[nan_values] = True
    msk = ~msk

    sliced_tensor = tf.boolean_mask(sliced_tensor, msk , axis=0)
    labels = tf.boolean_mask(labels , msk, axis=0)
    
    return sliced_tensor, labels

# %%
fraction_validation = 0.25
n_test = int(fraction_validation*len(labels))
n_train = len(labels) - n_test

train_features, train_labels, train_length = MFCCs_raw[:n_train], labels_raw[:n_train], length_songs[:n_train]
validation_features, validation_labels, validation_length = MFCCs_raw[n_train:], labels_raw[n_train:], length_songs[n_train:]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels, train_length))
validation_dataset = tf.data.Dataset.from_tensor_slices((validation_features, validation_labels, validation_length))

# %%
n_epochs = 100
batch_size = 50

history_df = pd.DataFrame()

for epoch in range(n_epochs):
    print("Epoch", epoch)
    train_ds = train_dataset.shuffle(n_train).batch(batch_size)
    val_ds = validation_dataset.shuffle(n_test).batch(n_test)
    
    x_val, y_val, length_val = next(iter(val_ds))
    x_val, y_val = slice_accordingly(x_val, y_val)
    
    for features, labels, lengths in train_ds:
        features, labels = slice_accordingly(features, labels)
        
        history = model.fit(features, labels,
                           validation_data=(x_val, y_val),verbose=1)
        history = pd.DataFrame(history.history)
        history_df = history_df.append(history)
# Out:
# Epoch 0
# 2/2 [==============================] - 3s 744ms/step - loss: 0.0506 - MSE: 0.1041 - cosine_similarity: 0.7890 - r_square: -4.0431 - val_loss: 0.0514 - val_MSE: 0.1056 - val_cosine_similarity: 0.7652 - val_r_square: -2.9463
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0460 - MSE: 0.0944 - cosine_similarity: 0.7876 - r_square: -2.7873 - val_loss: 0.0479 - val_MSE: 0.0984 - val_cosine_similarity: 0.7648 - val_r_square: -2.5910
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0241 - MSE: 0.0493 - cosine_similarity: 0.7363 - r_square: -0.7011 - val_loss: 0.0234 - val_MSE: 0.0475 - val_cosine_similarity: 0.7689 - val_r_square: -0.5106
# Epoch 9
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0276 - MSE: 0.0567 - cosine_similarity: 0.7189 - r_square: -0.8323 - val_loss: 0.0233 - val_MSE: 0.0474 - val_cosine_similarity: 0.7695 - val_r_square: -0.5056
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0220 - MSE: 0.0450 - cosine_similarity: 0.7356 - r_square: -0.3964 - val_loss: 0.0232 - val_MSE: 0.0471 - val_cosine_similarity: 0.7698 - val_r_square: -0.4925
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0243 - MSE: 0.0497 - cosine_similarity: 0.7235 - r_square: -0.7305 - val_loss: 0.0231 - val_MSE: 0.0470 - val_cosine_similarity: 0.7700 - val_r_square: -0.4885
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0229 - MSE: 0.0469 - cosine_similarity: 0.7264 - r_square: -0.8167 - val_loss: 0.0232 - val_MSE: 0.0471 - val_cosine_similarity: 0.7701 - val_r_square: -0.4992
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0249 - MSE: 0.0510 - cosine_similarity: 0.7337 - r_square: -0.4815 - val_loss: 0.0235 - val_MSE: 0.0478 - val_cosine_similarity: 0.7701 - val_r_square: -0.5363
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0243 - MSE: 0.0497 - cosine_similarity: 0.7362 - r_square: -0.8549 - val_loss: 0.0235 - val_MSE: 0.0477 - val_cosine_similarity: 0.7699 - val_r_square: -0.5408
# Epoch 10
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0234 - MSE: 0.0477 - cosine_similarity: 0.7597 - r_square: -0.5190 - val_loss: 0.0234 - val_MSE: 0.0474 - val_cosine_similarity: 0.7694 - val_r_square: -0.5318
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0243 - MSE: 0.0496 - cosine_similarity: 0.7375 - r_square: -0.7102 - val_loss: 0.0229 - val_MSE: 0.0464 - val_cosine_similarity: 0.7692 - val_r_square: -0.4938
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0236 - MSE: 0.0483 - cosine_similarity: 0.7342 - r_square: -0.8952 - val_loss: 0.0225 - val_MSE: 0.0456 - val_cosine_similarity: 0.7692 - val_r_square: -0.4602
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0268 - MSE: 0.0549 - cosine_similarity: 0.7205 - r_square: -0.6525 - val_loss: 0.0222 - val_MSE: 0.0450 - val_cosine_similarity: 0.7696 - val_r_square: -0.4322
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0242 - MSE: 0.0495 - cosine_similarity: 0.7345 - r_square: -0.5608 - val_loss: 0.0218 - val_MSE: 0.0443 - val_cosine_similarity: 0.7700 - val_r_square: -0.4053
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0203 - MSE: 0.0413 - cosine_similarity: 0.7528 - r_square: -0.7043 - val_loss: 0.0219 - val_MSE: 0.0445 - val_cosine_similarity: 0.7704 - val_r_square: -0.4144
# Epoch 11
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0227 - MSE: 0.0463 - cosine_similarity: 0.7406 - r_square: -0.6190 - val_loss: 0.0220 - val_MSE: 0.0446 - val_cosine_similarity: 0.7716 - val_r_square: -0.4188
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0214 - MSE: 0.0437 - cosine_similarity: 0.7390 - r_square: -0.5308 - val_loss: 0.0224 - val_MSE: 0.0455 - val_cosine_similarity: 0.7719 - val_r_square: -0.4547
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0240 - MSE: 0.0491 - cosine_similarity: 0.7415 - r_square: -0.6446 - val_loss: 0.0229 - val_MSE: 0.0464 - val_cosine_similarity: 0.7722 - val_r_square: -0.4946
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0205 - MSE: 0.0418 - cosine_similarity: 0.7606 - r_square: -0.7027 - val_loss: 0.0232 - val_MSE: 0.0471 - val_cosine_similarity: 0.7724 - val_r_square: -0.5264
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0270 - MSE: 0.0553 - cosine_similarity: 0.7257 - r_square: -0.5811 - val_loss: 0.0230 - val_MSE: 0.0467 - val_cosine_similarity: 0.7726 - val_r_square: -0.5088
# 2/2 [==============================] - 0s 90ms/step - loss: 0.0221 - MSE: 0.0453 - cosine_similarity: 0.7508 - r_square: -0.4116 - val_loss: 0.0228 - val_MSE: 0.0463 - val_cosine_similarity: 0.7729 - val_r_square: -0.4906
# Epoch 12
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0208 - MSE: 0.0426 - cosine_similarity: 0.7594 - r_square: -0.5660 - val_loss: 0.0229 - val_MSE: 0.0465 - val_cosine_similarity: 0.7724 - val_r_square: -0.5009
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0238 - MSE: 0.0485 - cosine_similarity: 0.7468 - r_square: -0.3576 - val_loss: 0.0229 - val_MSE: 0.0464 - val_cosine_similarity: 0.7724 - val_r_square: -0.5006
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0216 - MSE: 0.0441 - cosine_similarity: 0.7622 - r_square: -0.5740 - val_loss: 0.0226 - val_MSE: 0.0458 - val_cosine_similarity: 0.7725 - val_r_square: -0.4747
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0230 - MSE: 0.0472 - cosine_similarity: 0.7425 - r_square: -0.5781 - val_loss: 0.0221 - val_MSE: 0.0448 - val_cosine_similarity: 0.7727 - val_r_square: -0.4336
# 2/2 [==============================] - 0s 133ms/step - loss: 0.0207 - MSE: 0.0423 - cosine_similarity: 0.7456 - r_square: -0.5180 - val_loss: 0.0217 - val_MSE: 0.0441 - val_cosine_similarity: 0.7729 - val_r_square: -0.4024
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0223 - MSE: 0.0456 - cosine_similarity: 0.7476 - r_square: -0.5810 - val_loss: 0.0216 - val_MSE: 0.0438 - val_cosine_similarity: 0.7732 - val_r_square: -0.3895
# Epoch 13
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0233 - MSE: 0.0478 - cosine_similarity: 0.7337 - r_square: -0.3431 - val_loss: 0.0216 - val_MSE: 0.0438 - val_cosine_similarity: 0.7736 - val_r_square: -0.3903
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0210 - MSE: 0.0429 - cosine_similarity: 0.7513 - r_square: -0.3428 - val_loss: 0.0221 - val_MSE: 0.0447 - val_cosine_similarity: 0.7735 - val_r_square: -0.4309
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0205 - MSE: 0.0418 - cosine_similarity: 0.7677 - r_square: -0.5024 - val_loss: 0.0222 - val_MSE: 0.0451 - val_cosine_similarity: 0.7735 - val_r_square: -0.4482
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0204 - MSE: 0.0416 - cosine_similarity: 0.7569 - r_square: -0.6409 - val_loss: 0.0220 - val_MSE: 0.0446 - val_cosine_similarity: 0.7736 - val_r_square: -0.4298
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0208 - MSE: 0.0425 - cosine_similarity: 0.7589 - r_square: -0.5916 - val_loss: 0.0217 - val_MSE: 0.0440 - val_cosine_similarity: 0.7737 - val_r_square: -0.4061
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0217 - MSE: 0.0443 - cosine_similarity: 0.7341 - r_square: -0.4079 - val_loss: 0.0214 - val_MSE: 0.0435 - val_cosine_similarity: 0.7738 - val_r_square: -0.3820
# Epoch 14
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0253 - MSE: 0.0519 - cosine_similarity: 0.7110 - r_square: -0.4583 - val_loss: 0.0213 - val_MSE: 0.0432 - val_cosine_similarity: 0.7738 - val_r_square: -0.3670
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0212 - MSE: 0.0434 - cosine_similarity: 0.7446 - r_square: -0.5391 - val_loss: 0.0211 - val_MSE: 0.0428 - val_cosine_similarity: 0.7738 - val_r_square: -0.3521
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0220 - MSE: 0.0450 - cosine_similarity: 0.7399 - r_square: -0.5365 - val_loss: 0.0213 - val_MSE: 0.0431 - val_cosine_similarity: 0.7739 - val_r_square: -0.3637
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0202 - MSE: 0.0415 - cosine_similarity: 0.7615 - r_square: -0.3194 - val_loss: 0.0216 - val_MSE: 0.0437 - val_cosine_similarity: 0.7739 - val_r_square: -0.3904
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0203 - MSE: 0.0414 - cosine_similarity: 0.7635 - r_square: -0.4618 - val_loss: 0.0222 - val_MSE: 0.0451 - val_cosine_similarity: 0.7737 - val_r_square: -0.4497
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0208 - MSE: 0.0424 - cosine_similarity: 0.7692 - r_square: -0.5084 - val_loss: 0.0226 - val_MSE: 0.0458 - val_cosine_similarity: 0.7737 - val_r_square: -0.4807
# Epoch 15
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0188 - MSE: 0.0384 - cosine_similarity: 0.7814 - r_square: -0.4572 - val_loss: 0.0222 - val_MSE: 0.0451 - val_cosine_similarity: 0.7742 - val_r_square: -0.4512
# 2/2 [==============================] - 0s 101ms/step - loss: 0.
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0186 - MSE: 0.0380 - cosine_similarity: 0.7633 - r_square: -0.3047 - val_loss: 0.0198 - val_MSE: 0.0400 - val_cosine_similarity: 0.7770 - val_r_square: -0.2525
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0207 - MSE: 0.0424 - cosine_similarity: 0.7637 - r_square: -0.3359 - val_loss: 0.0196 - val_MSE: 0.0397 - val_cosine_similarity: 0.7772 - val_r_square: -0.2412
# Epoch 20
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0188 - MSE: 0.0382 - cosine_similarity: 0.7640 - r_square: -0.4430 - val_loss: 0.0197 - val_MSE: 0.0400 - val_cosine_similarity: 0.7771 - val_r_square: -0.2524
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0200 - MSE: 0.0409 - cosine_similarity: 0.7548 - r_square: -0.2187 - val_loss: 0.0202 - val_MSE: 0.0410 - val_cosine_similarity: 0.7769 - val_r_square: -0.2945
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0199 - MSE: 0.0405 - cosine_similarity: 0.7598 - r_square: -0.4026 - val_loss: 0.0205 - val_MSE: 0.0416 - val_cosine_similarity: 0.7767 - val_r_square: -0.3225
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0202 - MSE: 0.0411 - cosine_similarity: 0.7722 - r_square: -0.2832 - val_loss: 0.0209 - val_MSE: 0.0424 - val_cosine_similarity: 0.7763 - val_r_square: -0.3578
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0184 - MSE: 0.0377 - cosine_similarity: 0.7728 - r_square: -0.2052 - val_loss: 0.0210 - val_MSE: 0.0426 - val_cosine_similarity: 0.7761 - val_r_square: -0.3660
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0193 - MSE: 0.0392 - cosine_similarity: 0.7752 - r_square: -0.4794 - val_loss: 0.0207 - val_MSE: 0.0419 - val_cosine_similarity: 0.7763 - val_r_square: -0.3365
# Epoch 21
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0213 - MSE: 0.0435 - cosine_similarity: 0.7549 - r_square: -0.3487 - val_loss: 0.0201 - val_MSE: 0.0407 - val_cosine_similarity: 0.7768 - val_r_square: -0.2903
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0186 - MSE: 0.0378 - cosine_similarity: 0.7810 - r_square: -0.6014 - val_loss: 0.0199 - val_MSE: 0.0402 - val_cosine_similarity: 0.7769 - val_r_square: -0.2697
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0212 - MSE: 0.0431 - cosine_similarity: 0.7471 - r_square: -0.3610 - val_loss: 0.0203 - val_MSE: 0.0412 - val_cosine_similarity: 0.7766 - val_r_square: -0.3083
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0195 - MSE: 0.0398 - cosine_similarity: 0.7710 - r_square: -0.4745 - val_loss: 0.0208 - val_MSE: 0.0422 - val_cosine_similarity: 0.7764 - val_r_square: -0.3521
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0182 - MSE: 0.0369 - cosine_similarity: 0.7757 - r_square: -0.4191 - val_loss: 0.0207 - val_MSE: 0.0419 - val_cosine_similarity: 0.7766 - val_r_square: -0.3372
# Epoch 24
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0191 - MSE: 0.0389 - cosine_similarity: 0.7696 - r_square: -0.2838 - val_loss: 0.0202 - val_MSE: 0.0410 - val_cosine_similarity: 0.7778 - val_r_square: -0.3054
# 2/2 [==============================] - 0s 226ms/step - loss: 0.0174 - MSE: 0.0353 - cosine_similarity: 0.7770 - r_square: -0.2813 - val_loss: 0.0197 - val_MSE: 0.0399 - val_cosine_similarity: 0.7782 - val_r_square: -0.2582
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0212 - MSE: 0.0434 - cosine_similarity: 0.7489 - r_square: -0.2837 - val_loss: 0.0193 - val_MSE: 0.0391 - val_cosine_similarity: 0.7785 - val_r_square: -0.2273
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0180 - MSE: 0.0367 - cosine_similarity: 0.7800 - r_square: -0.2909 - val_loss: 0.0193 - val_MSE: 0.0392 - val_cosine_similarity: 0.7786 - val_r_square: -0.2293
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0187 - MSE: 0.0382 - cosine_similarity: 0.7634 - r_square: -0.2485 - val_loss: 0.0197 - val_MSE: 0.0399 - val_cosine_similarity: 0.7784 - val_r_square: -0.2574
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0177 - MSE: 0.0360 - cosine_similarity: 0.7639 - r_square: -0.2237 - val_loss: 0.0206 - val_MSE: 0.0417 - val_cosine_similarity: 0.7778 - val_r_square: -0.3286
# Epoch 25
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0186 - MSE: 0.0378 - cosine_similarity: 0.7766 - r_square: -0.2083 - val_loss: 0.0212 - val_MSE: 0.0429 - val_cosine_similarity: 0.7771 - val_r_square: -0.3770
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0159 - MSE: 0.0322 - cosine_similarity: 0.7930 - r_square: -0.3351 - val_loss: 0.0213 - val_MSE: 0.0432 - val_cosine_similarity: 0.7770 - val_r_square: -0.3860
# 2/2 [==============================] - 0s 91ms/step - loss: 0.0195 - MSE: 0.0396 - cosine_similarity: 0.7800 - r_square: -0.2935 - val_loss: 0.0207 - val_MSE: 0.0419 - val_cosine_similarity: 0.7774 - val_r_square: -0.3339
# 2/2 [==============================] - 0s 96ms/step - loss: 0.0193 - MSE: 0.0392 - cosine_similarity: 0.7713 - r_square: -0.3367 - val_loss: 0.0197 - val_MSE: 0.0400 - val_cosine_similarity: 0.7781 - val_r_square: -0.2521
# 2/2 [==============================] - 0s 123ms/step - loss: 0.0198 - MSE: 0.0406 - cosine_similarity: 0.7630 - r_square: -0.2791 - val_loss: 0.0190 - val_MSE: 0.0384 - val_cosine_similarity: 0.7785 - val_r_square: -0.1890
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0200 - MSE: 0.0408 - cosine_similarity: 0.7476 - r_square: -0.2926 - val_loss: 0.0187 - val_MSE: 0.0380 - val_cosine_similarity: 0.7787 - val_r_square: -0.1724
# Epoch 26
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0192 - MSE: 0.0392 - cosine_similarity: 0.7642 - r_square: -0.2549 - val_loss: 0.0193 - val_MSE: 0.0391 - val_cosine_similarity: 0.7783 - val_r_square: -0.2322
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0173 - MSE: 0.0354 - cosine_similarity: 0.7932 - r_square: -0.1944 - val_loss: 0.0196 - val_MSE: 0.0397 - val_cosine_similarity: 0.7780 - val_r_square: -0.2559
# 2/2 [==============================] - 0s 124ms/step - loss: 0.0195 - MSE: 0.0398 - cosine_similarity: 0.7601 - r_square: -0.2274 - val_loss: 0.0199 - val_MSE: 0.0404 - val_cosine_similarity: 0.7775 - val_r_square: -0.2860
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0191 - MSE: 0.0390 - cosine_similarity: 0.7680 - r_square: -0.3178 - val_loss: 0.0204 - val_MSE: 0.0413 - val_cosine_similarity: 0.7771 - val_r_square: -0.3246
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0198 - MSE: 0.0403 - cosine_similarity: 0.7633 - r_square: -0.2990 - val_loss: 0.0205 - val_MSE: 0.0415 - val_cosine_similarity: 0.7770 - val_r_square: -0.3341
# Epoch 29
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0187 - MSE: 0.0381 - cosine_similarity: 0.7783 - r_square: -0.1759 - val_loss: 0.0203 - val_MSE: 0.0412 - val_cosine_similarity: 0.7773 - val_r_square: -0.3217
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0187 - MSE: 0.0381 - cosine_similarity: 0.7776 - r_square: -0.2558 - val_loss: 0.0200 - val_MSE: 0.0405 - val_cosine_similarity: 0.7777 - val_r_square: -0.2935
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0204 - MSE: 0.0414 - cosine_similarity: 0.7540 - r_square: -0.2780 - val_loss: 0.0194 - val_MSE: 0.0393 - val_cosine_similarity: 0.7781 - val_r_square: -0.2458
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0194 - MSE: 0.0395 - cosine_similarity: 0.7752 - r_square: -0.3182 - val_loss: 0.0190 - val_MSE: 0.0384 - val_cosine_similarity: 0.7785 - val_r_square: -0.2089
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0162 - MSE: 0.0329 - cosine_similarity: 0.7857 - r_square: -0.3499 - val_loss: 0.0190 - val_MSE: 0.0386 - val_cosine_similarity: 0.7785 - val_r_square: -0.2158
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0189 - MSE: 0.0387 - cosine_similarity: 0.7696 - r_square: -0.4134 - val_loss: 0.0192 - val_MSE: 0.0389 - val_cosine_similarity: 0.7785 - val_r_square: -0.2286
# Epoch 30
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0184 - MSE: 0.0375 - cosine_similarity: 0.7735 - r_square: -0.2636 - val_loss: 0.0194 - val_MSE: 0.0393 - val_cosine_similarity: 0.7782 - val_r_square: -0.2439
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0203 - MSE: 0.0416 - cosine_similarity: 0.7733 - r_square: -0.2703 - val_loss: 0.0195 - val_MSE: 0.0395 - val_cosine_similarity: 0.7782 - val_r_square: -0.2503
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0199 - MSE: 0.0407 - cosine_similarity: 0.7661 - r_square: -0.2344 - val_loss: 0.0196 - val_MSE: 0.0398 - val_cosine_similarity: 0.7781 - val_r_square: -0.2613
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0174 - MSE: 0.0353 - cosine_similarity: 0.7767 - r_square: -0.2145 - val_loss: 0.0198 - val_MSE: 0.0401 - val_cosine_similarity: 0.7780 - val_r_square: -0.2744
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0174 - MSE: 0.0355 - cosine_similarity: 0.7849 - r_square: -0.2774 - val_loss: 0.0199 - val_MSE: 0.0402 - val_cosine_similarity: 0.7780 - val_r_square: -0.2776
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0173 - MSE: 0.0351 - cosine_similarity: 0.7790 - r_square: -0.2581 - val_loss: 0.0196 - val_MSE: 0.0396 - val_cosine_similarity: 0.7783 - val_r_square: -0.2504
# Epoch 31
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0160 - MSE: 0.0325 - cosine_similarity: 0.7982 - r_square: -0.2006 - val_loss: 0.0191 - val_MSE: 0.0387 - val_cosine_similarity: 0.7786 - val_r_square: -0.2115
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0203 - MSE: 0.0414 - cosine_similarity: 0.7612 - r_square: -0.2763 - val_loss: 0.0186 - val_MSE: 0.0378 - val_cosine_similarity: 0.7790 - val_r_square: -0.1730
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0183 - MSE: 0.0374 - cosine_similarity: 0.7621 - r_square: -0.3297 - val_loss: 0.0184 - val_MSE: 0.0373 - val_cosine_similarity: 0.7792 - val_r_square: -0.1547
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0172 - MSE: 0.0349 - cosine_similarity: 0.7917 - r_square: -0.3098 - val_loss: 0.0185 - val_MSE: 0.0375 - val_cosine_similarity: 0.7791 - val_r_square: -0.1624
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0221 - MSE: 0.0453 - cosine_similarity: 0.7434 - r_square: -0.2753 - val_loss: 0.0190 - val_MSE: 0.0384 - val_cosine_similarity: 0.7787 - val_r_square: -0.2009
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0187 - MSE: 0.0381 - cosine_similarity: 0.7640 - r_square: -0.3323 - val_loss: 0.0200 - val_MSE: 0.0405 - val_cosine_similarity: 0.7780 - val_r_square: -0.2865
# Epoch 32
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0198 - MSE: 0.0405 - cosine_similarity: 0.7576 - r_square: -0.4004 - val_loss: 0.0204 - val_MSE: 0.0413 - val_cosine_similarity: 0.7776 - val_r_square: -0.3209
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0186 - MSE: 0.0379 - cosine_similarity: 0.7725 - r_square: -0.1684 - val_loss: 0.0202 - val_MSE: 0.0410 - val_cosine_similarity: 0.7777 - val_r_square: -0.3065
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0146 - MSE: 0.0296 - cosine_similarity: 0.8038 - r_square: -0.2146 - val_loss: 0.0201 - val_MSE: 0.0406 - val_cosine_similarity: 0.7778 - val_r_square: -0.2925
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0180 - MSE: 0.0366 - cosine_similarity: 0.7845 - r_square: -0.2268 - val_loss: 0.0198 - val_MSE: 0.0401 - val_cosine_similarity: 0.7780 - val_r_square: -0.2702
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0194 - MSE: 0.0396 - cosine_similarity: 0.7675 - r_square: -0.2239 - val_loss: 0.0195 - val_MSE: 0.0395 - val_cosine_similarity: 0.7781 - val_r_square: -0.2473
# 2/2 [==============================] - 0s 138ms/step - loss: 0.0182 - MSE: 0.0371 - cosine_similarity: 0.7850 - r_square: -0.2397 - val_loss: 0.0193 - val_MSE: 0.0391 - val_cosine_similarity: 0.7783 - val_r_square: -0.2276
# Epoch 33
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0198 - MSE: 0.0404 - cosine_similarity: 0.7539 - r_square: -0.2474 - val_loss: 0.0192 - val_MSE: 0.0389 - val_cosine_similarity: 0.7778 - val_r_square: -0.2201
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0206 - MSE: 0.0422 - cosine_similarity: 0.7504 - r_square: -0.2416 - val_loss: 0.0193 - val_MSE: 0.0390 - val_cosine_similarity: 0.7777 - val_r_square: -0.2269
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0165 - MSE: 0.0336 - cosine_similarity: 0.7808 - r_square: -0.2328 - val_loss: 0.0194 - val_MSE: 0.0392 - val_cosine_similarity: 0.7775 - val_r_square: -0.2372
# 2/2 [==============================] - 0s 123ms/step - loss: 0.0165 - MSE: 0.0336 - cosine_similarity: 0.7980 - r_square: -0.2259 - val_loss: 0.0197 - val_MSE: 0.0399 - val_cosine_similarity: 0.7773 - val_r_square: -0.2639
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0172 - MSE: 0.0351 - cosine_similarity: 0.7829 - r_square: -0.2514 - val_loss: 0.0199 - val_MSE: 0.0404 - val_cosine_similarity: 0.7772 - val_r_square: -0.2848
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0175 - MSE: 0.0357 - cosine_similarity: 0.7860 - r_square: -0.2538 - val_loss: 0.0196 - val_MSE: 0.0397 - val_cosine_similarity: 0.7776 - val_r_square: -0.2571
# Epoch 34
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0174 - MSE: 0.0354 - cosine_similarity: 0.7752 - r_square: -0.2436 - val_loss: 0.0195 - val_MSE: 0.0395 - val_cosine_similarity: 0.7782 - val_r_square: -0.2477
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0205 - MSE: 0.0420 - cosine_similarity: 0.7546 - r_square: -0.2630 - val_loss: 0.0192 - val_MSE: 0.0390 - val_cosine_similarity: 0.7785 - val_r_square: -0.2271
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0178 - MSE: 0.0362 - cosine_similarity: 0.7866 - r_square: -0.1823 - val_loss: 0.0189 - val_MSE: 0.0383 - val_cosine_similarity: 0.7789 - val_r_square: -0.2017
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0198 - MSE: 0.0404 - cosine_similarity: 0.7641 - r_square: -0.2493 - val_loss: 0.0187 - val_MSE: 0.0379 - val_cosine_similarity: 0.7791 - val_r_square: -0.1834
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0179 - MSE: 0.0365 - cosine_similarity: 0.7731 - r_square: -0.3692 - val_loss: 0.0184 - val_MSE: 0.0373 - val_cosine_similarity: 0.7795 - val_r_square: -0.1563
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0178 - MSE: 0.0362 - cosine_similarity: 0.7875 - r_square: -0.2995 - val_loss: 0.0182 - val_MSE: 0.0370 - val_cosine_similarity: 0.7796 - val_r_square: -0.1435
# Epoch 35
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0163 - MSE: 0.0333 - cosine_similarity: 0.7879 - r_square: -0.2197 - val_loss: 0.0182 - val_MSE: 0.0370 - val_cosine_similarity: 0.7797 - val_r_square: -0.1442
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0162 - MSE: 0.0329 - cosine_similarity: 0.7986 - r_square: -0.2432 - val_loss: 0.0186 - val_MSE: 0.0378 - val_cosine_similarity: 0.7793 - val_r_square: -0.1777
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0181 - MSE: 0.0368 - cosine_similarity: 0.7754 - r_square: -0.2121 - val_loss: 0.0192 - val_MSE: 0.0388 - val_cosine_similarity: 0.7789 - val_r_square: -0.2225
# ...
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0156 - MSE: 0.0317 - cosine_similarity: 0.8067 - r_square: -0.1490 - val_loss: 0.0181 - val_MSE: 0.0366 - val_cosine_similarity: 0.7797 - val_r_square: -0.1372
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0165 - MSE: 0.0336 - cosine_similarity: 0.7934 - r_square: -0.1606 - val_loss: 0.0180 - val_MSE: 0.0365 - val_cosine_similarity: 0.7798 - val_r_square: -0.1333
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0180 - MSE: 0.0366 - cosine_similarity: 0.7810 - r_square: -0.1494 - val_loss: 0.0178 - val_MSE: 0.0361 - val_cosine_similarity: 0.7800 - val_r_square: -0.1138
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0168 - MSE: 0.0342 - cosine_similarity: 0.7799 - r_square: -0.0835 - val_loss: 0.0175 - val_MSE: 0.0356 - val_cosine_similarity: 0.7802 - val_r_square: -0.0917
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0166 - MSE: 0.0340 - cosine_similarity: 0.7859 - r_square: -0.1640 - val_loss: 0.0174 - val_MSE: 0.0353 - val_cosine_similarity: 0.7803 - val_r_square: -0.0800
# Epoch 89
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0177 - MSE: 0.0361 - cosine_similarity: 0.7876 - r_square: -0.1345 - val_loss: 0.0176 - val_MSE: 0.0357 - val_cosine_similarity: 0.7799 - val_r_square: -0.0944
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0141 - MSE: 0.0285 - cosine_similarity: 0.8222 - r_square: -0.0832 - val_loss: 0.0178 - val_MSE: 0.0361 - val_cosine_similarity: 0.7797 - val_r_square: -0.1102
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0170 - MSE: 0.0347 - cosine_similarity: 0.7880 - r_square: -0.1840 - val_loss: 0.0181 - val_MSE: 0.0366 - val_cosine_similarity: 0.7794 - val_r_square: -0.1327
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0175 - MSE: 0.0355 - cosine_similarity: 0.7810 - r_square: -0.0708 - val_loss: 0.0183 - val_MSE: 0.0370 - val_cosine_similarity: 0.7792 - val_r_square: -0.1516
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0176 - MSE: 0.0360 - cosine_similarity: 0.7748 - r_square: -0.1276 - val_loss: 0.0184 - val_MSE: 0.0374 - val_cosine_similarity: 0.7790 - val_r_square: -0.1664
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0174 - MSE: 0.0352 - cosine_similarity: 0.7867 - r_square: -0.1785 - val_loss: 0.0183 - val_MSE: 0.0370 - val_cosine_similarity: 0.7792 - val_r_square: -0.1509
# Epoch 90
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0158 - MSE: 0.0323 - cosine_similarity: 0.8071 - r_square: -0.1436 - val_loss: 0.0179 - val_MSE: 0.0364 - val_cosine_similarity: 0.7792 - val_r_square: -0.1248
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0173 - MSE: 0.0353 - cosine_similarity: 0.7803 - r_square: -0.1020 - val_loss: 0.0179 - val_MSE: 0.0362 - val_cosine_similarity: 0.7793 - val_r_square: -0.1184
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0168 - MSE: 0.0341 - cosine_similarity: 0.7958 - r_square: -0.1468 - val_loss: 0.0178 - val_MSE: 0.0361 - val_cosine_similarity: 0.7794 - val_r_square: -0.1145
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0179 - MSE: 0.0364 - cosine_similarity: 0.7763 - r_square: -0.1396 - val_loss: 0.0177 - val_MSE: 0.0358 - val_cosine_similarity: 0.7794 - val_r_square: -0.1032
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0171 - MSE: 0.0348 - cosine_similarity: 0.7785 - r_square: -0.1425 - val_loss: 0.0177 - val_MSE: 0.0359 - val_cosine_similarity: 0.7794 - val_r_square: -0.1057
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0144 - MSE: 0.0293 - cosine_similarity: 0.8125 - r_square: -0.1462 - val_loss: 0.0178 - val_MSE: 0.0361 - val_cosine_similarity: 0.7793 - val_r_square: -0.1167
# Epoch 91
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0186 - MSE: 0.0380 - cosine_similarity: 0.7681 - r_square: -0.1193 - val_loss: 0.0181 - val_MSE: 0.0368 - val_cosine_similarity: 0.7792 - val_r_square: -0.1450
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0177 - MSE: 0.0361 - cosine_similarity: 0.7753 - r_square: -0.1145 - val_loss: 0.0184 - val_MSE: 0.0372 - val_cosine_similarity: 0.7789 - val_r_square: -0.1665
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0170 - MSE: 0.0347 - cosine_similarity: 0.7985 - r_square: -0.1808 - val_loss: 0.0187 - val_MSE: 0.0378 - val_cosine_similarity: 0.7785 - val_r_square: -0.1930
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0159 - MSE: 0.0323 - cosine_similarity: 0.7935 - r_square: -0.1324 - val_loss: 0.0188 - val_MSE: 0.0381 - val_cosine_similarity: 0.7783 - val_r_square: -0.2056
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0160 - MSE: 0.0325 - cosine_similarity: 0.8002 - r_square: -0.1572 - val_loss: 0.0186 - val_MSE: 0.0377 - val_cosine_similarity: 0.7785 - val_r_square: -0.1866
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0161 - MSE: 0.0327 - cosine_similarity: 0.7852 - r_square: -0.1943 - val_loss: 0.0180 - val_MSE: 0.0366 - val_cosine_similarity: 0.7790 - val_r_square: -0.1380
# Epoch 92
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0155 - MSE: 0.0316 - cosine_similarity: 0.8010 - r_square: -0.0968 - val_loss: 0.0175 - val_MSE: 0.0354 - val_cosine_similarity: 0.7793 - val_r_square: -0.0847
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0191 - MSE: 0.0388 - cosine_similarity: 0.7667 - r_square: -0.1337 - val_loss: 0.0174 - val_MSE: 0.0352 - val_cosine_similarity: 0.7794 - val_r_square: -0.0777
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0175 - MSE: 0.0357 - cosine_similarity: 0.7802 - r_square: -0.1508 - val_loss: 0.0175 - val_MSE: 0.0354 - val_cosine_similarity: 0.7793 - val_r_square: -0.0852
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0159 - MSE: 0.0323 - cosine_similarity: 0.7931 - r_square: -0.0876 - val_loss: 0.0175 - val_MSE: 0.0355 - val_cosine_similarity: 0.7793 - val_r_square: -0.0883
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0170 - MSE: 0.0348 - cosine_similarity: 0.7917 - r_square: -0.1093 - val_loss: 0.0176 - val_MSE: 0.0358 - val_cosine_similarity: 0.7791 - val_r_square: -0.0984
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0149 - MSE: 0.0302 - cosine_similarity: 0.7947 - r_square: -0.1757 - val_loss: 0.0178 - val_MSE: 0.0361 - val_cosine_similarity: 0.7790 - val_r_square: -0.1121
# Epoch 93
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0168 - MSE: 0.0340 - cosine_similarity: 0.7863 - r_square: -0.1987 - val_loss: 0.0178 - val_MSE: 0.0360 - val_cosine_similarity: 0.7794 - val_r_square: -0.1110
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0160 - MSE: 0.0326 - cosine_similarity: 0.7981 - r_square: -0.0943 - val_loss: 0.0177 - val_MSE: 0.0360 - val_cosine_similarity: 0.7795 - val_r_square: -0.1090
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0174 - MSE: 0.0355 - cosine_similarity: 0.7880 - r_square: -0.1884 - val_loss: 0.0178 - val_MSE: 0.0361 - val_cosine_similarity: 0.7795 - val_r_square: -0.1134
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0151 - MSE: 0.0306 - cosine_similarity: 0.7980 - r_square: -0.1476 - val_loss: 0.0179 - val_MSE: 0.0363 - val_cosine_similarity: 0.7793 - val_r_square: -0.1250
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0175 - MSE: 0.0357 - cosine_similarity: 0.7784 - r_square: -0.1123 - val_loss: 0.0179 - val_MSE: 0.0363 - val_cosine_similarity: 0.7793 - val_r_square: -0.1260
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0173 - MSE: 0.0353 - cosine_similarity: 0.7902 - r_square: -0.1020 - val_loss: 0.0178 - val_MSE: 0.0361 - val_cosine_similarity: 0.7794 - val_r_square: -0.1168
# Epoch 94
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0152 - MSE: 0.0309 - cosine_similarity: 0.8025 - r_square: -0.1112 - val_loss: 0.0177 - val_MSE: 0.0358 - val_cosine_similarity: 0.7793 - val_r_square: -0.1037
# 2/2 [==============================] - 0s 123ms/step - loss: 0.0160 - MSE: 0.0325 - cosine_similarity: 0.7926 - r_square: -0.0852 - val_loss: 0.0175 - val_MSE: 0.0355 - val_cosine_similarity: 0.7794 - val_r_square: -0.0894
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0164 - MSE: 0.0333 - cosine_similarity: 0.7843 - r_square: -0.1072 - val_loss: 0.0174 - val_MSE: 0.0352 - val_cosine_similarity: 0.7795 - val_r_square: -0.0775
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0170 - MSE: 0.0347 - cosine_similarity: 0.7907 - r_square: -0.1487 - val_loss: 0.0174 - val_MSE: 0.0353 - val_cosine_similarity: 0.7795 - val_r_square: -0.0784
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0165 - MSE: 0.0337 - cosine_similarity: 0.7922 - r_square: -0.1180 - val_loss: 0.0176 - val_MSE: 0.0356 - val_cosine_similarity: 0.7793 - val_r_square: -0.0951
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0176 - MSE: 0.0360 - cosine_similarity: 0.7812 - r_square: -0.0833 - val_loss: 0.0179 - val_MSE: 0.0363 - val_cosine_similarity: 0.7789 - val_r_square: -0.1229
# Epoch 95
# 2/2 [==============================] - 0s 92ms/step - loss: 0.0155 - MSE: 0.0313 - cosine_similarity: 0.7957 - r_square: -0.1485 - val_loss: 0.0183 - val_MSE: 0.0371 - val_cosine_similarity: 0.7793 - val_r_square: -0.1636
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0191 - MSE: 0.0389 - cosine_similarity: 0.7792 - r_square: -0.0915 - val_loss: 0.0187 - val_MSE: 0.0378 - val_cosine_similarity: 0.7789 - val_r_square: -0.1915
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0164 - MSE: 0.0333 - cosine_similarity: 0.7853 - r_square: -0.1207 - val_loss: 0.0186 - val_MSE: 0.0377 - val_cosine_similarity: 0.7790 - val_r_square: -0.1857
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0158 - MSE: 0.0321 - cosine_similarity: 0.8009 - r_square: -0.1783 - val_loss: 0.0182 - val_MSE: 0.0368 - val_cosine_similarity: 0.7794 - val_r_square: -0.1499
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0166 - MSE: 0.0338 - cosine_similarity: 0.7984 - r_square: -0.1154 - val_loss: 0.0178 - val_MSE: 0.0360 - val_cosine_similarity: 0.7799 - val_r_square: -0.1153
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0166 - MSE: 0.0337 - cosine_similarity: 0.7849 - r_square: -0.2008 - val_loss: 0.0174 - val_MSE: 0.0352 - val_cosine_similarity: 0.7804 - val_r_square: -0.0796
# Epoch 96
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0165 - MSE: 0.0337 - cosine_similarity: 0.8016 - r_square: -0.1026 - val_loss: 0.0172 - val_MSE: 0.0350 - val_cosine_similarity: 0.7791 - val_r_square: -0.0657
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0159 - MSE: 0.0325 - cosine_similarity: 0.7968 - r_square: -0.1619 - val_loss: 0.0175 - val_MSE: 0.0354 - val_cosine_similarity: 0.7789 - val_r_square: -0.0841
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0162 - MSE: 0.0329 - cosine_similarity: 0.7856 - r_square: -0.1279 - val_loss: 0.0178 - val_MSE: 0.0361 - val_cosine_similarity: 0.7785 - val_r_square: -0.1138
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0168 - MSE: 0.0344 - cosine_similarity: 0.8018 - r_square: -0.1154 - val_loss: 0.0183 - val_MSE: 0.0370 - val_cosine_similarity: 0.7781 - val_r_square: -0.1520
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0179 - MSE: 0.0365 - cosine_similarity: 0.7806 - r_square: -0.1342 - val_loss: 0.0184 - val_MSE: 0.0373 - val_cosine_similarity: 0.7779 - val_r_square: -0.1660
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0156 - MSE: 0.0316 - cosine_similarity: 0.7964 - r_square: -0.0721 - val_loss: 0.0183 - val_MSE: 0.0371 - val_cosine_similarity: 0.7780 - val_r_square: -0.1569
# Epoch 97
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0167 - MSE: 0.0340 - cosine_similarity: 0.7930 - r_square: -0.1527 - val_loss: 0.0180 - val_MSE: 0.0365 - val_cosine_similarity: 0.7791 - val_r_square: -0.1316
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0160 - MSE: 0.0325 - cosine_similarity: 0.7970 - r_square: -0.1503 - val_loss: 0.0177 - val_MSE: 0.0359 - val_cosine_similarity: 0.7795 - val_r_square: -0.1054
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0181 - MSE: 0.0367 - cosine_similarity: 0.7700 - r_square: -0.1979 - val_loss: 0.0174 - val_MSE: 0.0353 - val_cosine_similarity: 0.7798 - val_r_square: -0.0803
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0158 - MSE: 0.0323 - cosine_similarity: 0.7977 - r_square: -0.0938 - val_loss: 0.0174 - val_MSE: 0.0353 - val_cosine_similarity: 0.7799 - val_r_square: -0.0779
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0173 - MSE: 0.0353 - cosine_similarity: 0.7885 - r_square: -0.1659 - val_loss: 0.0174 - val_MSE: 0.0354 - val_cosine_similarity: 0.7799 - val_r_square: -0.0827
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0170 - MSE: 0.0348 - cosine_similarity: 0.7789 - r_square: -0.1016 - val_loss: 0.0177 - val_MSE: 0.0359 - val_cosine_similarity: 0.7796 - val_r_square: -0.1070
# Epoch 98
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0174 - MSE: 0.0354 - cosine_similarity: 0.7816 - r_square: -0.0705 - val_loss: 0.0181 - val_MSE: 0.0366 - val_cosine_similarity: 0.7791 - val_r_square: -0.1364
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0153 - MSE: 0.0309 - cosine_similarity: 0.8029 - r_square: -0.1572 - val_loss: 0.0182 - val_MSE: 0.0369 - val_cosine_similarity: 0.7789 - val_r_square: -0.1486
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0157 - MSE: 0.0320 - cosine_similarity: 0.7955 - r_square: -0.1024 - val_loss: 0.0181 - val_MSE: 0.0366 - val_cosine_similarity: 0.7791 - val_r_square: -0.1383
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0181 - MSE: 0.0368 - cosine_similarity: 0.7693 - r_square: -0.1369 - val_loss: 0.0179 - val_MSE: 0.0363 - val_cosine_similarity: 0.7793 - val_r_square: -0.1217
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0150 - MSE: 0.0305 - cosine_similarity: 0.8032 - r_square: -0.1493 - val_loss: 0.0177 - val_MSE: 0.0359 - val_cosine_similarity: 0.7795 - val_r_square: -0.1055
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0170 - MSE: 0.0347 - cosine_similarity: 0.7927 - r_square: -0.0574 - val_loss: 0.0176 - val_MSE: 0.0356 - val_cosine_similarity: 0.7797 - val_r_square: -0.0940
# Epoch 99
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0154 - MSE: 0.0314 - cosine_similarity: 0.7857 - r_square: -0.0596 - val_loss: 0.0175 - val_MSE: 0.0355 - val_cosine_similarity: 0.7798 - val_r_square: -0.0878
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0147 - MSE: 0.0298 - cosine_similarity: 0.8095 - r_square: -0.0651 - val_loss: 0.0175 - val_MSE: 0.0356 - val_cosine_similarity: 0.7798 - val_r_square: -0.0916
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0188 - MSE: 0.0384 - cosine_similarity: 0.7733 - r_square: -0.1279 - val_loss: 0.0177 - val_MSE: 0.0359 - val_cosine_similarity: 0.7796 - val_r_square: -0.1083
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0172 - MSE: 0.0348 - cosine_similarity: 0.7870 - r_square: -0.2364 - val_loss: 0.0179 - val_MSE: 0.0362 - val_cosine_similarity: 0.7794 - val_r_square: -0.1197
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0159 - MSE: 0.0325 - cosine_similarity: 0.7993 - r_square: -0.1279 - val_loss: 0.0178 - val_MSE: 0.0361 - val_cosine_similarity: 0.7794 - val_r_square: -0.1144
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0173 - MSE: 0.0353 - cosine_similarity: 0.7799 - r_square: -0.1219 - val_loss: 0.0176 - val_MSE: 0.0357 - val_cosine_similarity: 0.7796 - val_r_square: -0.0987

# %%
# %matplotlib inline

metric = "cosine similarity" #Choose between 'loss', 'MSE', 'cosine similarity', 'r2'

import matplotlib.pyplot as plt
try: history_df = history_df.reset_index()
except: pass

metrics_dict = {"loss": ["loss", "val_loss"], "MSE": ["MSE", "val_MSE"], 
                "cosine similarity": ["cosine_similarity", "val_cosine_similarity"],
               "r2" : ["r_square", "val_r_square"]}

fig, ax = plt.subplots(figsize=(15,4),nrows=1, ncols=1)
ax.set_ylabel(f"{metric}")
ax.set_xlabel("Training time")
fig.suptitle(f"History of {metric} in training time")

train_plot = history_df.plot(y=metrics_dict[metric][0], use_index=True, ax=ax, label="Training")
val_plot = history_df.plot(y=metrics_dict[metric][1], use_index=True, ax=ax, label="Validation")

plt.show()

# %% [markdown]
# ## Evaluation of the results

# %%
val_ds = validation_dataset.shuffle(n_test).batch(n_test)
x_val, y_val, length_val = next(iter(val_ds))
x_val, y_val = slice_accordingly(x_val, y_val)
    

y_pred = model.predict(x_val)
y_true = y_val

# %%
def plot_epsilon_error(y_true, y_pred):
    
    N = len(y_true)
    
    cdf_abs_error = {}
    abs_error = np.abs(y_true - y_pred)
    
    fig, ax = plt.subplots(figsize=(12,6),nrows=1, ncols=2)
    ax[0].set_ylabel("Fraction of samples")
    ax[0].set_xlabel("Allowed absolute error")
    ax[0].set_title(f"CDF of the absolute error for different emotions")
    
    for i, emotion in enumerate(emotions):
        abs_error_emotion = np.sort(abs_error[:,i])
        X2 = np.sort(abs_error_emotion)
        F2 = np.array(range(N))/(float(N))
        
        cdf_abs_error[emotion] = [X2, F2]
        
        ax[0].plot(X2, F2, label=emotion)
        
    ax[0].legend()
    ax[0].grid()
    
    cdf_cosine_sim = {}
    cos_sim = np.array([np.dot(y_true[i], y_pred[i])/(np.linalg.norm(y_true[i])*np.linalg.norm(y_pred[i])) for i in range(N)])
    cos_error = 1-cos_sim
    
    X2 = np.sort(cos_error)
    F2 = np.array(range(N))/(float(N))

    ax[1].set_ylabel(f"Fraction of samples", rotation=-90, labelpad=15)
    ax[1].yaxis.set_label_position("right")
    ax[1].yaxis.tick_right()
    ax[1].set_xlabel("Allowed cosine error")
    ax[1].set_title(f"CDF of the cosine error")
    
    ax[1].plot(X2, F2)
    ax[1].grid()
    return cdf_abs_error

# %%
epsilon_error = plot_epsilon_error(y_true, y_pred)

x = epsilon_error["amazement"]
plt.show()

# %% [markdown]
# ## "Cross-validation"

# %%
def custom_loss(y_true, y_pred):
    cos_sim = tf.keras.losses.CosineSimilarity() 
    MSE = tf.keras.losses.MeanSquaredError()
        
    return cos_sim(y_true, y_pred) + MSE(y_true, y_pred)

# %%
from sklearn.model_selection import KFold


n_splits = 5
kf = KFold(n_splits=n_splits)

predictions_and_labels = {}


count = 0
for train_index, test_index in kf.split(MFCCs_raw):
    
    print(f"Training K-fold {1+count} of {n_splits}")

    train_features, train_labels = MFCCs_raw[train_index], labels_raw[train_index]
    validation_features, validation_labels = MFCCs_raw[test_index], labels_raw[test_index]

    train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels))
    validation_dataset = tf.data.Dataset.from_tensor_slices((validation_features, validation_labels))
    
    sample_size = (20, 50, 1)
    drop_out_rate = 0.4

    input_tensor = Input(sample_size)
    x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(input_tensor)
    x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(x)
    x = layers.Dropout(drop_out_rate)(x)
    x = layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)
    x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(x)
    x = layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)
    x = layers.Flatten()(x)
    x = layers.Dense(20, activation="relu")(x)
    x = layers.Flatten()(x)
    x = layers.Dropout(drop_out_rate)(x)
    output_tensor = layers.Dense(9, activation="sigmoid")(x)

    model = tf.keras.Model(input_tensor, output_tensor)
        
    model.compile(optimizer="adam",
                  loss = tf.keras.losses.LogCosh(),
                  #loss= custom_loss,
                  metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
    n_epochs = 100
    batch_size = 50
    
    for epoch in range(n_epochs):
        train_ds = train_dataset.shuffle(n_train).batch(batch_size)
        for features, labels in train_ds:
            features, labels = slice_accordingly(features, labels)
            model.fit(features, labels, verbose=0)
            
    val_ds = validation_dataset.shuffle(n_test).batch(n_test)
    x_val, y_val = next(iter(val_ds))
    x_val, y_val = slice_accordingly(x_val, y_val)

            
    predictions_and_labels[count] = [model.predict(x_val), y_val]
    count = count+1
# Out:
# Training K-fold 1 of 5
# Training K-fold 2 of 5
# Training K-fold 3 of 5
# Training K-fold 4 of 5
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000020A0344D620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Training K-fold 5 of 5
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000020A01EC8B70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
predictions = []
labels = []

for i in range(max(predictions_and_labels.keys())+1):
    predictions.append(predictions_and_labels[i][0])
    labels.append(predictions_and_labels[i][1])

predictions = np.concatenate(predictions)
labels = np.concatenate(labels)
epsilon_error = plot_epsilon_error(labels, predictions)

plt.show()

# %%
cos_sim = []
r2 = []
MSE = []

cos_sim_function = tf.keras.metrics.CosineSimilarity() 
MSE_function = tf.keras.metrics.MeanSquaredError()
r2_function = tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))

for i in range(max(predictions_and_labels.keys())+1):
    y_pred = predictions_and_labels[i][0]
    y_true = predictions_and_labels[i][1]
    
    cos_sim.append(cos_sim_function(y_true, y_pred).numpy())
    r2.append(r2_function(y_true, y_pred).numpy())
    MSE.append(MSE_function(y_true, y_pred).numpy())
    
print(f"The cosine similarity is approximately {100*np.mean(cos_sim):.2f}±{100*np.std(cos_sim):.2f}%")
print(f"The MSE is approximately {100*np.mean(MSE):.2f}±{100*np.std(MSE):.2f}%")
print(f"The R2 score is approximately {100*np.mean(r2):.2f}±{100*np.std(r2):.2f}%")
# Out:
# The cosine similarity is approximately 78.98±0.35%
# The MSE is approximately 3.38±0.05%
# The R2 score is approximately -9.84±1.23%
