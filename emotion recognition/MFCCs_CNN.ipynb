# %% [markdown]
# # Emotion Recognition: MFCCs_CNN.ipynb
#
# Model trained on *simple features* that aims at predicting the *emotion labels*.
#
# The approach consists on getting the arrays of MFCCs (in *preprocessing*) and train a *Convolutional Neural Network* with *Tensorflow*.
# The problem is treated as a *regression* problem, where the loss function can be chosen between *mean squared error*, *-cosine similarity*, or *both*, being a combination of both losses with equal weight. The results shown are using "*both*".

# %%
import numpy as np
import pandas as pd
import os

import tensorflow as tf
import tensorflow_addons as tfa

# %%
MFCCs = np.load("../preprocessing/MFCCs/MFCC.npy")
MFCCs = (MFCCs - np.nanmean(MFCCs))/np.nanstd(MFCCs)

# %%
info_songs = pd.read_csv("../data/Info/info.csv")
label_songs = pd.read_csv("../preprocessing/labels.csv")

# %%
# Retrieve emotions from the labels.csv file

emotions = ["amazement", "solemnity", "tenderness", "nostalgia", "calmness", 
            "power", "joyful_activation", "tension", "sadness"]

labels = label_songs[emotions]
labels = labels.to_numpy()

length_songs = pd.DataFrame(info_songs["Track ID"])
length_songs["Song length"] = info_songs["Duration"]*10
length_songs["Song length"] = length_songs["Song length"].astype(int)

# %%
n_data = len(length_songs)
idx = np.random.permutation(n_data)
length_songs = length_songs.reindex(idx)["Song length"].to_numpy()
MFCCs_raw = MFCCs[idx, :, :]
labels_raw = labels[idx]

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras import Input, layers
from tensorflow.keras import backend as K

sample_size = (20, 50, 1)

drop_out_rate = 0.4

# very simple keras Sequential model
input_tensor = Input(sample_size)
x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(input_tensor)
x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(x)
x = layers.Dropout(drop_out_rate)(x)
x = layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)
x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(x)
x = layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)
x = layers.Flatten()(x)
x = layers.Dense(20, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(drop_out_rate)(x)
output_tensor = layers.Dense(9, activation="sigmoid")(x)

model_1 = tf.keras.Model(input_tensor, output_tensor)
model_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 20, 50, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 18, 48, 16)        160
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 46, 16)        2320
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 46, 16)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 7, 22, 16)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 20, 16)         2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 9, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 288)               0
# _________________________________________________________________
# dense (Dense)                (None, 20)                5780
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 20)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 189
# =================================================================
# Total params: 10,769
# Trainable params: 10,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = model_1

#loss = "MSE"
#loss = "CosineSimilarity"
loss = "both"
#loss = "KLDivergence"
#loss = "RSquare"
#loss = "LogCosh"

if loss == "MSE":
    model.compile(optimizer="adam",
                  loss=tf.keras.losses.MeanSquaredError(),
                  metrics=["cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "CosineSimilarity":
    model.compile(optimizer="adam",
                  loss= tf.keras.losses.CosineSimilarity(),
                  metrics=["MSE", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "both":
    def custom_loss(y_true, y_pred):
        cos_sim = tf.keras.losses.CosineSimilarity() 
        MSE = tf.keras.losses.MeanSquaredError()
        return cos_sim(y_true, y_pred) + MSE(y_true, y_pred)
    
    model.compile(optimizer="adam",
                loss= custom_loss,
                metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])

elif loss == "KLDivergence":
    model.compile(optimizer="adam",
                loss = tf.keras.losses.KLDivergence(),
                metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "RSquare":
    def rsquare_loss(y_true, y_pred):
        metric = tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))
        return -metric(y_true, y_pred)
    
    model.compile(optimizer="adam",
                loss = tf.keras.losses.KLDivergence(),
                metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "LogCosh":
    model.compile(optimizer="adam",
                loss =  tf.keras.losses.LogCosh(),
                metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])

# %%
def slice_accordingly(input_tensor, labels, size=sample_size):

    input_shape = (tf.shape(input_tensor).numpy())
    
    input_shape[1], input_shape[2] = size[0], size[1]
    size = input_shape
    
    sliced_tensor = tf.image.random_crop(input_tensor, size)
    
    nan_values, idx = tf.unique(tf.gather(tf.where(tf.math.is_nan(sliced_tensor)), 0, axis=1))
    nan_values = nan_values.numpy()
  
    msk = np.zeros((input_shape[0]), dtype=np.bool)
    msk[nan_values] = True
    msk = ~msk

    sliced_tensor = tf.boolean_mask(sliced_tensor, msk , axis=0)
    labels = tf.boolean_mask(labels , msk, axis=0)
    
    return sliced_tensor, labels

# %%
fraction_validation = 0.25
n_test = int(fraction_validation*len(labels))
n_train = len(labels) - n_test

train_features, train_labels, train_length = MFCCs_raw[:n_train], labels_raw[:n_train], length_songs[:n_train]
validation_features, validation_labels, validation_length = MFCCs_raw[n_train:], labels_raw[n_train:], length_songs[n_train:]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels, train_length))
validation_dataset = tf.data.Dataset.from_tensor_slices((validation_features, validation_labels, validation_length))

# %%
n_epochs = 100
batch_size = 50

history_df = pd.DataFrame()

for epoch in range(n_epochs):
    print("Epoch", epoch)
    train_ds = train_dataset.shuffle(n_train).batch(batch_size)
    val_ds = validation_dataset.shuffle(n_test).batch(n_test)
    
    x_val, y_val, length_val = next(iter(val_ds))
    x_val, y_val = slice_accordingly(x_val, y_val)
    
    for features, labels, lengths in train_ds:
        features, labels = slice_accordingly(features, labels)
        
        history = model.fit(features, labels,
                           validation_data=(x_val, y_val),verbose=1)
        history = pd.DataFrame(history.history)
        history_df = history_df.append(history)
# Out:
# Epoch 0
# 2/2 [==============================] - 3s 708ms/step - loss: -0.6611 - MSE: 0.1165 - cosine_similarity: 0.7776 - r_square: -4.1918 - val_loss: -0.6651 - val_MSE: 0.1143 - val_cosine_similarity: 0.7794 - val_r_square: -3.8320
# 2/2 [==============================] - 0s 102ms/step - loss: -0.6516 - MSE: 0.1163 - cosine_similarity: 0.7678 - r_square: -3.5469 - val_loss: -0.6663 - val_MSE: 0.1136 - val_cosine_similarity: 0.7799 - val_r_square: -3.7877
# 2/2 [==============================] - 0s 101ms/step - loss: -0.6472 - MSE: 0.1174 - cosine_similarity: 0.7646 - r_square: -4.0053 - val_loss: -0.6670 - val_MSE: 0.1128 - val_cosine_similarity: 0.7798 - val_r_square: -3.7496
# 2/2 [==============================] - 0s 103ms/step - loss: -0.6511 - MSE: 0.1177 - cosine_similarity: 0.7688 - r_square: -3.8486 - val_loss: -0.6677 - val_MSE: 0.1120 - val_cosine_similarity: 0.7797 - val_r_square: -3.7127
# 2/2 [==============================] - 0s 101ms/step - loss: -0.6684 - MSE: 0.1102 - cosine_similarity: 0.7785 - r_square: -4.1310 - val_loss: -0.6684 - val_MSE: 0.1112 - val_cosine_similarity: 0.7796 - val_r_square: -3.6748
# 2/2 [==============================] - 0s 103ms/step - loss: -0.6448 - MSE: 0.1150 - cosine_similarity: 0.7598 - r_square: -4.3559 - val_loss: -0.6693 - val_MSE: 0.1103 - val_cosine_similarity: 0.7795 - val_r_square: -3.6327
# Epoch 1
# 2/2 [==============================] - 0s 109ms/step - loss: -0.6605 - MSE: 0.1102 - cosine_similarity: 0.7707 - r_square: -3.8807 - val_loss: -0.6707 - val_MSE: 0.1090 - val_cosine_similarity: 0.7797 - val_r_square: -3.5792
# 2/2 [==============================] - 0s 100ms/step - loss: -0.6410 - MSE: 0.1141 - cosine_similarity: 0.7551 - r_square: -4.2433 - val_loss: -0.6720 - val_MSE: 0.1076 - val_cosine_similarity: 0.7796 - val_r_square: -3.5141
# 2/2 [==============================] - 0s 102ms/step - loss: -0.6762 - MSE: 0.1048 - cosine_similarity: 0.7810 - r_square: -4.0915 - val_loss: -0.6732 - val_MSE: 0.1062 - val_cosine_similarity: 0.7795 - val_r_square: -3.4465
# 2/2 [==============================] - 0s 101ms/step - loss: -0.6670 - MSE: 0.1059 - cosine_similarity: 0.7729 - r_square: -3.5180 - val_loss: -0.6743 - val_MSE: 0.1051 - val_cosine_similarity: 0.7795 - val_r_square: -3.3910
# 2/2 [==============================] - 0s 115ms/step - loss: -0.6608 - MSE: 0.1058 - cosine_similarity: 0.7665 - r_square: -2.9703 - val_loss: -0.6752 - val_MSE: 0.1044 - val_cosine_similarity: 0.7796 - val_r_square: -3.3521
# 2/2 [==============================] - 0s 108ms/step - loss: -0.6577 - MSE: 0.1052 - cosine_similarity: 0.7629 - r_square: -3.0139 - val_loss: -0.6760 - val_MSE: 0.1035 - val_cosine_similarity: 0.7795 - val_r_square: -3.3012
# Epoch 2
# 2/2 [==============================] - 0s 86ms/step - loss: -0.6429 - MSE: 0.1078 - cosine_similarity: 0.7507 - r_square: -3.2666 - val_loss: -0.6765 - val_MSE: 0.1031 - val_cosine_similarity: 0.7797 - val_r_square: -3.2729
# 2/2 [==============================] - 0s 103ms/step - loss: -0.6514 - MSE: 0.1065 - cosine_similarity: 0.7579 - r_square: -3.1103 - val_loss: -0.6771 - val_MSE: 0.1025 - val_cosine_similarity: 0.7796 - val_r_square: -3.2337
# 2/2 [==============================] - 0s 102ms/step - loss: -0.6787 - MSE: 0.1007 - cosine_similarity: 0.7794 - r_square: -3.1955 - val_loss: -0.6781 - val_MSE: 0.1013 - val_cosine_similarity: 0.7794 - val_r_square: -3.1679
# 2/2 [==============================] - 0s 101ms/step - loss: -0.6879 - MSE: 0.0966 - cosine_similarity: 0.7845 - r_square: -3.0970 - val_loss: -0.6794 - val_MSE: 0.0997 - val_cosine_similarity: 0.7790 - val_r_square: -3.0828
# 2/2 [==============================] - 0s 101ms/step - loss: -0.6725 - MSE: 0.0972 - cosine_similarity: 0.7698 - r_square: -2.8318 - val_loss: -0.6806 - val_MSE: 0.0984 - val_cosine_similarity: 0.7790 - val_r_square: -3.0210
# 2/2 [==============================] - 0s 100ms/step - loss: -0.6593 - MSE: 0.0991 - cosine_similarity: 0.7584 - r_square: -3.7268 - val_loss: -0.6810 - val_MSE: 0.0986 - val_cosine_similarity: 0.7796 - val_r_square: -3.0313
# Epoch 3
# 2/2 [==============================] - 0s 111ms/step - loss: -0.6564 - MSE: 0.1042 - cosine_similarity: 0.7607 - r_square: -3.1122 - val_loss: -0.6808 - val_MSE: 0.0991 - val_cosine_similarity: 0.7799 - val_r_square: -3.0552
# 2/2 [==============================] - 0s 100ms/step - loss: -0.6664 - MSE: 0.0980 - cosine_similarity: 0.7644 - r_square: -3.2274 - val_loss: -0.6809 - val_MSE: 0.0993 - val_cosine_similarity: 0.7802 - val_r_square: -3.0658
# 2/2 [==============================] - 0s 103ms/step - loss: -0.6726 - MSE: 0.0974 - cosine_similarity: 0.7701 - r_square: -3.1678 - val_loss: -0.6809 - val_MSE: 0.0995 - val_cosine_similarity: 0.7804 - val_r_square: -3.0767
# 2/2 [==============================] - 0s 102ms/step - loss: -0.6801 - MSE: 0.0974 - cosine_similarity: 0.7774 - r_square: -3.1809 - val_loss: -0.6811 - val_MSE: 0.0995 - val_cosine_similarity: 0.7807 - val_r_square: -3.0784
# 2/2 [==============================] - 0s 101ms/step - loss: -0.6753 - MSE: 0.0989 - cosine_similarity: 0.7742 - r_square: -3.2141 - val_loss: -0.6815 - val_MSE: 0.0994 - val_cosine_similarity: 0.7809 - val_r_square: -3.0721
# 2/2 [==============================] - 0s 103ms/step - loss: -0.6669 - MSE: 0.0978 - cosine_similarity: 0.7647 - r_square: -2.7314 - val_loss: -0.6820 - val_MSE: 0.0989 - val_cosine_similarity: 0.7810 - val_r_square: -3.0491
# Epoch 4
# 2/2 [==============================] - 0s 109ms/step - loss: -0.6606 - MSE: 0.0991 - cosine_similarity: 0.7597 - r_square: -2.8581 - val_loss: -0.6824 - val_MSE: 0.0983 - val_cosine_similarity: 0.7807 - val_r_square: -3.0162
# 2/2 [==============================] - 0s 103ms/step - loss: -0.6726 - MSE: 0.0960 - cosine_similarity: 0.7686 - r_square: -3.6219 - val_loss: -0.6832 - val_MSE: 0.0977 - val_cosine_similarity: 0.7809 - val_r_square: -2.9863
# 2/2 [==============================] - 0s 103ms/step - loss: -0.6689 - MSE: 0.0949 - cosine_similarity: 0.7638 - r_square: -2.5986 - val_loss: -0.6840 - val_MSE: 0.0972 - val_cosine_similarity: 0.7812 - val_r_square: -2.9572
# 2/2 [==============================] - 0s 101ms/step - loss: -0.6755 - MSE: 0.0970 - cosine_similarity: 0.7725 - r_square: -3.1208 - val_loss: -0.6851 - val_MSE: 0.0964 - val_cosine_similarity: 0.7814 - val_r_square: -2.9157
# 2/2 [==============================] - 0s 102ms/step - loss: -0.6787 - MSE: 0.0954 - cosine_similarity: 0.7742 - r_square: -3.1221 - val_loss: -0.6862 - val_MSE: 0.0955 - val_cosine_similarity: 0.7816 - val_r_square: -2.8691
# 2/2 [==============================] - 0s 102ms/step - loss: -0.6805 - MSE: 0.0937 - cosine_similarity: 0.7742 - r_square: -2.4265 - val_loss: -0.6869 - val_MSE: 0.0949 - val_cosine_similarity: 0.7818 - val_r_square: -2.8384
# Epoch 5
# 2/2 [==============================] - 0s 111ms/step - loss: -0.7063 - MSE: 0.0882 - cosine_similarity: 0.7945 - r_square: -3.0019 - val_loss: -0.6879 - val_MSE: 0.0940 - val_cosine_similarity: 0.7819 - val_r_square: -2.7935
# 2/2 [==============================] - 0s 86ms/step - loss: -0.6985 - MSE: 0.0889 - cosine_similarity: 0.7874 - r_square: -3.2646 - val_loss: -0.6889 - val_MSE: 0.0930 - val_cosine_similarity: 0.7820 - val_r_square: -2.7419
# 2/2 [==============================] - 0s 102ms/step - loss: -0.6623 - MSE: 0.0961 - cosine_similarity: 0.7584 - r_square: -2.8382 - val_loss: -0.6898 - val_MSE: 0.0922 - val_cosine_similarity: 0.7820 - val_r_square: -2.7018
# 2/2 [==============================] - 0s 87ms/step - loss: -0.6519 - MSE: 0.0972 - cosine_similarity: 0.7490 - r_square: -2.6488 - val_loss: -0.6902 - val_MSE: 0.0920 - val_cosine_similarity: 0.7822 - val_r_square: -2.6902
# 2/2 [==============================] - 0s 102ms/step - loss: -0.6658 - MSE: 0.0942 - cosine_similarity: 0.7600 - r_square: -2.5980 - val_loss: -0.6906 - val_MSE: 0.0918 - val_cosine_similarity: 0.7824 - val_r_square: -2.6794
# 2/2 [==============================] - 0s 104ms/step - loss: -0.6748 - MSE: 0.0920 - cosine_similarity: 0.7668 - r_square: -2.3193 - val_loss: -0.6915 - val_MSE: 0.0911 - val_cosine_similarity: 0.7827 - val_r_square: -2.6476
# Epoch 6
# 2/2 [==============================] - 0s 95ms/step - loss: -0.6674 - MSE: 0.0920 - cosine_similarity: 0.7594 - r_square: -2.7336 - val_loss: -0.6931 - val_MSE: 0.0912 - val_cosine_similarity: 0.7843 - val_r_square: -2.6924
# 2/2 [==============================] - 0s 102ms/step - loss: -0.6923 - MSE: 0.0869 - cosine_similarity: 0.7792 - r_square: -2.4239 - val_loss: -0.6940 - val_MSE: 0.0909 - val_cosine_similarity: 0.7849 - val_r_square: -2.6862
# 2/2 [==============================] - 0s 104ms/step - loss: -0.6790 - MSE: 0.0892 - cosine_similarity: 0.7682 - r_square: -2.4308 - val_loss: -0.6951 - val_MSE: 0.0903 - val_cosine_similarity: 0.7853 - val_r_square: -2.6578
# 2/2 [==============================] - 0s 116ms/step - loss: -0.7009 - MSE: 0.0855 - cosine_similarity: 0.7863 - r_square: -2.9080 - val_loss: -0.6959 - val_MSE: 0.0899 - val_cosine_similarity: 0.7858 - val_r_square: -2.6386
# 2/2 [==============================] - 0s 100ms/step - loss: -0.6663 - MSE: 0.0922 - cosine_similarity: 0.7585 - r_square: -2.4298 - val_loss: -0.6971 - val_MSE: 0.0888 - val_cosine_similarity: 0.7859 - val_r_square: -2.5851
# 2/2 [==============================] - 0s 102ms/step - loss: -0.6810 - MSE: 0.0878 - cosine_similarity: 0.7688 - r_square: -2.3497 - val_loss: -0.6973 - val_MSE: 0.0886 - val_cosine_similarity: 0.7859 - val_r_square: -2.5694
# Epoch 7
# 2/2 [==============================] - 0s 111ms/step - loss: -0.6956 - MSE: 0.0839 - cosine_similarity: 0.7795 - r_square: -2.1579 - val_loss: -0.6955 - val_MSE: 0.0896 - val_cosine_similarity: 0.7851 - val_r_square: -2.6143
# 2/2 [==============================] - 0s 101ms/step - loss: -0.6886 - MSE: 0.0897 - cosine_similarity: 0.7783 - r_square: -3.2306 - val_loss: -0.6955 - val_MSE: 0.0896 - val_cosine_similarity: 0.7851 - val_r_square: -2.6100
# 2/2 [==============================] - 0s 124ms/step - loss: -0.6956 - MSE: 0.0838 - cosine_similarity: 0.7794 - r_square: -2.2708 - val_loss: -0.6958 - val_MSE: 0.0895 - val_cosine_similarity: 0.7853 - val_r_square: -2.6007
# 2/2 [==============================] - 0s 105ms/step - loss: -0.6793 - MSE: 0.0863 - cosine_similarity: 0.7657 - r_square: -2.5407 - val_loss: -0.6962 - val_MSE: 0.0894 - val_cosine_similarity: 0.7856 - val_r_square: -2.5930
# 2/2 [==============================] - 0s 114ms/step - loss: -0.6824 - MSE: 0.0885 - cosine_similarity: 0.7709 - r_square: -2.4145 - val_loss: -0.6969 - val_MSE: 0.0891 - val_cosine_similarity: 0.7859 - val_r_square: -2.5760
# 2/2 [==============================] - 0s 101ms/step - loss: -0.6629 - MSE: 0.0918 - cosine_similarity: 0.7546 - r_square: -2.2847 - val_loss: -0.6978 - val_MSE: 0.0884 - val_cosine_similarity: 0.7862 - val_r_square: -2.5425
# Epoch 8
# 2/2 [==============================] - 0s 109ms/step - loss: -0.6661 - MSE: 0.0909 - cosine_similarity: 0.7570 - r_square: -2.5669 - val_loss: -0.7000 - val_MSE: 0.0860 - val_cosine_similarity: 0.7860 - val_r_square: -2.3946
# 2/2 [==============================] - 0s 106ms/step - loss: -0.6924 - MSE: 0.0844 - cosine_similarity: 0.7768 - r_square: -2.2794 - val_loss: -0.7017 - val_MSE: 0.0847 - val_cosine_similarity: 0.7864 - val_r_square: -2.3372
# 2/2 [==============================] - 0s 107ms/step - loss: -0.6872 - MSE: 0.0810 - cosine_similarity: 0.7683 - r_square: -2.0912 - val_loss: -0.7036 - val_MSE: 0.0832 - val_cosine_similarity: 0.7868 - val_r_square: -2.2577
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7043 - MSE: 0.0769 - cosine_similarity: 0.7812 - r_square: -2.0968 - val_loss: -0.7070 - val_MSE: 0.0805 - val_cosine_similarity: 0.7874 - val_r_square: -2.1086
# 2/2 [==============================] - 0s 107ms/step - loss: -0.7050 - MSE: 0.0743 - cosine_similarity: 0.7793 - r_square: -2.1289 - val_loss: -0.7099 - val_MSE: 0.0781 - val_cosine_similarity: 0.7880 - val_r_square: -1.9773
# 2/2 [==============================] - 0s 121ms/step - loss: -0.6919 - MSE: 0.0752 - cosine_similarity: 0.7670 - r_square: -1.4402 - val_loss: -0.7114 - val_MSE: 0.0770 - val_cosine_similarity: 0.7884 - val_r_square: -1.9180
# Epoch 9
# 2/2 [==============================] - 0s 111ms/step - loss: -0.7122 - MSE: 0.0709 - cosine_similarity: 0.7831 - r_square: -1.8339 - val_loss: -0.7111 - val_MSE: 0.0773 - val_cosine_similarity: 0.7885 - val_r_square: -1.9321
# 2/2 [==============================] - 0s 104ms/step - loss: -0.6917 - MSE: 0.0778 - cosine_similarity: 0.7695 - r_square: -2.1832 - val_loss: -0.7101 - val_MSE: 0.0782 - val_cosine_similarity: 0.7883 - val_r_square: -1.9754
# 2/2 [==============================] - 0s 106ms/step - loss: -0.6971 - MSE: 0.0752 - cosine_similarity: 0.7724 - r_square: -2.0318 - val_loss: -0.7098 - val_MSE: 0.0785 - val_cosine_similarity: 0.7883 - val_r_square: -1.9871
# 2/2 [==============================] - 0s 94ms/step - loss: -0.6896 - MSE: 0.0800 - cosine_similarity: 0.7696 - r_square: -1.6944 - val_loss: -0.7099 - val_MSE: 0.0785 - val_cosine_similarity: 0.7884 - val_r_square: -1.9811
# 2/2 [==============================] - 0s 121ms/step - loss: -0.7119 - MSE: 0.0706 - cosine_similarity: 0.7825 - r_square: -1.6138 - val_loss: -0.7108 - val_MSE: 0.0777 - val_cosine_similarity: 0.7885 - val_r_square: -1.9419
# 2/2 [==============================] - 0s 120ms/step - loss: -0.6837 - MSE: 0.0794 - cosine_similarity: 0.7631 - r_square: -2.0947 - val_loss: -0.7122 - val_MSE: 0.0767 - val_cosine_similarity: 0.7889 - val_r_square: -1.8862
# Epoch 10
# 2/2 [==============================] - 0s 125ms/step - loss: -0.6839 - MSE: 0.0796 - cosine_similarity: 0.7635 - r_square: -1.7333 - val_loss: -0.7133 - val_MSE: 0.0766 - val_cosine_similarity: 0.7899 - val_r_square: -1.9110
# 2/2 [==============================] - 0s 105ms/step - loss: -0.7171 - MSE: 0.0706 - cosine_similarity: 0.7877 - r_square: -1.8190 - val_loss: -0.7140 - val_MSE: 0.0761 - val_cosine_similarity: 0.7901 - val_r_square: -1.8809
# 2/2 [==============================] - 0s 119ms/step - loss: -0.7050 - MSE: 0.0717 - cosine_similarity: 0.7767 - r_square: -1.6482 - val_loss: -0.7140 - val_MSE: 0.0762 - val_cosine_similarity: 0.7902 - val_r_square: -1.8827
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7192 - MSE: 0.0678 - cosine_similarity: 0.7870 - r_square: -1.9231 - val_loss: -0.7148 - val_MSE: 0.0756 - val_cosine_similarity: 0.7904 - val_r_square: -1.8514
# 2/2 [==============================] - 0s 108ms/step - loss: -0.7041 - MSE: 0.0726 - cosine_similarity: 0.7768 - r_square: -1.5671 - val_loss: -0.7157 - val_MSE: 0.0748 - val_cosine_similarity: 0.7905 - val_r_square: -1.8140
# 2/2 [==============================] - 0s 104ms/step - loss: -0.6928 - MSE: 0.0713 - cosine_similarity: 0.7641 - r_square: -1.2764 - val_loss: -0.7167 - val_MSE: 0.0739 - val_cosine_similarity: 0.7906 - val_r_square: -1.7672
# Epoch 11
# 2/2 [==============================] - 0s 115ms/step - loss: -0.7020 - MSE: 0.0721 - cosine_similarity: 0.7741 - r_square: -1.5318 - val_loss: -0.7174 - val_MSE: 0.0733 - val_cosine_similarity: 0.7907 - val_r_square: -1.7415
# 2/2 [==============================] - 0s 113ms/step - loss: -0.6850 - MSE: 0.0747 - cosine_similarity: 0.7597 - r_square: -1.5595 - val_loss: -0.7169 - val_MSE: 0.0738 - val_cosine_similarity: 0.7906 - val_r_square: -1.7720
# 2/2 [==============================] - 0s 101ms/step - loss: -0.6894 - MSE: 0.0759 - cosine_similarity: 0.7653 - r_square: -1.8683 - val_loss: -0.7161 - val_MSE: 0.0744 - val_cosine_similarity: 0.7906 - val_r_square: -1.8113
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7047 - MSE: 0.0722 - cosine_similarity: 0.7769 - r_square: -1.9530 - val_loss: -0.7151 - val_MSE: 0.0753 - val_cosine_similarity: 0.7904 - val_r_square: -1.8596
# 2/2 [==============================] - 0s 103ms/step - loss: -0.6914 - MSE: 0.0745 - cosine_similarity: 0.7659 - r_square: -1.4242 - val_loss: -0.7149 - val_MSE: 0.0755 - val_cosine_similarity: 0.7903 - val_r_square: -1.8743
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7168 - MSE: 0.0725 - cosine_similarity: 0.7893 - r_square: -1.9647 - val_loss: -0.7159 - val_MSE: 0.0746 - val_cosine_similarity: 0.7906 - val_r_square: -1.8350
# Epoch 12
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7245 - MSE: 0.0683 - cosine_similarity: 0.7928 - r_square: -1.9635 - val_loss: -0.7195 - val_MSE: 0.0722 - val_cosine_similarity: 0.7917 - val_r_square: -1.7095
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7142 - MSE: 0.0676 - cosine_similarity: 0.7818 - r_square: -1.4936 - val_loss: -0.7228 - val_MSE: 0.0694 - val_cosine_similarity: 0.7923 - val_r_square: -1.5726
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7071 - MSE: 0.0654 - cosine_similarity: 0.7725 - r_square: -1.1328 - val_loss: -0.7243 - val_MSE: 0.0682 - val_cosine_similarity: 0.7925 - val_r_square: -1.5165
# 2/2 [==============================] - 0s 100ms/step - loss: -0.6947 - MSE: 0.0688 - cosine_similarity: 0.7635 - r_square: -1.6098 - val_loss: -0.7240 - val_MSE: 0.0684 - val_cosine_similarity: 0.7924 - val_r_square: -1.5306
# 2/2 [==============================] - 0s 103ms/step - loss: -0.6797 - MSE: 0.0710 - cosine_similarity: 0.7507 - r_square: -1.2973 - val_loss: -0.7229 - val_MSE: 0.0692 - val_cosine_similarity: 0.7921 - val_r_square: -1.5756
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7184 - MSE: 0.0627 - cosine_similarity: 0.7812 - r_square: -1.1771 - val_loss: -0.7230 - val_MSE: 0.0691 - val_cosine_similarity: 0.7921 - val_r_square: -1.5713
# Epoch 13
# 2/2 [==============================] - 0s 94ms/step - loss: -0.7049 - MSE: 0.0629 - cosine_similarity: 0.7678 - r_square: -1.3881 - val_loss: -0.7219 - val_MSE: 0.0692 - val_cosine_similarity: 0.7911 - val_r_square: -1.5548
# 2/2 [==============================] - 0s 107ms/step - loss: -0.7017 - MSE: 0.0649 - cosine_similarity: 0.7666 - r_square: -1.0234 - val_loss: -0.7214 - val_MSE: 0.0696 - val_cosine_similarity: 0.7910 - val_r_square: -1.5752
# 2/2 [==============================] - 0s 101ms/step - loss: -0.6993 - MSE: 0.0681 - cosine_similarity: 0.7674 - r_square: -1.8077 - val_loss: -0.7215 - val_MSE: 0.0695 - val_cosine_similarity: 0.7910 - val_r_square: -1.5692
# 2/2 [==============================] - 0s 116ms/step - loss: -0.7110 - MSE: 0.0634 - cosine_similarity: 0.7744 - r_square: -1.1543 - val_loss: -0.7223 - val_MSE: 0.0689 - val_cosine_similarity: 0.7912 - val_r_square: -1.5382
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7236 - MSE: 0.0629 - cosine_similarity: 0.7865 - r_square: -1.1337 - val_loss: -0.7235 - val_MSE: 0.0680 - val_cosine_similarity: 0.7915 - val_r_square: -1.4916
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7144 - MSE: 0.0627 - cosine_similarity: 0.7771 - r_square: -1.6234 - val_loss: -0.7254 - val_MSE: 0.0666 - val_cosine_similarity: 0.7920 - val_r_square: -1.4256
# Epoch 14
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7125 - MSE: 0.0621 - cosine_similarity: 0.7746 - r_square: -1.0105 - val_loss: -0.7272 - val_MSE: 0.0654 - val_cosine_similarity: 0.7926 - val_r_square: -1.3865
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7228 - MSE: 0.0606 - cosine_similarity: 0.7835 - r_square: -1.3464 - val_loss: -0.7294 - val_MSE: 0.0637 - val_cosine_similarity: 0.7931 - val_r_square: -1.3058
# 2/2 [==============================] - 0s 114ms/step - loss: -0.7354 - MSE: 0.0572 - cosine_similarity: 0.7926 - r_square: -1.0525 - val_loss: -0.7306 - val_MSE: 0.0628 - val_cosine_similarity: 0.7934 - val_r_square: -1.2661
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7165 - MSE: 0.0571 - cosine_similarity: 0.7737 - r_square: -0.8088 - val_loss: -0.7303 - val_MSE: 0.0632 - val_cosine_similarity: 0.7935 - val_r_square: -1.2860
# 2/2 [==============================] - 0s 119ms/step - loss: -0.6990 - MSE: 0.0646 - cosine_similarity: 0.7636 - r_square: -1.1506 - val_loss: -0.7291 - val_MSE: 0.0643 - val_cosine_similarity: 0.7934 - val_r_square: -1.3411
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7201 - MSE: 0.0578 - cosine_similarity: 0.7779 - r_square: -1.2316 - val_loss: -0.7289 - val_MSE: 0.0647 - val_cosine_similarity: 0.7936 - val_r_square: -1.3596
# Epoch 15
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7139 - MSE: 0.0590 - cosine_similarity: 0.7729 - r_square: -1.0991 - val_loss: -0.7288 - val_MSE: 0.0649 - val_cosine_similarity: 0.7937 - val_r_square: -1.3535
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7121 - MSE: 0.0597 - cosine_similarity: 0.7718 - r_square: -1.0969 - val_loss: -0.7284 - val_MSE: 0.0653 - val_cosine_similarity: 0.7937 - val_r_square: -1.3762
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7172 - MSE: 0.0606 - cosine_similarity: 0.7778 - r_square: -1.1987 - val_loss: -0.7283 - val_MSE: 0.0653 - val_cosine_similarity: 0.7936 - val_r_square: -1.3796
# 2/2 [==============================] - 0s 114ms/step - loss: -0.7439 - MSE: 0.0553 - cosine_similarity: 0.7992 - r_square: -1.0943 - val_loss: -0.7295 - val_MSE: 0.0642 - val_cosine_similarity: 0.7938 - val_r_square: -1.3335
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7044 - MSE: 0.0648 - cosine_similarity: 0.7691 - r_square: -1.2550 - val_loss: -0.7310 - val_MSE: 0.0630 - val_cosine_similarity: 0.7940 - val_r_square: -1.2757
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7067 - MSE: 0.0634 - cosine_similarity: 0.7702 - r_square: -1.2254 - val_loss: -0.7315 - val_MSE: 0.0626 - val_cosine_similarity: 0.7941 - val_r_square: -1.2559
# Epoch 16
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7427 - MSE: 0.0561 - cosine_similarity: 0.7988 - r_square: -1.3157 - val_loss: -0.7326 - val_MSE: 0.0619 - val_cosine_similarity: 0.7944 - val_r_square: -1.2446
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7154 - MSE: 0.0577 - cosine_similarity: 0.7732 - r_square: -0.9650 - val_loss: -0.7335 - val_MSE: 0.0611 - val_cosine_similarity: 0.7946 - val_r_square: -1.2092
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7208 - MSE: 0.0598 - cosine_similarity: 0.7805 - r_square: -1.1370 - val_loss: -0.7326 - val_MSE: 0.0617 - val_cosine_similarity: 0.7942 - val_r_square: -1.2409
# 2/2 [==============================] - 0s 104ms/step - loss: -0.6777 - MSE: 0.0675 - cosine_similarity: 0.7452 - r_square: -1.1098 - val_loss: -0.7298 - val_MSE: 0.0637 - val_cosine_similarity: 0.7935 - val_r_square: -1.3413
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7173 - MSE: 0.0624 - cosine_similarity: 0.7797 - r_square: -1.6159 - val_loss: -0.7291 - val_MSE: 0.0641 - val_cosine_similarity: 0.7932 - val_r_square: -1.3671
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7267 - MSE: 0.0571 - cosine_similarity: 0.7838 - r_square: -1.0596 - val_loss: -0.7295 - val_MSE: 0.0638 - val_cosine_similarity: 0.7933 - val_r_square: -1.3503
# Epoch 17
# 2/2 [==============================] - 0s 112ms/step - loss: -0.7394 - MSE: 0.0554 - cosine_similarity: 0.7948 - r_square: -0.9557 - val_loss: -0.7319 - val_MSE: 0.0621 - val_cosine_similarity: 0.7940 - val_r_square: -1.2719
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7152 - MSE: 0.0588 - cosine_similarity: 0.7740 - r_square: -1.2234 - val_loss: -0.7349 - val_MSE: 0.0599 - val_cosine_similarity: 0.7948 - val_r_square: -1.1616
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7038 - MSE: 0.0595 - cosine_similarity: 0.7633 - r_square: -0.9047 - val_loss: -0.7376 - val_MSE: 0.0578 - val_cosine_similarity: 0.7954 - val_r_square: -1.0642
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7201 - MSE: 0.0547 - cosine_similarity: 0.7748 - r_square: -0.7466 - val_loss: -0.7390 - val_MSE: 0.0566 - val_cosine_similarity: 0.7956 - val_r_square: -1.0123
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7428 - MSE: 0.0472 - cosine_similarity: 0.7901 - r_square: -0.8069 - val_loss: -0.7391 - val_MSE: 0.0567 - val_cosine_similarity: 0.7958 - val_r_square: -1.0204
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7304 - MSE: 0.0512 - cosine_similarity: 0.7817 - r_square: -0.8117 - val_loss: -0.7383 - val_MSE: 0.0574 - val_cosine_similarity: 0.7957 - val_r_square: -1.0579
# Epoch 18
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7246 - MSE: 0.0534 - cosine_similarity: 0.7780 - r_square: -1.0996 - val_loss: -0.7371 - val_MSE: 0.0583 - val_cosine_similarity: 0.7953 - val_r_square: -1.0992
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7225 - MSE: 0.0560 - cosine_similarity: 0.7785 - r_square: -0.7509 - val_loss: -0.7366 - val_MSE: 0.0585 - val_cosine_similarity: 0.7951 - val_r_square: -1.1143
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7345 - MSE: 0.0529 - cosine_similarity: 0.7873 - r_square: -0.9171 - val_loss: -0.7362 - val_MSE: 0.0588 - val_cosine_similarity: 0.7950 - val_r_square: -1.1279
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7234 - MSE: 0.0601 - cosine_similarity: 0.7834 - r_square: -1.2098 - val_loss: -0.7355 - val_MSE: 0.0593 - val_cosine_similarity: 0.7947 - val_r_square: -1.1510
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7177 - MSE: 0.0577 - cosine_similarity: 0.7755 - r_square: -1.0109 - val_loss: -0.7350 - val_MSE: 0.0597 - val_cosine_similarity: 0.7947 - val_r_square: -1.1711
# 2/2 [==============================] - 0s 116ms/step - loss: -0.7273 - MSE: 0.0542 - cosine_similarity: 0.7815 - r_square: -0.8337 - val_loss: -0.7362 - val_MSE: 0.0589 - val_cosine_similarity: 0.7951 - val_r_square: -1.1369
# Epoch 19
# 2/2 [==============================] - 0s 93ms/step - loss: -0.7454 - MSE: 0.0515 - cosine_similarity: 0.7970 - r_square: -1.0442 - val_loss: -0.7390 - val_MSE: 0.0573 - val_cosine_similarity: 0.7964 - val_r_square: -1.0620
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7344 - MSE: 0.0526 - cosine_similarity: 0.7870 - r_square: -0.9296 - val_loss: -0.7413 - val_MSE: 0.0556 - val_cosine_similarity: 0.7969 - val_r_square: -0.9771
# 2/2 [==============================] - 0s 100ms/step - loss: -0.6998 - MSE: 0.0574 - cosine_similarity: 0.7572 - r_square: -1.0366 - val_loss: -0.7418 - val_MSE: 0.0552 - val_cosine_similarity: 0.7970 - val_r_square: -0.9584
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7412 - MSE: 0.0515 - cosine_similarity: 0.7927 - r_square: -0.8380 - val_loss: -0.7411 - val_MSE: 0.0557 - val_cosine_similarity: 0.7968 - val_r_square: -0.9853
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7357 - MSE: 0.0504 - cosine_similarity: 0.7861 - r_square: -0.7239 - val_loss: -0.7393 - val_MSE: 0.0570 - val_cosine_similarity: 0.7963 - val_r_square: -1.0447
# 2/2 [==============================] - 0s 102ms/step - loss: -0.6927 - MSE: 0.0606 - cosine_similarity: 0.7533 - r_square: -0.8970 - val_loss: -0.7368 - val_MSE: 0.0586 - val_cosine_similarity: 0.7954 - val_r_square: -1.1251
# Epoch 20
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7260 - MSE: 0.0568 - cosine_similarity: 0.7828 - r_square: -1.1059 - val_loss: -0.7341 - val_MSE: 0.0595 - val_cosine_similarity: 0.7936 - val_r_square: -1.1485
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7292 - MSE: 0.0511 - cosine_similarity: 0.7804 - r_square: -0.8588 - val_loss: -0.7333 - val_MSE: 0.0599 - val_cosine_similarity: 0.7932 - val_r_square: -1.1674
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7435 - MSE: 0.0546 - cosine_similarity: 0.7981 - r_square: -1.0306 - val_loss: -0.7336 - val_MSE: 0.0595 - val_cosine_similarity: 0.7931 - val_r_square: -1.1490
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7063 - MSE: 0.0577 - cosine_similarity: 0.7640 - r_square: -1.0376 - val_loss: -0.7347 - val_MSE: 0.0586 - val_cosine_similarity: 0.7933 - val_r_square: -1.1106
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7321 - MSE: 0.0533 - cosine_similarity: 0.7854 - r_square: -0.7604 - val_loss: -0.7367 - val_MSE: 0.0572 - val_cosine_similarity: 0.7938 - val_r_square: -1.0414
# 2/2 [==============================] - 0s 103ms/step - loss: -0.6973 - MSE: 0.0586 - cosine_similarity: 0.7559 - r_square: -1.0006 - val_loss: -0.7386 - val_MSE: 0.0557 - val_cosine_similarity: 0.7943 - val_r_square: -0.9728
# Epoch 21
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7221 - MSE: 0.0553 - cosine_similarity: 0.7775 - r_square: -1.0770 - val_loss: -0.7399 - val_MSE: 0.0546 - val_cosine_similarity: 0.7944 - val_r_square: -0.9249
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7074 - MSE: 0.0532 - cosine_similarity: 0.7607 - r_square: -0.5614 - val_loss: -0.7405 - val_MSE: 0.0541 - val_cosine_similarity: 0.7946 - val_r_square: -0.9037
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7378 - MSE: 0.0482 - cosine_similarity: 0.7859 - r_square: -0.7309 - val_loss: -0.7410 - val_MSE: 0.0537 - val_cosine_similarity: 0.7947 - val_r_square: -0.8863
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7265 - MSE: 0.0546 - cosine_similarity: 0.7811 - r_square: -0.9703 - val_loss: -0.7409 - val_MSE: 0.0537 - val_cosine_similarity: 0.7947 - val_r_square: -0.8881
# 2/2 [==============================] - 0s 125ms/step - loss: -0.7283 - MSE: 0.0528 - cosine_similarity: 0.7811 - r_square: -0.9413 - val_loss: -0.7414 - val_MSE: 0.0534 - val_cosine_similarity: 0.7948 - val_r_square: -0.8701
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7288 - MSE: 0.0525 - cosine_similarity: 0.7813 - r_square: -0.8789 - val_loss: -0.7415 - val_MSE: 0.0533 - val_cosine_similarity: 0.7948 - val_r_square: -0.8661
# Epoch 22
# 2/2 [==============================] - 0s 112ms/step - loss: -0.7315 - MSE: 0.0470 - cosine_similarity: 0.7785 - r_square: -0.7308 - val_loss: -0.7424 - val_MSE: 0.0532 - val_cosine_similarity: 0.7956 - val_r_square: -0.8836
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7178 - MSE: 0.0529 - cosine_similarity: 0.7708 - r_square: -0.6309 - val_loss: -0.7423 - val_MSE: 0.0532 - val_cosine_similarity: 0.7955 - val_r_square: -0.8868
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7261 - MSE: 0.0532 - cosine_similarity: 0.7793 - r_square: -0.7855 - val_loss: -0.7410 - val_MSE: 0.0542 - val_cosine_similarity: 0.7952 - val_r_square: -0.9345
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7365 - MSE: 0.0488 - cosine_similarity: 0.7852 - r_square: -0.7044 - val_loss: -0.7403 - val_MSE: 0.0547 - val_cosine_similarity: 0.7950 - val_r_square: -0.9572
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7310 - MSE: 0.0480 - cosine_similarity: 0.7790 - r_square: -0.7033 - val_loss: -0.7406 - val_MSE: 0.0545 - val_cosine_similarity: 0.7951 - val_r_square: -0.9474
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7423 - MSE: 0.0459 - cosine_similarity: 0.7882 - r_square: -0.7709 - val_loss: -0.7412 - val_MSE: 0.0541 - val_cosine_similarity: 0.7953 - val_r_square: -0.9293
# Epoch 23
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7193 - MSE: 0.0508 - cosine_similarity: 0.7701 - r_square: -0.6014 - val_loss: -0.7405 - val_MSE: 0.0540 - val_cosine_similarity: 0.7946 - val_r_square: -0.9086
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7352 - MSE: 0.0476 - cosine_similarity: 0.7828 - r_square: -0.5530 - val_loss: -0.7410 - val_MSE: 0.0537 - val_cosine_similarity: 0.7947 - val_r_square: -0.8952
# 2/2 [==============================] - 0s 87ms/step - loss: -0.7641 - MSE: 0.0462 - cosine_similarity: 0.8103 - r_square: -0.8821 - val_loss: -0.7423 - val_MSE: 0.0526 - val_cosine_similarity: 0.7948 - val_r_square: -0.8493
# 2/2 [==============================] - 0s 87ms/step - loss: -0.7323 - MSE: 0.0480 - cosine_similarity: 0.7803 - r_square: -0.7674 - val_loss: -0.7431 - val_MSE: 0.0519 - val_cosine_similarity: 0.7950 - val_r_square: -0.8197
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7084 - MSE: 0.0525 - cosine_similarity: 0.7609 - r_square: -0.6707 - val_loss: -0.7431 - val_MSE: 0.0519 - val_cosine_similarity: 0.7950 - val_r_square: -0.8197
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7361 - MSE: 0.0486 - cosine_similarity: 0.7846 - r_square: -0.8514 - val_loss: -0.7430 - val_MSE: 0.0519 - val_cosine_similarity: 0.7949 - val_r_square: -0.8210
# Epoch 24
# 2/2 [==============================] - 0s 111ms/step - loss: -0.7207 - MSE: 0.0533 - cosine_similarity: 0.7740 - r_square: -0.7710 - val_loss: -0.7423 - val_MSE: 0.0526 - val_cosine_similarity: 0.7949 - val_r_square: -0.8536
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7433 - MSE: 0.0500 - cosine_similarity: 0.7933 - r_square: -0.9853 - val_loss: -0.7417 - val_MSE: 0.0530 - val_cosine_similarity: 0.7947 - val_r_square: -0.8737
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7208 - MSE: 0.0488 - cosine_similarity: 0.7697 - r_square: -0.8106 - val_loss: -0.7411 - val_MSE: 0.0535 - val_cosine_similarity: 0.7946 - val_r_square: -0.8971
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7030 - MSE: 0.0554 - cosine_similarity: 0.7584 - r_square: -0.9271 - val_loss: -0.7398 - val_MSE: 0.0545 - val_cosine_similarity: 0.7943 - val_r_square: -0.9437
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7403 - MSE: 0.0492 - cosine_similarity: 0.7895 - r_square: -0.7083 - val_loss: -0.7384 - val_MSE: 0.0555 - val_cosine_similarity: 0.7940 - val_r_square: -0.9907
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7227 - MSE: 0.0523 - cosine_similarity: 0.7751 - r_square: -0.6967 - val_loss: -0.7375 - val_MSE: 0.0562 - val_cosine_similarity: 0.7937 - val_r_square: -1.0221
# Epoch 25
# 2/2 [==============================] - 0s 114ms/step - loss: -0.6819 - MSE: 0.0645 - cosine_similarity: 0.7465 - r_square: -1.3896 - val_loss: -0.7378 - val_MSE: 0.0567 - val_cosine_similarity: 0.7944 - val_r_square: -1.0641
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7560 - MSE: 0.0480 - cosine_similarity: 0.8039 - r_square: -0.7406 - val_loss: -0.7383 - val_MSE: 0.0562 - val_cosine_similarity: 0.7945 - val_r_square: -1.0424
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7259 - MSE: 0.0523 - cosine_similarity: 0.7781 - r_square: -0.8391 - val_loss: -0.7401 - val_MSE: 0.0548 - val_cosine_similarity: 0.7949 - val_r_square: -0.9781
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7320 - MSE: 0.0503 - cosine_similarity: 0.7823 - r_square: -0.7218 - val_loss: -0.7422 - val_MSE: 0.0532 - val_cosine_similarity: 0.7953 - val_r_square: -0.9025
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7312 - MSE: 0.0510 - cosine_similarity: 0.7822 - r_square: -0.7311 - val_loss: -0.7443 - val_MSE: 0.0515 - val_cosine_similarity: 0.7958 - val_r_square: -0.8286
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7435 - MSE: 0.0473 - cosine_similarity: 0.7908 - r_square: -0.8999 - val_loss: -0.7466 - val_MSE: 0.0498 - val_cosine_similarity: 0.7963 - val_r_square: -0.7499
# Epoch 26
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7316 - MSE: 0.0474 - cosine_similarity: 0.7789 - r_square: -0.7581 - val_loss: -0.7462 - val_MSE: 0.0499 - val_cosine_similarity: 0.7961 - val_r_square: -0.7566
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7260 - MSE: 0.0522 - cosine_similarity: 0.7782 - r_square: -0.6601 - val_loss: -0.7464 - val_MSE: 0.0498 - val_cosine_similarity: 0.7962 - val_r_square: -0.7545
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7157 - MSE: 0.0516 - cosine_similarity: 0.7673 - r_square: -0.7954 - val_loss: -0.7453 - val_MSE: 0.0507 - val_cosine_similarity: 0.7960 - val_r_square: -0.7954
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7107 - MSE: 0.0473 - cosine_similarity: 0.7580 - r_square: -0.5276 - val_loss: -0.7442 - val_MSE: 0.0516 - val_cosine_similarity: 0.7958 - val_r_square: -0.8388
# 2/2 [==============================] - 0s 87ms/step - loss: -0.7457 - MSE: 0.0447 - cosine_similarity: 0.7904 - r_square: -0.5506 - val_loss: -0.7444 - val_MSE: 0.0515 - val_cosine_similarity: 0.7959 - val_r_square: -0.8358
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7584 - MSE: 0.0436 - cosine_similarity: 0.8021 - r_square: -0.6382 - val_loss: -0.7446 - val_MSE: 0.0513 - val_cosine_similarity: 0.7959 - val_r_square: -0.8276
# Epoch 27
# 2/2 [==============================] - 0s 160ms/step - loss: -0.7383 - MSE: 0.0469 - cosine_similarity: 0.7852 - r_square: -0.6364 - val_loss: -0.7448 - val_MSE: 0.0513 - val_cosine_similarity: 0.7961 - val_r_square: -0.8287
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7223 - MSE: 0.0529 - cosine_similarity: 0.7752 - r_square: -0.8418 - val_loss: -0.7450 - val_MSE: 0.0510 - val_cosine_similarity: 0.7961 - val_r_square: -0.8193
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7376 - MSE: 0.0453 - cosine_similarity: 0.7828 - r_square: -0.6058 - val_loss: -0.7444 - val_MSE: 0.0514 - val_cosine_similarity: 0.7958 - val_r_square: -0.8386
# 2/2 [==============================] - 0s 119ms/step - loss: -0.7293 - MSE: 0.0470 - cosine_similarity: 0.7763 - r_square: -0.7091 - val_loss: -0.7436 - val_MSE: 0.0520 - val_cosine_similarity: 0.7956 - val_r_square: -0.8674
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7195 - MSE: 0.0531 - cosine_similarity: 0.7726 - r_square: -0.8145 - val_loss: -0.7430 - val_MSE: 0.0525 - val_cosine_similarity: 0.7955 - val_r_square: -0.8920
# 2/2 [==============================] - 0s 106ms/step - loss: -0.7296 - MSE: 0.0489 - cosine_similarity: 0.7785 - r_square: -0.7017 - val_loss: -0.7430 - val_MSE: 0.0526 - val_cosine_similarity: 0.7956 - val_r_square: -0.8958
# Epoch 28
# 2/2 [==============================] - 0s 95ms/step - loss: -0.6995 - MSE: 0.0568 - cosine_similarity: 0.7563 - r_square: -1.0103 - val_loss: -0.7428 - val_MSE: 0.0521 - val_cosine_similarity: 0.7949 - val_r_square: -0.8541
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7203 - MSE: 0.0516 - cosine_similarity: 0.7719 - r_square: -0.7795 - val_loss: -0.7428 - val_MSE: 0.0521 - val_cosine_similarity: 0.7949 - val_r_square: -0.8565
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7318 - MSE: 0.0474 - cosine_similarity: 0.7792 - r_square: -0.6658 - val_loss: -0.7428 - val_MSE: 0.0521 - val_cosine_similarity: 0.7949 - val_r_square: -0.8569
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7531 - MSE: 0.0442 - cosine_similarity: 0.7973 - r_square: -0.6395 - val_loss: -0.7438 - val_MSE: 0.0513 - val_cosine_similarity: 0.7950 - val_r_square: -0.8199
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7273 - MSE: 0.0488 - cosine_similarity: 0.7761 - r_square: -0.5225 - val_loss: -0.7451 - val_MSE: 0.0502 - val_cosine_similarity: 0.7953 - val_r_square: -0.7708
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7506 - MSE: 0.0456 - cosine_similarity: 0.7962 - r_square: -0.6463 - val_loss: -0.7465 - val_MSE: 0.0491 - val_cosine_similarity: 0.7955 - val_r_square: -0.7205
# Epoch 29
# 2/2 [==============================] - 0s 110ms/step - loss: -0.7473 - MSE: 0.0417 - cosine_similarity: 0.7890 - r_square: -0.5722 - val_loss: -0.7485 - val_MSE: 0.0481 - val_cosine_similarity: 0.7967 - val_r_square: -0.6956
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7201 - MSE: 0.0472 - cosine_similarity: 0.7673 - r_square: -0.5424 - val_loss: -0.7496 - val_MSE: 0.0473 - val_cosine_similarity: 0.7969 - val_r_square: -0.6568
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7381 - MSE: 0.0466 - cosine_similarity: 0.7847 - r_square: -0.6304 - val_loss: -0.7485 - val_MSE: 0.0481 - val_cosine_similarity: 0.7967 - val_r_square: -0.6929
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7517 - MSE: 0.0452 - cosine_similarity: 0.7969 - r_square: -0.5764 - val_loss: -0.7471 - val_MSE: 0.0492 - val_cosine_similarity: 0.7963 - val_r_square: -0.7438
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7337 - MSE: 0.0491 - cosine_similarity: 0.7828 - r_square: -0.8093 - val_loss: -0.7463 - val_MSE: 0.0497 - val_cosine_similarity: 0.7960 - val_r_square: -0.7677
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7347 - MSE: 0.0443 - cosine_similarity: 0.7790 - r_square: -0.4162 - val_loss: -0.7463 - val_MSE: 0.0496 - val_cosine_similarity: 0.7959 - val_r_square: -0.7639
# Epoch 30
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7510 - MSE: 0.0421 - cosine_similarity: 0.7931 - r_square: -0.5324 - val_loss: -0.7463 - val_MSE: 0.0493 - val_cosine_similarity: 0.7956 - val_r_square: -0.7355
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7325 - MSE: 0.0461 - cosine_similarity: 0.7786 - r_square: -0.7012 - val_loss: -0.7461 - val_MSE: 0.0494 - val_cosine_similarity: 0.7955 - val_r_square: -0.7428
# 2/2 [==============================] - 0s 119ms/step - loss: -0.7472 - MSE: 0.0433 - cosine_similarity: 0.7905 - r_square: -0.5875 - val_loss: -0.7465 - val_MSE: 0.0491 - val_cosine_similarity: 0.7956 - val_r_square: -0.7305
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7182 - MSE: 0.0489 - cosine_similarity: 0.7671 - r_square: -0.6039 - val_loss: -0.7477 - val_MSE: 0.0482 - val_cosine_similarity: 0.7958 - val_r_square: -0.6899
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7323 - MSE: 0.0458 - cosine_similarity: 0.7781 - r_square: -0.5329 - val_loss: -0.7491 - val_MSE: 0.0471 - val_cosine_similarity: 0.7962 - val_r_square: -0.6441
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7261 - MSE: 0.0489 - cosine_similarity: 0.7750 - r_square: -0.5231 - val_loss: -0.7500 - val_MSE: 0.0463 - val_cosine_similarity: 0.7964 - val_r_square: -0.6100
# Epoch 31
# 2/2 [==============================] - 0s 109ms/step - loss: -0.7246 - MSE: 0.0501 - cosine_similarity: 0.7747 - r_square: -0.8426 - val_loss: -0.7497 - val_MSE: 0.0466 - val_cosine_similarity: 0.7963 - val_r_square: -0.6191
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7356 - MSE: 0.0453 - cosine_similarity: 0.7809 - r_square: -0.5163 - val_loss: -0.7492 - val_MSE: 0.0470 - val_cosine_similarity: 0.7961 - val_r_square: -0.6369
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7317 - MSE: 0.0474 - cosine_similarity: 0.7791 - r_square: -0.6944 - val_loss: -0.7488 - val_MSE: 0.0473 - val_cosine_similarity: 0.7960 - val_r_square: -0.6519
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7399 - MSE: 0.0437 - cosine_similarity: 0.7837 - r_square: -0.5324 - val_loss: -0.7475 - val_MSE: 0.0483 - val_cosine_similarity: 0.7958 - val_r_square: -0.6957
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7291 - MSE: 0.0468 - cosine_similarity: 0.7759 - r_square: -0.6346 - val_loss: -0.7472 - val_MSE: 0.0485 - val_cosine_similarity: 0.7957 - val_r_square: -0.7081
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7449 - MSE: 0.0429 - cosine_similarity: 0.7877 - r_square: -0.4565 - val_loss: -0.7470 - val_MSE: 0.0486 - val_cosine_similarity: 0.7956 - val_r_square: -0.7131
# Epoch 32
# 2/2 [==============================] - 0s 109ms/step - loss: -0.7185 - MSE: 0.0487 - cosine_similarity: 0.7672 - r_square: -0.5511 - val_loss: -0.7483 - val_MSE: 0.0479 - val_cosine_similarity: 0.7962 - val_r_square: -0.6997
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7364 - MSE: 0.0453 - cosine_similarity: 0.7817 - r_square: -0.5010 - val_loss: -0.7491 - val_MSE: 0.0473 - val_cosine_similarity: 0.7964 - val_r_square: -0.6728
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7432 - MSE: 0.0446 - cosine_similarity: 0.7878 - r_square: -0.6008 - val_loss: -0.7498 - val_MSE: 0.0468 - val_cosine_similarity: 0.7966 - val_r_square: -0.6492
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7501 - MSE: 0.0453 - cosine_similarity: 0.7954 - r_square: -0.6482 - val_loss: -0.7511 - val_MSE: 0.0457 - val_cosine_similarity: 0.7969 - val_r_square: -0.6025
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7208 - MSE: 0.0443 - cosine_similarity: 0.7652 - r_square: -0.4288 - val_loss: -0.7518 - val_MSE: 0.0453 - val_cosine_similarity: 0.7971 - val_r_square: -0.5817
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7497 - MSE: 0.0437 - cosine_similarity: 0.7934 - r_square: -0.6905 - val_loss: -0.7513 - val_MSE: 0.0457 - val_cosine_similarity: 0.7970 - val_r_square: -0.6003
# Epoch 33
# 2/2 [==============================] - 0s 109ms/step - loss: -0.7412 - MSE: 0.0442 - cosine_similarity: 0.7854 - r_square: -0.5628 - val_loss: -0.7496 - val_MSE: 0.0466 - val_cosine_similarity: 0.7961 - val_r_square: -0.6245
# 2/2 [==============================] - 0s 118ms/step - loss: -0.7219 - MSE: 0.0506 - cosine_similarity: 0.7725 - r_square: -0.6611 - val_loss: -0.7480 - val_MSE: 0.0477 - val_cosine_similarity: 0.7957 - val_r_square: -0.6758
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7311 - MSE: 0.0473 - cosine_similarity: 0.7784 - r_square: -0.6500 - val_loss: -0.7473 - val_MSE: 0.0483 - val_cosine_similarity: 0.7956 - val_r_square: -0.7002
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7342 - MSE: 0.0489 - cosine_similarity: 0.7831 - r_square: -1.2176 - val_loss: -0.7472 - val_MSE: 0.0483 - val_cosine_similarity: 0.7955 - val_r_square: -0.7026
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7379 - MSE: 0.0471 - cosine_similarity: 0.7850 - r_square: -0.6629 - val_loss: -0.7474 - val_MSE: 0.0481 - val_cosine_similarity: 0.7955 - val_r_square: -0.6955
# 2/2 [==============================] - 0s 120ms/step - loss: -0.7302 - MSE: 0.0465 - cosine_similarity: 0.7767 - r_square: -0.6508 - val_loss: -0.7472 - val_MSE: 0.0482 - val_cosine_similarity: 0.7955 - val_r_square: -0.6995
# Epoch 34
# 2/2 [==============================] - 0s 119ms/step - loss: -0.7410 - MSE: 0.0454 - cosine_similarity: 0.7863 - r_square: -0.8154 - val_loss: -0.7474 - val_MSE: 0.0482 - val_cosine_similarity: 0.7955 - val_r_square: -0.6978
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7233 - MSE: 0.0501 - cosine_similarity: 0.7734 - r_square: -0.5480 - val_loss: -0.7479 - val_MSE: 0.0477 - val_cosine_similarity: 0.7956 - val_r_square: -0.6794
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7583 - MSE: 0.0396 - cosine_similarity: 0.7979 - r_square: -0.5157 - val_loss: -0.7490 - val_MSE: 0.0468 - val_cosine_similarity: 0.7958 - val_r_square: -0.6417
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7065 - MSE: 0.0545 - cosine_similarity: 0.7610 - r_square: -0.7087 - val_loss: -0.7504 - val_MSE: 0.0457 - val_cosine_similarity: 0.7961 - val_r_square: -0.5934
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7386 - MSE: 0.0463 - cosine_similarity: 0.7848 - r_square: -0.6510 - val_loss: -0.7517 - val_MSE: 0.0447 - val_cosine_similarity: 0.7964 - val_r_square: -0.5478
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7391 - MSE: 0.0430 - cosine_similarity: 0.7821 - r_square: -0.4368 - val_loss: -0.7517 - val_MSE: 0.0447 - val_cosine_similarity: 0.7964 - val_r_square: -0.5490
# Epoch 35
# 2/2 [==============================] - 0s 109ms/step - loss: -0.7473 - MSE: 0.0437 - cosine_similarity: 0.7910 - r_square: -0.5735 - val_loss: -0.7517 - val_MSE: 0.0453 - val_cosine_similarity: 0.7971 - val_r_square: -0.5954
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7457 - MSE: 0.0444 - cosine_similarity: 0.7901 - r_square: -0.5785 - val_loss: -0.7506 - val_MSE: 0.0462 - val_cosine_similarity: 0.7968 - val_r_square: -0.6310
# ...
# 2/2 [==============================] - 0s 114ms/step - loss: -0.7474 - MSE: 0.0378 - cosine_similarity: 0.7852 - r_square: -0.2854 - val_loss: -0.7602 - val_MSE: 0.0367 - val_cosine_similarity: 0.7970 - val_r_square: -0.2378
# 2/2 [==============================] - 0s 113ms/step - loss: -0.7595 - MSE: 0.0387 - cosine_similarity: 0.7982 - r_square: -0.3994 - val_loss: -0.7607 - val_MSE: 0.0364 - val_cosine_similarity: 0.7970 - val_r_square: -0.2221
# 2/2 [==============================] - 0s 117ms/step - loss: -0.7620 - MSE: 0.0391 - cosine_similarity: 0.8011 - r_square: -0.4421 - val_loss: -0.7608 - val_MSE: 0.0362 - val_cosine_similarity: 0.7970 - val_r_square: -0.2156
# 2/2 [==============================] - 0s 141ms/step - loss: -0.7316 - MSE: 0.0425 - cosine_similarity: 0.7741 - r_square: -0.2927 - val_loss: -0.7605 - val_MSE: 0.0365 - val_cosine_similarity: 0.7970 - val_r_square: -0.2256
# Epoch 89
# 2/2 [==============================] - 0s 145ms/step - loss: -0.7608 - MSE: 0.0346 - cosine_similarity: 0.7954 - r_square: -0.2286 - val_loss: -0.7608 - val_MSE: 0.0368 - val_cosine_similarity: 0.7976 - val_r_square: -0.2527
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7402 - MSE: 0.0431 - cosine_similarity: 0.7832 - r_square: -0.5043 - val_loss: -0.7606 - val_MSE: 0.0370 - val_cosine_similarity: 0.7976 - val_r_square: -0.2596
# 2/2 [==============================] - 0s 118ms/step - loss: -0.7445 - MSE: 0.0386 - cosine_similarity: 0.7831 - r_square: -0.0928 - val_loss: -0.7603 - val_MSE: 0.0373 - val_cosine_similarity: 0.7976 - val_r_square: -0.2750
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7481 - MSE: 0.0368 - cosine_similarity: 0.7849 - r_square: -0.2354 - val_loss: -0.7601 - val_MSE: 0.0376 - val_cosine_similarity: 0.7976 - val_r_square: -0.2853
# 2/2 [==============================] - 0s 113ms/step - loss: -0.7443 - MSE: 0.0393 - cosine_similarity: 0.7836 - r_square: -0.3828 - val_loss: -0.7598 - val_MSE: 0.0378 - val_cosine_similarity: 0.7976 - val_r_square: -0.2954
# 2/2 [==============================] - 0s 107ms/step - loss: -0.7491 - MSE: 0.0392 - cosine_similarity: 0.7883 - r_square: -0.3722 - val_loss: -0.7597 - val_MSE: 0.0379 - val_cosine_similarity: 0.7976 - val_r_square: -0.2990
# Epoch 90
# 2/2 [==============================] - 0s 105ms/step - loss: -0.7386 - MSE: 0.0427 - cosine_similarity: 0.7814 - r_square: -0.3697 - val_loss: -0.7584 - val_MSE: 0.0380 - val_cosine_similarity: 0.7965 - val_r_square: -0.2909
# 2/2 [==============================] - 0s 106ms/step - loss: -0.7292 - MSE: 0.0428 - cosine_similarity: 0.7720 - r_square: -0.3049 - val_loss: -0.7586 - val_MSE: 0.0379 - val_cosine_similarity: 0.7965 - val_r_square: -0.2861
# 2/2 [==============================] - 0s 111ms/step - loss: -0.7666 - MSE: 0.0361 - cosine_similarity: 0.8028 - r_square: -0.2897 - val_loss: -0.7591 - val_MSE: 0.0375 - val_cosine_similarity: 0.7966 - val_r_square: -0.2671
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7518 - MSE: 0.0364 - cosine_similarity: 0.7881 - r_square: -0.2916 - val_loss: -0.7597 - val_MSE: 0.0370 - val_cosine_similarity: 0.7967 - val_r_square: -0.2453
# 2/2 [==============================] - 0s 110ms/step - loss: -0.7349 - MSE: 0.0412 - cosine_similarity: 0.7761 - r_square: -0.2829 - val_loss: -0.7602 - val_MSE: 0.0366 - val_cosine_similarity: 0.7968 - val_r_square: -0.2264
# 2/2 [==============================] - 0s 107ms/step - loss: -0.7680 - MSE: 0.0377 - cosine_similarity: 0.8057 - r_square: -0.3381 - val_loss: -0.7606 - val_MSE: 0.0362 - val_cosine_similarity: 0.7968 - val_r_square: -0.2098
# Epoch 91
# 2/2 [==============================] - 0s 110ms/step - loss: -0.7291 - MSE: 0.0425 - cosine_similarity: 0.7716 - r_square: -0.2190 - val_loss: -0.7614 - val_MSE: 0.0362 - val_cosine_similarity: 0.7976 - val_r_square: -0.2236
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7543 - MSE: 0.0360 - cosine_similarity: 0.7903 - r_square: -0.2468 - val_loss: -0.7609 - val_MSE: 0.0366 - val_cosine_similarity: 0.7975 - val_r_square: -0.2410
# 2/2 [==============================] - 0s 107ms/step - loss: -0.7736 - MSE: 0.0333 - cosine_similarity: 0.8068 - r_square: -0.2510 - val_loss: -0.7603 - val_MSE: 0.0371 - val_cosine_similarity: 0.7974 - val_r_square: -0.2624
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7428 - MSE: 0.0393 - cosine_similarity: 0.7821 - r_square: -0.2944 - val_loss: -0.7600 - val_MSE: 0.0374 - val_cosine_similarity: 0.7973 - val_r_square: -0.2758
# 2/2 [==============================] - 0s 109ms/step - loss: -0.7685 - MSE: 0.0337 - cosine_similarity: 0.8022 - r_square: -0.1173 - val_loss: -0.7599 - val_MSE: 0.0375 - val_cosine_similarity: 0.7974 - val_r_square: -0.2801
# 2/2 [==============================] - 0s 105ms/step - loss: -0.7379 - MSE: 0.0409 - cosine_similarity: 0.7788 - r_square: -0.3532 - val_loss: -0.7602 - val_MSE: 0.0373 - val_cosine_similarity: 0.7974 - val_r_square: -0.2715
# Epoch 92
# 2/2 [==============================] - 0s 110ms/step - loss: -0.7574 - MSE: 0.0368 - cosine_similarity: 0.7942 - r_square: -0.2115 - val_loss: -0.7612 - val_MSE: 0.0368 - val_cosine_similarity: 0.7980 - val_r_square: -0.2485
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7491 - MSE: 0.0377 - cosine_similarity: 0.7867 - r_square: -0.2846 - val_loss: -0.7613 - val_MSE: 0.0367 - val_cosine_similarity: 0.7980 - val_r_square: -0.2470
# 2/2 [==============================] - 0s 122ms/step - loss: -0.7597 - MSE: 0.0348 - cosine_similarity: 0.7945 - r_square: -0.2849 - val_loss: -0.7611 - val_MSE: 0.0369 - val_cosine_similarity: 0.7980 - val_r_square: -0.2543
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7534 - MSE: 0.0405 - cosine_similarity: 0.7939 - r_square: -0.3696 - val_loss: -0.7612 - val_MSE: 0.0368 - val_cosine_similarity: 0.7980 - val_r_square: -0.2518
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7380 - MSE: 0.0413 - cosine_similarity: 0.7793 - r_square: -0.2560 - val_loss: -0.7615 - val_MSE: 0.0366 - val_cosine_similarity: 0.7981 - val_r_square: -0.2429
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7392 - MSE: 0.0412 - cosine_similarity: 0.7804 - r_square: -0.4461 - val_loss: -0.7621 - val_MSE: 0.0362 - val_cosine_similarity: 0.7983 - val_r_square: -0.2244
# Epoch 93
# 2/2 [==============================] - 0s 121ms/step - loss: -0.7375 - MSE: 0.0421 - cosine_similarity: 0.7795 - r_square: -0.3613 - val_loss: -0.7615 - val_MSE: 0.0361 - val_cosine_similarity: 0.7976 - val_r_square: -0.2190
# 2/2 [==============================] - 0s 106ms/step - loss: -0.7525 - MSE: 0.0380 - cosine_similarity: 0.7905 - r_square: -0.2596 - val_loss: -0.7620 - val_MSE: 0.0358 - val_cosine_similarity: 0.7978 - val_r_square: -0.2022
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7400 - MSE: 0.0402 - cosine_similarity: 0.7803 - r_square: -0.3079 - val_loss: -0.7623 - val_MSE: 0.0355 - val_cosine_similarity: 0.7978 - val_r_square: -0.1931
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7664 - MSE: 0.0371 - cosine_similarity: 0.8035 - r_square: -0.2769 - val_loss: -0.7623 - val_MSE: 0.0355 - val_cosine_similarity: 0.7978 - val_r_square: -0.1913
# 2/2 [==============================] - 0s 115ms/step - loss: -0.7472 - MSE: 0.0410 - cosine_similarity: 0.7882 - r_square: -0.4952 - val_loss: -0.7620 - val_MSE: 0.0358 - val_cosine_similarity: 0.7977 - val_r_square: -0.2029
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7473 - MSE: 0.0403 - cosine_similarity: 0.7876 - r_square: -0.4321 - val_loss: -0.7614 - val_MSE: 0.0362 - val_cosine_similarity: 0.7976 - val_r_square: -0.2227
# Epoch 94
# 2/2 [==============================] - 0s 111ms/step - loss: -0.7337 - MSE: 0.0411 - cosine_similarity: 0.7748 - r_square: -0.3127 - val_loss: -0.7604 - val_MSE: 0.0366 - val_cosine_similarity: 0.7970 - val_r_square: -0.2280
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7639 - MSE: 0.0357 - cosine_similarity: 0.7996 - r_square: -0.3269 - val_loss: -0.7601 - val_MSE: 0.0368 - val_cosine_similarity: 0.7969 - val_r_square: -0.2396
# 2/2 [==============================] - 0s 114ms/step - loss: -0.7594 - MSE: 0.0369 - cosine_similarity: 0.7962 - r_square: -0.4856 - val_loss: -0.7602 - val_MSE: 0.0367 - val_cosine_similarity: 0.7969 - val_r_square: -0.2357
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7457 - MSE: 0.0402 - cosine_similarity: 0.7858 - r_square: -0.3508 - val_loss: -0.7607 - val_MSE: 0.0364 - val_cosine_similarity: 0.7970 - val_r_square: -0.2202
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7759 - MSE: 0.0329 - cosine_similarity: 0.8088 - r_square: -0.1144 - val_loss: -0.7610 - val_MSE: 0.0361 - val_cosine_similarity: 0.7971 - val_r_square: -0.2074
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7307 - MSE: 0.0437 - cosine_similarity: 0.7743 - r_square: -0.2123 - val_loss: -0.7612 - val_MSE: 0.0359 - val_cosine_similarity: 0.7971 - val_r_square: -0.2008
# Epoch 95
# 2/2 [==============================] - 0s 120ms/step - loss: -0.7539 - MSE: 0.0391 - cosine_similarity: 0.7930 - r_square: -0.3255 - val_loss: -0.7629 - val_MSE: 0.0358 - val_cosine_similarity: 0.7987 - val_r_square: -0.2124
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7345 - MSE: 0.0377 - cosine_similarity: 0.7722 - r_square: -0.2111 - val_loss: -0.7626 - val_MSE: 0.0361 - val_cosine_similarity: 0.7987 - val_r_square: -0.2242
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7625 - MSE: 0.0377 - cosine_similarity: 0.8002 - r_square: -0.4070 - val_loss: -0.7624 - val_MSE: 0.0363 - val_cosine_similarity: 0.7987 - val_r_square: -0.2343
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7587 - MSE: 0.0371 - cosine_similarity: 0.7958 - r_square: -0.3002 - val_loss: -0.7623 - val_MSE: 0.0364 - val_cosine_similarity: 0.7987 - val_r_square: -0.2385
# 2/2 [==============================] - 0s 119ms/step - loss: -0.7404 - MSE: 0.0422 - cosine_similarity: 0.7826 - r_square: -0.3126 - val_loss: -0.7624 - val_MSE: 0.0363 - val_cosine_similarity: 0.7988 - val_r_square: -0.2368
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7514 - MSE: 0.0415 - cosine_similarity: 0.7929 - r_square: -0.2461 - val_loss: -0.7629 - val_MSE: 0.0361 - val_cosine_similarity: 0.7990 - val_r_square: -0.2287
# Epoch 96
# 2/2 [==============================] - 0s 111ms/step - loss: -0.7615 - MSE: 0.0355 - cosine_similarity: 0.7970 - r_square: -0.2828 - val_loss: -0.7612 - val_MSE: 0.0363 - val_cosine_similarity: 0.7975 - val_r_square: -0.2199
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7627 - MSE: 0.0357 - cosine_similarity: 0.7984 - r_square: -0.1249 - val_loss: -0.7612 - val_MSE: 0.0363 - val_cosine_similarity: 0.7975 - val_r_square: -0.2185
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7375 - MSE: 0.0411 - cosine_similarity: 0.7786 - r_square: -0.4048 - val_loss: -0.7610 - val_MSE: 0.0364 - val_cosine_similarity: 0.7974 - val_r_square: -0.2226
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7535 - MSE: 0.0393 - cosine_similarity: 0.7928 - r_square: -0.2231 - val_loss: -0.7609 - val_MSE: 0.0364 - val_cosine_similarity: 0.7973 - val_r_square: -0.2222
# 2/2 [==============================] - 0s 108ms/step - loss: -0.7349 - MSE: 0.0414 - cosine_similarity: 0.7763 - r_square: -0.2630 - val_loss: -0.7609 - val_MSE: 0.0363 - val_cosine_similarity: 0.7972 - val_r_square: -0.2189
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7503 - MSE: 0.0373 - cosine_similarity: 0.7876 - r_square: -0.3423 - val_loss: -0.7611 - val_MSE: 0.0361 - val_cosine_similarity: 0.7973 - val_r_square: -0.2102
# Epoch 97
# 2/2 [==============================] - 0s 111ms/step - loss: -0.7174 - MSE: 0.0423 - cosine_similarity: 0.7597 - r_square: -0.2183 - val_loss: -0.7627 - val_MSE: 0.0359 - val_cosine_similarity: 0.7986 - val_r_square: -0.2163
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7622 - MSE: 0.0357 - cosine_similarity: 0.7979 - r_square: -0.3276 - val_loss: -0.7633 - val_MSE: 0.0355 - val_cosine_similarity: 0.7988 - val_r_square: -0.1995
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7501 - MSE: 0.0383 - cosine_similarity: 0.7885 - r_square: -0.2791 - val_loss: -0.7639 - val_MSE: 0.0350 - val_cosine_similarity: 0.7990 - val_r_square: -0.1798
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7484 - MSE: 0.0395 - cosine_similarity: 0.7879 - r_square: -0.2499 - val_loss: -0.7639 - val_MSE: 0.0351 - val_cosine_similarity: 0.7990 - val_r_square: -0.1805
# 2/2 [==============================] - 0s 109ms/step - loss: -0.7526 - MSE: 0.0381 - cosine_similarity: 0.7907 - r_square: -0.3756 - val_loss: -0.7635 - val_MSE: 0.0355 - val_cosine_similarity: 0.7990 - val_r_square: -0.1979
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7662 - MSE: 0.0384 - cosine_similarity: 0.8046 - r_square: -0.3909 - val_loss: -0.7630 - val_MSE: 0.0359 - val_cosine_similarity: 0.7989 - val_r_square: -0.2166
# Epoch 98
# 2/2 [==============================] - 0s 108ms/step - loss: -0.7378 - MSE: 0.0399 - cosine_similarity: 0.7776 - r_square: -0.2106 - val_loss: -0.7610 - val_MSE: 0.0365 - val_cosine_similarity: 0.7974 - val_r_square: -0.2250
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7546 - MSE: 0.0373 - cosine_similarity: 0.7919 - r_square: -0.1758 - val_loss: -0.7603 - val_MSE: 0.0370 - val_cosine_similarity: 0.7974 - val_r_square: -0.2482
# 2/2 [==============================] - 0s 110ms/step - loss: -0.7370 - MSE: 0.0401 - cosine_similarity: 0.7770 - r_square: -0.1922 - val_loss: -0.7599 - val_MSE: 0.0374 - val_cosine_similarity: 0.7973 - val_r_square: -0.2647
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7795 - MSE: 0.0327 - cosine_similarity: 0.8122 - r_square: -0.2283 - val_loss: -0.7599 - val_MSE: 0.0375 - val_cosine_similarity: 0.7974 - val_r_square: -0.2675
# 2/2 [==============================] - 0s 107ms/step - loss: -0.7538 - MSE: 0.0380 - cosine_similarity: 0.7918 - r_square: -0.4108 - val_loss: -0.7603 - val_MSE: 0.0373 - val_cosine_similarity: 0.7975 - val_r_square: -0.2583
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7568 - MSE: 0.0390 - cosine_similarity: 0.7958 - r_square: -0.3727 - val_loss: -0.7609 - val_MSE: 0.0368 - val_cosine_similarity: 0.7977 - val_r_square: -0.2392
# Epoch 99
# 2/2 [==============================] - 0s 112ms/step - loss: -0.7523 - MSE: 0.0381 - cosine_similarity: 0.7904 - r_square: -0.2503 - val_loss: -0.7619 - val_MSE: 0.0364 - val_cosine_similarity: 0.7983 - val_r_square: -0.2225
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7450 - MSE: 0.0375 - cosine_similarity: 0.7825 - r_square: -0.2447 - val_loss: -0.7620 - val_MSE: 0.0363 - val_cosine_similarity: 0.7982 - val_r_square: -0.2150
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7614 - MSE: 0.0376 - cosine_similarity: 0.7991 - r_square: -0.4002 - val_loss: -0.7623 - val_MSE: 0.0359 - val_cosine_similarity: 0.7982 - val_r_square: -0.2005
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7532 - MSE: 0.0380 - cosine_similarity: 0.7913 - r_square: -0.3457 - val_loss: -0.7623 - val_MSE: 0.0359 - val_cosine_similarity: 0.7981 - val_r_square: -0.1982
# 2/2 [==============================] - 0s 111ms/step - loss: -0.7538 - MSE: 0.0376 - cosine_similarity: 0.7914 - r_square: -0.2572 - val_loss: -0.7623 - val_MSE: 0.0358 - val_cosine_similarity: 0.7981 - val_r_square: -0.1925
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7405 - MSE: 0.0386 - cosine_similarity: 0.7790 - r_square: -0.1327 - val_loss: -0.7625 - val_MSE: 0.0356 - val_cosine_similarity: 0.7981 - val_r_square: -0.1850

# %%
# %matplotlib inline

metrics = ["MSE", "cosine similarity", "r2"] #Choose between 'loss', 'MSE', 'cosine similarity', 'r2'

metrics_dict = {"loss": ["loss", "val_loss"], "MSE": ["MSE", "val_MSE"], 
                "cosine similarity": ["cosine_similarity", "val_cosine_similarity"],
               "r2" : ["r_square", "val_r_square"]}

import matplotlib.pyplot as plt
try: history_df = history_df.reset_index()
except: pass

for metric in metrics:
    fig, ax = plt.subplots(figsize=(15,4),nrows=1, ncols=1)
    ax.set_ylabel(f"{metric}")
    ax.set_xlabel("Training time")
    fig.suptitle(f"History of {metric} in training time")

    train_plot = history_df.plot(y=metrics_dict[metric][0], use_index=True, ax=ax, label="Training")
    val_plot = history_df.plot(y=metrics_dict[metric][1], use_index=True, ax=ax, label="Validation")

    plt.show()

# %% [markdown]
# ## Evaluation of the results

# %%
val_ds = validation_dataset.shuffle(n_test).batch(n_test)
x_val, y_val, length_val = next(iter(val_ds))
x_val, y_val = slice_accordingly(x_val, y_val)
    

y_pred = model.predict(x_val)
y_true = y_val

# %%
def plot_epsilon_error(y_true, y_pred):
    
    N = len(y_true)
    
    cdf_abs_error = {}
    abs_error = np.abs(y_true - y_pred)
    
    fig, ax = plt.subplots(figsize=(12,6),nrows=1, ncols=2)
    ax[0].set_ylabel("Fraction of samples")
    ax[0].set_xlabel("Allowed absolute error")
    ax[0].set_title(f"CDF of the absolute error for different emotions")
    
    ax[0].set_ylim([0,1])
    
    for i, emotion in enumerate(emotions):
        abs_error_emotion = np.sort(abs_error[:,i])
        X2 = np.sort(abs_error_emotion)
        F2 = np.array(range(N))/(float(N))
        
        cdf_abs_error[emotion] = [X2, F2]
        
        ax[0].plot(X2, F2, label=emotion)
        
    ax[0].legend()
    ax[0].grid()
    
    cdf_cosine_sim = {}
    cos_sim = np.array([np.dot(y_true[i], y_pred[i])/(np.linalg.norm(y_true[i])*np.linalg.norm(y_pred[i])) for i in range(N)])
    cos_error = 1-cos_sim
    
    X2 = np.sort(cos_error)
    F2 = np.array(range(N))/(float(N))

    ax[1].set_ylabel(f"Fraction of samples", rotation=-90, labelpad=15)
    ax[1].yaxis.set_label_position("right")
    ax[1].yaxis.tick_right()
    ax[1].set_xlabel("Allowed cosine error")
    ax[1].set_title(f"CDF of the cosine error")
    
    ax[1].set_ylim([0,1])
    
    ax[1].plot(X2, F2)
    ax[1].grid()
    return cdf_abs_error

# %%
epsilon_error = plot_epsilon_error(y_true, y_pred)

x = epsilon_error["amazement"]
plt.show()

# %% [markdown]
# ## "Cross-validation"

# %%
def custom_loss(y_true, y_pred):
    cos_sim = tf.keras.losses.CosineSimilarity() 
    MSE = tf.keras.losses.MeanSquaredError()
        
    return cos_sim(y_true, y_pred) + MSE(y_true, y_pred)

# %%
from sklearn.model_selection import KFold


n_splits = 5
kf = KFold(n_splits=n_splits)

predictions_and_labels = {}


count = 0
for train_index, test_index in kf.split(MFCCs_raw):
    
    print(f"Training K-fold {1+count} of {n_splits}")

    train_features, train_labels = MFCCs_raw[train_index], labels_raw[train_index]
    validation_features, validation_labels = MFCCs_raw[test_index], labels_raw[test_index]

    train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels))
    validation_dataset = tf.data.Dataset.from_tensor_slices((validation_features, validation_labels))
    
    sample_size = (20, 50, 1)
    drop_out_rate = 0.4

    input_tensor = Input(sample_size)
    x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(input_tensor)
    x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(x)
    x = layers.Dropout(drop_out_rate)(x)
    x = layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)
    x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(x)
    x = layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)
    x = layers.Flatten()(x)
    x = layers.Dense(20, activation="relu")(x)
    x = layers.Flatten()(x)
    x = layers.Dropout(drop_out_rate)(x)
    output_tensor = layers.Dense(9, activation="sigmoid")(x)

    model = tf.keras.Model(input_tensor, output_tensor)
        
    model.compile(optimizer="adam",
                  #loss = tf.keras.losses.LogCosh(),
                  loss= custom_loss,
                  metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
    n_epochs = 100
    batch_size = 50
    
    for epoch in range(n_epochs):
        train_ds = train_dataset.shuffle(n_train).batch(batch_size)
        for features, labels in train_ds:
            features, labels = slice_accordingly(features, labels)
            model.fit(features, labels, verbose=0)
            
    val_ds = validation_dataset.shuffle(n_test).batch(n_test)
    x_val, y_val = next(iter(val_ds))
    x_val, y_val = slice_accordingly(x_val, y_val)

            
    predictions_and_labels[count] = [model.predict(x_val), y_val]
    count = count+1
# Out:
# Training K-fold 1 of 5
# Training K-fold 2 of 5
# Training K-fold 3 of 5
# Training K-fold 4 of 5
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001B5B8AAA400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Training K-fold 5 of 5
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001B5B8AAA048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
predictions = []
labels = []

for i in range(max(predictions_and_labels.keys())+1):
    predictions.append(predictions_and_labels[i][0])
    labels.append(predictions_and_labels[i][1])

predictions = np.concatenate(predictions)
labels = np.concatenate(labels)
epsilon_error = plot_epsilon_error(labels, predictions)

plt.show()

# %%
cos_sim = []
r2 = []
MSE = []

cos_sim_function = tf.keras.metrics.CosineSimilarity() 
MSE_function = tf.keras.metrics.MeanSquaredError()
r2_function = tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))

for i in range(max(predictions_and_labels.keys())+1):
    y_pred = predictions_and_labels[i][0]
    y_true = predictions_and_labels[i][1]
    
    cos_sim.append(cos_sim_function(y_true, y_pred).numpy())
    r2.append(r2_function(y_true, y_pred).numpy())
    MSE.append(MSE_function(y_true, y_pred).numpy())
    
print(f"The cosine similarity is approximately {np.mean(cos_sim):.5f}±{np.std(cos_sim):.5f}")
print(f"The MSE is approximately {np.mean(MSE):.5f}±{np.std(MSE):.5f}")
print(f"The R2 score is approximately {np.mean(r2):.5f}±{np.std(r2):.5f}")
# Out:
# The cosine similarity is approximately 0.78626±0.00116
# The MSE is approximately 0.03711±0.00056
# The R2 score is approximately -0.21222±0.00658
