# %% [markdown]
# # Emotion Recognition: MFCCs_CNN.ipynb
#
# Model trained on *simple features* that aims at predicting the *emotion labels*.
#
# The approach consists on getting the arrays of MFCCs (in *preprocessing*) and train a *Convolutional Neural Network* with *Tensorflow*.
# The problem is treated as a *regression* problem, where the loss function can be chosen between *mean squared error*, *-cosine similarity*, or *both*, being a combination of both losses with equal weight. The results shown are using "*both*".

# %%
import numpy as np
import pandas as pd
import os

import tensorflow as tf
import tensorflow_addons as tfa

# %%
MFCCs = np.load("../preprocessing/MFCCs/MFCC.npy")
MFCCs = (MFCCs - np.nanmean(MFCCs))/np.nanstd(MFCCs)

# %%
info_songs = pd.read_csv("../data/Info/info.csv")
label_songs = pd.read_csv("../preprocessing/labels.csv")

# %%
# Retrieve emotions from the labels.csv file

emotions = ["amazement", "solemnity", "tenderness", "nostalgia", "calmness", 
            "power", "joyful_activation", "tension", "sadness"]

labels = label_songs[emotions]
labels = labels.to_numpy()

length_songs = pd.DataFrame(info_songs["Track ID"])
length_songs["Song length"] = info_songs["Duration"]*10
length_songs["Song length"] = length_songs["Song length"].astype(int)

# %%
n_data = len(length_songs)
idx = np.random.permutation(n_data)
length_songs = length_songs.reindex(idx)["Song length"].to_numpy()
MFCCs_raw = MFCCs[idx, :, :]
labels_raw = labels[idx]

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras import Input, layers
from tensorflow.keras import backend as K

sample_size = (20, 50, 1)

drop_out_rate = 0.4

# very simple keras Sequential model
input_tensor = Input(sample_size)
x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(input_tensor)
x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(x)
x = layers.Dropout(drop_out_rate)(x)
x = layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)
x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(x)
x = layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)
x = layers.Flatten()(x)
x = layers.Dense(20, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(drop_out_rate)(x)
output_tensor = layers.Dense(9, activation="sigmoid")(x)

model_1 = tf.keras.Model(input_tensor, output_tensor)
model_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 20, 50, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 18, 48, 16)        160
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 46, 16)        2320
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 46, 16)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 7, 22, 16)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 20, 16)         2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 9, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 288)               0
# _________________________________________________________________
# dense (Dense)                (None, 20)                5780
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 20)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 189
# =================================================================
# Total params: 10,769
# Trainable params: 10,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = model_1

loss = "MSE"
#loss = "CosineSimilarity"
loss = "both"
loss = "KLDivergence"
loss = "RSquare"
loss = "LogCosh"

if loss == "MSE":
    model.compile(optimizer="adam",
                  loss=tf.keras.losses.MeanSquaredError(),
                  metrics=["cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "CosineSimilarity":
    model.compile(optimizer="adam",
                  loss= tf.keras.losses.CosineSimilarity(),
                  metrics=["MSE", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "both":
    def custom_loss(y_true, y_pred):
        cos_sim = tf.keras.losses.CosineSimilarity() 
        MSE = tf.keras.losses.MeanSquaredError()
        return cos_sim(y_true, y_pred) + MSE(y_true, y_pred)
    
    model.compile(optimizer="adam",
                loss= custom_loss,
                metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])

elif loss == "KLDivergence":
    model.compile(optimizer="adam",
                loss = tf.keras.losses.KLDivergence(),
                metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "RSquare":
    def rsquare_loss(y_true, y_pred):
        metric = tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))
        return -metric(y_true, y_pred)
    
    model.compile(optimizer="adam",
                loss = tf.keras.losses.KLDivergence(),
                metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "LogCosh":
    model.compile(optimizer="adam",
                loss =  tf.keras.losses.LogCosh(),
                metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])

# %%
def slice_accordingly(input_tensor, labels, size=sample_size):

    input_shape = (tf.shape(input_tensor).numpy())
    
    input_shape[1], input_shape[2] = size[0], size[1]
    size = input_shape
    
    sliced_tensor = tf.image.random_crop(input_tensor, size)
    
    nan_values, idx = tf.unique(tf.gather(tf.where(tf.math.is_nan(sliced_tensor)), 0, axis=1))
    nan_values = nan_values.numpy()
  
    msk = np.zeros((input_shape[0]), dtype=np.bool)
    msk[nan_values] = True
    msk = ~msk

    sliced_tensor = tf.boolean_mask(sliced_tensor, msk , axis=0)
    labels = tf.boolean_mask(labels , msk, axis=0)
    
    return sliced_tensor, labels

# %%
fraction_validation = 0.25
n_test = int(fraction_validation*len(labels))
n_train = len(labels) - n_test

train_features, train_labels, train_length = MFCCs_raw[:n_train], labels_raw[:n_train], length_songs[:n_train]
validation_features, validation_labels, validation_length = MFCCs_raw[n_train:], labels_raw[n_train:], length_songs[n_train:]

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels, train_length))
validation_dataset = tf.data.Dataset.from_tensor_slices((validation_features, validation_labels, validation_length))

# %%
n_epochs = 100
batch_size = 50

history_df = pd.DataFrame()

for epoch in range(n_epochs):
    print("Epoch", epoch)
    train_ds = train_dataset.shuffle(n_train).batch(batch_size)
    val_ds = validation_dataset.shuffle(n_test).batch(n_test)
    
    x_val, y_val, length_val = next(iter(val_ds))
    x_val, y_val = slice_accordingly(x_val, y_val)
    
    for features, labels, lengths in train_ds:
        features, labels = slice_accordingly(features, labels)
        
        history = model.fit(features, labels,
                           validation_data=(x_val, y_val),verbose=1)
        history = pd.DataFrame(history.history)
        history_df = history_df.append(history)
# Out:
# Epoch 0
# 2/2 [==============================] - 0s 146ms/step - loss: 0.0271 - MSE: 0.0555 - cosine_similarity: 0.6953 - r_square: -0.9458 - val_loss: 0.0229 - val_MSE: 0.0465 - val_cosine_similarity: 0.7711 - val_r_square: -0.8084
# 2/2 [==============================] - 0s 183ms/step - loss: 0.0220 - MSE: 0.0448 - cosine_similarity: 0.7408 - r_square: -0.7216 - val_loss: 0.0232 - val_MSE: 0.0472 - val_cosine_similarity: 0.7715 - val_r_square: -0.8346
# 2/2 [==============================] - 0s 149ms/step - loss: 0.0231 - MSE: 0.0472 - cosine_similarity: 0.7321 - r_square: -0.9226 - val_loss: 0.0236 - val_MSE: 0.0479 - val_cosine_similarity: 0.7718 - val_r_square: -0.8643
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0239 - MSE: 0.0490 - cosine_similarity: 0.7372 - r_square: -0.9287 - val_loss: 0.0237 - val_MSE: 0.0482 - val_cosine_similarity: 0.7717 - val_r_square: -0.8766
# 2/2 [==============================] - 0s 129ms/step - loss: 0.0224 - MSE: 0.0456 - cosine_similarity: 0.7403 - r_square: -0.7712 - val_loss: 0.0235 - val_MSE: 0.0478 - val_cosine_similarity: 0.7718 - val_r_square: -0.8504
# Epoch 5
# 2/2 [==============================] - 0s 155ms/step - loss: 0.0256 - MSE: 0.0523 - cosine_similarity: 0.7205 - r_square: -0.7311 - val_loss: 0.0235 - val_MSE: 0.0478 - val_cosine_similarity: 0.7703 - val_r_square: -0.8543
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0221 - MSE: 0.0450 - cosine_similarity: 0.7263 - r_square: -0.5764 - val_loss: 0.0233 - val_MSE: 0.0474 - val_cosine_similarity: 0.7704 - val_r_square: -0.8241
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0223 - MSE: 0.0456 - cosine_similarity: 0.7518 - r_square: -0.7012 - val_loss: 0.0232 - val_MSE: 0.0472 - val_cosine_similarity: 0.7706 - val_r_square: -0.8080
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0227 - MSE: 0.0463 - cosine_similarity: 0.7299 - r_square: -0.6852 - val_loss: 0.0232 - val_MSE: 0.0471 - val_cosine_similarity: 0.7709 - val_r_square: -0.7959
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0212 - MSE: 0.0434 - cosine_similarity: 0.7453 - r_square: -1.0121 - val_loss: 0.0231 - val_MSE: 0.0469 - val_cosine_similarity: 0.7712 - val_r_square: -0.7808
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0235 - MSE: 0.0480 - cosine_similarity: 0.7352 - r_square: -0.9009 - val_loss: 0.0229 - val_MSE: 0.0464 - val_cosine_similarity: 0.7710 - val_r_square: -0.7588
# Epoch 6
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0219 - MSE: 0.0448 - cosine_similarity: 0.7525 - r_square: -0.6965 - val_loss: 0.0221 - val_MSE: 0.0448 - val_cosine_similarity: 0.7716 - val_r_square: -0.6820
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0216 - MSE: 0.0442 - cosine_similarity: 0.7410 - r_square: -0.6725 - val_loss: 0.0215 - val_MSE: 0.0436 - val_cosine_similarity: 0.7740 - val_r_square: -0.5860
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0234 - MSE: 0.0479 - cosine_similarity: 0.7198 - r_square: -0.6514 - val_loss: 0.0215 - val_MSE: 0.0435 - val_cosine_similarity: 0.7738 - val_r_square: -0.5900
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0198 - MSE: 0.0403 - cosine_similarity: 0.7414 - r_square: -0.6067 - val_loss: 0.0214 - val_MSE: 0.0435 - val_cosine_similarity: 0.7739 - val_r_square: -0.5888
# 2/2 [==============================] - 0s 96ms/step - loss: 0.0238 - MSE: 0.0486 - cosine_similarity: 0.7274 - r_square: -0.8374 - val_loss: 0.0212 - val_MSE: 0.0430 - val_cosine_similarity: 0.7741 - val_r_square: -0.5653
# Epoch 9
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0212 - MSE: 0.0434 - cosine_similarity: 0.7467 - r_square: -0.7300 - val_loss: 0.0207 - val_MSE: 0.0421 - val_cosine_similarity: 0.7745 - val_r_square: -0.5081
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0228 - MSE: 0.0466 - cosine_similarity: 0.7257 - r_square: -0.6035 - val_loss: 0.0205 - val_MSE: 0.0416 - val_cosine_similarity: 0.7747 - val_r_square: -0.4809
# 2/2 [==============================] - 0s 132ms/step - loss: 0.0209 - MSE: 0.0427 - cosine_similarity: 0.7362 - r_square: -0.6207 - val_loss: 0.0207 - val_MSE: 0.0421 - val_cosine_similarity: 0.7751 - val_r_square: -0.4972
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0209 - MSE: 0.0426 - cosine_similarity: 0.7698 - r_square: -0.4464 - val_loss: 0.0213 - val_MSE: 0.0432 - val_cosine_similarity: 0.7753 - val_r_square: -0.5398
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0209 - MSE: 0.0426 - cosine_similarity: 0.7357 - r_square: -0.4434 - val_loss: 0.0221 - val_MSE: 0.0449 - val_cosine_similarity: 0.7753 - val_r_square: -0.6148
# 2/2 [==============================] - 0s 130ms/step - loss: 0.0211 - MSE: 0.0430 - cosine_similarity: 0.7477 - r_square: -0.6443 - val_loss: 0.0223 - val_MSE: 0.0454 - val_cosine_similarity: 0.7756 - val_r_square: -0.6242
# Epoch 10
# 2/2 [==============================] - 0s 155ms/step - loss: 0.0211 - MSE: 0.0431 - cosine_similarity: 0.7435 - r_square: -0.6989 - val_loss: 0.0222 - val_MSE: 0.0451 - val_cosine_similarity: 0.7751 - val_r_square: -0.6103
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0183 - MSE: 0.0372 - cosine_similarity: 0.7776 - r_square: -0.2844 - val_loss: 0.0215 - val_MSE: 0.0437 - val_cosine_similarity: 0.7755 - val_r_square: -0.5378
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0208 - MSE: 0.0425 - cosine_similarity: 0.7539 - r_square: -0.7849 - val_loss: 0.0205 - val_MSE: 0.0417 - val_cosine_similarity: 0.7749 - val_r_square: -0.4909
# 2/2 [==============================] - 0s 156ms/step - loss: 0.0196 - MSE: 0.0401 - cosine_similarity: 0.7412 - r_square: -0.3657 - val_loss: 0.0204 - val_MSE: 0.0414 - val_cosine_similarity: 0.7752 - val_r_square: -0.4726
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0235 - MSE: 0.0480 - cosine_similarity: 0.7118 - r_square: -0.4772 - val_loss: 0.0204 - val_MSE: 0.0415 - val_cosine_similarity: 0.7756 - val_r_square: -0.4702
# 2/2 [==============================] - 0s 150ms/step - loss: 0.0206 - MSE: 0.0419 - cosine_similarity: 0.7471 - r_square: -0.5370 - val_loss: 0.0204 - val_MSE: 0.0414 - val_cosine_similarity: 0.7762 - val_r_square: -0.4563
# Epoch 13
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0214 - MSE: 0.0436 - cosine_similarity: 0.7463 - r_square: -0.4058 - val_loss: 0.0209 - val_MSE: 0.0424 - val_cosine_similarity: 0.7761 - val_r_square: -0.4844
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0200 - MSE: 0.0408 - cosine_similarity: 0.7562 - r_square: -0.3750 - val_loss: 0.0211 - val_MSE: 0.0429 - val_cosine_similarity: 0.7767 - val_r_square: -0.4933
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0219 - MSE: 0.0447 - cosine_similarity: 0.7305 - r_square: -0.6249 - val_loss: 0.0214 - val_MSE: 0.0435 - val_cosine_similarity: 0.7769 - val_r_square: -0.5169
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0187 - MSE: 0.0380 - cosine_similarity: 0.7762 - r_square: -0.4231 - val_loss: 0.0215 - val_MSE: 0.0437 - val_cosine_similarity: 0.7769 - val_r_square: -0.5250
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0195 - MSE: 0.0397 - cosine_similarity: 0.7724 - r_square: -0.4314 - val_loss: 0.0212 - val_MSE: 0.0430 - val_cosine_similarity: 0.7770 - val_r_square: -0.4919
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0190 - MSE: 0.0386 - cosine_similarity: 0.7636 - r_square: -0.4818 - val_loss: 0.0205 - val_MSE: 0.0417 - val_cosine_similarity: 0.7771 - val_r_square: -0.4305
# Epoch 14
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0186 - MSE: 0.0377 - cosine_similarity: 0.7604 - r_square: -0.3991 - val_loss: 0.0199 - val_MSE: 0.0404 - val_cosine_similarity: 0.7776 - val_r_square: -0.3623
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0208 - MSE: 0.0425 - cosine_similarity: 0.7434 - r_square: -0.3963 - val_loss: 0.0201 - val_MSE: 0.0409 - val_cosine_similarity: 0.7770 - val_r_square: -0.3958
# 2/2 [==============================] - 0s 101ms/step - loss: 0.
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0194 - MSE: 0.0395 - cosine_similarity: 0.7692 - r_square: -0.2689 - val_loss: 0.0198 - val_MSE: 0.0402 - val_cosine_similarity: 0.7795 - val_r_square: -0.3210
# 2/2 [==============================] - 0s 132ms/step - loss: 0.0172 - MSE: 0.0350 - cosine_similarity: 0.7814 - r_square: -0.2919 - val_loss: 0.0201 - val_MSE: 0.0409 - val_cosine_similarity: 0.7794 - val_r_square: -0.3531
# Epoch 27
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0193 - MSE: 0.0393 - cosine_similarity: 0.7819 - r_square: -0.2731 - val_loss: 0.0203 - val_MSE: 0.0412 - val_cosine_similarity: 0.7810 - val_r_square: -0.3793
# 2/2 [==============================] - 0s 123ms/step - loss: 0.0178 - MSE: 0.0361 - cosine_similarity: 0.7830 - r_square: -0.1554 - val_loss: 0.0205 - val_MSE: 0.0415 - val_cosine_similarity: 0.7808 - val_r_square: -0.3970
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0182 - MSE: 0.0370 - cosine_similarity: 0.7739 - r_square: -0.3039 - val_loss: 0.0200 - val_MSE: 0.0406 - val_cosine_similarity: 0.7810 - val_r_square: -0.3549
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0174 - MSE: 0.0353 - cosine_similarity: 0.7747 - r_square: -0.2491 - val_loss: 0.0193 - val_MSE: 0.0392 - val_cosine_similarity: 0.7814 - val_r_square: -0.2931
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0169 - MSE: 0.0343 - cosine_similarity: 0.7946 - r_square: -0.3489 - val_loss: 0.0187 - val_MSE: 0.0380 - val_cosine_similarity: 0.7819 - val_r_square: -0.2311
# 2/2 [==============================] - 0s 168ms/step - loss: 0.0180 - MSE: 0.0368 - cosine_similarity: 0.7561 - r_square: -0.2659 - val_loss: 0.0186 - val_MSE: 0.0377 - val_cosine_similarity: 0.7820 - val_r_square: -0.2202
# Epoch 28
# 2/2 [==============================] - 0s 126ms/step - loss: 0.0190 - MSE: 0.0388 - cosine_similarity: 0.7566 - r_square: -0.3236 - val_loss: 0.0189 - val_MSE: 0.0384 - val_cosine_similarity: 0.7799 - val_r_square: -0.2472
# 2/2 [==============================] - 0s 229ms/step - loss: 0.0189 - MSE: 0.0387 - cosine_similarity: 0.7625 - r_square: -0.2627 - val_loss: 0.0192 - val_MSE: 0.0389 - val_cosine_similarity: 0.7796 - val_r_square: -0.2725
# 2/2 [==============================] - 0s 142ms/step - loss: 0.0175 - MSE: 0.0355 - cosine_similarity: 0.7809 - r_square: -0.2306 - val_loss: 0.0195 - val_MSE: 0.0397 - val_cosine_similarity: 0.7792 - val_r_square: -0.3068
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0183 - MSE: 0.0372 - cosine_similarity: 0.7674 - r_square: -0.2523 - val_loss: 0.0199 - val_MSE: 0.0405 - val_cosine_similarity: 0.7789 - val_r_square: -0.3462
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0178 - MSE: 0.0363 - cosine_similarity: 0.7851 - r_square: -0.1791 - val_loss: 0.0201 - val_MSE: 0.0407 - val_cosine_similarity: 0.7787 - val_r_square: -0.3602
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0178 - MSE: 0.0361 - cosine_similarity: 0.7791 - r_square: -0.2819 - val_loss: 0.0201 - val_MSE: 0.0408 - val_cosine_similarity: 0.7787 - val_r_square: -0.3649
# Epoch 29
# 2/2 [==============================] - 0s 124ms/step - loss: 0.0175 - MSE: 0.0356 - cosine_similarity: 0.7919 - r_square: -0.2891 - val_loss: 0.0196 - val_MSE: 0.0398 - val_cosine_similarity: 0.7805 - val_r_square: -0.3175
# 2/2 [==============================] - 0s 128ms/step - loss: 0.0173 - MSE: 0.0352 - cosine_similarity: 0.7797 - r_square: -0.2857 - val_loss: 0.0192 - val_MSE: 0.0389 - val_cosine_similarity: 0.7810 - val_r_square: -0.2723
# 2/2 [==============================] - 0s 156ms/step - loss: 0.0185 - MSE: 0.0377 - cosine_similarity: 0.7717 - r_square: -0.3626 - val_loss: 0.0189 - val_MSE: 0.0383 - val_cosine_similarity: 0.7815 - val_r_square: -0.2378
# 2/2 [==============================] - 0s 144ms/step - loss: 0.0175 - MSE: 0.0355 - cosine_similarity: 0.7723 - r_square: -0.2786 - val_loss: 0.0186 - val_MSE: 0.0378 - val_cosine_similarity: 0.7818 - val_r_square: -0.2145
# 2/2 [==============================] - 0s 131ms/step - loss: 0.0177 - MSE: 0.0361 - cosine_similarity: 0.7827 - r_square: -0.2260 - val_loss: 0.0185 - val_MSE: 0.0376 - val_cosine_similarity: 0.7819 - val_r_square: -0.2050
# 2/2 [==============================] - 0s 146ms/step - loss: 0.0202 - MSE: 0.0411 - cosine_similarity: 0.7433 - r_square: -0.2760 - val_loss: 0.0188 - val_MSE: 0.0382 - val_cosine_similarity: 0.7819 - val_r_square: -0.2290
# Epoch 30
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0180 - MSE: 0.0367 - cosine_similarity: 0.7771 - r_square: -0.2477 - val_loss: 0.0195 - val_MSE: 0.0395 - val_cosine_similarity: 0.7801 - val_r_square: -0.2808
# 2/2 [==============================] - 0s 126ms/step - loss: 0.0174 - MSE: 0.0353 - cosine_similarity: 0.7777 - r_square: -0.1907 - val_loss: 0.0196 - val_MSE: 0.0399 - val_cosine_similarity: 0.7801 - val_r_square: -0.2944
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0149 - MSE: 0.0303 - cosine_similarity: 0.8064 - r_square: -0.1732 - val_loss: 0.0200 - val_MSE: 0.0405 - val_cosine_similarity: 0.7799 - val_r_square: -0.3238
# 2/2 [==============================] - 0s 125ms/step - loss: 0.0199 - MSE: 0.0406 - cosine_similarity: 0.7623 - r_square: -0.1726 - val_loss: 0.0203 - val_MSE: 0.0411 - val_cosine_similarity: 0.7796 - val_r_square: -0.3541
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0163 - MSE: 0.0332 - cosine_similarity: 0.7888 - r_square: -0.3022 - val_loss: 0.0201 - val_MSE: 0.0409 - val_cosine_similarity: 0.7795 - val_r_square: -0.3470
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0198 - MSE: 0.0402 - cosine_similarity: 0.7548 - r_square: -0.3193 - val_loss: 0.0196 - val_MSE: 0.0397 - val_cosine_similarity: 0.7796 - val_r_square: -0.2989
# Epoch 31
# 2/2 [==============================] - 0s 126ms/step - loss: 0.0159 - MSE: 0.0322 - cosine_similarity: 0.7884 - r_square: -0.2102 - val_loss: 0.0190 - val_MSE: 0.0387 - val_cosine_similarity: 0.7800 - val_r_square: -0.2540
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0190 - MSE: 0.0387 - cosine_similarity: 0.7620 - r_square: -0.2607 - val_loss: 0.0187 - val_MSE: 0.0380 - val_cosine_similarity: 0.7802 - val_r_square: -0.2238
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0191 - MSE: 0.0390 - cosine_similarity: 0.7582 - r_square: -0.3550 - val_loss: 0.0185 - val_MSE: 0.0376 - val_cosine_similarity: 0.7804 - val_r_square: -0.2069
# 2/2 [==============================] - 0s 125ms/step - loss: 0.0197 - MSE: 0.0402 - cosine_similarity: 0.7619 - r_square: -0.3510 - val_loss: 0.0188 - val_MSE: 0.0383 - val_cosine_similarity: 0.7800 - val_r_square: -0.2405
# 2/2 [==============================] - 0s 126ms/step - loss: 0.0181 - MSE: 0.0368 - cosine_similarity: 0.7819 - r_square: -0.3127 - val_loss: 0.0192 - val_MSE: 0.0391 - val_cosine_similarity: 0.7797 - val_r_square: -0.2788
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0179 - MSE: 0.0365 - cosine_similarity: 0.7658 - r_square: -0.1996 - val_loss: 0.0196 - val_MSE: 0.0399 - val_cosine_similarity: 0.7794 - val_r_square: -0.3171
# Epoch 32
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0184 - MSE: 0.0373 - cosine_similarity: 0.7706 - r_square: -0.2565 - val_loss: 0.0199 - val_MSE: 0.0403 - val_cosine_similarity: 0.7806 - val_r_square: -0.3433
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0183 - MSE: 0.0372 - cosine_similarity: 0.7687 - r_square: -0.2285 - val_loss: 0.0197 - val_MSE: 0.0400 - val_cosine_similarity: 0.7808 - val_r_square: -0.3281
# 2/2 [==============================] - 0s 129ms/step - loss: 0.0159 - MSE: 0.0322 - cosine_similarity: 0.7876 - r_square: -0.2306 - val_loss: 0.0193 - val_MSE: 0.0391 - val_cosine_similarity: 0.7813 - val_r_square: -0.2848
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0205 - MSE: 0.0418 - cosine_similarity: 0.7508 - r_square: -0.3327 - val_loss: 0.0188 - val_MSE: 0.0381 - val_cosine_similarity: 0.7820 - val_r_square: -0.2324
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0173 - MSE: 0.0352 - cosine_similarity: 0.7877 - r_square: -0.2381 - val_loss: 0.0184 - val_MSE: 0.0374 - val_cosine_similarity: 0.7826 - val_r_square: -0.1915
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0190 - MSE: 0.0386 - cosine_similarity: 0.7696 - r_square: -0.2937 - val_loss: 0.0195 - val_MSE: 0.0396 - val_cosine_similarity: 0.7798 - val_r_square: -0.2856
# Epoch 35
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0164 - MSE: 0.0333 - cosine_similarity: 0.7947 - r_square: -0.3555 - val_loss: 0.0197 - val_MSE: 0.0400 - val_cosine_similarity: 0.7786 - val_r_square: -0.3114
# 2/2 [==============================] - 0s 93ms/step - loss: 0.0211 - MSE: 0.0431 - cosine_similarity: 0.7413 - r_square: -0.2676 - val_loss: 0.0194 - val_MSE: 0.0395 - val_cosine_similarity: 0.7791 - val_r_square: -0.2875
# 2/2 [==============================] - 0s 123ms/step - loss: 0.0173 - MSE: 0.0351 - cosine_similarity: 0.7837 - r_square: -0.2812 - val_loss: 0.0195 - val_MSE: 0.0396 - val_cosine_similarity: 0.7795 - val_r_square: -0.2875
# ...
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0160 - MSE: 0.0326 - cosine_similarity: 0.7913 - r_square: -0.1353 - val_loss: 0.0179 - val_MSE: 0.0365 - val_cosine_similarity: 0.7803 - val_r_square: -0.1211
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0179 - MSE: 0.0363 - cosine_similarity: 0.7882 - r_square: -0.0705 - val_loss: 0.0180 - val_MSE: 0.0366 - val_cosine_similarity: 0.7803 - val_r_square: -0.1262
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0152 - MSE: 0.0310 - cosine_similarity: 0.8087 - r_square: -0.0626 - val_loss: 0.0182 - val_MSE: 0.0369 - val_cosine_similarity: 0.7800 - val_r_square: -0.1422
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0156 - MSE: 0.0316 - cosine_similarity: 0.7993 - r_square: -0.0789 - val_loss: 0.0181 - val_MSE: 0.0368 - val_cosine_similarity: 0.7799 - val_r_square: -0.1353
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0161 - MSE: 0.0327 - cosine_similarity: 0.7922 - r_square: -0.0815 - val_loss: 0.0180 - val_MSE: 0.0365 - val_cosine_similarity: 0.7798 - val_r_square: -0.1211
# Epoch 89
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0156 - MSE: 0.0317 - cosine_similarity: 0.7941 - r_square: -0.0823 - val_loss: 0.0176 - val_MSE: 0.0357 - val_cosine_similarity: 0.7823 - val_r_square: -0.1005
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0158 - MSE: 0.0321 - cosine_similarity: 0.7945 - r_square: -0.1734 - val_loss: 0.0175 - val_MSE: 0.0357 - val_cosine_similarity: 0.7822 - val_r_square: -0.0974
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0165 - MSE: 0.0335 - cosine_similarity: 0.7879 - r_square: -0.1717 - val_loss: 0.0176 - val_MSE: 0.0359 - val_cosine_similarity: 0.7820 - val_r_square: -0.1042
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0138 - MSE: 0.0279 - cosine_similarity: 0.8168 - r_square: -0.0994 - val_loss: 0.0178 - val_MSE: 0.0362 - val_cosine_similarity: 0.7817 - val_r_square: -0.1162
# 2/2 [==============================] - 0s 134ms/step - loss: 0.0196 - MSE: 0.0400 - cosine_similarity: 0.7520 - r_square: -0.1313 - val_loss: 0.0179 - val_MSE: 0.0363 - val_cosine_similarity: 0.7817 - val_r_square: -0.1252
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0170 - MSE: 0.0346 - cosine_similarity: 0.7931 - r_square: -0.1267 - val_loss: 0.0180 - val_MSE: 0.0365 - val_cosine_similarity: 0.7818 - val_r_square: -0.1335
# Epoch 90
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0175 - MSE: 0.0356 - cosine_similarity: 0.7884 - r_square: -0.1118 - val_loss: 0.0181 - val_MSE: 0.0367 - val_cosine_similarity: 0.7818 - val_r_square: -0.1361
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0156 - MSE: 0.0316 - cosine_similarity: 0.7992 - r_square: -0.1177 - val_loss: 0.0179 - val_MSE: 0.0364 - val_cosine_similarity: 0.7819 - val_r_square: -0.1225
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0163 - MSE: 0.0331 - cosine_similarity: 0.7940 - r_square: -0.0880 - val_loss: 0.0177 - val_MSE: 0.0360 - val_cosine_similarity: 0.7821 - val_r_square: -0.1023
# 2/2 [==============================] - 0s 126ms/step - loss: 0.0173 - MSE: 0.0352 - cosine_similarity: 0.7786 - r_square: -0.1652 - val_loss: 0.0175 - val_MSE: 0.0356 - val_cosine_similarity: 0.7822 - val_r_square: -0.0847
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0149 - MSE: 0.0302 - cosine_similarity: 0.7945 - r_square: -0.1666 - val_loss: 0.0175 - val_MSE: 0.0356 - val_cosine_similarity: 0.7821 - val_r_square: -0.0801
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0169 - MSE: 0.0343 - cosine_similarity: 0.7826 - r_square: -0.0883 - val_loss: 0.0176 - val_MSE: 0.0358 - val_cosine_similarity: 0.7821 - val_r_square: -0.0910
# Epoch 91
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0180 - MSE: 0.0366 - cosine_similarity: 0.7761 - r_square: -0.0979 - val_loss: 0.0177 - val_MSE: 0.0360 - val_cosine_similarity: 0.7820 - val_r_square: -0.1076
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0171 - MSE: 0.0348 - cosine_similarity: 0.7800 - r_square: -0.1996 - val_loss: 0.0177 - val_MSE: 0.0361 - val_cosine_similarity: 0.7820 - val_r_square: -0.1132
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0174 - MSE: 0.0354 - cosine_similarity: 0.7737 - r_square: -0.1175 - val_loss: 0.0178 - val_MSE: 0.0362 - val_cosine_similarity: 0.7821 - val_r_square: -0.1195
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0163 - MSE: 0.0331 - cosine_similarity: 0.7934 - r_square: -0.1301 - val_loss: 0.0179 - val_MSE: 0.0363 - val_cosine_similarity: 0.7820 - val_r_square: -0.1269
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0149 - MSE: 0.0303 - cosine_similarity: 0.8052 - r_square: -0.1331 - val_loss: 0.0178 - val_MSE: 0.0363 - val_cosine_similarity: 0.7821 - val_r_square: -0.1249
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0149 - MSE: 0.0302 - cosine_similarity: 0.8144 - r_square: -0.0719 - val_loss: 0.0178 - val_MSE: 0.0361 - val_cosine_similarity: 0.7822 - val_r_square: -0.1201
# Epoch 92
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0153 - MSE: 0.0311 - cosine_similarity: 0.7936 - r_square: -0.0713 - val_loss: 0.0177 - val_MSE: 0.0360 - val_cosine_similarity: 0.7825 - val_r_square: -0.1187
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0171 - MSE: 0.0346 - cosine_similarity: 0.7808 - r_square: -0.1576 - val_loss: 0.0176 - val_MSE: 0.0359 - val_cosine_similarity: 0.7826 - val_r_square: -0.1117
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0170 - MSE: 0.0346 - cosine_similarity: 0.7891 - r_square: -0.0701 - val_loss: 0.0175 - val_MSE: 0.0357 - val_cosine_similarity: 0.7826 - val_r_square: -0.1043
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0162 - MSE: 0.0330 - cosine_similarity: 0.7967 - r_square: -0.0681 - val_loss: 0.0176 - val_MSE: 0.0358 - val_cosine_similarity: 0.7824 - val_r_square: -0.1128
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0161 - MSE: 0.0329 - cosine_similarity: 0.7940 - r_square: -0.0630 - val_loss: 0.0178 - val_MSE: 0.0362 - val_cosine_similarity: 0.7822 - val_r_square: -0.1298
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0141 - MSE: 0.0286 - cosine_similarity: 0.8047 - r_square: -0.1110 - val_loss: 0.0178 - val_MSE: 0.0362 - val_cosine_similarity: 0.7821 - val_r_square: -0.1332
# Epoch 93
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0161 - MSE: 0.0326 - cosine_similarity: 0.7926 - r_square: -0.1665 - val_loss: 0.0177 - val_MSE: 0.0361 - val_cosine_similarity: 0.7825 - val_r_square: -0.1290
# 2/2 [==============================] - 0s 123ms/step - loss: 0.0173 - MSE: 0.0353 - cosine_similarity: 0.7898 - r_square: -0.1046 - val_loss: 0.0177 - val_MSE: 0.0359 - val_cosine_similarity: 0.7826 - val_r_square: -0.1201
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0162 - MSE: 0.0330 - cosine_similarity: 0.7895 - r_square: -0.2067 - val_loss: 0.0176 - val_MSE: 0.0357 - val_cosine_similarity: 0.7827 - val_r_square: -0.1113
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0169 - MSE: 0.0345 - cosine_similarity: 0.7767 - r_square: -0.0914 - val_loss: 0.0176 - val_MSE: 0.0357 - val_cosine_similarity: 0.7829 - val_r_square: -0.1106
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0151 - MSE: 0.0307 - cosine_similarity: 0.7993 - r_square: -0.0756 - val_loss: 0.0175 - val_MSE: 0.0357 - val_cosine_similarity: 0.7830 - val_r_square: -0.1063
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0142 - MSE: 0.0289 - cosine_similarity: 0.8159 - r_square: -0.0722 - val_loss: 0.0176 - val_MSE: 0.0358 - val_cosine_similarity: 0.7832 - val_r_square: -0.1089
# Epoch 94
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0174 - MSE: 0.0353 - cosine_similarity: 0.7862 - r_square: -0.0962 - val_loss: 0.0177 - val_MSE: 0.0360 - val_cosine_similarity: 0.7825 - val_r_square: -0.1118
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0161 - MSE: 0.0328 - cosine_similarity: 0.8137 - r_square: -0.0983 - val_loss: 0.0180 - val_MSE: 0.0365 - val_cosine_similarity: 0.7822 - val_r_square: -0.1341
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0155 - MSE: 0.0314 - cosine_similarity: 0.7965 - r_square: -0.0856 - val_loss: 0.0181 - val_MSE: 0.0368 - val_cosine_similarity: 0.7821 - val_r_square: -0.1472
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0163 - MSE: 0.0331 - cosine_similarity: 0.7886 - r_square: -0.1293 - val_loss: 0.0181 - val_MSE: 0.0368 - val_cosine_similarity: 0.7821 - val_r_square: -0.1456
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0150 - MSE: 0.0304 - cosine_similarity: 0.7899 - r_square: -0.0162 - val_loss: 0.0180 - val_MSE: 0.0365 - val_cosine_similarity: 0.7823 - val_r_square: -0.1311
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0165 - MSE: 0.0335 - cosine_similarity: 0.7891 - r_square: -0.1421 - val_loss: 0.0178 - val_MSE: 0.0362 - val_cosine_similarity: 0.7825 - val_r_square: -0.1173
# Epoch 95
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0169 - MSE: 0.0344 - cosine_similarity: 0.7920 - r_square: -0.1041 - val_loss: 0.0177 - val_MSE: 0.0360 - val_cosine_similarity: 0.7830 - val_r_square: -0.1027
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0163 - MSE: 0.0332 - cosine_similarity: 0.7926 - r_square: -0.1372 - val_loss: 0.0178 - val_MSE: 0.0362 - val_cosine_similarity: 0.7829 - val_r_square: -0.1089
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0150 - MSE: 0.0304 - cosine_similarity: 0.7926 - r_square: -0.1147 - val_loss: 0.0178 - val_MSE: 0.0361 - val_cosine_similarity: 0.7828 - val_r_square: -0.1066
# 2/2 [==============================] - 0s 215ms/step - loss: 0.0156 - MSE: 0.0317 - cosine_similarity: 0.7958 - r_square: -0.0530 - val_loss: 0.0176 - val_MSE: 0.0357 - val_cosine_similarity: 0.7832 - val_r_square: -0.0884
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0159 - MSE: 0.0323 - cosine_similarity: 0.7977 - r_square: -0.0908 - val_loss: 0.0175 - val_MSE: 0.0355 - val_cosine_similarity: 0.7837 - val_r_square: -0.0787
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0176 - MSE: 0.0358 - cosine_similarity: 0.7687 - r_square: -0.1612 - val_loss: 0.0175 - val_MSE: 0.0355 - val_cosine_similarity: 0.7838 - val_r_square: -0.0812
# Epoch 96
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0156 - MSE: 0.0316 - cosine_similarity: 0.7967 - r_square: -0.1116 - val_loss: 0.0178 - val_MSE: 0.0362 - val_cosine_similarity: 0.7819 - val_r_square: -0.1135
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0172 - MSE: 0.0349 - cosine_similarity: 0.7842 - r_square: -0.1032 - val_loss: 0.0179 - val_MSE: 0.0365 - val_cosine_similarity: 0.7816 - val_r_square: -0.1261
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0137 - MSE: 0.0278 - cosine_similarity: 0.8159 - r_square: -0.0513 - val_loss: 0.0180 - val_MSE: 0.0365 - val_cosine_similarity: 0.7814 - val_r_square: -0.1314
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0168 - MSE: 0.0342 - cosine_similarity: 0.7802 - r_square: -0.0838 - val_loss: 0.0179 - val_MSE: 0.0364 - val_cosine_similarity: 0.7811 - val_r_square: -0.1264
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0159 - MSE: 0.0323 - cosine_similarity: 0.7982 - r_square: -0.0762 - val_loss: 0.0178 - val_MSE: 0.0362 - val_cosine_similarity: 0.7809 - val_r_square: -0.1191
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0176 - MSE: 0.0359 - cosine_similarity: 0.7787 - r_square: -0.1113 - val_loss: 0.0178 - val_MSE: 0.0363 - val_cosine_similarity: 0.7803 - val_r_square: -0.1227
# Epoch 97
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0170 - MSE: 0.0346 - cosine_similarity: 0.7872 - r_square: -0.0768 - val_loss: 0.0175 - val_MSE: 0.0355 - val_cosine_similarity: 0.7849 - val_r_square: -0.1078
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0159 - MSE: 0.0324 - cosine_similarity: 0.7888 - r_square: -0.1615 - val_loss: 0.0176 - val_MSE: 0.0357 - val_cosine_similarity: 0.7847 - val_r_square: -0.1176
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0140 - MSE: 0.0284 - cosine_similarity: 0.8170 - r_square: -0.1085 - val_loss: 0.0178 - val_MSE: 0.0362 - val_cosine_similarity: 0.7844 - val_r_square: -0.1398
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0160 - MSE: 0.0326 - cosine_similarity: 0.7918 - r_square: -0.1352 - val_loss: 0.0179 - val_MSE: 0.0364 - val_cosine_similarity: 0.7843 - val_r_square: -0.1480
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0152 - MSE: 0.0308 - cosine_similarity: 0.8006 - r_square: -0.1099 - val_loss: 0.0178 - val_MSE: 0.0361 - val_cosine_similarity: 0.7845 - val_r_square: -0.1355
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0188 - MSE: 0.0382 - cosine_similarity: 0.7686 - r_square: -0.0915 - val_loss: 0.0176 - val_MSE: 0.0357 - val_cosine_similarity: 0.7850 - val_r_square: -0.1164
# Epoch 98
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0164 - MSE: 0.0333 - cosine_similarity: 0.7798 - r_square: -0.1511 - val_loss: 0.0177 - val_MSE: 0.0359 - val_cosine_similarity: 0.7820 - val_r_square: -0.1060
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0176 - MSE: 0.0358 - cosine_similarity: 0.7968 - r_square: -0.0975 - val_loss: 0.0175 - val_MSE: 0.0356 - val_cosine_similarity: 0.7825 - val_r_square: -0.0876
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0169 - MSE: 0.0345 - cosine_similarity: 0.7806 - r_square: -0.1802 - val_loss: 0.0175 - val_MSE: 0.0356 - val_cosine_similarity: 0.7827 - val_r_square: -0.0878
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0156 - MSE: 0.0317 - cosine_similarity: 0.7900 - r_square: -0.1029 - val_loss: 0.0176 - val_MSE: 0.0358 - val_cosine_similarity: 0.7828 - val_r_square: -0.0970
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0154 - MSE: 0.0313 - cosine_similarity: 0.7866 - r_square: -0.0974 - val_loss: 0.0176 - val_MSE: 0.0358 - val_cosine_similarity: 0.7830 - val_r_square: -0.1000
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0162 - MSE: 0.0329 - cosine_similarity: 0.7886 - r_square: -0.1275 - val_loss: 0.0176 - val_MSE: 0.0358 - val_cosine_similarity: 0.7832 - val_r_square: -0.0998
# Epoch 99
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0150 - MSE: 0.0305 - cosine_similarity: 0.8050 - r_square: -0.1160 - val_loss: 0.0176 - val_MSE: 0.0358 - val_cosine_similarity: 0.7834 - val_r_square: -0.1046
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0157 - MSE: 0.0319 - cosine_similarity: 0.7959 - r_square: -0.0652 - val_loss: 0.0175 - val_MSE: 0.0356 - val_cosine_similarity: 0.7837 - val_r_square: -0.0947
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0158 - MSE: 0.0322 - cosine_similarity: 0.7925 - r_square: -0.0832 - val_loss: 0.0174 - val_MSE: 0.0354 - val_cosine_similarity: 0.7840 - val_r_square: -0.0830
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0166 - MSE: 0.0339 - cosine_similarity: 0.7989 - r_square: -0.1611 - val_loss: 0.0176 - val_MSE: 0.0357 - val_cosine_similarity: 0.7837 - val_r_square: -0.0989
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0172 - MSE: 0.0349 - cosine_similarity: 0.7819 - r_square: -0.0852 - val_loss: 0.0179 - val_MSE: 0.0364 - val_cosine_similarity: 0.7831 - val_r_square: -0.1269
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0156 - MSE: 0.0317 - cosine_similarity: 0.7897 - r_square: -0.0594 - val_loss: 0.0181 - val_MSE: 0.0368 - val_cosine_similarity: 0.7826 - val_r_square: -0.1451

# %%
# %matplotlib inline

metrics = ["MSE", "cosine similarity", "r2"] #Choose between 'loss', 'MSE', 'cosine similarity', 'r2'

metrics_dict = {"loss": ["loss", "val_loss"], "MSE": ["MSE", "val_MSE"], 
                "cosine similarity": ["cosine_similarity", "val_cosine_similarity"],
               "r2" : ["r_square", "val_r_square"]}

import matplotlib.pyplot as plt
try: history_df = history_df.reset_index()
except: pass

for metric in metrics:
    fig, ax = plt.subplots(figsize=(15,4),nrows=1, ncols=1)
    ax.set_ylabel(f"{metric}")
    ax.set_xlabel("Training time")
    fig.suptitle(f"History of {metric} in training time")

    train_plot = history_df.plot(y=metrics_dict[metric][0], use_index=True, ax=ax, label="Training")
    val_plot = history_df.plot(y=metrics_dict[metric][1], use_index=True, ax=ax, label="Validation")

    plt.show()

# %% [markdown]
# ## Evaluation of the results

# %%
val_ds = validation_dataset.shuffle(n_test).batch(n_test)
x_val, y_val, length_val = next(iter(val_ds))
x_val, y_val = slice_accordingly(x_val, y_val)
    

y_pred = model.predict(x_val)
y_true = y_val

# %%
def plot_epsilon_error(y_true, y_pred):
    
    N = len(y_true)
    
    cdf_abs_error = {}
    abs_error = np.abs(y_true - y_pred)
    
    fig, ax = plt.subplots(figsize=(12,6),nrows=1, ncols=2)
    ax[0].set_ylabel("Fraction of samples")
    ax[0].set_xlabel("Allowed absolute error")
    ax[0].set_title(f"CDF of the absolute error for different emotions")
    
    ax[0].set_ylim([0,1])
    
    for i, emotion in enumerate(emotions):
        abs_error_emotion = np.sort(abs_error[:,i])
        X2 = np.sort(abs_error_emotion)
        F2 = np.array(range(N))/(float(N))
        
        cdf_abs_error[emotion] = [X2, F2]
        
        ax[0].plot(X2, F2, label=emotion)
        
    ax[0].legend()
    ax[0].grid()
    
    cdf_cosine_sim = {}
    cos_sim = np.array([np.dot(y_true[i], y_pred[i])/(np.linalg.norm(y_true[i])*np.linalg.norm(y_pred[i])) for i in range(N)])
    cos_error = 1-cos_sim
    
    X2 = np.sort(cos_error)
    F2 = np.array(range(N))/(float(N))

    ax[1].set_ylabel(f"Fraction of samples", rotation=-90, labelpad=15)
    ax[1].yaxis.set_label_position("right")
    ax[1].yaxis.tick_right()
    ax[1].set_xlabel("Allowed cosine error")
    ax[1].set_title(f"CDF of the cosine error")
    
    ax[1].set_ylim([0,1])
    
    ax[1].plot(X2, F2)
    ax[1].grid()
    return cdf_abs_error

# %%
epsilon_error = plot_epsilon_error(y_true, y_pred)

x = epsilon_error["amazement"]
plt.show()

# %% [markdown]
# ## "Cross-validation"

# %%
def custom_loss(y_true, y_pred):
    cos_sim = tf.keras.losses.CosineSimilarity() 
    MSE = tf.keras.losses.MeanSquaredError()
        
    return cos_sim(y_true, y_pred) + MSE(y_true, y_pred)

# %%
from sklearn.model_selection import KFold


n_splits = 5
kf = KFold(n_splits=n_splits)

predictions_and_labels = {}


count = 0
for train_index, test_index in kf.split(MFCCs_raw):
    
    print(f"Training K-fold {1+count} of {n_splits}")

    train_features, train_labels = MFCCs_raw[train_index], labels_raw[train_index]
    validation_features, validation_labels = MFCCs_raw[test_index], labels_raw[test_index]

    train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels))
    validation_dataset = tf.data.Dataset.from_tensor_slices((validation_features, validation_labels))
    
    sample_size = (20, 50, 1)
    drop_out_rate = 0.4

    input_tensor = Input(sample_size)
    x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(input_tensor)
    x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(x)
    x = layers.Dropout(drop_out_rate)(x)
    x = layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)
    x = layers.Conv2D(16, (3, 3), padding="valid", activation="relu", strides=1)(x)
    x = layers.MaxPooling2D(pool_size=(3,3), strides=(2,2))(x)
    x = layers.Flatten()(x)
    x = layers.Dense(20, activation="relu")(x)
    x = layers.Flatten()(x)
    x = layers.Dropout(drop_out_rate)(x)
    output_tensor = layers.Dense(9, activation="sigmoid")(x)

    model = tf.keras.Model(input_tensor, output_tensor)
        
    model.compile(optimizer="adam",
                  loss = tf.keras.losses.LogCosh(),
                  #loss= custom_loss,
                  metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
    n_epochs = 100
    batch_size = 50
    
    for epoch in range(n_epochs):
        train_ds = train_dataset.shuffle(n_train).batch(batch_size)
        for features, labels in train_ds:
            features, labels = slice_accordingly(features, labels)
            model.fit(features, labels, verbose=0)
            
    val_ds = validation_dataset.shuffle(n_test).batch(n_test)
    x_val, y_val = next(iter(val_ds))
    x_val, y_val = slice_accordingly(x_val, y_val)

            
    predictions_and_labels[count] = [model.predict(x_val), y_val]
    count = count+1
# Out:
# Training K-fold 1 of 5
# Training K-fold 2 of 5
# Training K-fold 3 of 5
# Training K-fold 4 of 5
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001C5049A4378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Training K-fold 5 of 5
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001C5050D0400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
predictions = []
labels = []

for i in range(max(predictions_and_labels.keys())+1):
    predictions.append(predictions_and_labels[i][0])
    labels.append(predictions_and_labels[i][1])

predictions = np.concatenate(predictions)
labels = np.concatenate(labels)
epsilon_error = plot_epsilon_error(labels, predictions)

plt.show()

# %%
cos_sim = []
r2 = []
MSE = []

cos_sim_function = tf.keras.metrics.CosineSimilarity() 
MSE_function = tf.keras.metrics.MeanSquaredError()
r2_function = tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))

for i in range(max(predictions_and_labels.keys())+1):
    y_pred = predictions_and_labels[i][0]
    y_true = predictions_and_labels[i][1]
    
    cos_sim.append(cos_sim_function(y_true, y_pred).numpy())
    r2.append(r2_function(y_true, y_pred).numpy())
    MSE.append(MSE_function(y_true, y_pred).numpy())
    
print(f"The cosine similarity is approximately {100*np.mean(cos_sim):.2f}±{100*np.std(cos_sim):.2f}%")
print(f"The MSE is approximately {100*np.mean(MSE):.2f}±{100*np.std(MSE):.2f}%")
print(f"The R2 score is approximately {100*np.mean(r2):.2f}±{100*np.std(r2):.2f}%")
# Out:
# The cosine similarity is approximately 78.99±0.05%
# The MSE is approximately 3.39±0.02%
# The R2 score is approximately -10.18±1.81%
