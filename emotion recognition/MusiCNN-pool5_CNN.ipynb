# %% [markdown]
# # Emotion Recognition: MusiCNN-pool5_CNN.ipynb
#
# Model trained on *simple features* that aims at predicting the *emotion labels*.
#
# The approach consists on getting the arrays of MusiCNN-pool5 (in *preprocessing*) and train a *Convolutional Neural Network* with *Tensorflow*.
# The problem is treated as a *regression* problem, where the loss function can be chosen between *mean squared error*, *-cosine similarity*, or *both*, being a combination of both losses with equal weight. The results shown are using "*both*".

# %%
import numpy as np
import pandas as pd

import sys
import os

# %%
pool5 = np.load("../preprocessing/MusiCNNFeatures/pool5.npy")
print(np.shape(pool5))
# Out:
# (400, 40, 128)

# %%
label_songs = pd.read_csv("../preprocessing/labels.csv")
info_songs = pd.read_csv("../data/Info/info.csv")

# Retrieve emotions from the labels.csv file
emotions = ["amazement", "solemnity", "tenderness", "nostalgia", "calmness", 
            "power", "joyful_activation", "tension", "sadness"]

labels = label_songs[emotions]
labels = labels.to_numpy()

length_songs = pd.DataFrame(info_songs["Track ID"])
length_songs["Song length"] = info_songs["Duration"]*10
length_songs["Song length"] = length_songs["Song length"].astype(int)

# %%
n_data = len(label_songs)
idx = np.random.permutation(n_data)
info_songs = info_songs.reindex(idx)

pool5 = pool5[idx, :, :]
labels = labels[idx]

pool5_raw = pool5[:]
labels_raw = labels[:]

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras import Input, layers
from tensorflow.keras import backend as K

sample_size = (10, 128, 1)

drop_out_rate = 0.5

input_tensor = Input(sample_size)
x = layers.Conv2D(8, (5, 1), padding="valid", activation="relu")(input_tensor)
x = layers.Dropout(drop_out_rate)(x)
x = layers.Dense(32, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(drop_out_rate)(x)
output_tensor = layers.Dense(9, activation="sigmoid")(x)

model_1 = tf.keras.Model(input_tensor, output_tensor)
model_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 10, 128, 1)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 6, 128, 8)         48
# _________________________________________________________________
# dropout (Dropout)            (None, 6, 128, 8)         0
# _________________________________________________________________
# dense (Dense)                (None, 6, 128, 32)        288
# _________________________________________________________________
# flatten (Flatten)            (None, 24576)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24576)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 221193
# =================================================================
# Total params: 221,529
# Trainable params: 221,529
# Non-trainable params: 0
# _________________________________________________________________

# %%
def slice_accordingly(input_tensor, labels, size=10):

    input_shape = (tf.shape(input_tensor).numpy())
    
    input_shape[1] = size
    size = input_shape
    
    sliced_tensor = tf.image.random_crop(input_tensor, size)
    
    nan_values, idx = tf.unique(tf.gather(tf.where(tf.math.is_nan(sliced_tensor)), 0, axis=1))
    nan_values = nan_values.numpy()
  
    msk = np.zeros((input_shape[0]), dtype=np.bool)
    msk[nan_values] = True
    msk = ~msk

    sliced_tensor = tf.boolean_mask(sliced_tensor, msk , axis=0)
    labels = tf.boolean_mask(labels , msk, axis=0)
    
    return sliced_tensor, labels

# %%
fraction_validation = 0.25
n_test = int(fraction_validation*len(labels))
n_train = len(labels) - n_test

train_features, train_labels = pool5[:n_train], labels[:n_train]
validation_features, validation_labels = pool5[n_train:], labels[n_train:]

train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels))
validation_dataset = tf.data.Dataset.from_tensor_slices((validation_features, validation_labels))

# %%
model = model_1

loss = "MSE"
#loss = "CosineSimilarity"
loss = "both"

if loss == "MSE":
    model.compile(optimizer="adam",
                  loss=tf.keras.losses.MeanSquaredError(),
                  metrics=["cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "CosineSimilarity":
    model.compile(optimizer="adam",
                  loss= tf.keras.losses.CosineSimilarity(),
                  metrics=["MSE", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "both":
    def custom_loss(y_true, y_pred):
        cos_sim = tf.keras.losses.CosineSimilarity() 
        MSE = tf.keras.losses.MeanSquaredError()
        
        return cos_sim(y_true, y_pred) + MSE(y_true, y_pred)
        
    model.compile(optimizer="adam",
                  loss= custom_loss,
                  metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])

# %%
n_epochs = 100
batch_size = 50

history_df = pd.DataFrame()

for epoch in range(n_epochs):
    print("Epoch", epoch)
    train_ds = train_dataset.shuffle(n_train).batch(batch_size)
    val_ds = validation_dataset.shuffle(n_test).batch(n_test)
    
    x_val, y_val = next(iter(val_ds))
    x_val, y_val = slice_accordingly(x_val, y_val)
    
    for features, labels in train_ds:
        features, labels = slice_accordingly(features, labels)
        
        history = model.fit(features, labels,
                           validation_data=(x_val, y_val),verbose=1)
        history = pd.DataFrame(history.history)
        history_df = history_df.append(history)
# Out:
# Epoch 0
# 2/2 [==============================] - 2s 430ms/step - loss: -0.6585 - MSE: 0.0983 - cosine_similarity: 0.7568 - r_square: -3.4421 - val_loss: -0.6715 - val_MSE: 0.0556 - val_cosine_similarity: 0.7271 - val_r_square: -0.6462
# 2/2 [==============================] - 0s 98ms/step - loss: -0.6482 - MSE: 0.0520 - cosine_similarity: 0.7002 - r_square: -0.6813 - val_loss: -0.7264 - val_MSE: 0.0400 - val_cosine_similarity: 0.7664 - val_r_square: -0.2309
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7181 - MSE: 0.0387 - cosine_similarity: 0.7568 - r_square: -0.2158 - val_loss: -0.7353 - val_MSE: 0.0387 - val_cosine_similarity: 0.7740 - val_r_square: -0.2459
# 2/2 [==============================] - 0s 95ms/step - loss: -0.6911 - MSE: 0.0419 - cosine_similarity: 0.7330 - r_square: -0.3415 - val_loss: -0.7301 - val_MSE: 0.0399 - val_cosine_similarity: 0.7700 - val_r_square: -0.2575
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7403 - MSE: 0.0328 - cosine_similarity: 0.7731 - r_square: -0.2367 - val_loss: -0.7311 - val_MSE: 0.0401 - val_cosine_similarity: 0.7712 - val_r_square: -0.3708
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7275 - MSE: 0.0386 - cosine_similarity: 0.7661 - r_square: -0.1435 - val_loss: -0.7227 - val_MSE: 0.0424 - val_cosine_similarity: 0.7652 - val_r_square: -0.4220
# Epoch 1
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7081 - MSE: 0.0398 - cosine_similarity: 0.7479 - r_square: -0.2748 - val_loss: -0.7189 - val_MSE: 0.0442 - val_cosine_similarity: 0.7631 - val_r_square: -0.3807
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7430 - MSE: 0.0379 - cosine_similarity: 0.7809 - r_square: -0.1437 - val_loss: -0.7304 - val_MSE: 0.0436 - val_cosine_similarity: 0.7741 - val_r_square: -0.3824
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7774 - MSE: 0.0318 - cosine_similarity: 0.8092 - r_square: -0.0900 - val_loss: -0.7362 - val_MSE: 0.0438 - val_cosine_similarity: 0.7801 - val_r_square: -0.4398
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7343 - MSE: 0.0375 - cosine_similarity: 0.7719 - r_square: -0.2407 - val_loss: -0.7378 - val_MSE: 0.0442 - val_cosine_similarity: 0.7820 - val_r_square: -0.4899
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7486 - MSE: 0.0370 - cosine_similarity: 0.7856 - r_square: -0.2241 - val_loss: -0.7408 - val_MSE: 0.0436 - val_cosine_similarity: 0.7844 - val_r_square: -0.4764
# 2/2 [==============================] - 0s 110ms/step - loss: -0.7432 - MSE: 0.0375 - cosine_similarity: 0.7808 - r_square: -0.2474 - val_loss: -0.7400 - val_MSE: 0.0435 - val_cosine_similarity: 0.7835 - val_r_square: -0.4675
# Epoch 2
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7300 - MSE: 0.0410 - cosine_similarity: 0.7710 - r_square: -0.1143 - val_loss: -0.7376 - val_MSE: 0.0437 - val_cosine_similarity: 0.7813 - val_r_square: -0.4965
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7573 - MSE: 0.0348 - cosine_similarity: 0.7921 - r_square: -0.1784 - val_loss: -0.7391 - val_MSE: 0.0428 - val_cosine_similarity: 0.7819 - val_r_square: -0.4458
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7695 - MSE: 0.0314 - cosine_similarity: 0.8009 - r_square: -0.1874 - val_loss: -0.7430 - val_MSE: 0.0418 - val_cosine_similarity: 0.7848 - val_r_square: -0.3848
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7641 - MSE: 0.0320 - cosine_similarity: 0.7960 - r_square: -0.1654 - val_loss: -0.7435 - val_MSE: 0.0417 - val_cosine_similarity: 0.7851 - val_r_square: -0.3968
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7699 - MSE: 0.0321 - cosine_similarity: 0.8020 - r_square: -0.0655 - val_loss: -0.7404 - val_MSE: 0.0422 - val_cosine_similarity: 0.7825 - val_r_square: -0.4450
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7185 - MSE: 0.0375 - cosine_similarity: 0.7560 - r_square: -0.1356 - val_loss: -0.7366 - val_MSE: 0.0427 - val_cosine_similarity: 0.7794 - val_r_square: -0.4775
# Epoch 3
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7569 - MSE: 0.0343 - cosine_similarity: 0.7912 - r_square: -0.1169 - val_loss: -0.7365 - val_MSE: 0.0433 - val_cosine_similarity: 0.7797 - val_r_square: -0.4656
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7626 - MSE: 0.0329 - cosine_similarity: 0.7955 - r_square: -0.1403 - val_loss: -0.7390 - val_MSE: 0.0431 - val_cosine_similarity: 0.7821 - val_r_square: -0.4379
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7309 - MSE: 0.0362 - cosine_similarity: 0.7671 - r_square: -0.4464 - val_loss: -0.7423 - val_MSE: 0.0426 - val_cosine_similarity: 0.7849 - val_r_square: -0.4148
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7570 - MSE: 0.0335 - cosine_similarity: 0.7905 - r_square: -0.1193 - val_loss: -0.7418 - val_MSE: 0.0426 - val_cosine_similarity: 0.7843 - val_r_square: -0.3969
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7599 - MSE: 0.0337 - cosine_similarity: 0.7936 - r_square: -0.0521 - val_loss: -0.7359 - val_MSE: 0.0432 - val_cosine_similarity: 0.7792 - val_r_square: -0.4142
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7488 - MSE: 0.0336 - cosine_similarity: 0.7824 - r_square: -0.1362 - val_loss: -0.7306 - val_MSE: 0.0444 - val_cosine_similarity: 0.7750 - val_r_square: -0.4690
# Epoch 4
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7509 - MSE: 0.0351 - cosine_similarity: 0.7859 - r_square: -0.0180 - val_loss: -0.7217 - val_MSE: 0.0456 - val_cosine_similarity: 0.7673 - val_r_square: -0.5609
# 2/2 [==============================] - 0s 94ms/step - loss: -0.7494 - MSE: 0.0337 - cosine_similarity: 0.7831 - r_square: -0.2110 - val_loss: -0.7236 - val_MSE: 0.0461 - val_cosine_similarity: 0.7697 - val_r_square: -0.6051
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7576 - MSE: 0.0349 - cosine_similarity: 0.7925 - r_square: -0.1842 - val_loss: -0.7304 - val_MSE: 0.0458 - val_cosine_similarity: 0.7762 - val_r_square: -0.6098
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7384 - MSE: 0.0374 - cosine_similarity: 0.7758 - r_square: -0.1088 - val_loss: -0.7349 - val_MSE: 0.0457 - val_cosine_similarity: 0.7805 - val_r_square: -0.6004
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7716 - MSE: 0.0331 - cosine_similarity: 0.8048 - r_square: -0.1729 - val_loss: -0.7370 - val_MSE: 0.0456 - val_cosine_similarity: 0.7826 - val_r_square: -0.5966
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7482 - MSE: 0.0360 - cosine_similarity: 0.7841 - r_square: -0.1877 - val_loss: -0.7376 - val_MSE: 0.0453 - val_cosine_similarity: 0.7829 - val_r_square: -0.5852
# Epoch 5
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7385 - MSE: 0.0379 - cosine_similarity: 0.7764 - r_square: -0.0764 - val_loss: -0.7413 - val_MSE: 0.0449 - val_cosine_similarity: 0.7862 - val_r_square: -0.5732
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7758 - MSE: 0.0305 - cosine_similarity: 0.8063 - r_square: -0.0760 - val_loss: -0.7388 - val_MSE: 0.0449 - val_cosine_similarity: 0.7837 - val_r_square: -0.5750
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7925 - MSE: 0.0280 - cosine_similarity: 0.8205 - r_square: -0.1191 - val_loss: -0.7326 - val_MSE: 0.0454 - val_cosine_similarity: 0.7780 - val_r_square: -0.5886
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7681 - MSE: 0.0318 - cosine_similarity: 0.7999 - r_square: -0.1160 - val_loss: -0.7285 - val_MSE: 0.0457 - val_cosine_similarity: 0.7742 - val_r_square: -0.5808
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7482 - MSE: 0.0365 - cosine_similarity: 0.7847 - r_square: -0.1352 - val_loss: -0.7300 - val_MSE: 0.0450 - val_cosine_similarity: 0.7750 - val_r_square: -0.5354
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7461 - MSE: 0.0351 - cosine_similarity: 0.7812 - r_square: -0.1132 - val_loss: -0.7347 - val_MSE: 0.0440 - val_cosine_similarity: 0.7788 - val_r_square: -0.4915
# Epoch 6
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7634 - MSE: 0.0327 - cosine_similarity: 0.7962 - r_square: -0.0417 - val_loss: -0.7400 - val_MSE: 0.0427 - val_cosine_similarity: 0.7827 - val_r_square: -0.4517
# 2/2 [==============================] - 0s 111ms/step - loss: -0.7720 - MSE: 0.0321 - cosine_similarity: 0.8041 - r_square: -0.0078 - val_loss: -0.7426 - val_MSE: 0.0425 - val_cosine_similarity: 0.7850 - val_r_square: -0.4574
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7890 - MSE: 0.0281 - cosine_similarity: 0.8171 - r_square: -0.0435 - val_loss: -0.7436 - val_MSE: 0.0424 - val_cosine_similarity: 0.7860 - val_r_square: -0.4657
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7686 - MSE: 0.0315 - cosine_similarity: 0.8001 - r_square: -0.0508 - val_loss: -0.7447 - val_MSE: 0.0423 - val_cosine_similarity: 0.7870 - val_r_square: -0.4660
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7395 - MSE: 0.0373 - cosine_similarity: 0.7768 - r_square: -0.0288 - val_loss: -0.7441 - val_MSE: 0.0425 - val_cosine_similarity: 0.7867 - val_r_square: -0.4820
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7486 - MSE: 0.0333 - cosine_similarity: 0.7819 - r_square: -0.1436 - val_loss: -0.7421 - val_MSE: 0.0429 - val_cosine_similarity: 0.7850 - val_r_square: -0.5061
# Epoch 7
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7584 - MSE: 0.0336 - cosine_similarity: 0.7920 - r_square: -0.0316 - val_loss: -0.7399 - val_MSE: 0.0437 - val_cosine_similarity: 0.7836 - val_r_square: -0.5472
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7654 - MSE: 0.0317 - cosine_similarity: 0.7970 - r_square: -0.1075 - val_loss: -0.7366 - val_MSE: 0.0443 - val_cosine_similarity: 0.7809 - val_r_square: -0.5649
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7705 - MSE: 0.0303 - cosine_similarity: 0.8007 - r_square: -0.0220 - val_loss: -0.7347 - val_MSE: 0.0447 - val_cosine_similarity: 0.7794 - val_r_square: -0.5767
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7722 - MSE: 0.0323 - cosine_similarity: 0.8045 - r_square: -0.0463 - val_loss: -0.7359 - val_MSE: 0.0446 - val_cosine_similarity: 0.7805 - val_r_square: -0.5686
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7422 - MSE: 0.0352 - cosine_similarity: 0.7774 - r_square: -0.1356 - val_loss: -0.7371 - val_MSE: 0.0442 - val_cosine_similarity: 0.7813 - val_r_square: -0.5542
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7606 - MSE: 0.0328 - cosine_similarity: 0.7933 - r_square: -0.0965 - val_loss: -0.7398 - val_MSE: 0.0436 - val_cosine_similarity: 0.7834 - val_r_square: -0.5165
# Epoch 8
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7850 - MSE: 0.0303 - cosine_similarity: 0.8154 - r_square: 0.0376 - val_loss: -0.7414 - val_MSE: 0.0426 - val_cosine_similarity: 0.7841 - val_r_square: -0.4452
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7586 - MSE: 0.0334 - cosine_similarity: 0.7920 - r_square: -0.0472 - val_loss: -0.7435 - val_MSE: 0.0420 - val_cosine_similarity: 0.7856 - val_r_square: -0.3948
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7386 - MSE: 0.0349 - cosine_similarity: 0.7735 - r_square: -0.1706 - val_loss: -0.7433 - val_MSE: 0.0419 - val_cosine_similarity: 0.7852 - val_r_square: -0.3898
# 2/2 [==============================] - 0s 106ms/step - loss: -0.7677 - MSE: 0.0314 - cosine_similarity: 0.7991 - r_square: -0.0017 - val_loss: -0.7417 - val_MSE: 0.0420 - val_cosine_similarity: 0.7837 - val_r_square: -0.4064
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7932 - MSE: 0.0290 - cosine_similarity: 0.8222 - r_square: -0.0432 - val_loss: -0.7414 - val_MSE: 0.0422 - val_cosine_similarity: 0.7835 - val_r_square: -0.4381
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7733 - MSE: 0.0306 - cosine_similarity: 0.8039 - r_square: -0.0052 - val_loss: -0.7397 - val_MSE: 0.0427 - val_cosine_similarity: 0.7825 - val_r_square: -0.4922
# Epoch 9
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7764 - MSE: 0.0303 - cosine_similarity: 0.8066 - r_square: 0.0311 - val_loss: -0.7417 - val_MSE: 0.0422 - val_cosine_similarity: 0.7839 - val_r_square: -0.4940
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7652 - MSE: 0.0297 - cosine_similarity: 0.7949 - r_square: -0.0702 - val_loss: -0.7416 - val_MSE: 0.0420 - val_cosine_similarity: 0.7836 - val_r_square: -0.4892
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7831 - MSE: 0.0301 - cosine_similarity: 0.8132 - r_square: 0.0356 - val_loss: -0.7415 - val_MSE: 0.0417 - val_cosine_similarity: 0.7832 - val_r_square: -0.4748
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7595 - MSE: 0.0320 - cosine_similarity: 0.7915 - r_square: 0.0134 - val_loss: -0.7422 - val_MSE: 0.0412 - val_cosine_similarity: 0.7834 - val_r_square: -0.4360
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7746 - MSE: 0.0316 - cosine_similarity: 0.8062 - r_square: -0.0421 - val_loss: -0.7432 - val_MSE: 0.0408 - val_cosine_similarity: 0.7840 - val_r_square: -0.4054
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7765 - MSE: 0.0321 - cosine_similarity: 0.8085 - r_square: 0.0186 - val_loss: -0.7431 - val_MSE: 0.0408 - val_cosine_similarity: 0.7839 - val_r_square: -0.3945
# Epoch 10
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7546 - MSE: 0.0335 - cosine_similarity: 0.7881 - r_square: -0.0244 - val_loss: -0.7365 - val_MSE: 0.0419 - val_cosine_similarity: 0.7784 - val_r_square: -0.4270
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7954 - MSE: 0.0283 - cosine_similarity: 0.8237 - r_square: 0.0815 - val_loss: -0.7352 - val_MSE: 0.0417 - val_cosine_similarity: 0.7770 - val_r_square: -0.4060
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7861 - MSE: 0.0279 - cosine_similarity: 0.8140 - r_square: 0.0285 - val_loss: -0.7354 - val_MSE: 0.0415 - val_cosine_similarity: 0.7769 - val_r_square: -0.3939
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7690 - MSE: 0.0324 - cosine_similarity: 0.8013 - r_square: -0.0317 - val_loss: -0.7372 - val_MSE: 0.0415 - val_cosine_similarity: 0.7787 - val_r_square: -0.3971
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7806 - MSE: 0.0300 - cosine_similarity: 0.8106 - r_square: -0.0087 - val_loss: -0.7383 - val_MSE: 0.0419 - val_cosine_similarity: 0.7802 - val_r_square: -0.4242
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7744 - MSE: 0.0297 - cosine_similarity: 0.8041 - r_square: -0.0147 - val_loss: -0.7383 - val_MSE: 0.0425 - val_cosine_similarity: 0.7809 - val_r_square: -0.4680
# Epoch 11
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7800 - MSE: 0.0295 - cosine_similarity: 0.8096 - r_square: 0.0509 - val_loss: -0.7432 - val_MSE: 0.0423 - val_cosine_similarity: 0.7855 - val_r_square: -0.4767
# 2/2 [==============================] - 0s 106ms/step - loss: -0.7783 - MSE: 0.0317 - cosine_similarity: 0.8100 - r_square: -0.0402 - val_loss: -0.7439 - val_MSE: 0.0421 - val_cosine_similarity: 0.7860 - val_r_square: -0.4624
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7713 - MSE: 0.0298 - cosine_similarity: 0.8011 - r_square: -0.0956 - val_loss: -0.7438 - val_MSE: 0.0419 - val_cosine_similarity: 0.7857 - val_r_square: -0.4560
# 2/2 [==============================] - 0s 108ms/step - loss: -0.7791 - MSE: 0.0297 - cosine_similarity: 0.8088 - r_square: 0.0083 - val_loss: -0.7430 - val_MSE: 0.0420 - val_cosine_similarity: 0.7850 - val_r_square: -0.4708
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7803 - MSE: 0.0293 - cosine_similarity: 0.8095 - r_square: 0.0673 - val_loss: -0.7418 - val_MSE: 0.0421 - val_cosine_similarity: 0.7839 - val_r_square: -0.4749
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7620 - MSE: 0.0328 - cosine_similarity: 0.7948 - r_square: -0.0090 - val_loss: -0.7424 - val_MSE: 0.0419 - val_cosine_similarity: 0.7843 - val_r_square: -0.4567
# Epoch 12
# 2/2 [==============================] - 0s 109ms/step - loss: -0.7751 - MSE: 0.0313 - cosine_similarity: 0.8064 - r_square: 0.0159 - val_loss: -0.7395 - val_MSE: 0.0420 - val_cosine_similarity: 0.7815 - val_r_square: -0.4376
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7701 - MSE: 0.0309 - cosine_similarity: 0.8010 - r_square: 0.0315 - val_loss: -0.7410 - val_MSE: 0.0415 - val_cosine_similarity: 0.7825 - val_r_square: -0.4065
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7953 - MSE: 0.0292 - cosine_similarity: 0.8244 - r_square: 0.0097 - val_loss: -0.7418 - val_MSE: 0.0411 - val_cosine_similarity: 0.7829 - val_r_square: -0.3823
# 2/2 [==============================] - 0s 115ms/step - loss: -0.7835 - MSE: 0.0289 - cosine_similarity: 0.8124 - r_square: 0.0059 - val_loss: -0.7427 - val_MSE: 0.0406 - val_cosine_similarity: 0.7833 - val_r_square: -0.3580
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7562 - MSE: 0.0319 - cosine_similarity: 0.7881 - r_square: 0.0086 - val_loss: -0.7430 - val_MSE: 0.0402 - val_cosine_similarity: 0.7832 - val_r_square: -0.3363
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7758 - MSE: 0.0299 - cosine_similarity: 0.8057 - r_square: 0.0349 - val_loss: -0.7430 - val_MSE: 0.0399 - val_cosine_similarity: 0.7829 - val_r_square: -0.3323
# Epoch 13
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7794 - MSE: 0.0293 - cosine_similarity: 0.8086 - r_square: 0.0139 - val_loss: -0.7450 - val_MSE: 0.0394 - val_cosine_similarity: 0.7845 - val_r_square: -0.3225
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7803 - MSE: 0.0306 - cosine_similarity: 0.8109 - r_square: 0.0205 - val_loss: -0.7428 - val_MSE: 0.0399 - val_cosine_similarity: 0.7827 - val_r_square: -0.3512
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7733 - MSE: 0.0299 - cosine_similarity: 0.8031 - r_square: 0.0022 - val_loss: -0.7421 - val_MSE: 0.0400 - val_cosine_similarity: 0.7821 - val_r_square: -0.3645
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7628 - MSE: 0.0322 - cosine_similarity: 0.7949 - r_square: -0.1169 - val_loss: -0.7433 - val_MSE: 0.0398 - val_cosine_similarity: 0.7832 - val_r_square: -0.3464
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7882 - MSE: 0.0289 - cosine_similarity: 0.8171 - r_square: 0.0723 - val_loss: -0.7442 - val_MSE: 0.0399 - val_cosine_similarity: 0.7841 - val_r_square: -0.3435
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7784 - MSE: 0.0312 - cosine_similarity: 0.8096 - r_square: 0.0824 - val_loss: -0.7458 - val_MSE: 0.0397 - val_cosine_similarity: 0.7855 - val_r_square: -0.3274
# Epoch 14
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7797 - MSE: 0.0298 - cosine_similarity: 0.8095 - r_square: 0.0365 - val_loss: -0.7478 - val_MSE: 0.0394 - val_cosine_similarity: 0.7872 - val_r_square: -0.3215
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7621 - MSE: 0.0330 - cosine_similarity: 0.7951 - r_square: -0.0099 - val_loss: -0.7465 - val_MSE: 0.0395 - val_cosine_similarity: 0.7861 - val_r_square: -0.3224
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7785 - MSE: 0.0283 - cosine_similarity: 0.8068 - r_square: 0.0023 - val_loss: -0.7442 - val_MSE: 0.0397 - val_cosine_similarity: 0.7839 - val_r_square: -0.3233
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7860 - MSE: 0.0306 - cosine_similarity: 0.8165 - r_square: -0.0159 - val_loss: -0.7435 - val_MSE: 0.0396 - val_cosine_similarity: 0.7832 - val_r_square: -0.3145
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7874 - MSE: 0.0303 - cosine_similarity: 0.8176 - r_square: 0.0818 - val_loss: -0.7447 - val_MSE: 0.0395 - val_cosine_similarity: 0.7842 - val_r_square: -0.3241
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7964 - MSE: 0.0271 - cosine_similarity: 0.8235 - r_square: 0.0462 - val_loss: -0.7460 - val_MSE: 0.0395 - val_cosine_similarity: 0.7856 - val_r_square: -0.3382
# Epoch 15
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7493 - MSE: 0.0346 - cosine_similarity: 0.7840 - r_square: -0.0013 - val_loss: -0.7413 - val_MSE: 0.0411 - val_cosine_similarity: 0.7824 - val_r_square: -0.4121
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7828 - MSE: 0.0296 - cosine_similarity: 0.8124 - r_square: 0.0827 - val_loss: -0.7406 - val_MSE: 0.0413 - val_cosine_similarity: 0.7819 - val_r_square: -0.4263
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7718 - MSE: 0.0311 - cosine_similarity: 0.8030 - r_square: 0.0409 - val_loss: -0.7399 - val_MSE: 0.0414 - val_cosine_similarity: 0.7813 - val_r_square: -0.4205
# 2/2 [==============================] - 0s 98ms/step - loss: -0.8241 - MSE: 0.0222 - cosine_similarity: 0.8462 - r_square: 0.0529 - val_loss: -0.7406 - val_MSE: 0.0410 - val_cosine_similarity: 0.7817 - val_r_square: -0.3870
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7743 - MSE: 0.0338 - cosine_similarity: 0.8081 - r_square: 0.0754 - val_loss: -0.7402 - val_MSE: 0.0410 - val_cosine_similarity: 0.7812 - val_r_square: -0.3798
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7936 - MSE: 0.0254 - cosine_similarity: 0.8190 - r_square: -0.0025 - val_loss: -0.7385 - val_MSE: 0.0413 - val_cosine_similarity: 0.7798 - val_r_square: -0.3965
# Epoch 16
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7946 - MSE: 0.0259 - cosine_similarity: 0.8206 - r_square: 0.0392 - val_loss: -0.7361 - val_MSE: 0.0416 - val_cosine_similarity: 0.7777 - val_r_square: -0.4171
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7677 - MSE: 0.0321 - cosine_similarity: 0.7998 - r_square: -0.0275 - val_loss: -0.7351 - val_MSE: 0.0417 - val_cosine_similarity: 0.7769 - val_r_square: -0.4291
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7619 - MSE: 0.0344 - cosine_similarity: 0.7963 - r_square: 0.0878 - val_loss: -0.7360 - val_MSE: 0.0415 - val_cosine_similarity: 0.7774 - val_r_square: -0.3991
# 2/2 [==============================] - 0s 109ms/step - loss: -0.7995 - MSE: 0.0270 - cosine_similarity: 0.8265 - r_square: 0.0425 - val_loss: -0.7373 - val_MSE: 0.0410 - val_cosine_similarity: 0.7783 - val_r_square: -0.3616
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7954 - MSE: 0.0268 - cosine_similarity: 0.8221 - r_square: 0.0536 - val_loss: -0.7377 - val_MSE: 0.0410 - val_cosine_similarity: 0.7787 - val_r_square: -0.3577
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7792 - MSE: 0.0303 - cosine_similarity: 0.8095 - r_square: 0.0649 - val_loss: -0.7383 - val_MSE: 0.0410 - val_cosine_similarity: 0.7793 - val_r_square: -0.3645
# Epoch 17
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7774 - MSE: 0.0306 - cosine_similarity: 0.8080 - r_square: 0.0176 - val_loss: -0.7438 - val_MSE: 0.0406 - val_cosine_similarity: 0.7844 - val_r_square: -0.3555
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7666 - MSE: 0.0319 - cosine_similarity: 0.7985 - r_square: 0.0259 - val_loss: -0.7441 - val_MSE: 0.0406 - val_cosine_similarity: 0.7847 - val_r_square: -0.3646
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7533 - MSE: 0.0335 - cosine_similarity: 0.7868 - r_square: -0.0159 - val_loss: -0.7430 - val_MSE: 0.0410 - val_cosine_similarity: 0.7840 - val_r_square: -0.3905
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7806 - MSE: 0.0293 - cosine_similarity: 0.8099 - r_square: 0.0687 - val_loss: -0.7418 - val_MSE: 0.0417 - val_cosine_similarity: 0.7835 - val_r_square: -0.4340
# 2/2 [==============================] - 0s 98ms/step - loss: -0.8051 - MSE: 0.0256 - cosine_similarity: 0.8306 - r_square: 0.0853 - val_loss: -0.7413 - val_MSE: 0.0421 - val_cosine_similarity: 0.7834 - val_r_square: -0.4656
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7975 - MSE: 0.0278 - cosine_similarity: 0.8252 - r_square: 0.0972 - val_loss: -0.7412 - val_MSE: 0.0423 - val_cosine_similarity: 0.7835 - val_r_square: -0.4747
# Epoch 18
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7831 - MSE: 0.0300 - cosine_similarity: 0.8131 - r_square: -0.0276 - val_loss: -0.7412 - val_MSE: 0.0413 - val_cosine_similarity: 0.7825 - val_r_square: -0.4298
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7840 - MSE: 0.0283 - cosine_similarity: 0.8123 - r_square: 0.0372 - val_loss: -0.7424 - val_MSE: 0.0410 - val_cosine_similarity: 0.7834 - val_r_square: -0.4132
# 2/2 [==============================] - 0s 105ms/step - loss: -0.7937 - MSE: 0.0275 - cosine_similarity: 0.8213 - r_square: 0.0764 - val_loss: -0.7434 - val_MSE: 0.0406 - val_cosine_similarity: 0.7840 - val_r_square: -0.3827
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7939 - MSE: 0.0271 - cosine_similarity: 0.8210 - r_square: 0.0592 - val_loss: -0.7433 - val_MSE: 0.0402 - val_cosine_similarity: 0.7836 - val_r_square: -0.3462
# 2/2 [==============================] - 0s 106ms/step - loss: -0.7697 - MSE: 0.0322 - cosine_similarity: 0.8018 - r_square: 0.0047 - val_loss: -0.7414 - val_MSE: 0.0401 - val_cosine_similarity: 0.7815 - val_r_square: -0.3218
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7685 - MSE: 0.0331 - cosine_similarity: 0.8015 - r_square: 0.0434 - val_loss: -0.7384 - val_MSE: 0.0405 - val_cosine_similarity: 0.7789 - val_r_square: -0.3258
# Epoch 19
# 2/2 [==============================] - 0s 101ms/step - loss: -0.8017 - MSE: 0.0273 - cosine_similarity: 0.8290 - r_square: 0.0661 - val_loss: -0.7357 - val_MSE: 0.0411 - val_cosine_similarity: 0.7768 - val_r_square: -0.3536
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7807 - MSE: 0.0296 - cosine_similarity: 0.8103 - r_square: 0.0953 - val_loss: -0.7375 - val_MSE: 0.0409 - val_cosine_similarity: 0.7784 - val_r_square: -0.3586
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7844 - MSE: 0.0304 - cosine_similarity: 0.8148 - r_square: 0.0285 - val_loss: -0.7381 - val_MSE: 0.0407 - val_cosine_similarity: 0.7789 - val_r_square: -0.3586
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7899 - MSE: 0.0288 - cosine_similarity: 0.8187 - r_square: 0.0887 - val_loss: -0.7392 - val_MSE: 0.0406 - val_cosine_similarity: 0.7798 - val_r_square: -0.3620
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7960 - MSE: 0.0284 - cosine_similarity: 0.8244 - r_square: 0.0984 - val_loss: -0.7398 - val_MSE: 0.0406 - val_cosine_similarity: 0.7804 - val_r_square: -0.3703
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7756 - MSE: 0.0287 - cosine_similarity: 0.8043 - r_square: -0.0270 - val_loss: -0.7393 - val_MSE: 0.0410 - val_cosine_similarity: 0.7803 - val_r_square: -0.3985
# Epoch 20
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7965 - MSE: 0.0285 - cosine_similarity: 0.8250 - r_square: 0.0845 - val_loss: -0.7404 - val_MSE: 0.0411 - val_cosine_similarity: 0.7815 - val_r_square: -0.4377
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7515 - MSE: 0.0352 - cosine_similarity: 0.7867 - r_square: -0.0079 - val_loss: -0.7389 - val_MSE: 0.0416 - val_cosine_similarity: 0.7804 - val_r_square: -0.4646
# 2/2 [==============================] - 0s 99ms/step - loss: -0.8086 - MSE: 0.0258 - cosine_similarity: 0.8344 - r_square: 0.0428 - val_loss: -0.7388 - val_MSE: 0.0417 - val_cosine_similarity: 0.7805 - val_r_square: -0.4548
# 2/2 [==============================] - 0s 103ms/step - loss: -0.8090 - MSE: 0.0251 - cosine_similarity: 0.8340 - r_square: 0.0480 - val_loss: -0.7410 - val_MSE: 0.0413 - val_cosine_similarity: 0.7823 - val_r_square: -0.4147
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7507 - MSE: 0.0347 - cosine_similarity: 0.7854 - r_square: 0.0081 - val_loss: -0.7433 - val_MSE: 0.0408 - val_cosine_similarity: 0.7842 - val_r_square: -0.3763
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7740 - MSE: 0.0297 - cosine_similarity: 0.8037 - r_square: 0.0446 - val_loss: -0.7434 - val_MSE: 0.0407 - val_cosine_similarity: 0.7840 - val_r_square: -0.3559
# Epoch 21
# 2/2 [==============================] - 0s 97ms/step - loss: -0.8220 - MSE: 0.0241 - cosine_similarity: 0.8462 - r_square: 0.1283 - val_loss: -0.7384 - val_MSE: 0.0415 - val_cosine_similarity: 0.7799 - val_r_square: -0.3893
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7815 - MSE: 0.0296 - cosine_similarity: 0.8111 - r_square: 0.0817 - val_loss: -0.7374 - val_MSE: 0.0417 - val_cosine_similarity: 0.7790 - val_r_square: -0.4050
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7598 - MSE: 0.0319 - cosine_similarity: 0.7917 - r_square: -0.0196 - val_loss: -0.7365 - val_MSE: 0.0417 - val_cosine_similarity: 0.7782 - val_r_square: -0.4069
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7937 - MSE: 0.0291 - cosine_similarity: 0.8229 - r_square: 0.0984 - val_loss: -0.7361 - val_MSE: 0.0414 - val_cosine_similarity: 0.7775 - val_r_square: -0.3854
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7985 - MSE: 0.0272 - cosine_similarity: 0.8257 - r_square: 0.0569 - val_loss: -0.7346 - val_MSE: 0.0412 - val_cosine_similarity: 0.7758 - val_r_square: -0.3756
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7755 - MSE: 0.0305 - cosine_similarity: 0.8060 - r_square: 0.0347 - val_loss: -0.7343 - val_MSE: 0.0408 - val_cosine_similarity: 0.7751 - val_r_square: -0.3507
# Epoch 22
# 2/2 [==============================] - 0s 104ms/step - loss: -0.8086 - MSE: 0.0256 - cosine_similarity: 0.8342 - r_square: 0.0891 - val_loss: -0.7380 - val_MSE: 0.0397 - val_cosine_similarity: 0.7777 - val_r_square: -0.3030
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7696 - MSE: 0.0305 - cosine_similarity: 0.8001 - r_square: 0.0125 - val_loss: -0.7381 - val_MSE: 0.0399 - val_cosine_similarity: 0.7780 - val_r_square: -0.3211
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7971 - MSE: 0.0289 - cosine_similarity: 0.8260 - r_square: 0.1248 - val_loss: -0.7388 - val_MSE: 0.0402 - val_cosine_similarity: 0.7790 - val_r_square: -0.3487
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7724 - MSE: 0.0316 - cosine_similarity: 0.8040 - r_square: 0.0284 - val_loss: -0.7396 - val_MSE: 0.0406 - val_cosine_similarity: 0.7802 - val_r_square: -0.3871
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7785 - MSE: 0.0303 - cosine_similarity: 0.8087 - r_square: 0.0813 - val_loss: -0.7415 - val_MSE: 0.0406 - val_cosine_similarity: 0.7821 - val_r_square: -0.3988
# 2/2 [==============================] - 0s 98ms/step - loss: -0.8066 - MSE: 0.0261 - cosine_similarity: 0.8327 - r_square: 0.1070 - val_loss: -0.7431 - val_MSE: 0.0405 - val_cosine_similarity: 0.7836 - val_r_square: -0.4011
# Epoch 23
# 2/2 [==============================] - 0s 101ms/step - loss: -0.8131 - MSE: 0.0236 - cosine_similarity: 0.8367 - r_square: 0.0879 - val_loss: -0.7408 - val_MSE: 0.0416 - val_cosine_similarity: 0.7824 - val_r_square: -0.4441
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7697 - MSE: 0.0326 - cosine_similarity: 0.8022 - r_square: -3.2128e-04 - val_loss: -0.7391 - val_MSE: 0.0419 - val_cosine_similarity: 0.7810 - val_r_square: -0.4542
# 2/2 [==============================] - 0s 213ms/step - loss: -0.8075 - MSE: 0.0263 - cosine_similarity: 0.8339 - r_square: 0.0962 - val_loss: -0.7374 - val_MSE: 0.0421 - val_cosine_similarity: 0.7795 - val_r_square: -0.4574
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7573 - MSE: 0.0348 - cosine_similarity: 0.7921 - r_square: -0.0214 - val_loss: -0.7379 - val_MSE: 0.0419 - val_cosine_similarity: 0.7798 - val_r_square: -0.4281
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7863 - MSE: 0.0304 - cosine_similarity: 0.8167 - r_square: 0.0821 - val_loss: -0.7391 - val_MSE: 0.0416 - val_cosine_similarity: 0.7807 - val_r_square: -0.3839
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7889 - MSE: 0.0280 - cosine_similarity: 0.8169 - r_square: 0.0438 - val_loss: -0.7400 - val_MSE: 0.0414 - val_cosine_similarity: 0.7814 - val_r_square: -0.3619
# Epoch 24
# 2/2 [==============================] - 0s 107ms/step - loss: -0.8021 - MSE: 0.0285 - cosine_similarity: 0.8306 - r_square: 0.0734 - val_loss: -0.7418 - val_MSE: 0.0406 - val_cosine_similarity: 0.7824 - val_r_square: -0.3307
# 2/2 [==============================] - 0s 99ms/step - loss: -0.8068 - MSE: 0.0258 - cosine_similarity: 0.8327 - r_square: 0.1143 - val_loss: -0.7431 - val_MSE: 0.0404 - val_cosine_similarity: 0.7835 - val_r_square: -0.3392
# 2/2 [==============================] - 0s 100ms/step - loss: -0.8010 - MSE: 0.0271 - cosine_similarity: 0.8281 - r_square: 0.0725 - val_loss: -0.7440 - val_MSE: 0.0405 - val_cosine_similarity: 0.7845 - val_r_square: -0.3530
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7643 - MSE: 0.0331 - cosine_similarity: 0.7974 - r_square: 0.0620 - val_loss: -0.7443 - val_MSE: 0.0404 - val_cosine_similarity: 0.7847 - val_r_square: -0.3585
# 2/2 [==============================] - 0s 106ms/step - loss: -0.7844 - MSE: 0.0294 - cosine_similarity: 0.8138 - r_square: 0.0988 - val_loss: -0.7428 - val_MSE: 0.0405 - val_cosine_similarity: 0.7833 - val_r_square: -0.3640
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7680 - MSE: 0.0301 - cosine_similarity: 0.7981 - r_square: -0.0489 - val_loss: -0.7391 - val_MSE: 0.0412 - val_cosine_similarity: 0.7803 - val_r_square: -0.4126
# Epoch 25
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7903 - MSE: 0.0303 - cosine_similarity: 0.8205 - r_square: 0.1120 - val_loss: -0.7352 - val_MSE: 0.0420 - val_cosine_similarity: 0.7772 - val_r_square: -0.4347
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7944 - MSE: 0.0292 - cosine_similarity: 0.8235 - r_square: 0.0946 - val_loss: -0.7322 - val_MSE: 0.0422 - val_cosine_similarity: 0.7744 - val_r_square: -0.4363
# 2/2 [==============================] - 0s 114ms/step - loss: -0.7987 - MSE: 0.0259 - cosine_similarity: 0.8245 - r_square: 0.1320 - val_loss: -0.7288 - val_MSE: 0.0426 - val_cosine_similarity: 0.7714 - val_r_square: -0.4556
# 2/2 [==============================] - 0s 99ms/step - loss: -0.8014 - MSE: 0.0277 - cosine_similarity: 0.8291 - r_square: 0.0748 - val_loss: -0.7273 - val_MSE: 0.0428 - val_cosine_similarity: 0.7701 - val_r_square: -0.4679
# 2/2 [==============================] - 0s 100ms/step - loss: -0.8094 - MSE: 0.0274 - cosine_similarity: 0.8368 - r_square: 0.0857 - val_loss: -0.7304 - val_MSE: 0.0424 - val_cosine_similarity: 0.7728 - val_r_square: -0.4382
# 2/2 [==============================] - 0s 111ms/step - loss: -0.7980 - MSE: 0.0256 - cosine_similarity: 0.8236 - r_square: 0.0405 - val_loss: -0.7339 - val_MSE: 0.0418 - val_cosine_similarity: 0.7757 - val_r_square: -0.3901
# Epoch 26
# 2/2 [==============================] - 0s 105ms/step - loss: -0.7899 - MSE: 0.0282 - cosine_similarity: 0.8181 - r_square: 0.0407 - val_loss: -0.7355 - val_MSE: 0.0416 - val_cosine_similarity: 0.7771 - val_r_square: -0.3820
# 2/2 [==============================] - 0s 102ms/step - loss: -0.8015 - MSE: 0.0262 - cosine_similarity: 0.8277 - r_square: 0.1096 - val_loss: -0.7378 - val_MSE: 0.0414 - val_cosine_similarity: 0.7791 - val_r_square: -0.3741
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7768 - MSE: 0.0303 - cosine_similarity: 0.8071 - r_square: 0.0051 - val_loss: -0.7401 - val_MSE: 0.0413 - val_cosine_similarity: 0.7814 - val_r_square: -0.3770
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7960 - MSE: 0.0299 - cosine_similarity: 0.8258 - r_square: 0.0664 - val_loss: -0.7410 - val_MSE: 0.0414 - val_cosine_similarity: 0.7824 - val_r_square: -0.3864
# 2/2 [==============================] - 0s 105ms/step - loss: -0.7762 - MSE: 0.0307 - cosine_similarity: 0.8069 - r_square: -0.0597 - val_loss: -0.7400 - val_MSE: 0.0420 - val_cosine_similarity: 0.7820 - val_r_square: -0.4269
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7768 - MSE: 0.0321 - cosine_similarity: 0.8089 - r_square: 0.0736 - val_loss: -0.7383 - val_MSE: 0.0423 - val_cosine_similarity: 0.7806 - val_r_square: -0.4603
# Epoch 27
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7674 - MSE: 0.0327 - cosine_similarity: 0.8001 - r_square: 0.1108 - val_loss: -0.7371 - val_MSE: 0.0422 - val_cosine_similarity: 0.7794 - val_r_square: -0.4551
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7821 - MSE: 0.0305 - cosine_similarity: 0.8126 - r_square: -0.0180 - val_loss: -0.7340 - val_MSE: 0.0426 - val_cosine_similarity: 0.7766 - val_r_square: -0.4701
# 2/2 [==============================] - 0s 105ms/step - loss: -0.7782 - MSE: 0.0306 - cosine_similarity: 0.8088 - r_square: 0.0309 - val_loss: -0.7314 - val_MSE: 0.0429 - val_cosine_similarity: 0.7742 - val_r_square: -0.4725
# 2/2 [==============================] - 0s 97ms/step - loss: -0.8176 - MSE: 0.0243 - cosine_similarity: 0.8419 - r_square: 0.1052 - val_loss: -0.7300 - val_MSE: 0.0429 - val_cosine_similarity: 0.7728 - val_r_square: -0.4531
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7838 - MSE: 0.0306 - cosine_similarity: 0.8144 - r_square: 0.0206 - val_loss: -0.7324 - val_MSE: 0.0425 - val_cosine_similarity: 0.7749 - val_r_square: -0.4325
# 2/2 [==============================] - 0s 99ms/step - loss: -0.8152 - MSE: 0.0251 - cosine_similarity: 0.8403 - r_square: 0.0992 - val_loss: -0.7335 - val_MSE: 0.0419 - val_cosine_similarity: 0.7755 - val_r_square: -0.4104
# Epoch 28
# 2/2 [==============================] - 0s 108ms/step - loss: -0.7896 - MSE: 0.0283 - cosine_similarity: 0.8179 - r_square: 0.1438 - val_loss: -0.7339 - val_MSE: 0.0417 - val_cosine_similarity: 0.7756 - val_r_square: -0.3980
# 2/2 [==============================] - 0s 99ms/step - loss: -0.8013 - MSE: 0.0284 - cosine_similarity: 0.8298 - r_square: 0.0957 - val_loss: -0.7354 - val_MSE: 0.0408 - val_cosine_similarity: 0.7762 - val_r_square: -0.3529
# 2/2 [==============================] - 0s 112ms/step - loss: -0.8107 - MSE: 0.0260 - cosine_similarity: 0.8367 - r_square: 0.1503 - val_loss: -0.7360 - val_MSE: 0.0405 - val_cosine_similarity: 0.7765 - val_r_square: -0.3372
# 2/2 [==============================] - 0s 107ms/step - loss: -0.7802 - MSE: 0.0305 - cosine_similarity: 0.8107 - r_square: 0.0753 - val_loss: -0.7362 - val_MSE: 0.0403 - val_cosine_similarity: 0.7765 - val_r_square: -0.3402
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7903 - MSE: 0.0288 - cosine_similarity: 0.8191 - r_square: 0.0579 - val_loss: -0.7366 - val_MSE: 0.0402 - val_cosine_similarity: 0.7768 - val_r_square: -0.3517
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7874 - MSE: 0.0263 - cosine_similarity: 0.8137 - r_square: 0.0104 - val_loss: -0.7364 - val_MSE: 0.0405 - val_cosine_similarity: 0.7769 - val_r_square: -0.3786
# Epoch 29
# 2/2 [==============================] - 0s 106ms/step - loss: -0.8196 - MSE: 0.0250 - cosine_similarity: 0.8446 - r_square: 0.1465 - val_loss: -0.7420 - val_MSE: 0.0391 - val_cosine_similarity: 0.7811 - val_r_square: -0.3510
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7959 - MSE: 0.0278 - cosine_similarity: 0.8237 - r_square: 0.1058 - val_loss: -0.7414 - val_MSE: 0.0394 - val_cosine_similarity: 0.7807 - val_r_square: -0.3589
# 2/2 [==============================] - 0s 116ms/step - loss: -0.7881 - MSE: 0.0282 - cosine_similarity: 0.8163 - r_square: 0.0178 - val_loss: -0.7417 - val_MSE: 0.0392 - val_cosine_similarity: 0.7810 - val_r_square: -0.3320
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7793 - MSE: 0.0295 - cosine_similarity: 0.8088 - r_square: 0.0500 - val_loss: -0.7427 - val_MSE: 0.0393 - val_cosine_similarity: 0.7819 - val_r_square: -0.3194
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7885 - MSE: 0.0307 - cosine_similarity: 0.8192 - r_square: 0.1125 - val_loss: -0.7432 - val_MSE: 0.0395 - val_cosine_similarity: 0.7827 - val_r_square: -0.3142
# 2/2 [==============================] - 0s 97ms/step - loss: -0.8058 - MSE: 0.0258 - cosine_similarity: 0.8316 - r_square: 8.5837e-04 - val_loss: -0.7427 - val_MSE: 0.0398 - val_cosine_similarity: 0.7826 - val_r_square: -0.3261
# Epoch 30
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7763 - MSE: 0.0324 - cosine_similarity: 0.8087 - r_square: 0.0649 - val_loss: -0.7383 - val_MSE: 0.0414 - val_cosine_similarity: 0.7797 - val_r_square: -0.3687
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7889 - MSE: 0.0301 - cosine_similarity: 0.8190 - r_square: 0.0877 - val_loss: -0.7377 - val_MSE: 0.0414 - val_cosine_similarity: 0.7791 - val_r_square: -0.3605
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7797 - MSE: 0.0291 - cosine_similarity: 0.8088 - r_square: 0.0690 - val_loss: -0.7374 - val_MSE: 0.0414 - val_cosine_similarity: 0.7789 - val_r_square: -0.3657
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7962 - MSE: 0.0279 - cosine_similarity: 0.8241 - r_square: 0.1030 - val_loss: -0.7378 - val_MSE: 0.0413 - val_cosine_similarity: 0.7791 - val_r_square: -0.3591
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7994 - MSE: 0.0257 - cosine_similarity: 0.8251 - r_square: 0.0406 - val_loss: -0.7376 - val_MSE: 0.0413 - val_cosine_similarity: 0.7789 - val_r_square: -0.3762
# 2/2 [==============================] - 0s 98ms/step - loss: -0.8092 - MSE: 0.0253 - cosine_similarity: 0.8345 - r_square: 0.0869 - val_loss: -0.7372 - val_MSE: 0.0413 - val_cosine_similarity: 0.7785 - val_r_square: -0.3865
# Epoch 31
# 2/2 [==============================] - 0s 101ms/step - loss: -0.8156 - MSE: 0.0267 - cosine_similarity: 0.8423 - r_square: 0.1092 - val_loss: -0.7424 - val_MSE: 0.0405 - val_cosine_similarity: 0.7829 - val_r_square: -0.3604
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7740 - MSE: 0.0306 - cosine_similarity: 0.8046 - r_square: 0.0705 - val_loss: -0.7411 - val_MSE: 0.0409 - val_cosine_similarity: 0.7821 - val_r_square: -0.3957
# 2/2 [==============================] - 0s 105ms/step - loss: -0.7558 - MSE: 0.0346 - cosine_similarity: 0.7904 - r_square: -0.0185 - val_loss: -0.7394 - val_MSE: 0.0414 - val_cosine_similarity: 0.7808 - val_r_square: -0.4150
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7996 - MSE: 0.0277 - cosine_similarity: 0.8273 - r_square: 0.1650 - val_loss: -0.7404 - val_MSE: 0.0410 - val_cosine_similarity: 0.7814 - val_r_square: -0.3910
# 2/2 [==============================] - 0s 99ms/step - loss: -0.8048 - MSE: 0.0269 - cosine_similarity: 0.8317 - r_square: 0.1052 - val_loss: -0.7423 - val_MSE: 0.0404 - val_cosine_similarity: 0.7827 - val_r_square: -0.3405
# 2/2 [==============================] - 0s 99ms/step - loss: -0.8131 - MSE: 0.0238 - cosine_similarity: 0.8369 - r_square: 0.0642 - val_loss: -0.7434 - val_MSE: 0.0397 - val_cosine_similarity: 0.7831 - val_r_square: -0.2997
# Epoch 32
# 2/2 [==============================] - 0s 107ms/step - loss: -0.7978 - MSE: 0.0274 - cosine_similarity: 0.8252 - r_square: 0.1478 - val_loss: -0.7427 - val_MSE: 0.0393 - val_cosine_similarity: 0.7820 - val_r_square: -0.2798
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7761 - MSE: 0.0308 - cosine_similarity: 0.8070 - r_square: 0.0506 - val_loss: -0.7409 - val_MSE: 0.0392 - val_cosine_similarity: 0.7801 - val_r_square: -0.2733
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7809 - MSE: 0.0297 - cosine_similarity: 0.8106 - r_square: 0.0773 - val_loss: -0.7379 - val_MSE: 0.0395 - val_cosine_similarity: 0.7774 - val_r_square: -0.2805
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7826 - MSE: 0.0301 - cosine_similarity: 0.8127 - r_square: -0.0545 - val_loss: -0.7379 - val_MSE: 0.0398 - val_cosine_similarity: 0.7776 - val_r_square: -0.2953
# 2/2 [==============================] - 0s 105ms/step - loss: -0.7993 - MSE: 0.0262 - cosine_similarity: 0.8255 - r_square: 0.0434 - val_loss: -0.7393 - val_MSE: 0.0401 - val_cosine_similarity: 0.7794 - val_r_square: -0.3196
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7903 - MSE: 0.0291 - cosine_similarity: 0.8194 - r_square: 0.0395 - val_loss: -0.7415 - val_MSE: 0.0403 - val_cosine_similarity: 0.7817 - val_r_square: -0.3507
# Epoch 33
# 2/2 [==============================] - 0s 105ms/step - loss: -0.7831 - MSE: 0.0291 - cosine_similarity: 0.8122 - r_square: 0.0046 - val_loss: -0.7423 - val_MSE: 0.0396 - val_cosine_similarity: 0.7819 - val_r_square: -0.3454
# 2/2 [==============================] - 0s 99ms/step - loss: -0.8156 - MSE: 0.0240 - cosine_similarity: 0.8396 - r_square: 0.0801 - val_loss: -0.7436 - val_MSE: 0.0397 - val_cosine_similarity: 0.7833 - val_r_square: -0.3361
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7583 - MSE: 0.0342 - cosine_similarity: 0.7925 - r_square: 0.0238 - val_loss: -0.7431 - val_MSE: 0.0402 - val_cosine_similarity: 0.7833 - val_r_square: -0.3508
# 2/2 [==============================] - 0s 106ms/step - loss: -0.7852 - MSE: 0.0295 - cosine_similarity: 0.8146 - r_square: 0.0984 - val_loss: -0.7420 - val_MSE: 0.0407 - val_cosine_similarity: 0.7827 - val_r_square: -0.3672
# 2/2 [==============================] - 0s 99ms/step - loss: -0.8182 - MSE: 0.0254 - cosine_similarity: 0.8436 - r_square: 0.1131 - val_loss: -0.7402 - val_MSE: 0.0412 - val_cosine_similarity: 0.7814 - val_r_square: -0.4024
# 2/2 [==============================] - 0s 94ms/step - loss: -0.7838 - MSE: 0.0306 - cosine_similarity: 0.8144 - r_square: 0.1158 - val_loss: -0.7378 - val_MSE: 0.0416 - val_cosine_similarity: 0.7794 - val_r_square: -0.4474
# Epoch 34
# 2/2 [==============================] - 0s 112ms/step - loss: -0.7927 - MSE: 0.0282 - cosine_similarity: 0.8210 - r_square: 0.0704 - val_loss: -0.7336 - val_MSE: 0.0420 - val_cosine_similarity: 0.7756 - val_r_square: -0.4767
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7852 - MSE: 0.0301 - cosine_similarity: 0.8153 - r_square: 0.0659 - val_loss: -0.7315 - val_MSE: 0.0415 - val_cosine_similarity: 0.7730 - val_r_square: -0.4313
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7998 - MSE: 0.0265 - cosine_similarity: 0.8263 - r_square: 0.1133 - val_loss: -0.7288 - val_MSE: 0.0410 - val_cosine_similarity: 0.7699 - val_r_square: -0.3648
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7471 - MSE: 0.0362 - cosine_similarity: 0.7833 - r_square: 0.0269 - val_loss: -0.7278 - val_MSE: 0.0408 - val_cosine_similarity: 0.7686 - val_r_square: -0.3252
# 2/2 [==============================] - 0s 110ms/step - loss: -0.8001 - MSE: 0.0250 - cosine_similarity: 0.8251 - r_square: -0.0248 - val_loss: -0.7293 - val_MSE: 0.0409 - val_cosine_similarity: 0.7703 - val_r_square: -0.3348
# 2/2 [==============================] - 0s 133ms/step - loss: -0.8016 - MSE: 0.0285 - cosine_similarity: 0.8301 - r_square: 0.1065 - val_loss: -0.7324 - val_MSE: 0.0411 - val_cosine_similarity: 0.7736 - val_r_square: -0.3620
# Epoch 35
# 2/2 [==============================] - 0s 104ms/step - loss: -0.7890 - MSE: 0.0288 - cosine_similarity: 0.8178 - r_square: 0.0787 - val_loss: -0.7296 - val_MSE: 0.0424 - val_cosine_similarity: 0.7720 - val_r_square: -0.4009
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7800 - MSE: 0.0284 - cosine_similarity: 0.8084 - r_square: 0.0178 - val_loss: -0.7299 - val_MSE: 0.0428 - val_cosine_similarity: 0.7727 - val_r_square: -0.4312
# 2/2 [==============================] - 0s 105ms/step - loss: -0.8121 - MSE: 0.0260 - cosine_similarity: 0.8381 - r_square: 0.1554 - val_loss: -0.7305 - val_MSE: 0.0427 - val_cosine_similarity: 0.7731 - val_r_square: -0.4437
# ...
# 2/2 [==============================] - 0s 104ms/step - loss: -0.8163 - MSE: 0.0245 - cosine_similarity: 0.8408 - r_square: 0.2480 - val_loss: -0.7140 - val_MSE: 0.0415 - val_cosine_similarity: 0.7555 - val_r_square: -0.2777
# 2/2 [==============================] - 0s 99ms/step - loss: -0.8024 - MSE: 0.0270 - cosine_similarity: 0.8293 - r_square: 0.0843 - val_loss: -0.7119 - val_MSE: 0.0417 - val_cosine_similarity: 0.7535 - val_r_square: -0.2762
# 2/2 [==============================] - 0s 98ms/step - loss: -0.8176 - MSE: 0.0244 - cosine_similarity: 0.8421 - r_square: 0.1414 - val_loss: -0.7125 - val_MSE: 0.0418 - val_cosine_similarity: 0.7542 - val_r_square: -0.2875
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7922 - MSE: 0.0287 - cosine_similarity: 0.8210 - r_square: 0.1828 - val_loss: -0.7142 - val_MSE: 0.0421 - val_cosine_similarity: 0.7563 - val_r_square: -0.3291
# 2/2 [==============================] - 0s 98ms/step - loss: -0.8286 - MSE: 0.0255 - cosine_similarity: 0.8541 - r_square: 0.1823 - val_loss: -0.7160 - val_MSE: 0.0425 - val_cosine_similarity: 0.7585 - val_r_square: -0.3816
# Epoch 89
# 2/2 [==============================] - 0s 102ms/step - loss: -0.8300 - MSE: 0.0228 - cosine_similarity: 0.8528 - r_square: 0.1785 - val_loss: -0.7296 - val_MSE: 0.0411 - val_cosine_similarity: 0.7706 - val_r_square: -0.3487
# 2/2 [==============================] - 0s 99ms/step - loss: -0.8091 - MSE: 0.0269 - cosine_similarity: 0.8360 - r_square: 0.1298 - val_loss: -0.7295 - val_MSE: 0.0409 - val_cosine_similarity: 0.7704 - val_r_square: -0.3465
# 2/2 [==============================] - 0s 119ms/step - loss: -0.8267 - MSE: 0.0247 - cosine_similarity: 0.8514 - r_square: 0.1344 - val_loss: -0.7299 - val_MSE: 0.0406 - val_cosine_similarity: 0.7705 - val_r_square: -0.3323
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7901 - MSE: 0.0288 - cosine_similarity: 0.8189 - r_square: -0.0025 - val_loss: -0.7323 - val_MSE: 0.0400 - val_cosine_similarity: 0.7723 - val_r_square: -0.3025
# 2/2 [==============================] - 0s 97ms/step - loss: -0.8119 - MSE: 0.0267 - cosine_similarity: 0.8386 - r_square: 0.1561 - val_loss: -0.7347 - val_MSE: 0.0395 - val_cosine_similarity: 0.7742 - val_r_square: -0.2703
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7842 - MSE: 0.0305 - cosine_similarity: 0.8146 - r_square: 0.1230 - val_loss: -0.7366 - val_MSE: 0.0393 - val_cosine_similarity: 0.7759 - val_r_square: -0.2453
# Epoch 90
# 2/2 [==============================] - 0s 98ms/step - loss: -0.8520 - MSE: 0.0206 - cosine_similarity: 0.8727 - r_square: 0.2739 - val_loss: -0.7293 - val_MSE: 0.0402 - val_cosine_similarity: 0.7694 - val_r_square: -0.2612
# 2/2 [==============================] - 0s 98ms/step - loss: -0.8001 - MSE: 0.0281 - cosine_similarity: 0.8282 - r_square: 0.1605 - val_loss: -0.7291 - val_MSE: 0.0403 - val_cosine_similarity: 0.7694 - val_r_square: -0.2606
# 2/2 [==============================] - 0s 106ms/step - loss: -0.8113 - MSE: 0.0266 - cosine_similarity: 0.8379 - r_square: 0.1846 - val_loss: -0.7288 - val_MSE: 0.0406 - val_cosine_similarity: 0.7693 - val_r_square: -0.2711
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7903 - MSE: 0.0275 - cosine_similarity: 0.8178 - r_square: 0.0089 - val_loss: -0.7272 - val_MSE: 0.0409 - val_cosine_similarity: 0.7681 - val_r_square: -0.2875
# 2/2 [==============================] - 0s 96ms/step - loss: -0.8094 - MSE: 0.0275 - cosine_similarity: 0.8369 - r_square: 0.1966 - val_loss: -0.7239 - val_MSE: 0.0413 - val_cosine_similarity: 0.7651 - val_r_square: -0.3033
# 2/2 [==============================] - 0s 95ms/step - loss: -0.8178 - MSE: 0.0243 - cosine_similarity: 0.8421 - r_square: 0.1798 - val_loss: -0.7213 - val_MSE: 0.0415 - val_cosine_similarity: 0.7628 - val_r_square: -0.3183
# Epoch 91
# 2/2 [==============================] - 0s 99ms/step - loss: -0.8352 - MSE: 0.0245 - cosine_similarity: 0.8596 - r_square: 0.2335 - val_loss: -0.7273 - val_MSE: 0.0407 - val_cosine_similarity: 0.7680 - val_r_square: -0.3028
# 2/2 [==============================] - 0s 98ms/step - loss: -0.8187 - MSE: 0.0234 - cosine_similarity: 0.8421 - r_square: 0.0828 - val_loss: -0.7285 - val_MSE: 0.0404 - val_cosine_similarity: 0.7689 - val_r_square: -0.3039
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7907 - MSE: 0.0277 - cosine_similarity: 0.8184 - r_square: 0.1197 - val_loss: -0.7298 - val_MSE: 0.0400 - val_cosine_similarity: 0.7698 - val_r_square: -0.2834
# 2/2 [==============================] - 0s 100ms/step - loss: -0.8179 - MSE: 0.0251 - cosine_similarity: 0.8430 - r_square: 0.1956 - val_loss: -0.7295 - val_MSE: 0.0398 - val_cosine_similarity: 0.7694 - val_r_square: -0.2694
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7992 - MSE: 0.0279 - cosine_similarity: 0.8272 - r_square: 0.1684 - val_loss: -0.7290 - val_MSE: 0.0397 - val_cosine_similarity: 0.7686 - val_r_square: -0.2541
# 2/2 [==============================] - 0s 100ms/step - loss: -0.8148 - MSE: 0.0254 - cosine_similarity: 0.8402 - r_square: 0.1987 - val_loss: -0.7285 - val_MSE: 0.0395 - val_cosine_similarity: 0.7679 - val_r_square: -0.2401
# Epoch 92
# 2/2 [==============================] - 0s 96ms/step - loss: -0.8320 - MSE: 0.0229 - cosine_similarity: 0.8549 - r_square: 0.2192 - val_loss: -0.7338 - val_MSE: 0.0387 - val_cosine_similarity: 0.7725 - val_r_square: -0.2170
# 2/2 [==============================] - 0s 97ms/step - loss: -0.8268 - MSE: 0.0238 - cosine_similarity: 0.8506 - r_square: 0.2313 - val_loss: -0.7330 - val_MSE: 0.0384 - val_cosine_similarity: 0.7714 - val_r_square: -0.2075
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7958 - MSE: 0.0283 - cosine_similarity: 0.8241 - r_square: 0.1157 - val_loss: -0.7316 - val_MSE: 0.0383 - val_cosine_similarity: 0.7698 - val_r_square: -0.2005
# 2/2 [==============================] - 0s 98ms/step - loss: -0.8354 - MSE: 0.0255 - cosine_similarity: 0.8609 - r_square: 0.1950 - val_loss: -0.7300 - val_MSE: 0.0383 - val_cosine_similarity: 0.7683 - val_r_square: -0.1952
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7925 - MSE: 0.0281 - cosine_similarity: 0.8207 - r_square: 0.1302 - val_loss: -0.7303 - val_MSE: 0.0383 - val_cosine_similarity: 0.7686 - val_r_square: -0.1987
# 2/2 [==============================] - 0s 235ms/step - loss: -0.8110 - MSE: 0.0248 - cosine_similarity: 0.8359 - r_square: 0.0698 - val_loss: -0.7328 - val_MSE: 0.0383 - val_cosine_similarity: 0.7711 - val_r_square: -0.2116
# Epoch 93
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7744 - MSE: 0.0317 - cosine_similarity: 0.8061 - r_square: 0.0754 - val_loss: -0.7246 - val_MSE: 0.0396 - val_cosine_similarity: 0.7643 - val_r_square: -0.2784
# 2/2 [==============================] - 0s 114ms/step - loss: -0.8011 - MSE: 0.0275 - cosine_similarity: 0.8286 - r_square: 0.1359 - val_loss: -0.7267 - val_MSE: 0.0398 - val_cosine_similarity: 0.7665 - val_r_square: -0.2970
# 2/2 [==============================] - 0s 106ms/step - loss: -0.7958 - MSE: 0.0272 - cosine_similarity: 0.8231 - r_square: 0.0598 - val_loss: -0.7276 - val_MSE: 0.0402 - val_cosine_similarity: 0.7678 - val_r_square: -0.3132
# 2/2 [==============================] - 0s 108ms/step - loss: -0.7917 - MSE: 0.0287 - cosine_similarity: 0.8203 - r_square: 0.1048 - val_loss: -0.7276 - val_MSE: 0.0407 - val_cosine_similarity: 0.7683 - val_r_square: -0.3282
# 2/2 [==============================] - 0s 116ms/step - loss: -0.8416 - MSE: 0.0214 - cosine_similarity: 0.8630 - r_square: 0.2107 - val_loss: -0.7274 - val_MSE: 0.0412 - val_cosine_similarity: 0.7686 - val_r_square: -0.3449
# 2/2 [==============================] - 0s 106ms/step - loss: -0.8175 - MSE: 0.0247 - cosine_similarity: 0.8422 - r_square: 0.1533 - val_loss: -0.7274 - val_MSE: 0.0414 - val_cosine_similarity: 0.7688 - val_r_square: -0.3513
# Epoch 94
# 2/2 [==============================] - 0s 101ms/step - loss: -0.8111 - MSE: 0.0265 - cosine_similarity: 0.8376 - r_square: 0.1458 - val_loss: -0.7351 - val_MSE: 0.0402 - val_cosine_similarity: 0.7753 - val_r_square: -0.3055
# 2/2 [==============================] - 0s 121ms/step - loss: -0.8151 - MSE: 0.0267 - cosine_similarity: 0.8419 - r_square: 0.1747 - val_loss: -0.7356 - val_MSE: 0.0401 - val_cosine_similarity: 0.7757 - val_r_square: -0.3005
# 2/2 [==============================] - 0s 108ms/step - loss: -0.8056 - MSE: 0.0255 - cosine_similarity: 0.8311 - r_square: 0.0681 - val_loss: -0.7369 - val_MSE: 0.0397 - val_cosine_similarity: 0.7765 - val_r_square: -0.2788
# 2/2 [==============================] - 0s 118ms/step - loss: -0.7954 - MSE: 0.0277 - cosine_similarity: 0.8230 - r_square: 0.0612 - val_loss: -0.7379 - val_MSE: 0.0392 - val_cosine_similarity: 0.7771 - val_r_square: -0.2520
# 2/2 [==============================] - 0s 97ms/step - loss: -0.8102 - MSE: 0.0276 - cosine_similarity: 0.8378 - r_square: 0.1597 - val_loss: -0.7377 - val_MSE: 0.0387 - val_cosine_similarity: 0.7765 - val_r_square: -0.2200
# 2/2 [==============================] - 0s 103ms/step - loss: -0.8124 - MSE: 0.0255 - cosine_similarity: 0.8380 - r_square: 0.1158 - val_loss: -0.7350 - val_MSE: 0.0387 - val_cosine_similarity: 0.7736 - val_r_square: -0.2106
# Epoch 95
# 2/2 [==============================] - 0s 103ms/step - loss: -0.8073 - MSE: 0.0263 - cosine_similarity: 0.8336 - r_square: 0.1265 - val_loss: -0.7203 - val_MSE: 0.0405 - val_cosine_similarity: 0.7608 - val_r_square: -0.2560
# 2/2 [==============================] - 0s 95ms/step - loss: -0.8120 - MSE: 0.0250 - cosine_similarity: 0.8370 - r_square: 0.1184 - val_loss: -0.7150 - val_MSE: 0.0412 - val_cosine_similarity: 0.7562 - val_r_square: -0.2910
# 2/2 [==============================] - 0s 96ms/step - loss: -0.8496 - MSE: 0.0204 - cosine_similarity: 0.8700 - r_square: 0.3051 - val_loss: -0.7125 - val_MSE: 0.0415 - val_cosine_similarity: 0.7541 - val_r_square: -0.3220
# 2/2 [==============================] - 0s 103ms/step - loss: -0.8229 - MSE: 0.0245 - cosine_similarity: 0.8474 - r_square: 0.2420 - val_loss: -0.7111 - val_MSE: 0.0416 - val_cosine_similarity: 0.7527 - val_r_square: -0.3268
# 2/2 [==============================] - 0s 99ms/step - loss: -0.8032 - MSE: 0.0284 - cosine_similarity: 0.8316 - r_square: 0.1692 - val_loss: -0.7112 - val_MSE: 0.0415 - val_cosine_similarity: 0.7527 - val_r_square: -0.3214
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7900 - MSE: 0.0287 - cosine_similarity: 0.8188 - r_square: 0.0367 - val_loss: -0.7159 - val_MSE: 0.0409 - val_cosine_similarity: 0.7568 - val_r_square: -0.3040
# Epoch 96
# 2/2 [==============================] - 0s 96ms/step - loss: -0.8330 - MSE: 0.0247 - cosine_similarity: 0.8576 - r_square: 0.2317 - val_loss: -0.7297 - val_MSE: 0.0387 - val_cosine_similarity: 0.7684 - val_r_square: -0.2420
# 2/2 [==============================] - 0s 111ms/step - loss: -0.8096 - MSE: 0.0277 - cosine_similarity: 0.8373 - r_square: 0.1862 - val_loss: -0.7343 - val_MSE: 0.0380 - val_cosine_similarity: 0.7723 - val_r_square: -0.2147
# 2/2 [==============================] - 0s 99ms/step - loss: -0.8182 - MSE: 0.0237 - cosine_similarity: 0.8418 - r_square: 0.1451 - val_loss: -0.7364 - val_MSE: 0.0378 - val_cosine_similarity: 0.7742 - val_r_square: -0.2094
# 2/2 [==============================] - 0s 99ms/step - loss: -0.8497 - MSE: 0.0212 - cosine_similarity: 0.8709 - r_square: 0.2542 - val_loss: -0.7382 - val_MSE: 0.0377 - val_cosine_similarity: 0.7758 - val_r_square: -0.2057
# 2/2 [==============================] - 0s 100ms/step - loss: -0.8240 - MSE: 0.0236 - cosine_similarity: 0.8476 - r_square: 0.1558 - val_loss: -0.7382 - val_MSE: 0.0378 - val_cosine_similarity: 0.7760 - val_r_square: -0.2111
# 2/2 [==============================] - 0s 108ms/step - loss: -0.7883 - MSE: 0.0283 - cosine_similarity: 0.8166 - r_square: 0.1529 - val_loss: -0.7378 - val_MSE: 0.0379 - val_cosine_similarity: 0.7757 - val_r_square: -0.2081
# Epoch 97
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7992 - MSE: 0.0260 - cosine_similarity: 0.8252 - r_square: 0.0362 - val_loss: -0.7357 - val_MSE: 0.0384 - val_cosine_similarity: 0.7740 - val_r_square: -0.2273
# 2/2 [==============================] - 0s 97ms/step - loss: -0.8360 - MSE: 0.0218 - cosine_similarity: 0.8578 - r_square: 0.1554 - val_loss: -0.7321 - val_MSE: 0.0390 - val_cosine_similarity: 0.7712 - val_r_square: -0.2506
# 2/2 [==============================] - 0s 118ms/step - loss: -0.8105 - MSE: 0.0267 - cosine_similarity: 0.8372 - r_square: 0.1857 - val_loss: -0.7279 - val_MSE: 0.0397 - val_cosine_similarity: 0.7676 - val_r_square: -0.2641
# 2/2 [==============================] - 0s 108ms/step - loss: -0.8266 - MSE: 0.0237 - cosine_similarity: 0.8503 - r_square: 0.2175 - val_loss: -0.7226 - val_MSE: 0.0404 - val_cosine_similarity: 0.7630 - val_r_square: -0.2810
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7875 - MSE: 0.0306 - cosine_similarity: 0.8181 - r_square: 0.1488 - val_loss: -0.7207 - val_MSE: 0.0409 - val_cosine_similarity: 0.7616 - val_r_square: -0.2970
# 2/2 [==============================] - 0s 98ms/step - loss: -0.8323 - MSE: 0.0241 - cosine_similarity: 0.8564 - r_square: 0.2701 - val_loss: -0.7235 - val_MSE: 0.0405 - val_cosine_similarity: 0.7640 - val_r_square: -0.2983
# Epoch 98
# 2/2 [==============================] - 0s 100ms/step - loss: -0.8349 - MSE: 0.0232 - cosine_similarity: 0.8581 - r_square: 0.2389 - val_loss: -0.7240 - val_MSE: 0.0408 - val_cosine_similarity: 0.7648 - val_r_square: -0.3142
# 2/2 [==============================] - 0s 106ms/step - loss: -0.8030 - MSE: 0.0281 - cosine_similarity: 0.8312 - r_square: 0.1815 - val_loss: -0.7259 - val_MSE: 0.0405 - val_cosine_similarity: 0.7664 - val_r_square: -0.3032
# 2/2 [==============================] - 0s 98ms/step - loss: -0.8038 - MSE: 0.0274 - cosine_similarity: 0.8312 - r_square: 0.1654 - val_loss: -0.7267 - val_MSE: 0.0402 - val_cosine_similarity: 0.7669 - val_r_square: -0.2844
# 2/2 [==============================] - 0s 100ms/step - loss: -0.8199 - MSE: 0.0240 - cosine_similarity: 0.8439 - r_square: 0.1698 - val_loss: -0.7292 - val_MSE: 0.0396 - val_cosine_similarity: 0.7688 - val_r_square: -0.2517
# 2/2 [==============================] - 0s 112ms/step - loss: -0.8133 - MSE: 0.0262 - cosine_similarity: 0.8395 - r_square: 0.1029 - val_loss: -0.7315 - val_MSE: 0.0391 - val_cosine_similarity: 0.7706 - val_r_square: -0.2304
# 2/2 [==============================] - 0s 107ms/step - loss: -0.8047 - MSE: 0.0260 - cosine_similarity: 0.8307 - r_square: 0.0981 - val_loss: -0.7325 - val_MSE: 0.0388 - val_cosine_similarity: 0.7713 - val_r_square: -0.2217
# Epoch 99
# 2/2 [==============================] - 0s 98ms/step - loss: -0.8048 - MSE: 0.0257 - cosine_similarity: 0.8305 - r_square: 0.0915 - val_loss: -0.7261 - val_MSE: 0.0396 - val_cosine_similarity: 0.7658 - val_r_square: -0.2414
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7998 - MSE: 0.0269 - cosine_similarity: 0.8267 - r_square: 0.1238 - val_loss: -0.7236 - val_MSE: 0.0400 - val_cosine_similarity: 0.7636 - val_r_square: -0.2571
# 2/2 [==============================] - 0s 98ms/step - loss: -0.8192 - MSE: 0.0256 - cosine_similarity: 0.8449 - r_square: 0.2298 - val_loss: -0.7215 - val_MSE: 0.0402 - val_cosine_similarity: 0.7617 - val_r_square: -0.2658
# 2/2 [==============================] - 0s 114ms/step - loss: -0.7841 - MSE: 0.0310 - cosine_similarity: 0.8150 - r_square: 0.1053 - val_loss: -0.7206 - val_MSE: 0.0403 - val_cosine_similarity: 0.7608 - val_r_square: -0.2738
# 2/2 [==============================] - 0s 107ms/step - loss: -0.8128 - MSE: 0.0270 - cosine_similarity: 0.8398 - r_square: 0.0848 - val_loss: -0.7220 - val_MSE: 0.0403 - val_cosine_similarity: 0.7623 - val_r_square: -0.2861
# 2/2 [==============================] - 0s 97ms/step - loss: -0.8338 - MSE: 0.0229 - cosine_similarity: 0.8567 - r_square: 0.2134 - val_loss: -0.7231 - val_MSE: 0.0403 - val_cosine_similarity: 0.7635 - val_r_square: -0.2931

# %%
# %matplotlib inline

metrics = ["MSE", "cosine similarity", "r2"] #Choose between 'loss', 'MSE', 'cosine similarity', 'r2'

metrics_dict = {"loss": ["loss", "val_loss"], "MSE": ["MSE", "val_MSE"], 
                "cosine similarity": ["cosine_similarity", "val_cosine_similarity"],
               "r2" : ["r_square", "val_r_square"]}

import matplotlib.pyplot as plt
try: history_df = history_df.reset_index()
except: pass

for metric in metrics:
    fig, ax = plt.subplots(figsize=(15,4),nrows=1, ncols=1)
    ax.set_ylabel(f"{metric}")
    ax.set_xlabel("Training time")
    fig.suptitle(f"History of {metric} in training time")

    train_plot = history_df.plot(y=metrics_dict[metric][0], use_index=True, ax=ax, label="Training")
    val_plot = history_df.plot(y=metrics_dict[metric][1], use_index=True, ax=ax, label="Validation")

    plt.show()

# %%
def slice(input_tensor, labels, begin, size=10):

    input_shape = (tf.shape(input_tensor).numpy())
    
    begin = [0, begin, 0]
    size = [100, size, 128]
    
    sliced_tensor = tf.slice(input_tensor, begin, size)
    
    nan_values, idx = tf.unique(tf.gather(tf.where(tf.math.is_nan(sliced_tensor)), 0, axis=1))
    nan_values = nan_values.numpy()
  
    msk = np.zeros((input_shape[0]), dtype=np.bool)
    msk[nan_values] = True
    msk = ~msk

    sliced_tensor = tf.boolean_mask(sliced_tensor, msk , axis=0)
    labels = tf.boolean_mask(labels , msk, axis=0)
    
    return sliced_tensor, labels

# %%
val_ds = validation_dataset.shuffle(n_test).batch(n_test)
x_val, y_val = next(iter(val_ds))
x_val, y_val = slice_accordingly(x_val, y_val)
    

y_pred = model.predict(x_val)
y_true = y_val

# %%
def plot_epsilon_error(y_true, y_pred):
    
    N = len(y_true)
    
    cdf_abs_error = {}
    abs_error = np.abs(y_true - y_pred)
    
    fig, ax = plt.subplots(figsize=(12,6),nrows=1, ncols=2)
    ax[0].set_ylabel("Fraction of samples")
    ax[0].set_xlabel("Allowed absolute error")
    ax[0].set_title(f"CDF of the absolute error for different emotions")
    
    ax[0].set_ylim([0,1])
    
    for i, emotion in enumerate(emotions):
        abs_error_emotion = np.sort(abs_error[:,i])
        X2 = np.sort(abs_error_emotion)
        F2 = np.array(range(N))/(float(N))
        
        cdf_abs_error[emotion] = [X2, F2]
        
        ax[0].plot(X2, F2, label=emotion)
        
    ax[0].legend()
    ax[0].grid()
    
    cdf_cosine_sim = {}
    cos_sim = np.array([np.dot(y_true[i], y_pred[i])/(np.linalg.norm(y_true[i])*np.linalg.norm(y_pred[i])) for i in range(N)])
    cos_error = 1-cos_sim
    
    X2 = np.sort(cos_error)
    F2 = np.array(range(N))/(float(N))

    ax[1].set_ylabel(f"Fraction of samples", rotation=-90, labelpad=15)
    ax[1].yaxis.set_label_position("right")
    ax[1].yaxis.tick_right()
    ax[1].set_xlabel("Allowed cosine error")
    ax[1].set_title(f"CDF of the cosine error")
    
    ax[1].set_ylim([0,1])
    
    ax[1].plot(X2, F2)
    ax[1].grid()
    return cdf_abs_error

# %%
epsilon_error = plot_epsilon_error(y_true, y_pred)

x = epsilon_error["amazement"]
plt.show()

# %% [markdown]
# ## "Cross-validation"

# %%
def custom_loss(y_true, y_pred):
    cos_sim = tf.keras.losses.CosineSimilarity() 
    MSE = tf.keras.losses.MeanSquaredError()
        
    return cos_sim(y_true, y_pred) + MSE(y_true, y_pred)

# %%
from sklearn.model_selection import KFold


n_splits = 5
kf = KFold(n_splits=n_splits)

predictions_and_labels = {}


count = 0
for train_index, test_index in kf.split(pool5_raw):
    
    print(f"Training K-fold {1+count} of {n_splits}")

    train_features, train_labels = pool5_raw[train_index], labels_raw[train_index]
    validation_features, validation_labels = pool5_raw[test_index], labels_raw[test_index]

    train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels))
    validation_dataset = tf.data.Dataset.from_tensor_slices((validation_features, validation_labels))
    
    sample_size = (10, 128, 1)
    drop_out_rate = 0.5

    input_tensor = Input(sample_size)
    x = layers.Conv2D(8, (5, 1), padding="valid", activation="relu")(input_tensor)
    x = layers.Dropout(drop_out_rate)(x)
    x = layers.Dense(32, activation="relu")(x)
    x = layers.Flatten()(x)
    x = layers.Dropout(drop_out_rate)(x)
    output_tensor = layers.Dense(9, activation="sigmoid")(x)

    model = tf.keras.Model(input_tensor, output_tensor)

    model.compile(optimizer="adam",
                loss= custom_loss,
                metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
    n_epochs = 100
    batch_size = 50
    
    for epoch in range(n_epochs):
        train_ds = train_dataset.shuffle(n_train).batch(batch_size)
        for features, labels in train_ds:
            features, labels = slice_accordingly(features, labels)
            model.fit(features, labels, verbose=0)
            
    val_ds = validation_dataset.shuffle(n_test).batch(n_test)
    x_val, y_val = next(iter(val_ds))
    x_val, y_val = slice_accordingly(x_val, y_val)

            
    predictions_and_labels[count] = [model.predict(x_val), y_val]
    count = count+1
# Out:
# Training K-fold 1 of 5
# Training K-fold 2 of 5
# Training K-fold 3 of 5
# Training K-fold 4 of 5
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002A000F33E18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Training K-fold 5 of 5
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002A0081CE378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
predictions = []
labels = []

for i in range(max(predictions_and_labels.keys())+1):
    predictions.append(predictions_and_labels[i][0])
    labels.append(predictions_and_labels[i][1])

predictions = np.concatenate(predictions)
labels = np.concatenate(labels)
epsilon_error = plot_epsilon_error(labels, predictions)

plt.show()

# %%
cos_sim = []
r2 = []
MSE = []

cos_sim_function = tf.keras.metrics.CosineSimilarity() 
MSE_function = tf.keras.metrics.MeanSquaredError()
r2_function = tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))

for i in range(max(predictions_and_labels.keys())+1):
    y_pred = predictions_and_labels[i][0]
    y_true = predictions_and_labels[i][1]
    
    cos_sim.append(cos_sim_function(y_true, y_pred).numpy())
    r2.append(r2_function(y_true, y_pred).numpy())
    MSE.append(MSE_function(y_true, y_pred).numpy())
    
print(f"The cosine similarity is approximately {100*np.mean(cos_sim):.2f}±{100*np.std(cos_sim):.2f}%")
print(f"The MSE is approximately {100*np.mean(MSE):.2f}±{100*np.std(MSE):.2f}%")
print(f"The R2 score is approximately {100*np.mean(r2):.2f}±{100*np.std(r2):.2f}%")
# Out:
# The cosine similarity is approximately 77.39±0.26%
# The MSE is approximately 4.05±0.05%
# The R2 score is approximately -31.77±2.85%
