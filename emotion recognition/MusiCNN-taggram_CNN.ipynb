# %% [markdown]
# # Emotion Recognition: MusiCNN-taggram_CNN.ipynb
#
# Model trained on *simple features* that aims at predicting the *emotion labels*.
#
# The approach consists on getting the arrays of MusiCNN-taggram (in *preprocessing*) and train a *Convolutional Neural Network* with *Tensorflow*.
# The problem is treated as a *regression* problem, where the loss function can be chosen between *mean squared error*, *-cosine similarity*, or *both*, being a combination of both losses with equal weight. The results shown are using "*both*".

# %%
import numpy as np
import pandas as pd

import sys
import os

# %%
taggram = np.load("../preprocessing/MusiCNNFeatures/taggram_array.npy")
print(np.shape(taggram))
# Out:
# (400, 20, 50)

# %%
label_songs = pd.read_csv("../preprocessing/labels.csv")
info_songs = pd.read_csv("../data/Info/info.csv")

# Retrieve emotions from the labels.csv file
emotions = ["amazement", "solemnity", "tenderness", "nostalgia", "calmness", 
            "power", "joyful_activation", "tension", "sadness"]

labels = label_songs[emotions]
labels = labels.to_numpy()

length_songs = pd.DataFrame(info_songs["Track ID"])
length_songs["Song length"] = info_songs["Duration"]*10
length_songs["Song length"] = length_songs["Song length"].astype(int)

# %%
n_data = len(label_songs)
idx = np.random.permutation(n_data)
info_songs = info_songs.reindex(idx)

taggram = taggram[idx, :, :]
labels = labels[idx]

taggram_raw = taggram[:]
labels_raw = labels[:]

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras import Input, layers
from tensorflow.keras import backend as K

sample_size = (10, 50, 1)

drop_out_rate = 0.5

input_tensor = Input(sample_size)
x = layers.Conv2D(8, (5, 1), padding="valid", activation="relu")(input_tensor)
x = layers.Dropout(drop_out_rate)(x)
x = layers.Dense(32, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(drop_out_rate)(x)
output_tensor = layers.Dense(9, activation="sigmoid")(x)

model_1 = tf.keras.Model(input_tensor, output_tensor)
model_1.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 10, 50, 1)]       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 6, 50, 8)          48
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 50, 8)          0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6, 50, 32)         288
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9600)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 9600)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 9)                 86409
# =================================================================
# Total params: 86,745
# Trainable params: 86,745
# Non-trainable params: 0
# _________________________________________________________________

# %%
fraction_validation = 0.25
n_test = int(fraction_validation*len(labels))
n_train = len(labels) - n_test

train_features, train_labels = taggram[:n_train], labels[:n_train]
validation_features, validation_labels = taggram[n_train:], labels[n_train:]

train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels))
validation_dataset = tf.data.Dataset.from_tensor_slices((validation_features, validation_labels))

# %%
def slice_accordingly(input_tensor, labels, size=10):

    input_shape = (tf.shape(input_tensor).numpy())
    
    input_shape[1] = size
    size = input_shape
    
    sliced_tensor = tf.image.random_crop(input_tensor, size)
    
    nan_values, idx = tf.unique(tf.gather(tf.where(tf.math.is_nan(sliced_tensor)), 0, axis=1))
    nan_values = nan_values.numpy()
  
    msk = np.zeros((input_shape[0]), dtype=np.bool)
    msk[nan_values] = True
    msk = ~msk

    sliced_tensor = tf.boolean_mask(sliced_tensor, msk , axis=0)
    labels = tf.boolean_mask(labels , msk, axis=0)
    
    return sliced_tensor, labels

# %%
model = model_1

loss = "MSE"
#loss = "CosineSimilarity"
loss = "both"

if loss == "MSE":
    model.compile(optimizer="adam",
                  loss=tf.keras.losses.MeanSquaredError(),
                  metrics=["cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "CosineSimilarity":
    model.compile(optimizer="adam",
                  loss= tf.keras.losses.CosineSimilarity(),
                  metrics=["MSE", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "both":
    def custom_loss(y_true, y_pred):
        cos_sim = tf.keras.losses.CosineSimilarity() 
        MSE = tf.keras.losses.MeanSquaredError()
        
        return cos_sim(y_true, y_pred) + MSE(y_true, y_pred)
        
    model.compile(optimizer="adam",
                  loss= custom_loss,
                  metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])

# %%
n_epochs = 100
batch_size = 50

history_df = pd.DataFrame()

for epoch in range(n_epochs):
    print("Epoch", epoch)
    train_ds = train_dataset.shuffle(n_train).batch(batch_size)
    val_ds = validation_dataset.shuffle(n_test).batch(n_test)
    
    x_val, y_val = next(iter(val_ds))
    x_val, y_val = slice_accordingly(x_val, y_val)
    
    for features, labels in train_ds:
        features, labels = slice_accordingly(features, labels)
        
        history = model.fit(features, labels,
                           validation_data=(x_val, y_val),verbose=1)
        history = pd.DataFrame(history.history)
        history_df = history_df.append(history)
# Out:
# Epoch 0
# 2/2 [==============================] - 2s 423ms/step - loss: -0.6553 - MSE: 0.1124 - cosine_similarity: 0.7677 - r_square: -3.2944 - val_loss: -0.6655 - val_MSE: 0.1057 - val_cosine_similarity: 0.7712 - val_r_square: -3.2091
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7032 - MSE: 0.0933 - cosine_similarity: 0.7966 - r_square: -3.1906 - val_loss: -0.6816 - val_MSE: 0.0933 - val_cosine_similarity: 0.7748 - val_r_square: -2.5794
# 2/2 [==============================] - 0s 82ms/step - loss: -0.6745 - MSE: 0.0885 - cosine_similarity: 0.7630 - r_square: -2.3282 - val_loss: -0.6988 - val_MSE: 0.0797 - val_cosine_similarity: 0.7785 - val_r_square: -1.9071
# 2/2 [==============================] - 0s 81ms/step - loss: -0.7275 - MSE: 0.0681 - cosine_similarity: 0.7956 - r_square: -1.6890 - val_loss: -0.7147 - val_MSE: 0.0663 - val_cosine_similarity: 0.7810 - val_r_square: -1.2630
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7623 - MSE: 0.0518 - cosine_similarity: 0.8141 - r_square: -1.2272 - val_loss: -0.7261 - val_MSE: 0.0548 - val_cosine_similarity: 0.7808 - val_r_square: -0.7320
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7138 - MSE: 0.0512 - cosine_similarity: 0.7650 - r_square: -0.4701 - val_loss: -0.7319 - val_MSE: 0.0465 - val_cosine_similarity: 0.7784 - val_r_square: -0.3947
# Epoch 1
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7709 - MSE: 0.0359 - cosine_similarity: 0.8067 - r_square: -0.2006 - val_loss: -0.7346 - val_MSE: 0.0411 - val_cosine_similarity: 0.7756 - val_r_square: -0.2122
# 2/2 [==============================] - 0s 81ms/step - loss: -0.7822 - MSE: 0.0306 - cosine_similarity: 0.8128 - r_square: -0.1030 - val_loss: -0.7372 - val_MSE: 0.0379 - val_cosine_similarity: 0.7751 - val_r_square: -0.1299
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7460 - MSE: 0.0343 - cosine_similarity: 0.7803 - r_square: -0.1595 - val_loss: -0.7422 - val_MSE: 0.0360 - val_cosine_similarity: 0.7782 - val_r_square: -0.0869
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7750 - MSE: 0.0306 - cosine_similarity: 0.8056 - r_square: -0.0680 - val_loss: -0.7442 - val_MSE: 0.0353 - val_cosine_similarity: 0.7795 - val_r_square: -0.0782
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7322 - MSE: 0.0359 - cosine_similarity: 0.7680 - r_square: -0.0577 - val_loss: -0.7434 - val_MSE: 0.0353 - val_cosine_similarity: 0.7786 - val_r_square: -0.0857
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7201 - MSE: 0.0378 - cosine_similarity: 0.7579 - r_square: -0.0645 - val_loss: -0.7430 - val_MSE: 0.0353 - val_cosine_similarity: 0.7783 - val_r_square: -0.0930
# Epoch 2
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7654 - MSE: 0.0318 - cosine_similarity: 0.7972 - r_square: 0.0094 - val_loss: -0.7414 - val_MSE: 0.0355 - val_cosine_similarity: 0.7769 - val_r_square: -0.1032
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7578 - MSE: 0.0336 - cosine_similarity: 0.7914 - r_square: -0.0306 - val_loss: -0.7398 - val_MSE: 0.0357 - val_cosine_similarity: 0.7755 - val_r_square: -0.1136
# 2/2 [==============================] - 0s 92ms/step - loss: -0.7573 - MSE: 0.0323 - cosine_similarity: 0.7896 - r_square: -0.0550 - val_loss: -0.7391 - val_MSE: 0.0356 - val_cosine_similarity: 0.7747 - val_r_square: -0.1138
# 2/2 [==============================] - 0s 91ms/step - loss: -0.7734 - MSE: 0.0305 - cosine_similarity: 0.8039 - r_square: -0.0832 - val_loss: -0.7393 - val_MSE: 0.0355 - val_cosine_similarity: 0.7747 - val_r_square: -0.1088
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7485 - MSE: 0.0336 - cosine_similarity: 0.7821 - r_square: -0.0537 - val_loss: -0.7408 - val_MSE: 0.0351 - val_cosine_similarity: 0.7759 - val_r_square: -0.0918
# 2/2 [==============================] - 0s 94ms/step - loss: -0.7512 - MSE: 0.0319 - cosine_similarity: 0.7831 - r_square: -0.0505 - val_loss: -0.7431 - val_MSE: 0.0347 - val_cosine_similarity: 0.7778 - val_r_square: -0.0717
# Epoch 3
# 2/2 [==============================] - 0s 94ms/step - loss: -0.7596 - MSE: 0.0319 - cosine_similarity: 0.7915 - r_square: 0.0153 - val_loss: -0.7450 - val_MSE: 0.0343 - val_cosine_similarity: 0.7794 - val_r_square: -0.0564
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7551 - MSE: 0.0327 - cosine_similarity: 0.7878 - r_square: -0.0175 - val_loss: -0.7460 - val_MSE: 0.0343 - val_cosine_similarity: 0.7802 - val_r_square: -0.0517
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7603 - MSE: 0.0318 - cosine_similarity: 0.7921 - r_square: -0.0427 - val_loss: -0.7473 - val_MSE: 0.0342 - val_cosine_similarity: 0.7815 - val_r_square: -0.0486
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7522 - MSE: 0.0329 - cosine_similarity: 0.7851 - r_square: -0.0244 - val_loss: -0.7494 - val_MSE: 0.0342 - val_cosine_similarity: 0.7836 - val_r_square: -0.0488
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7832 - MSE: 0.0310 - cosine_similarity: 0.8142 - r_square: -0.0283 - val_loss: -0.7498 - val_MSE: 0.0344 - val_cosine_similarity: 0.7842 - val_r_square: -0.0576
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7681 - MSE: 0.0300 - cosine_similarity: 0.7981 - r_square: -0.0564 - val_loss: -0.7495 - val_MSE: 0.0347 - val_cosine_similarity: 0.7842 - val_r_square: -0.0715
# Epoch 4
# 2/2 [==============================] - 0s 91ms/step - loss: -0.7701 - MSE: 0.0314 - cosine_similarity: 0.8015 - r_square: 0.0042 - val_loss: -0.7475 - val_MSE: 0.0353 - val_cosine_similarity: 0.7829 - val_r_square: -0.0985
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7635 - MSE: 0.0326 - cosine_similarity: 0.7961 - r_square: -0.0285 - val_loss: -0.7468 - val_MSE: 0.0355 - val_cosine_similarity: 0.7823 - val_r_square: -0.1056
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7727 - MSE: 0.0296 - cosine_similarity: 0.8023 - r_square: -0.0155 - val_loss: -0.7466 - val_MSE: 0.0355 - val_cosine_similarity: 0.7822 - val_r_square: -0.1081
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7600 - MSE: 0.0318 - cosine_similarity: 0.7918 - r_square: -0.0583 - val_loss: -0.7466 - val_MSE: 0.0355 - val_cosine_similarity: 0.7820 - val_r_square: -0.1053
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7639 - MSE: 0.0315 - cosine_similarity: 0.7954 - r_square: -0.0220 - val_loss: -0.7463 - val_MSE: 0.0354 - val_cosine_similarity: 0.7818 - val_r_square: -0.1036
# 2/2 [==============================] - 0s 92ms/step - loss: -0.7576 - MSE: 0.0335 - cosine_similarity: 0.7911 - r_square: 0.0297 - val_loss: -0.7461 - val_MSE: 0.0352 - val_cosine_similarity: 0.7813 - val_r_square: -0.0962
# Epoch 5
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7545 - MSE: 0.0337 - cosine_similarity: 0.7882 - r_square: -0.0145 - val_loss: -0.7480 - val_MSE: 0.0345 - val_cosine_similarity: 0.7826 - val_r_square: -0.0680
# 2/2 [==============================] - 0s 87ms/step - loss: -0.7617 - MSE: 0.0322 - cosine_similarity: 0.7939 - r_square: 0.0193 - val_loss: -0.7477 - val_MSE: 0.0344 - val_cosine_similarity: 0.7821 - val_r_square: -0.0593
# 2/2 [==============================] - 0s 92ms/step - loss: -0.7686 - MSE: 0.0310 - cosine_similarity: 0.7996 - r_square: -0.0296 - val_loss: -0.7480 - val_MSE: 0.0342 - val_cosine_similarity: 0.7822 - val_r_square: -0.0519
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7771 - MSE: 0.0308 - cosine_similarity: 0.8079 - r_square: 0.0105 - val_loss: -0.7480 - val_MSE: 0.0341 - val_cosine_similarity: 0.7821 - val_r_square: -0.0487
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7486 - MSE: 0.0324 - cosine_similarity: 0.7810 - r_square: -0.0077 - val_loss: -0.7482 - val_MSE: 0.0341 - val_cosine_similarity: 0.7823 - val_r_square: -0.0495
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7765 - MSE: 0.0295 - cosine_similarity: 0.8060 - r_square: -0.0551 - val_loss: -0.7479 - val_MSE: 0.0342 - val_cosine_similarity: 0.7821 - val_r_square: -0.0536
# Epoch 6
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7518 - MSE: 0.0328 - cosine_similarity: 0.7847 - r_square: -0.0281 - val_loss: -0.7466 - val_MSE: 0.0344 - val_cosine_similarity: 0.7809 - val_r_square: -0.0610
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7745 - MSE: 0.0292 - cosine_similarity: 0.8037 - r_square: -0.0232 - val_loss: -0.7471 - val_MSE: 0.0344 - val_cosine_similarity: 0.7815 - val_r_square: -0.0649
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7813 - MSE: 0.0295 - cosine_similarity: 0.8108 - r_square: 0.0237 - val_loss: -0.7470 - val_MSE: 0.0345 - val_cosine_similarity: 0.7816 - val_r_square: -0.0729
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7564 - MSE: 0.0328 - cosine_similarity: 0.7892 - r_square: -0.0207 - val_loss: -0.7474 - val_MSE: 0.0345 - val_cosine_similarity: 0.7819 - val_r_square: -0.0680
# 2/2 [==============================] - 0s 92ms/step - loss: -0.7780 - MSE: 0.0298 - cosine_similarity: 0.8079 - r_square: -0.0079 - val_loss: -0.7475 - val_MSE: 0.0344 - val_cosine_similarity: 0.7819 - val_r_square: -0.0635
# 2/2 [==============================] - 0s 90ms/step - loss: -0.7449 - MSE: 0.0355 - cosine_similarity: 0.7803 - r_square: -0.0480 - val_loss: -0.7469 - val_MSE: 0.0346 - val_cosine_similarity: 0.7815 - val_r_square: -0.0713
# Epoch 7
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7585 - MSE: 0.0309 - cosine_similarity: 0.7895 - r_square: 0.0078 - val_loss: -0.7488 - val_MSE: 0.0344 - val_cosine_similarity: 0.7832 - val_r_square: -0.0667
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7857 - MSE: 0.0290 - cosine_similarity: 0.8147 - r_square: -0.0421 - val_loss: -0.7490 - val_MSE: 0.0343 - val_cosine_similarity: 0.7833 - val_r_square: -0.0596
# 2/2 [==============================] - 0s 90ms/step - loss: -0.7650 - MSE: 0.0317 - cosine_similarity: 0.7967 - r_square: 0.0190 - val_loss: -0.7496 - val_MSE: 0.0342 - val_cosine_similarity: 0.7837 - val_r_square: -0.0554
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7635 - MSE: 0.0327 - cosine_similarity: 0.7962 - r_square: 0.0041 - val_loss: -0.7493 - val_MSE: 0.0343 - val_cosine_similarity: 0.7835 - val_r_square: -0.0592
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7743 - MSE: 0.0304 - cosine_similarity: 0.8047 - r_square: -0.0301 - val_loss: -0.7485 - val_MSE: 0.0344 - val_cosine_similarity: 0.7829 - val_r_square: -0.0652
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7672 - MSE: 0.0318 - cosine_similarity: 0.7991 - r_square: 0.0091 - val_loss: -0.7476 - val_MSE: 0.0348 - val_cosine_similarity: 0.7824 - val_r_square: -0.0795
# Epoch 8
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7759 - MSE: 0.0318 - cosine_similarity: 0.8077 - r_square: 0.0084 - val_loss: -0.7464 - val_MSE: 0.0351 - val_cosine_similarity: 0.7815 - val_r_square: -0.0957
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7902 - MSE: 0.0285 - cosine_similarity: 0.8187 - r_square: 0.0016 - val_loss: -0.7455 - val_MSE: 0.0352 - val_cosine_similarity: 0.7808 - val_r_square: -0.0999
# 2/2 [==============================] - 0s 94ms/step - loss: -0.7688 - MSE: 0.0320 - cosine_similarity: 0.8008 - r_square: -0.0122 - val_loss: -0.7450 - val_MSE: 0.0351 - val_cosine_similarity: 0.7801 - val_r_square: -0.0886
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7475 - MSE: 0.0333 - cosine_similarity: 0.7808 - r_square: -0.0381 - val_loss: -0.7454 - val_MSE: 0.0349 - val_cosine_similarity: 0.7803 - val_r_square: -0.0802
# 2/2 [==============================] - 0s 94ms/step - loss: -0.7512 - MSE: 0.0323 - cosine_similarity: 0.7834 - r_square: -0.0755 - val_loss: -0.7465 - val_MSE: 0.0347 - val_cosine_similarity: 0.7812 - val_r_square: -0.0731
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7541 - MSE: 0.0319 - cosine_similarity: 0.7860 - r_square: -0.0062 - val_loss: -0.7478 - val_MSE: 0.0346 - val_cosine_similarity: 0.7823 - val_r_square: -0.0683
# Epoch 9
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7645 - MSE: 0.0310 - cosine_similarity: 0.7955 - r_square: -0.0189 - val_loss: -0.7493 - val_MSE: 0.0344 - val_cosine_similarity: 0.7837 - val_r_square: -0.0633
# 2/2 [==============================] - 0s 92ms/step - loss: -0.7661 - MSE: 0.0312 - cosine_similarity: 0.7973 - r_square: -0.0126 - val_loss: -0.7504 - val_MSE: 0.0343 - val_cosine_similarity: 0.7847 - val_r_square: -0.0606
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7556 - MSE: 0.0335 - cosine_similarity: 0.7891 - r_square: 0.0101 - val_loss: -0.7506 - val_MSE: 0.0342 - val_cosine_similarity: 0.7848 - val_r_square: -0.0595
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7397 - MSE: 0.0355 - cosine_similarity: 0.7752 - r_square: -0.0025 - val_loss: -0.7508 - val_MSE: 0.0343 - val_cosine_similarity: 0.7850 - val_r_square: -0.0615
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7914 - MSE: 0.0274 - cosine_similarity: 0.8188 - r_square: -0.0021 - val_loss: -0.7502 - val_MSE: 0.0343 - val_cosine_similarity: 0.7845 - val_r_square: -0.0616
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7724 - MSE: 0.0308 - cosine_similarity: 0.8032 - r_square: -0.0062 - val_loss: -0.7493 - val_MSE: 0.0345 - val_cosine_similarity: 0.7838 - val_r_square: -0.0653
# Epoch 10
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7662 - MSE: 0.0311 - cosine_similarity: 0.7974 - r_square: -0.0183 - val_loss: -0.7470 - val_MSE: 0.0347 - val_cosine_similarity: 0.7817 - val_r_square: -0.0694
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7862 - MSE: 0.0286 - cosine_similarity: 0.8148 - r_square: -0.0542 - val_loss: -0.7447 - val_MSE: 0.0348 - val_cosine_similarity: 0.7796 - val_r_square: -0.0657
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7597 - MSE: 0.0317 - cosine_similarity: 0.7914 - r_square: -0.0058 - val_loss: -0.7432 - val_MSE: 0.0351 - val_cosine_similarity: 0.7783 - val_r_square: -0.0718
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7686 - MSE: 0.0308 - cosine_similarity: 0.7994 - r_square: 0.0259 - val_loss: -0.7430 - val_MSE: 0.0354 - val_cosine_similarity: 0.7784 - val_r_square: -0.0882
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7589 - MSE: 0.0342 - cosine_similarity: 0.7931 - r_square: -0.0224 - val_loss: -0.7428 - val_MSE: 0.0360 - val_cosine_similarity: 0.7788 - val_r_square: -0.1184
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7591 - MSE: 0.0313 - cosine_similarity: 0.7905 - r_square: -0.0291 - val_loss: -0.7432 - val_MSE: 0.0363 - val_cosine_similarity: 0.7795 - val_r_square: -0.1359
# Epoch 11
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7603 - MSE: 0.0320 - cosine_similarity: 0.7923 - r_square: -0.0727 - val_loss: -0.7463 - val_MSE: 0.0361 - val_cosine_similarity: 0.7824 - val_r_square: -0.1329
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7915 - MSE: 0.0289 - cosine_similarity: 0.8204 - r_square: 0.0028 - val_loss: -0.7476 - val_MSE: 0.0359 - val_cosine_similarity: 0.7834 - val_r_square: -0.1230
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7672 - MSE: 0.0321 - cosine_similarity: 0.7993 - r_square: -0.0195 - val_loss: -0.7481 - val_MSE: 0.0354 - val_cosine_similarity: 0.7835 - val_r_square: -0.1043
# 2/2 [==============================] - 0s 81ms/step - loss: -0.7836 - MSE: 0.0294 - cosine_similarity: 0.8130 - r_square: 0.0320 - val_loss: -0.7490 - val_MSE: 0.0348 - val_cosine_similarity: 0.7838 - val_r_square: -0.0763
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7333 - MSE: 0.0369 - cosine_similarity: 0.7702 - r_square: -0.0476 - val_loss: -0.7497 - val_MSE: 0.0342 - val_cosine_similarity: 0.7839 - val_r_square: -0.0505
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7705 - MSE: 0.0292 - cosine_similarity: 0.7997 - r_square: -0.0437 - val_loss: -0.7500 - val_MSE: 0.0339 - val_cosine_similarity: 0.7839 - val_r_square: -0.0371
# Epoch 12
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7827 - MSE: 0.0273 - cosine_similarity: 0.8100 - r_square: 0.0094 - val_loss: -0.7489 - val_MSE: 0.0340 - val_cosine_similarity: 0.7829 - val_r_square: -0.0374
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7579 - MSE: 0.0335 - cosine_similarity: 0.7914 - r_square: -0.0034 - val_loss: -0.7486 - val_MSE: 0.0340 - val_cosine_similarity: 0.7826 - val_r_square: -0.0400
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7751 - MSE: 0.0288 - cosine_similarity: 0.8039 - r_square: 0.0066 - val_loss: -0.7485 - val_MSE: 0.0340 - val_cosine_similarity: 0.7825 - val_r_square: -0.0412
# 2/2 [==============================] - 0s 90ms/step - loss: -0.7967 - MSE: 0.0279 - cosine_similarity: 0.8246 - r_square: 0.0103 - val_loss: -0.7475 - val_MSE: 0.0341 - val_cosine_similarity: 0.7816 - val_r_square: -0.0447
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7494 - MSE: 0.0349 - cosine_similarity: 0.7844 - r_square: 0.0218 - val_loss: -0.7462 - val_MSE: 0.0344 - val_cosine_similarity: 0.7806 - val_r_square: -0.0527
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7518 - MSE: 0.0335 - cosine_similarity: 0.7853 - r_square: 0.0058 - val_loss: -0.7460 - val_MSE: 0.0345 - val_cosine_similarity: 0.7805 - val_r_square: -0.0590
# Epoch 13
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7846 - MSE: 0.0302 - cosine_similarity: 0.8148 - r_square: 0.0130 - val_loss: -0.7418 - val_MSE: 0.0351 - val_cosine_similarity: 0.7769 - val_r_square: -0.0773
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7429 - MSE: 0.0345 - cosine_similarity: 0.7774 - r_square: -0.0313 - val_loss: -0.7413 - val_MSE: 0.0353 - val_cosine_similarity: 0.7766 - val_r_square: -0.0824
# 2/2 [==============================] - 0s 81ms/step - loss: -0.7573 - MSE: 0.0318 - cosine_similarity: 0.7891 - r_square: -0.0474 - val_loss: -0.7430 - val_MSE: 0.0356 - val_cosine_similarity: 0.7786 - val_r_square: -0.1056
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7539 - MSE: 0.0330 - cosine_similarity: 0.7868 - r_square: -0.0140 - val_loss: -0.7446 - val_MSE: 0.0360 - val_cosine_similarity: 0.7806 - val_r_square: -0.1300
# 2/2 [==============================] - 0s 81ms/step - loss: -0.7758 - MSE: 0.0283 - cosine_similarity: 0.8042 - r_square: -0.0273 - val_loss: -0.7459 - val_MSE: 0.0360 - val_cosine_similarity: 0.7819 - val_r_square: -0.1332
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7858 - MSE: 0.0296 - cosine_similarity: 0.8155 - r_square: 0.0196 - val_loss: -0.7465 - val_MSE: 0.0357 - val_cosine_similarity: 0.7822 - val_r_square: -0.1168
# Epoch 14
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7780 - MSE: 0.0303 - cosine_similarity: 0.8083 - r_square: 0.0288 - val_loss: -0.7516 - val_MSE: 0.0345 - val_cosine_similarity: 0.7860 - val_r_square: -0.0681
# 2/2 [==============================] - 0s 90ms/step - loss: -0.7604 - MSE: 0.0319 - cosine_similarity: 0.7923 - r_square: 0.0212 - val_loss: -0.7519 - val_MSE: 0.0340 - val_cosine_similarity: 0.7859 - val_r_square: -0.0475
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7734 - MSE: 0.0294 - cosine_similarity: 0.8028 - r_square: -0.0021 - val_loss: -0.7518 - val_MSE: 0.0338 - val_cosine_similarity: 0.7856 - val_r_square: -0.0362
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7770 - MSE: 0.0308 - cosine_similarity: 0.8078 - r_square: 0.0179 - val_loss: -0.7513 - val_MSE: 0.0337 - val_cosine_similarity: 0.7850 - val_r_square: -0.0340
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7709 - MSE: 0.0306 - cosine_similarity: 0.8015 - r_square: -0.0408 - val_loss: -0.7502 - val_MSE: 0.0336 - val_cosine_similarity: 0.7839 - val_r_square: -0.0295
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7605 - MSE: 0.0324 - cosine_similarity: 0.7929 - r_square: -4.2921e-04 - val_loss: -0.7500 - val_MSE: 0.0336 - val_cosine_similarity: 0.7836 - val_r_square: -0.0287
# Epoch 15
# 2/2 [==============================] - 0s 81ms/step - loss: -0.7714 - MSE: 0.0280 - cosine_similarity: 0.7994 - r_square: -0.0151 - val_loss: -0.7464 - val_MSE: 0.0343 - val_cosine_similarity: 0.7807 - val_r_square: -0.0553
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7713 - MSE: 0.0307 - cosine_similarity: 0.8020 - r_square: 0.0298 - val_loss: -0.7469 - val_MSE: 0.0345 - val_cosine_similarity: 0.7814 - val_r_square: -0.0666
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7481 - MSE: 0.0345 - cosine_similarity: 0.7826 - r_square: -0.0271 - val_loss: -0.7462 - val_MSE: 0.0348 - val_cosine_similarity: 0.7810 - val_r_square: -0.0803
# 2/2 [==============================] - 0s 87ms/step - loss: -0.7763 - MSE: 0.0305 - cosine_similarity: 0.8067 - r_square: -0.0107 - val_loss: -0.7456 - val_MSE: 0.0350 - val_cosine_similarity: 0.7807 - val_r_square: -0.0908
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7761 - MSE: 0.0304 - cosine_similarity: 0.8066 - r_square: 0.0549 - val_loss: -0.7456 - val_MSE: 0.0351 - val_cosine_similarity: 0.7807 - val_r_square: -0.0938
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7541 - MSE: 0.0330 - cosine_similarity: 0.7872 - r_square: -0.0178 - val_loss: -0.7459 - val_MSE: 0.0352 - val_cosine_similarity: 0.7811 - val_r_square: -0.0992
# Epoch 16
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7715 - MSE: 0.0303 - cosine_similarity: 0.8017 - r_square: -0.0181 - val_loss: -0.7500 - val_MSE: 0.0346 - val_cosine_similarity: 0.7847 - val_r_square: -0.0756
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7702 - MSE: 0.0321 - cosine_similarity: 0.8023 - r_square: 0.0178 - val_loss: -0.7497 - val_MSE: 0.0346 - val_cosine_similarity: 0.7843 - val_r_square: -0.0692
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7924 - MSE: 0.0278 - cosine_similarity: 0.8202 - r_square: -0.0014 - val_loss: -0.7494 - val_MSE: 0.0344 - val_cosine_similarity: 0.7838 - val_r_square: -0.0611
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7715 - MSE: 0.0297 - cosine_similarity: 0.8012 - r_square: 0.0117 - val_loss: -0.7493 - val_MSE: 0.0342 - val_cosine_similarity: 0.7835 - val_r_square: -0.0524
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7549 - MSE: 0.0341 - cosine_similarity: 0.7890 - r_square: -0.0026 - val_loss: -0.7500 - val_MSE: 0.0340 - val_cosine_similarity: 0.7840 - val_r_square: -0.0449
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7472 - MSE: 0.0324 - cosine_similarity: 0.7795 - r_square: 0.0161 - val_loss: -0.7508 - val_MSE: 0.0340 - val_cosine_similarity: 0.7847 - val_r_square: -0.0430
# Epoch 17
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7575 - MSE: 0.0304 - cosine_similarity: 0.7879 - r_square: -0.0261 - val_loss: -0.7497 - val_MSE: 0.0341 - val_cosine_similarity: 0.7838 - val_r_square: -0.0491
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7855 - MSE: 0.0287 - cosine_similarity: 0.8142 - r_square: -0.0096 - val_loss: -0.7490 - val_MSE: 0.0342 - val_cosine_similarity: 0.7832 - val_r_square: -0.0499
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7681 - MSE: 0.0323 - cosine_similarity: 0.8004 - r_square: -0.0134 - val_loss: -0.7484 - val_MSE: 0.0343 - val_cosine_similarity: 0.7827 - val_r_square: -0.0589
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7741 - MSE: 0.0297 - cosine_similarity: 0.8038 - r_square: 0.0061 - val_loss: -0.7477 - val_MSE: 0.0346 - val_cosine_similarity: 0.7823 - val_r_square: -0.0745
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7374 - MSE: 0.0355 - cosine_similarity: 0.7728 - r_square: -0.0036 - val_loss: -0.7484 - val_MSE: 0.0347 - val_cosine_similarity: 0.7831 - val_r_square: -0.0816
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7805 - MSE: 0.0301 - cosine_similarity: 0.8106 - r_square: -0.0064 - val_loss: -0.7489 - val_MSE: 0.0346 - val_cosine_similarity: 0.7835 - val_r_square: -0.0767
# Epoch 18
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7711 - MSE: 0.0308 - cosine_similarity: 0.8019 - r_square: 0.0126 - val_loss: -0.7503 - val_MSE: 0.0342 - val_cosine_similarity: 0.7845 - val_r_square: -0.0596
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7829 - MSE: 0.0287 - cosine_similarity: 0.8117 - r_square: 0.0180 - val_loss: -0.7501 - val_MSE: 0.0341 - val_cosine_similarity: 0.7841 - val_r_square: -0.0499
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7551 - MSE: 0.0319 - cosine_similarity: 0.7869 - r_square: 0.0113 - val_loss: -0.7497 - val_MSE: 0.0341 - val_cosine_similarity: 0.7838 - val_r_square: -0.0515
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7771 - MSE: 0.0303 - cosine_similarity: 0.8074 - r_square: 0.0131 - val_loss: -0.7490 - val_MSE: 0.0342 - val_cosine_similarity: 0.7831 - val_r_square: -0.0533
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7571 - MSE: 0.0333 - cosine_similarity: 0.7904 - r_square: 0.0227 - val_loss: -0.7482 - val_MSE: 0.0342 - val_cosine_similarity: 0.7824 - val_r_square: -0.0503
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7686 - MSE: 0.0308 - cosine_similarity: 0.7994 - r_square: -0.0166 - val_loss: -0.7478 - val_MSE: 0.0342 - val_cosine_similarity: 0.7820 - val_r_square: -0.0508
# Epoch 19
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7614 - MSE: 0.0313 - cosine_similarity: 0.7926 - r_square: 0.0132 - val_loss: -0.7478 - val_MSE: 0.0343 - val_cosine_similarity: 0.7821 - val_r_square: -0.0572
# 2/2 [==============================] - 0s 84ms/step - loss: -0.8008 - MSE: 0.0268 - cosine_similarity: 0.8276 - r_square: 0.0251 - val_loss: -0.7470 - val_MSE: 0.0346 - val_cosine_similarity: 0.7816 - val_r_square: -0.0677
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7564 - MSE: 0.0316 - cosine_similarity: 0.7880 - r_square: 0.0091 - val_loss: -0.7463 - val_MSE: 0.0348 - val_cosine_similarity: 0.7811 - val_r_square: -0.0764
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7589 - MSE: 0.0330 - cosine_similarity: 0.7919 - r_square: -4.8307e-04 - val_loss: -0.7458 - val_MSE: 0.0349 - val_cosine_similarity: 0.7806 - val_r_square: -0.0793
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7639 - MSE: 0.0316 - cosine_similarity: 0.7955 - r_square: -0.0298 - val_loss: -0.7456 - val_MSE: 0.0349 - val_cosine_similarity: 0.7805 - val_r_square: -0.0777
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7781 - MSE: 0.0306 - cosine_similarity: 0.8087 - r_square: 0.0196 - val_loss: -0.7447 - val_MSE: 0.0348 - val_cosine_similarity: 0.7794 - val_r_square: -0.0687
# Epoch 20
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7835 - MSE: 0.0288 - cosine_similarity: 0.8123 - r_square: -0.0203 - val_loss: -0.7386 - val_MSE: 0.0354 - val_cosine_similarity: 0.7740 - val_r_square: -0.0848
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7440 - MSE: 0.0335 - cosine_similarity: 0.7775 - r_square: -0.0252 - val_loss: -0.7381 - val_MSE: 0.0354 - val_cosine_similarity: 0.7735 - val_r_square: -0.0864
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7767 - MSE: 0.0299 - cosine_similarity: 0.8066 - r_square: 0.0106 - val_loss: -0.7382 - val_MSE: 0.0355 - val_cosine_similarity: 0.7737 - val_r_square: -0.0916
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7733 - MSE: 0.0311 - cosine_similarity: 0.8044 - r_square: -0.0011 - val_loss: -0.7391 - val_MSE: 0.0359 - val_cosine_similarity: 0.7750 - val_r_square: -0.1087
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7685 - MSE: 0.0313 - cosine_similarity: 0.7998 - r_square: -0.0056 - val_loss: -0.7397 - val_MSE: 0.0364 - val_cosine_similarity: 0.7761 - val_r_square: -0.1297
# 2/2 [==============================] - 0s 192ms/step - loss: -0.7578 - MSE: 0.0323 - cosine_similarity: 0.7901 - r_square: 8.9753e-04 - val_loss: -0.7398 - val_MSE: 0.0369 - val_cosine_similarity: 0.7767 - val_r_square: -0.1541
# Epoch 21
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7533 - MSE: 0.0336 - cosine_similarity: 0.7869 - r_square: -0.0710 - val_loss: -0.7437 - val_MSE: 0.0365 - val_cosine_similarity: 0.7803 - val_r_square: -0.1409
# 2/2 [==============================] - 0s 87ms/step - loss: -0.7777 - MSE: 0.0294 - cosine_similarity: 0.8071 - r_square: -0.0539 - val_loss: -0.7447 - val_MSE: 0.0361 - val_cosine_similarity: 0.7808 - val_r_square: -0.1219
# 2/2 [==============================] - 0s 87ms/step - loss: -0.7659 - MSE: 0.0314 - cosine_similarity: 0.7973 - r_square: -0.0116 - val_loss: -0.7456 - val_MSE: 0.0356 - val_cosine_similarity: 0.7812 - val_r_square: -0.1018
# 2/2 [==============================] - 0s 90ms/step - loss: -0.7796 - MSE: 0.0304 - cosine_similarity: 0.8101 - r_square: 0.0218 - val_loss: -0.7457 - val_MSE: 0.0353 - val_cosine_similarity: 0.7810 - val_r_square: -0.0910
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7905 - MSE: 0.0281 - cosine_similarity: 0.8186 - r_square: 0.0734 - val_loss: -0.7450 - val_MSE: 0.0353 - val_cosine_similarity: 0.7802 - val_r_square: -0.0871
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7491 - MSE: 0.0333 - cosine_similarity: 0.7824 - r_square: 0.0080 - val_loss: -0.7454 - val_MSE: 0.0351 - val_cosine_similarity: 0.7804 - val_r_square: -0.0789
# Epoch 22
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7621 - MSE: 0.0317 - cosine_similarity: 0.7938 - r_square: -0.0269 - val_loss: -0.7462 - val_MSE: 0.0347 - val_cosine_similarity: 0.7809 - val_r_square: -0.0651
# 2/2 [==============================] - 0s 93ms/step - loss: -0.7773 - MSE: 0.0305 - cosine_similarity: 0.8078 - r_square: 0.0190 - val_loss: -0.7463 - val_MSE: 0.0346 - val_cosine_similarity: 0.7809 - val_r_square: -0.0610
# 2/2 [==============================] - 0s 90ms/step - loss: -0.7698 - MSE: 0.0304 - cosine_similarity: 0.8001 - r_square: 0.0116 - val_loss: -0.7473 - val_MSE: 0.0344 - val_cosine_similarity: 0.7816 - val_r_square: -0.0568
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7797 - MSE: 0.0284 - cosine_similarity: 0.8081 - r_square: 0.0349 - val_loss: -0.7481 - val_MSE: 0.0342 - val_cosine_similarity: 0.7823 - val_r_square: -0.0495
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7508 - MSE: 0.0343 - cosine_similarity: 0.7852 - r_square: -0.0097 - val_loss: -0.7496 - val_MSE: 0.0338 - val_cosine_similarity: 0.7834 - val_r_square: -0.0382
# 2/2 [==============================] - 0s 116ms/step - loss: -0.7736 - MSE: 0.0301 - cosine_similarity: 0.8036 - r_square: 0.0116 - val_loss: -0.7505 - val_MSE: 0.0337 - val_cosine_similarity: 0.7843 - val_r_square: -0.0359
# Epoch 23
# 2/2 [==============================] - 0s 87ms/step - loss: -0.7485 - MSE: 0.0349 - cosine_similarity: 0.7835 - r_square: 0.0525 - val_loss: -0.7502 - val_MSE: 0.0338 - val_cosine_similarity: 0.7840 - val_r_square: -0.0374
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7938 - MSE: 0.0269 - cosine_similarity: 0.8208 - r_square: 0.0069 - val_loss: -0.7494 - val_MSE: 0.0339 - val_cosine_similarity: 0.7833 - val_r_square: -0.0417
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7893 - MSE: 0.0284 - cosine_similarity: 0.8177 - r_square: 0.0401 - val_loss: -0.7483 - val_MSE: 0.0341 - val_cosine_similarity: 0.7824 - val_r_square: -0.0450
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7463 - MSE: 0.0334 - cosine_similarity: 0.7797 - r_square: 0.0075 - val_loss: -0.7474 - val_MSE: 0.0343 - val_cosine_similarity: 0.7817 - val_r_square: -0.0539
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7961 - MSE: 0.0285 - cosine_similarity: 0.8246 - r_square: 0.0065 - val_loss: -0.7458 - val_MSE: 0.0347 - val_cosine_similarity: 0.7805 - val_r_square: -0.0728
# 2/2 [==============================] - 0s 90ms/step - loss: -0.7550 - MSE: 0.0319 - cosine_similarity: 0.7869 - r_square: -0.0130 - val_loss: -0.7448 - val_MSE: 0.0351 - val_cosine_similarity: 0.7799 - val_r_square: -0.0897
# Epoch 24
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7823 - MSE: 0.0278 - cosine_similarity: 0.8101 - r_square: 0.0281 - val_loss: -0.7444 - val_MSE: 0.0353 - val_cosine_similarity: 0.7797 - val_r_square: -0.1018
# 2/2 [==============================] - 0s 91ms/step - loss: -0.7574 - MSE: 0.0324 - cosine_similarity: 0.7898 - r_square: 0.0119 - val_loss: -0.7435 - val_MSE: 0.0355 - val_cosine_similarity: 0.7790 - val_r_square: -0.1042
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7780 - MSE: 0.0310 - cosine_similarity: 0.8090 - r_square: -0.0338 - val_loss: -0.7420 - val_MSE: 0.0357 - val_cosine_similarity: 0.7777 - val_r_square: -0.1066
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7660 - MSE: 0.0324 - cosine_similarity: 0.7984 - r_square: 0.0299 - val_loss: -0.7407 - val_MSE: 0.0356 - val_cosine_similarity: 0.7764 - val_r_square: -0.0973
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7768 - MSE: 0.0289 - cosine_similarity: 0.8057 - r_square: -0.0366 - val_loss: -0.7403 - val_MSE: 0.0355 - val_cosine_similarity: 0.7758 - val_r_square: -0.0887
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7634 - MSE: 0.0323 - cosine_similarity: 0.7958 - r_square: 0.0056 - val_loss: -0.7414 - val_MSE: 0.0353 - val_cosine_similarity: 0.7767 - val_r_square: -0.0800
# Epoch 25
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7713 - MSE: 0.0297 - cosine_similarity: 0.8010 - r_square: -0.0013 - val_loss: -0.7419 - val_MSE: 0.0354 - val_cosine_similarity: 0.7772 - val_r_square: -0.0802
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7945 - MSE: 0.0290 - cosine_similarity: 0.8235 - r_square: 0.0382 - val_loss: -0.7425 - val_MSE: 0.0355 - val_cosine_similarity: 0.7780 - val_r_square: -0.0875
# 2/2 [==============================] - 0s 93ms/step - loss: -0.7554 - MSE: 0.0324 - cosine_similarity: 0.7878 - r_square: -1.3878e-04 - val_loss: -0.7439 - val_MSE: 0.0357 - val_cosine_similarity: 0.7796 - val_r_square: -0.0983
# 2/2 [==============================] - 0s 90ms/step - loss: -0.7831 - MSE: 0.0285 - cosine_similarity: 0.8117 - r_square: 0.0660 - val_loss: -0.7451 - val_MSE: 0.0358 - val_cosine_similarity: 0.7809 - val_r_square: -0.1038
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7607 - MSE: 0.0331 - cosine_similarity: 0.7938 - r_square: 0.0242 - val_loss: -0.7464 - val_MSE: 0.0356 - val_cosine_similarity: 0.7820 - val_r_square: -0.0983
# 2/2 [==============================] - 0s 81ms/step - loss: -0.7634 - MSE: 0.0312 - cosine_similarity: 0.7945 - r_square: -0.0401 - val_loss: -0.7479 - val_MSE: 0.0351 - val_cosine_similarity: 0.7830 - val_r_square: -0.0815
# Epoch 26
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7719 - MSE: 0.0294 - cosine_similarity: 0.8013 - r_square: 0.0439 - val_loss: -0.7500 - val_MSE: 0.0344 - val_cosine_similarity: 0.7845 - val_r_square: -0.0590
# 2/2 [==============================] - 0s 93ms/step - loss: -0.7637 - MSE: 0.0318 - cosine_similarity: 0.7955 - r_square: 0.0118 - val_loss: -0.7504 - val_MSE: 0.0342 - val_cosine_similarity: 0.7846 - val_r_square: -0.0498
# 2/2 [==============================] - 0s 87ms/step - loss: -0.7681 - MSE: 0.0312 - cosine_similarity: 0.7993 - r_square: -0.0373 - val_loss: -0.7498 - val_MSE: 0.0341 - val_cosine_similarity: 0.7839 - val_r_square: -0.0476
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7811 - MSE: 0.0295 - cosine_similarity: 0.8106 - r_square: 0.0152 - val_loss: -0.7494 - val_MSE: 0.0340 - val_cosine_similarity: 0.7834 - val_r_square: -0.0432
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7663 - MSE: 0.0313 - cosine_similarity: 0.7976 - r_square: 0.0191 - val_loss: -0.7484 - val_MSE: 0.0341 - val_cosine_similarity: 0.7825 - val_r_square: -0.0455
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7738 - MSE: 0.0309 - cosine_similarity: 0.8047 - r_square: 0.0381 - val_loss: -0.7487 - val_MSE: 0.0341 - val_cosine_similarity: 0.7828 - val_r_square: -0.0506
# Epoch 27
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7896 - MSE: 0.0288 - cosine_similarity: 0.8184 - r_square: 0.0361 - val_loss: -0.7433 - val_MSE: 0.0350 - val_cosine_similarity: 0.7783 - val_r_square: -0.0846
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7627 - MSE: 0.0315 - cosine_similarity: 0.7942 - r_square: 0.0125 - val_loss: -0.7432 - val_MSE: 0.0353 - val_cosine_similarity: 0.7785 - val_r_square: -0.0981
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7711 - MSE: 0.0319 - cosine_similarity: 0.8030 - r_square: 0.0115 - val_loss: -0.7428 - val_MSE: 0.0356 - val_cosine_similarity: 0.7783 - val_r_square: -0.1150
# 2/2 [==============================] - 0s 90ms/step - loss: -0.7796 - MSE: 0.0292 - cosine_similarity: 0.8088 - r_square: 4.1095e-04 - val_loss: -0.7434 - val_MSE: 0.0356 - val_cosine_similarity: 0.7790 - val_r_square: -0.1189
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7648 - MSE: 0.0303 - cosine_similarity: 0.7951 - r_square: -0.0090 - val_loss: -0.7449 - val_MSE: 0.0354 - val_cosine_similarity: 0.7803 - val_r_square: -0.1061
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7665 - MSE: 0.0315 - cosine_similarity: 0.7981 - r_square: 0.0399 - val_loss: -0.7459 - val_MSE: 0.0349 - val_cosine_similarity: 0.7808 - val_r_square: -0.0829
# Epoch 28
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7765 - MSE: 0.0289 - cosine_similarity: 0.8054 - r_square: -0.0057 - val_loss: -0.7469 - val_MSE: 0.0345 - val_cosine_similarity: 0.7813 - val_r_square: -0.0639
# 2/2 [==============================] - 0s 91ms/step - loss: -0.7680 - MSE: 0.0316 - cosine_similarity: 0.7995 - r_square: 0.0050 - val_loss: -0.7464 - val_MSE: 0.0344 - val_cosine_similarity: 0.7808 - val_r_square: -0.0572
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7808 - MSE: 0.0311 - cosine_similarity: 0.8120 - r_square: 0.0275 - val_loss: -0.7450 - val_MSE: 0.0345 - val_cosine_similarity: 0.7795 - val_r_square: -0.0556
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7684 - MSE: 0.0309 - cosine_similarity: 0.7993 - r_square: 0.0024 - val_loss: -0.7428 - val_MSE: 0.0347 - val_cosine_similarity: 0.7775 - val_r_square: -0.0594
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7726 - MSE: 0.0293 - cosine_similarity: 0.8019 - r_square: 0.0441 - val_loss: -0.7406 - val_MSE: 0.0350 - val_cosine_similarity: 0.7756 - val_r_square: -0.0668
# 2/2 [==============================] - 0s 91ms/step - loss: -0.7480 - MSE: 0.0336 - cosine_similarity: 0.7816 - r_square: -0.0124 - val_loss: -0.7405 - val_MSE: 0.0352 - val_cosine_similarity: 0.7757 - val_r_square: -0.0781
# Epoch 29
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7669 - MSE: 0.0315 - cosine_similarity: 0.7984 - r_square: 0.0145 - val_loss: -0.7418 - val_MSE: 0.0353 - val_cosine_similarity: 0.7771 - val_r_square: -0.0871
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7766 - MSE: 0.0309 - cosine_similarity: 0.8076 - r_square: 0.0368 - val_loss: -0.7424 - val_MSE: 0.0357 - val_cosine_similarity: 0.7780 - val_r_square: -0.1072
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7884 - MSE: 0.0279 - cosine_similarity: 0.8163 - r_square: -0.0031 - val_loss: -0.7430 - val_MSE: 0.0357 - val_cosine_similarity: 0.7787 - val_r_square: -0.1120
# 2/2 [==============================] - 0s 90ms/step - loss: -0.7696 - MSE: 0.0301 - cosine_similarity: 0.7997 - r_square: 0.0525 - val_loss: -0.7438 - val_MSE: 0.0354 - val_cosine_similarity: 0.7793 - val_r_square: -0.1014
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7618 - MSE: 0.0331 - cosine_similarity: 0.7949 - r_square: 0.0179 - val_loss: -0.7450 - val_MSE: 0.0350 - val_cosine_similarity: 0.7800 - val_r_square: -0.0827
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7779 - MSE: 0.0293 - cosine_similarity: 0.8072 - r_square: 0.0448 - val_loss: -0.7458 - val_MSE: 0.0345 - val_cosine_similarity: 0.7803 - val_r_square: -0.0619
# Epoch 30
# 2/2 [==============================] - 0s 87ms/step - loss: -0.7764 - MSE: 0.0311 - cosine_similarity: 0.8074 - r_square: 0.0616 - val_loss: -0.7495 - val_MSE: 0.0338 - val_cosine_similarity: 0.7832 - val_r_square: -0.0336
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7772 - MSE: 0.0297 - cosine_similarity: 0.8070 - r_square: 0.0417 - val_loss: -0.7491 - val_MSE: 0.0337 - val_cosine_similarity: 0.7828 - val_r_square: -0.0303
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7683 - MSE: 0.0311 - cosine_similarity: 0.7994 - r_square: -0.0093 - val_loss: -0.7482 - val_MSE: 0.0340 - val_cosine_similarity: 0.7822 - val_r_square: -0.0421
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7662 - MSE: 0.0297 - cosine_similarity: 0.7958 - r_square: 0.0172 - val_loss: -0.7476 - val_MSE: 0.0344 - val_cosine_similarity: 0.7820 - val_r_square: -0.0645
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7741 - MSE: 0.0311 - cosine_similarity: 0.8052 - r_square: -0.0271 - val_loss: -0.7467 - val_MSE: 0.0349 - val_cosine_similarity: 0.7815 - val_r_square: -0.0822
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7826 - MSE: 0.0293 - cosine_similarity: 0.8120 - r_square: 0.0698 - val_loss: -0.7459 - val_MSE: 0.0351 - val_cosine_similarity: 0.7810 - val_r_square: -0.0922
# Epoch 31
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7472 - MSE: 0.0348 - cosine_similarity: 0.7821 - r_square: -0.0196 - val_loss: -0.7405 - val_MSE: 0.0359 - val_cosine_similarity: 0.7764 - val_r_square: -0.1154
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7683 - MSE: 0.0310 - cosine_similarity: 0.7993 - r_square: -0.0076 - val_loss: -0.7405 - val_MSE: 0.0357 - val_cosine_similarity: 0.7761 - val_r_square: -0.1003
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7802 - MSE: 0.0285 - cosine_similarity: 0.8088 - r_square: 0.0107 - val_loss: -0.7405 - val_MSE: 0.0356 - val_cosine_similarity: 0.7761 - val_r_square: -0.0964
# 2/2 [==============================] - 0s 93ms/step - loss: -0.7939 - MSE: 0.0265 - cosine_similarity: 0.8205 - r_square: 0.0405 - val_loss: -0.7408 - val_MSE: 0.0356 - val_cosine_similarity: 0.7764 - val_r_square: -0.0947
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7727 - MSE: 0.0310 - cosine_similarity: 0.8037 - r_square: 0.0531 - val_loss: -0.7418 - val_MSE: 0.0356 - val_cosine_similarity: 0.7774 - val_r_square: -0.1004
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7659 - MSE: 0.0318 - cosine_similarity: 0.7977 - r_square: 0.0270 - val_loss: -0.7421 - val_MSE: 0.0358 - val_cosine_similarity: 0.7779 - val_r_square: -0.1107
# Epoch 32
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7581 - MSE: 0.0319 - cosine_similarity: 0.7901 - r_square: 0.0125 - val_loss: -0.7447 - val_MSE: 0.0354 - val_cosine_similarity: 0.7801 - val_r_square: -0.1012
# 2/2 [==============================] - 0s 91ms/step - loss: -0.7802 - MSE: 0.0303 - cosine_similarity: 0.8105 - r_square: 0.0453 - val_loss: -0.7447 - val_MSE: 0.0353 - val_cosine_similarity: 0.7800 - val_r_square: -0.0959
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7727 - MSE: 0.0289 - cosine_similarity: 0.8017 - r_square: -0.0075 - val_loss: -0.7450 - val_MSE: 0.0352 - val_cosine_similarity: 0.7801 - val_r_square: -0.0924
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7820 - MSE: 0.0279 - cosine_similarity: 0.8099 - r_square: 0.0264 - val_loss: -0.7456 - val_MSE: 0.0350 - val_cosine_similarity: 0.7806 - val_r_square: -0.0831
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7783 - MSE: 0.0321 - cosine_similarity: 0.8103 - r_square: 0.0508 - val_loss: -0.7455 - val_MSE: 0.0348 - val_cosine_similarity: 0.7803 - val_r_square: -0.0698
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7736 - MSE: 0.0310 - cosine_similarity: 0.8046 - r_square: -0.0257 - val_loss: -0.7449 - val_MSE: 0.0348 - val_cosine_similarity: 0.7797 - val_r_square: -0.0672
# Epoch 33
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7428 - MSE: 0.0327 - cosine_similarity: 0.7754 - r_square: -0.0252 - val_loss: -0.7406 - val_MSE: 0.0355 - val_cosine_similarity: 0.7762 - val_r_square: -0.0912
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7656 - MSE: 0.0312 - cosine_similarity: 0.7968 - r_square: -0.0201 - val_loss: -0.7381 - val_MSE: 0.0362 - val_cosine_similarity: 0.7743 - val_r_square: -0.1143
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7736 - MSE: 0.0299 - cosine_similarity: 0.8036 - r_square: 0.0144 - val_loss: -0.7363 - val_MSE: 0.0367 - val_cosine_similarity: 0.7730 - val_r_square: -0.1298
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7598 - MSE: 0.0338 - cosine_similarity: 0.7936 - r_square: 0.0693 - val_loss: -0.7353 - val_MSE: 0.0371 - val_cosine_similarity: 0.7724 - val_r_square: -0.1467
# 2/2 [==============================] - 0s 123ms/step - loss: -0.8007 - MSE: 0.0273 - cosine_similarity: 0.8280 - r_square: 0.0508 - val_loss: -0.7359 - val_MSE: 0.0372 - val_cosine_similarity: 0.7730 - val_r_square: -0.1493
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7825 - MSE: 0.0292 - cosine_similarity: 0.8117 - r_square: -0.0307 - val_loss: -0.7376 - val_MSE: 0.0368 - val_cosine_similarity: 0.7745 - val_r_square: -0.1388
# Epoch 34
# 2/2 [==============================] - 0s 91ms/step - loss: -0.7928 - MSE: 0.0275 - cosine_similarity: 0.8203 - r_square: 0.0638 - val_loss: -0.7444 - val_MSE: 0.0357 - val_cosine_similarity: 0.7801 - val_r_square: -0.1078
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7601 - MSE: 0.0321 - cosine_similarity: 0.7921 - r_square: 0.0112 - val_loss: -0.7454 - val_MSE: 0.0356 - val_cosine_similarity: 0.7811 - val_r_square: -0.1136
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7696 - MSE: 0.0305 - cosine_similarity: 0.8001 - r_square: 0.0203 - val_loss: -0.7460 - val_MSE: 0.0355 - val_cosine_similarity: 0.7814 - val_r_square: -0.1112
# 2/2 [==============================] - 0s 81ms/step - loss: -0.7829 - MSE: 0.0295 - cosine_similarity: 0.8124 - r_square: -0.0585 - val_loss: -0.7464 - val_MSE: 0.0353 - val_cosine_similarity: 0.7817 - val_r_square: -0.1033
# 2/2 [==============================] - 0s 87ms/step - loss: -0.7827 - MSE: 0.0304 - cosine_similarity: 0.8131 - r_square: 0.0731 - val_loss: -0.7466 - val_MSE: 0.0350 - val_cosine_similarity: 0.7816 - val_r_square: -0.0879
# 2/2 [==============================] - 0s 90ms/step - loss: -0.7556 - MSE: 0.0320 - cosine_similarity: 0.7876 - r_square: 0.0075 - val_loss: -0.7475 - val_MSE: 0.0347 - val_cosine_similarity: 0.7822 - val_r_square: -0.0733
# Epoch 35
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7558 - MSE: 0.0345 - cosine_similarity: 0.7903 - r_square: 0.0325 - val_loss: -0.7434 - val_MSE: 0.0352 - val_cosine_similarity: 0.7786 - val_r_square: -0.0863
# 2/2 [==============================] - 0s 80ms/step - loss: -0.7805 - MSE: 0.0290 - cosine_similarity: 0.8095 - r_square: 0.0488 - val_loss: -0.7436 - val_MSE: 0.0351 - val_cosine_similarity: 0.7786 - val_r_square: -0.0794
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7893 - MSE: 0.0260 - cosine_similarity: 0.8153 - r_square: 0.0118 - val_loss: -0.7434 - val_MSE: 0.0350 - val_cosine_similarity: 0.7784 - val_r_square: -0.0754
# ...
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7845 - MSE: 0.0292 - cosine_similarity: 0.8137 - r_square: 0.0669 - val_loss: -0.7417 - val_MSE: 0.0362 - val_cosine_similarity: 0.7780 - val_r_square: -0.1186
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7937 - MSE: 0.0261 - cosine_similarity: 0.8198 - r_square: 0.0413 - val_loss: -0.7405 - val_MSE: 0.0362 - val_cosine_similarity: 0.7767 - val_r_square: -0.1179
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7692 - MSE: 0.0319 - cosine_similarity: 0.8011 - r_square: 0.0016 - val_loss: -0.7397 - val_MSE: 0.0363 - val_cosine_similarity: 0.7760 - val_r_square: -0.1205
# 2/2 [==============================] - 0s 87ms/step - loss: -0.7862 - MSE: 0.0287 - cosine_similarity: 0.8150 - r_square: 0.0326 - val_loss: -0.7392 - val_MSE: 0.0364 - val_cosine_similarity: 0.7756 - val_r_square: -0.1277
# 2/2 [==============================] - 0s 87ms/step - loss: -0.7869 - MSE: 0.0289 - cosine_similarity: 0.8157 - r_square: 0.0752 - val_loss: -0.7390 - val_MSE: 0.0366 - val_cosine_similarity: 0.7756 - val_r_square: -0.1383
# Epoch 89
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7758 - MSE: 0.0303 - cosine_similarity: 0.8060 - r_square: 0.0725 - val_loss: -0.7329 - val_MSE: 0.0376 - val_cosine_similarity: 0.7705 - val_r_square: -0.1696
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7902 - MSE: 0.0282 - cosine_similarity: 0.8184 - r_square: 6.5019e-04 - val_loss: -0.7319 - val_MSE: 0.0377 - val_cosine_similarity: 0.7696 - val_r_square: -0.1733
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7739 - MSE: 0.0310 - cosine_similarity: 0.8049 - r_square: 0.0568 - val_loss: -0.7322 - val_MSE: 0.0377 - val_cosine_similarity: 0.7699 - val_r_square: -0.1753
# 2/2 [==============================] - 0s 94ms/step - loss: -0.7696 - MSE: 0.0310 - cosine_similarity: 0.8006 - r_square: 0.0620 - val_loss: -0.7338 - val_MSE: 0.0376 - val_cosine_similarity: 0.7714 - val_r_square: -0.1746
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7662 - MSE: 0.0321 - cosine_similarity: 0.7983 - r_square: 0.0447 - val_loss: -0.7340 - val_MSE: 0.0376 - val_cosine_similarity: 0.7716 - val_r_square: -0.1745
# 2/2 [==============================] - 0s 84ms/step - loss: -0.8282 - MSE: 0.0224 - cosine_similarity: 0.8506 - r_square: 0.0786 - val_loss: -0.7339 - val_MSE: 0.0374 - val_cosine_similarity: 0.7713 - val_r_square: -0.1646
# Epoch 90
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7881 - MSE: 0.0275 - cosine_similarity: 0.8157 - r_square: 0.1162 - val_loss: -0.7396 - val_MSE: 0.0362 - val_cosine_similarity: 0.7758 - val_r_square: -0.1242
# 2/2 [==============================] - 0s 92ms/step - loss: -0.7964 - MSE: 0.0270 - cosine_similarity: 0.8234 - r_square: 0.1040 - val_loss: -0.7385 - val_MSE: 0.0361 - val_cosine_similarity: 0.7746 - val_r_square: -0.1127
# 2/2 [==============================] - 0s 248ms/step - loss: -0.7930 - MSE: 0.0285 - cosine_similarity: 0.8215 - r_square: 0.0384 - val_loss: -0.7369 - val_MSE: 0.0361 - val_cosine_similarity: 0.7730 - val_r_square: -0.1121
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7758 - MSE: 0.0313 - cosine_similarity: 0.8072 - r_square: 0.0477 - val_loss: -0.7355 - val_MSE: 0.0362 - val_cosine_similarity: 0.7718 - val_r_square: -0.1138
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7771 - MSE: 0.0296 - cosine_similarity: 0.8067 - r_square: 0.0269 - val_loss: -0.7345 - val_MSE: 0.0363 - val_cosine_similarity: 0.7708 - val_r_square: -0.1166
# 2/2 [==============================] - 0s 94ms/step - loss: -0.7698 - MSE: 0.0318 - cosine_similarity: 0.8017 - r_square: 0.0224 - val_loss: -0.7336 - val_MSE: 0.0365 - val_cosine_similarity: 0.7701 - val_r_square: -0.1227
# Epoch 91
# 2/2 [==============================] - 0s 110ms/step - loss: -0.8036 - MSE: 0.0263 - cosine_similarity: 0.8299 - r_square: 0.1196 - val_loss: -0.7324 - val_MSE: 0.0368 - val_cosine_similarity: 0.7692 - val_r_square: -0.1338
# 2/2 [==============================] - 0s 91ms/step - loss: -0.7642 - MSE: 0.0324 - cosine_similarity: 0.7966 - r_square: 0.0889 - val_loss: -0.7316 - val_MSE: 0.0372 - val_cosine_similarity: 0.7688 - val_r_square: -0.1496
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7988 - MSE: 0.0256 - cosine_similarity: 0.8244 - r_square: 0.0073 - val_loss: -0.7334 - val_MSE: 0.0373 - val_cosine_similarity: 0.7707 - val_r_square: -0.1602
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7528 - MSE: 0.0339 - cosine_similarity: 0.7868 - r_square: 0.0027 - val_loss: -0.7366 - val_MSE: 0.0373 - val_cosine_similarity: 0.7739 - val_r_square: -0.1643
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7828 - MSE: 0.0279 - cosine_similarity: 0.8108 - r_square: 0.0549 - val_loss: -0.7391 - val_MSE: 0.0372 - val_cosine_similarity: 0.7763 - val_r_square: -0.1647
# 2/2 [==============================] - 0s 91ms/step - loss: -0.7843 - MSE: 0.0303 - cosine_similarity: 0.8146 - r_square: -0.0308 - val_loss: -0.7407 - val_MSE: 0.0373 - val_cosine_similarity: 0.7780 - val_r_square: -0.1722
# Epoch 92
# 2/2 [==============================] - 0s 103ms/step - loss: -0.7926 - MSE: 0.0287 - cosine_similarity: 0.8213 - r_square: 0.0636 - val_loss: -0.7416 - val_MSE: 0.0373 - val_cosine_similarity: 0.7789 - val_r_square: -0.1765
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7756 - MSE: 0.0312 - cosine_similarity: 0.8068 - r_square: -0.0339 - val_loss: -0.7411 - val_MSE: 0.0373 - val_cosine_similarity: 0.7784 - val_r_square: -0.1784
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7882 - MSE: 0.0268 - cosine_similarity: 0.8150 - r_square: 0.0748 - val_loss: -0.7405 - val_MSE: 0.0374 - val_cosine_similarity: 0.7779 - val_r_square: -0.1833
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7654 - MSE: 0.0317 - cosine_similarity: 0.7971 - r_square: 0.0365 - val_loss: -0.7404 - val_MSE: 0.0376 - val_cosine_similarity: 0.7779 - val_r_square: -0.1880
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7782 - MSE: 0.0305 - cosine_similarity: 0.8087 - r_square: 0.0532 - val_loss: -0.7397 - val_MSE: 0.0377 - val_cosine_similarity: 0.7774 - val_r_square: -0.1885
# 2/2 [==============================] - 0s 86ms/step - loss: -0.8017 - MSE: 0.0262 - cosine_similarity: 0.8278 - r_square: 0.0617 - val_loss: -0.7399 - val_MSE: 0.0375 - val_cosine_similarity: 0.7774 - val_r_square: -0.1768
# Epoch 93
# 2/2 [==============================] - 0s 106ms/step - loss: -0.7851 - MSE: 0.0293 - cosine_similarity: 0.8144 - r_square: 0.0173 - val_loss: -0.7321 - val_MSE: 0.0387 - val_cosine_similarity: 0.7708 - val_r_square: -0.2057
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7936 - MSE: 0.0271 - cosine_similarity: 0.8206 - r_square: 0.0728 - val_loss: -0.7307 - val_MSE: 0.0386 - val_cosine_similarity: 0.7693 - val_r_square: -0.1961
# 2/2 [==============================] - 0s 111ms/step - loss: -0.7592 - MSE: 0.0342 - cosine_similarity: 0.7934 - r_square: 0.0713 - val_loss: -0.7309 - val_MSE: 0.0383 - val_cosine_similarity: 0.7692 - val_r_square: -0.1853
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7893 - MSE: 0.0284 - cosine_similarity: 0.8177 - r_square: 0.0589 - val_loss: -0.7311 - val_MSE: 0.0381 - val_cosine_similarity: 0.7692 - val_r_square: -0.1761
# 2/2 [==============================] - 0s 93ms/step - loss: -0.7929 - MSE: 0.0275 - cosine_similarity: 0.8204 - r_square: 0.0766 - val_loss: -0.7320 - val_MSE: 0.0378 - val_cosine_similarity: 0.7698 - val_r_square: -0.1644
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7719 - MSE: 0.0295 - cosine_similarity: 0.8015 - r_square: 0.0353 - val_loss: -0.7333 - val_MSE: 0.0376 - val_cosine_similarity: 0.7710 - val_r_square: -0.1585
# Epoch 94
# 2/2 [==============================] - 0s 87ms/step - loss: -0.8045 - MSE: 0.0265 - cosine_similarity: 0.8310 - r_square: 0.0895 - val_loss: -0.7361 - val_MSE: 0.0372 - val_cosine_similarity: 0.7734 - val_r_square: -0.1492
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7717 - MSE: 0.0300 - cosine_similarity: 0.8016 - r_square: 0.0496 - val_loss: -0.7362 - val_MSE: 0.0373 - val_cosine_similarity: 0.7735 - val_r_square: -0.1540
# 2/2 [==============================] - 0s 97ms/step - loss: -0.7969 - MSE: 0.0263 - cosine_similarity: 0.8233 - r_square: 0.0096 - val_loss: -0.7371 - val_MSE: 0.0372 - val_cosine_similarity: 0.7743 - val_r_square: -0.1520
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7609 - MSE: 0.0337 - cosine_similarity: 0.7946 - r_square: 0.0267 - val_loss: -0.7379 - val_MSE: 0.0371 - val_cosine_similarity: 0.7749 - val_r_square: -0.1463
# 2/2 [==============================] - 0s 92ms/step - loss: -0.7886 - MSE: 0.0290 - cosine_similarity: 0.8176 - r_square: 0.0377 - val_loss: -0.7385 - val_MSE: 0.0369 - val_cosine_similarity: 0.7754 - val_r_square: -0.1411
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7671 - MSE: 0.0314 - cosine_similarity: 0.7985 - r_square: 0.0645 - val_loss: -0.7383 - val_MSE: 0.0370 - val_cosine_similarity: 0.7753 - val_r_square: -0.1456
# Epoch 95
# 2/2 [==============================] - 0s 100ms/step - loss: -0.7869 - MSE: 0.0278 - cosine_similarity: 0.8147 - r_square: 0.0586 - val_loss: -0.7333 - val_MSE: 0.0380 - val_cosine_similarity: 0.7713 - val_r_square: -0.1820
# 2/2 [==============================] - 0s 91ms/step - loss: -0.7662 - MSE: 0.0312 - cosine_similarity: 0.7974 - r_square: 0.0455 - val_loss: -0.7327 - val_MSE: 0.0381 - val_cosine_similarity: 0.7708 - val_r_square: -0.1877
# 2/2 [==============================] - 0s 102ms/step - loss: -0.7752 - MSE: 0.0310 - cosine_similarity: 0.8061 - r_square: 0.0895 - val_loss: -0.7327 - val_MSE: 0.0380 - val_cosine_similarity: 0.7707 - val_r_square: -0.1864
# 2/2 [==============================] - 0s 94ms/step - loss: -0.8123 - MSE: 0.0239 - cosine_similarity: 0.8362 - r_square: 0.0810 - val_loss: -0.7335 - val_MSE: 0.0376 - val_cosine_similarity: 0.7711 - val_r_square: -0.1739
# 2/2 [==============================] - 0s 96ms/step - loss: -0.7554 - MSE: 0.0353 - cosine_similarity: 0.7907 - r_square: 0.0217 - val_loss: -0.7335 - val_MSE: 0.0373 - val_cosine_similarity: 0.7707 - val_r_square: -0.1545
# 2/2 [==============================] - 0s 86ms/step - loss: -0.8030 - MSE: 0.0259 - cosine_similarity: 0.8289 - r_square: 0.0216 - val_loss: -0.7332 - val_MSE: 0.0371 - val_cosine_similarity: 0.7704 - val_r_square: -0.1463
# Epoch 96
# 2/2 [==============================] - 0s 101ms/step - loss: -0.7693 - MSE: 0.0307 - cosine_similarity: 0.7999 - r_square: 0.0453 - val_loss: -0.7397 - val_MSE: 0.0360 - val_cosine_similarity: 0.7757 - val_r_square: -0.1104
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7835 - MSE: 0.0315 - cosine_similarity: 0.8150 - r_square: 0.0784 - val_loss: -0.7388 - val_MSE: 0.0364 - val_cosine_similarity: 0.7752 - val_r_square: -0.1271
# 2/2 [==============================] - 0s 90ms/step - loss: -0.7887 - MSE: 0.0289 - cosine_similarity: 0.8177 - r_square: 0.1183 - val_loss: -0.7376 - val_MSE: 0.0368 - val_cosine_similarity: 0.7744 - val_r_square: -0.1463
# 2/2 [==============================] - 0s 120ms/step - loss: -0.7782 - MSE: 0.0291 - cosine_similarity: 0.8073 - r_square: 0.0517 - val_loss: -0.7365 - val_MSE: 0.0373 - val_cosine_similarity: 0.7737 - val_r_square: -0.1656
# 2/2 [==============================] - 0s 92ms/step - loss: -0.7933 - MSE: 0.0270 - cosine_similarity: 0.8203 - r_square: 0.0456 - val_loss: -0.7355 - val_MSE: 0.0377 - val_cosine_similarity: 0.7732 - val_r_square: -0.1807
# 2/2 [==============================] - 0s 99ms/step - loss: -0.7879 - MSE: 0.0281 - cosine_similarity: 0.8160 - r_square: 0.0227 - val_loss: -0.7355 - val_MSE: 0.0379 - val_cosine_similarity: 0.7733 - val_r_square: -0.1837
# Epoch 97
# 2/2 [==============================] - 0s 110ms/step - loss: -0.7743 - MSE: 0.0310 - cosine_similarity: 0.8052 - r_square: 0.0681 - val_loss: -0.7287 - val_MSE: 0.0393 - val_cosine_similarity: 0.7679 - val_r_square: -0.2270
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7797 - MSE: 0.0307 - cosine_similarity: 0.8104 - r_square: 0.0104 - val_loss: -0.7297 - val_MSE: 0.0392 - val_cosine_similarity: 0.7688 - val_r_square: -0.2237
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7777 - MSE: 0.0299 - cosine_similarity: 0.8076 - r_square: -0.0034 - val_loss: -0.7290 - val_MSE: 0.0392 - val_cosine_similarity: 0.7682 - val_r_square: -0.2218
# 2/2 [==============================] - 0s 84ms/step - loss: -0.8054 - MSE: 0.0255 - cosine_similarity: 0.8309 - r_square: 0.0605 - val_loss: -0.7279 - val_MSE: 0.0393 - val_cosine_similarity: 0.7672 - val_r_square: -0.2156
# 2/2 [==============================] - 0s 95ms/step - loss: -0.8036 - MSE: 0.0251 - cosine_similarity: 0.8288 - r_square: 0.0892 - val_loss: -0.7280 - val_MSE: 0.0391 - val_cosine_similarity: 0.7671 - val_r_square: -0.2097
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7452 - MSE: 0.0348 - cosine_similarity: 0.7800 - r_square: 0.0564 - val_loss: -0.7289 - val_MSE: 0.0391 - val_cosine_similarity: 0.7680 - val_r_square: -0.2126
# Epoch 98
# 2/2 [==============================] - 0s 87ms/step - loss: -0.7825 - MSE: 0.0289 - cosine_similarity: 0.8114 - r_square: 0.0805 - val_loss: -0.7383 - val_MSE: 0.0376 - val_cosine_similarity: 0.7759 - val_r_square: -0.1733
# 2/2 [==============================] - 0s 84ms/step - loss: -0.8074 - MSE: 0.0271 - cosine_similarity: 0.8345 - r_square: 0.1546 - val_loss: -0.7397 - val_MSE: 0.0375 - val_cosine_similarity: 0.7772 - val_r_square: -0.1745
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7988 - MSE: 0.0258 - cosine_similarity: 0.8246 - r_square: 0.0147 - val_loss: -0.7408 - val_MSE: 0.0372 - val_cosine_similarity: 0.7780 - val_r_square: -0.1612
# 2/2 [==============================] - 0s 95ms/step - loss: -0.7645 - MSE: 0.0319 - cosine_similarity: 0.7963 - r_square: 0.0547 - val_loss: -0.7420 - val_MSE: 0.0368 - val_cosine_similarity: 0.7788 - val_r_square: -0.1466
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7576 - MSE: 0.0331 - cosine_similarity: 0.7907 - r_square: 0.0201 - val_loss: -0.7431 - val_MSE: 0.0365 - val_cosine_similarity: 0.7796 - val_r_square: -0.1357
# 2/2 [==============================] - 0s 90ms/step - loss: -0.7815 - MSE: 0.0292 - cosine_similarity: 0.8106 - r_square: 0.0262 - val_loss: -0.7433 - val_MSE: 0.0364 - val_cosine_similarity: 0.7798 - val_r_square: -0.1303
# Epoch 99
# 2/2 [==============================] - 0s 92ms/step - loss: -0.7817 - MSE: 0.0284 - cosine_similarity: 0.8102 - r_square: 0.0309 - val_loss: -0.7355 - val_MSE: 0.0378 - val_cosine_similarity: 0.7733 - val_r_square: -0.1691
# 2/2 [==============================] - 0s 93ms/step - loss: -0.7668 - MSE: 0.0320 - cosine_similarity: 0.7988 - r_square: 0.0453 - val_loss: -0.7353 - val_MSE: 0.0376 - val_cosine_similarity: 0.7729 - val_r_square: -0.1571
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7846 - MSE: 0.0304 - cosine_similarity: 0.8149 - r_square: 0.1037 - val_loss: -0.7350 - val_MSE: 0.0374 - val_cosine_similarity: 0.7724 - val_r_square: -0.1503
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7920 - MSE: 0.0283 - cosine_similarity: 0.8203 - r_square: 0.0178 - val_loss: -0.7347 - val_MSE: 0.0373 - val_cosine_similarity: 0.7720 - val_r_square: -0.1447
# 2/2 [==============================] - 0s 92ms/step - loss: -0.7869 - MSE: 0.0282 - cosine_similarity: 0.8151 - r_square: 0.0802 - val_loss: -0.7348 - val_MSE: 0.0372 - val_cosine_similarity: 0.7720 - val_r_square: -0.1444
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7944 - MSE: 0.0274 - cosine_similarity: 0.8218 - r_square: 0.0786 - val_loss: -0.7342 - val_MSE: 0.0373 - val_cosine_similarity: 0.7715 - val_r_square: -0.1500

# %%
# %matplotlib inline

metrics = ["MSE", "cosine similarity", "r2"] #Choose between 'loss', 'MSE', 'cosine similarity', 'r2'

metrics_dict = {"loss": ["loss", "val_loss"], "MSE": ["MSE", "val_MSE"], 
                "cosine similarity": ["cosine_similarity", "val_cosine_similarity"],
               "r2" : ["r_square", "val_r_square"]}

import matplotlib.pyplot as plt
try: history_df = history_df.reset_index()
except: pass

for metric in metrics:
    fig, ax = plt.subplots(figsize=(15,4),nrows=1, ncols=1)
    ax.set_ylabel(f"{metric}")
    ax.set_xlabel("Training time")
    fig.suptitle(f"History of {metric} in training time")

    train_plot = history_df.plot(y=metrics_dict[metric][0], use_index=True, ax=ax, label="Training")
    val_plot = history_df.plot(y=metrics_dict[metric][1], use_index=True, ax=ax, label="Validation")

    plt.show()

# %%
def slice(input_tensor, labels, begin, size=10):

    input_shape = (tf.shape(input_tensor).numpy())
    
    begin = [0, begin, 0]
    size = [100, size, 128]
    
    sliced_tensor = tf.slice(input_tensor, begin, size)
    
    nan_values, idx = tf.unique(tf.gather(tf.where(tf.math.is_nan(sliced_tensor)), 0, axis=1))
    nan_values = nan_values.numpy()
  
    msk = np.zeros((input_shape[0]), dtype=np.bool)
    msk[nan_values] = True
    msk = ~msk

    sliced_tensor = tf.boolean_mask(sliced_tensor, msk , axis=0)
    labels = tf.boolean_mask(labels , msk, axis=0)
    
    return sliced_tensor, labels

# %%
val_ds = validation_dataset.shuffle(n_test).batch(n_test)
x_val, y_val = next(iter(val_ds))
x_val, y_val = slice_accordingly(x_val, y_val)
    

y_pred = model.predict(x_val)
y_true = y_val

# %%
def plot_epsilon_error(y_true, y_pred):
    
    N = len(y_true)
    
    cdf_abs_error = {}
    abs_error = np.abs(y_true - y_pred)
    
    fig, ax = plt.subplots(figsize=(12,6),nrows=1, ncols=2)
    ax[0].set_ylabel("Fraction of samples")
    ax[0].set_xlabel("Allowed absolute error")
    ax[0].set_title(f"CDF of the absolute error for different emotions")
    
    ax[0].set_ylim([0,1])
    
    for i, emotion in enumerate(emotions):
        abs_error_emotion = np.sort(abs_error[:,i])
        X2 = np.sort(abs_error_emotion)
        F2 = np.array(range(N))/(float(N))
        
        cdf_abs_error[emotion] = [X2, F2]
        
        ax[0].plot(X2, F2, label=emotion)
        
    ax[0].legend()
    ax[0].grid()
    
    cdf_cosine_sim = {}
    cos_sim = np.array([np.dot(y_true[i], y_pred[i])/(np.linalg.norm(y_true[i])*np.linalg.norm(y_pred[i])) for i in range(N)])
    cos_error = 1-cos_sim
    
    X2 = np.sort(cos_error)
    F2 = np.array(range(N))/(float(N))

    ax[1].set_ylabel(f"Fraction of samples", rotation=-90, labelpad=15)
    ax[1].yaxis.set_label_position("right")
    ax[1].yaxis.tick_right()
    ax[1].set_xlabel("Allowed cosine error")
    ax[1].set_title(f"CDF of the cosine error")
    
    ax[1].set_ylim([0,1])
    
    ax[1].plot(X2, F2)
    ax[1].grid()
    return cdf_abs_error

# %%
epsilon_error = plot_epsilon_error(y_true, y_pred)

x = epsilon_error["amazement"]
plt.show()

# %% [markdown]
# ## "Cross-validation"

# %%
def custom_loss(y_true, y_pred):
    cos_sim = tf.keras.losses.CosineSimilarity() 
    MSE = tf.keras.losses.MeanSquaredError()
        
    return cos_sim(y_true, y_pred) + MSE(y_true, y_pred)

# %%
from sklearn.model_selection import KFold


n_splits = 5
kf = KFold(n_splits=n_splits)

predictions_and_labels = {}


count = 0
for train_index, test_index in kf.split(taggram_raw):
    
    print(f"Training K-fold {1+count} of {n_splits}")

    train_features, train_labels = taggram_raw[train_index], labels_raw[train_index]
    validation_features, validation_labels = taggram_raw[test_index], labels_raw[test_index]

    train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels))
    validation_dataset = tf.data.Dataset.from_tensor_slices((validation_features, validation_labels))

    sample_size = (10, 50, 1)

    drop_out_rate = 0.5

    input_tensor = Input(sample_size)
    x = layers.Conv2D(8, (5, 1), padding="valid", activation="relu")(input_tensor)
    x = layers.Dropout(drop_out_rate)(x)
    x = layers.Dense(32, activation="relu")(x)
    x = layers.Flatten()(x)
    x = layers.Dropout(drop_out_rate)(x)
    output_tensor = layers.Dense(9, activation="sigmoid")(x)

    model_1 = tf.keras.Model(input_tensor, output_tensor)

    model.compile(optimizer="adam",
                loss= custom_loss,
                metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
    n_epochs = 100
    batch_size = 50
    
    for epoch in range(n_epochs):
        train_ds = train_dataset.shuffle(n_train).batch(batch_size)
        for features, labels in train_ds:
            features, labels = slice_accordingly(features, labels)
            model.fit(features, labels, verbose=0)
            
    val_ds = validation_dataset.shuffle(n_test).batch(n_test)
    x_val, y_val = next(iter(val_ds))
    x_val, y_val = slice_accordingly(x_val, y_val)

            
    predictions_and_labels[count] = [model.predict(x_val), y_val]
    count = count+1
# Out:
# Training K-fold 1 of 5
# Training K-fold 2 of 5
# Training K-fold 3 of 5
# Training K-fold 4 of 5
# WARNING:tensorflow:5 out of the last 22 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002786C94EBF8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Training K-fold 5 of 5
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000027876CDC6A8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
predictions = []
labels = []

for i in range(max(predictions_and_labels.keys())+1):
    predictions.append(predictions_and_labels[i][0])
    labels.append(predictions_and_labels[i][1])

predictions = np.concatenate(predictions)
labels = np.concatenate(labels)
epsilon_error = plot_epsilon_error(labels, predictions)

plt.show()

# %%
cos_sim = []
r2 = []
MSE = []

cos_sim_function = tf.keras.metrics.CosineSimilarity() 
MSE_function = tf.keras.metrics.MeanSquaredError()
r2_function = tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))

for i in range(max(predictions_and_labels.keys())+1):
    y_pred = predictions_and_labels[i][0]
    y_true = predictions_and_labels[i][1]
    
    cos_sim.append(cos_sim_function(y_true, y_pred).numpy())
    r2.append(r2_function(y_true, y_pred).numpy())
    MSE.append(MSE_function(y_true, y_pred).numpy())
    
print(f"The cosine similarity is approximately {100*np.mean(cos_sim):.2f}±{100*np.std(cos_sim):.2f}%")
print(f"The MSE is approximately {100*np.mean(MSE):.2f}±{100*np.std(MSE):.2f}%")
print(f"The R2 score is approximately {100*np.mean(r2):.2f}±{100*np.std(r2):.2f}%")
# Out:
# The cosine similarity is approximately 78.35±0.60%
# The MSE is approximately 3.54±0.08%
# The R2 score is approximately -11.39±0.82%
