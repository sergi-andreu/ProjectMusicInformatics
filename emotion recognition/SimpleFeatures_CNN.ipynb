# %% [markdown]
# # Emotion Recognition: SimpleFeatures_CNN.ipynb
#
# Model trained on *simple features* that aims at predicting the *emotion labels*.
#
# The approach consists on getting the arrays of simple features (in *preprocessing*) and train a *Convolutional Neural Network* with *Tensorflow*.
# The problem is treated as a *regression* problem, where the loss function can be chosen between *mean squared error*, *-cosine similarity*, or *both*, being a combination of both losses with equal weight.

# %%
# Import needed packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import KFold

# %%
# Import the array of simple features from the preprocessing folder
genres = ["classical", "electronic", "pop", "rock"]

ZC = np.load('../preprocessing/SimpleFeatures/zeroCrossings_frame200ms_hop100ms.npy')
SC = np.load('../preprocessing/SimpleFeatures/spectralCentroid_frame200ms_hop100ms.npy')
SV = np.load('../preprocessing/SimpleFeatures/spectralVariance_frame200ms_hop100ms.npy')

# %%
# Check that the dimensions match 
# The dimensions represent (n_samples, time)
print("Shape ZC", np.shape(ZC))
print("Shape SC", np.shape(SC))
print("Shape SV", np.shape(SV))
# Out:
# Shape ZC (400, 598)
# Shape SC (400, 598)
# Shape SV (400, 598)

# %%
# Standardize the samples and stack them to the same array (matrix)
ZC = (ZC - np.nanmean(ZC)) / np.nanstd(ZC)
SC = (SC - np.nanmean(SC)) / np.nanstd(SC)
SV = (SV - np.nanmean(SV)) / np.nanstd(SV)

features = np.stack((ZC, SC, SV), axis=1)

# the dimensions are (n_samples, features, time)
print(np.shape(features))
# Out:
# (400, 3, 598)

# %%
# Import and preprocess the labels (obtained from the annotations)

# The length_songs is not used in this notebook, but may be useful for different implementations
# (some songs have shorter duration)

label_songs = pd.read_csv("../preprocessing/labels.csv")
info_songs = pd.read_csv("../Data/Info/info.csv")

# Retrieve emotions from the labels.csv file
emotions = ["amazement", "solemnity", "tenderness", "nostalgia", "calmness", 
            "power", "joyful_activation", "tension", "sadness"]

labels = label_songs[emotions]
labels = labels.to_numpy()

length_songs = pd.DataFrame(info_songs["Track ID"])
length_songs["Song length"] = info_songs["Duration"]*10
length_songs["Song length"] = length_songs["Song length"].astype(int)

# %%
# Shuffle the data

n_data = len(label_songs)
idx = np.random.permutation(n_data)
info_songs = info_songs.reindex(idx)

features = features[idx, :, :]
labels = labels[idx]

features_raw = features[:]
labels_raw = labels[:]
# This _raw arrays would be needed in the end. We need a "raw" copy of the arrays

# %% [markdown]
# ---

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras import Input, layers
from tensorflow.keras import backend as K

sample_size = (3, 50, 1) # 50 corresponds to approximately 5 seconds. This parameter is arbitrary

drop_out_rate = 0.4 #hyperparameter

input_tensor = Input(sample_size)
x = layers.Conv2D(16, (1, 10), padding="valid", activation="relu", strides=1)(input_tensor)
x = layers.Flatten()(x)
x = layers.Dropout(drop_out_rate)(x)
output_tensor = layers.Dense(9, activation="sigmoid")(x)
model_1 = tf.keras.Model(input_tensor, output_tensor)
model_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3, 50, 1)]        0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 3, 41, 16)         176
# _________________________________________________________________
# flatten (Flatten)            (None, 1968)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1968)              0
# _________________________________________________________________
# dense (Dense)                (None, 9)                 17721
# =================================================================
# Total params: 17,897
# Trainable params: 17,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
def slice_accordingly(input_tensor, labels, size=50):

    input_shape = (tf.shape(input_tensor).numpy())
    
    input_shape[2] = size
    size = input_shape
    
    sliced_tensor = tf.image.random_crop(input_tensor, size)
    
    nan_values, idx = tf.unique(tf.gather(tf.where(tf.math.is_nan(sliced_tensor)), 0, axis=1))
    nan_values = nan_values.numpy()
  
    msk = np.zeros((input_shape[0]), dtype=np.bool)
    msk[nan_values] = True
    msk = ~msk

    sliced_tensor = tf.boolean_mask(sliced_tensor, msk , axis=0)
    labels = tf.boolean_mask(labels , msk, axis=0)
    
    return sliced_tensor, labels

# %%
fraction_validation = 0.25
n_test = int(fraction_validation*len(labels))
n_train = len(labels) - n_test

train_features, train_labels = features[:n_train], labels[:n_train]
validation_features, validation_labels = features[n_train:], labels[n_train:]

train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels))
validation_dataset = tf.data.Dataset.from_tensor_slices((validation_features, validation_labels))

# %%
model = model_1

loss = "MSE"
#loss = "CosineSimilarity"
loss = "both"

if loss == "MSE":
    model.compile(optimizer="adam",
                  loss=tf.keras.losses.MeanSquaredError(),
                  metrics=["cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "CosineSimilarity":
    model.compile(optimizer="adam",
                  loss= tf.keras.losses.CosineSimilarity(),
                  metrics=["MSE", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
elif loss == "both":
    def custom_loss(y_true, y_pred):
        cos_sim = tf.keras.losses.CosineSimilarity() 
        MSE = tf.keras.losses.MeanSquaredError()
        
        return cos_sim(y_true, y_pred) + MSE(y_true, y_pred)
        
    model.compile(optimizer="adam",
                  loss= custom_loss,
                  metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])

# %%
n_epochs = 20
batch_size = 50

history_df = pd.DataFrame()

for epoch in range(n_epochs):
    print("Epoch", epoch)
    train_ds = train_dataset.shuffle(n_train).batch(batch_size)
    val_ds = validation_dataset.shuffle(n_test).batch(n_test)
    
    x_val, y_val = next(iter(val_ds))
    x_val, y_val = slice_accordingly(x_val, y_val)
    
    for features, labels in train_ds:
        features, labels = slice_accordingly(features, labels)
        
        history = model.fit(features, labels,
                           validation_data=(x_val, y_val),verbose=1)
        history = pd.DataFrame(history.history)
        history_df = history_df.append(history)
# Out:
# Epoch 0
# 2/2 [==============================] - 3s 386ms/step - loss: -0.6516 - MSE: 0.1266 - cosine_similarity: 0.7783 - r_square: -3.4142 - val_loss: -0.6735 - val_MSE: 0.0986 - val_cosine_similarity: 0.7721 - val_r_square: -2.7526
# 2/2 [==============================] - 0s 83ms/step - loss: -0.6773 - MSE: 0.0949 - cosine_similarity: 0.7722 - r_square: -2.5223 - val_loss: -0.6964 - val_MSE: 0.0777 - val_cosine_similarity: 0.7740 - val_r_square: -1.7473
# 2/2 [==============================] - 0s 75ms/step - loss: -0.6899 - MSE: 0.0798 - cosine_similarity: 0.7697 - r_square: -2.0761 - val_loss: -0.7139 - val_MSE: 0.0635 - val_cosine_similarity: 0.7775 - val_r_square: -1.1170
# 2/2 [==============================] - 0s 80ms/step - loss: -0.7394 - MSE: 0.0557 - cosine_similarity: 0.7950 - r_square: -1.1907 - val_loss: -0.7211 - val_MSE: 0.0545 - val_cosine_similarity: 0.7757 - val_r_square: -0.7561
# 2/2 [==============================] - 0s 76ms/step - loss: -0.7038 - MSE: 0.0548 - cosine_similarity: 0.7586 - r_square: -0.9603 - val_loss: -0.7278 - val_MSE: 0.0490 - val_cosine_similarity: 0.7768 - val_r_square: -0.5587
# 2/2 [==============================] - 0s 79ms/step - loss: -0.7215 - MSE: 0.0531 - cosine_similarity: 0.7746 - r_square: -0.7515 - val_loss: -0.7334 - val_MSE: 0.0450 - val_cosine_similarity: 0.7784 - val_r_square: -0.4277
# Epoch 1
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7007 - MSE: 0.0507 - cosine_similarity: 0.7514 - r_square: -0.4788 - val_loss: -0.7370 - val_MSE: 0.0430 - val_cosine_similarity: 0.7800 - val_r_square: -0.3871
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7268 - MSE: 0.0455 - cosine_similarity: 0.7723 - r_square: -0.4505 - val_loss: -0.7418 - val_MSE: 0.0408 - val_cosine_similarity: 0.7826 - val_r_square: -0.3244
# 2/2 [==============================] - 0s 79ms/step - loss: -0.7521 - MSE: 0.0384 - cosine_similarity: 0.7905 - r_square: -0.4040 - val_loss: -0.7445 - val_MSE: 0.0394 - val_cosine_similarity: 0.7839 - val_r_square: -0.2799
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7212 - MSE: 0.0444 - cosine_similarity: 0.7656 - r_square: -0.5781 - val_loss: -0.7459 - val_MSE: 0.0386 - val_cosine_similarity: 0.7845 - val_r_square: -0.2464
# 2/2 [==============================] - 0s 78ms/step - loss: -0.7392 - MSE: 0.0382 - cosine_similarity: 0.7774 - r_square: -0.2962 - val_loss: -0.7458 - val_MSE: 0.0382 - val_cosine_similarity: 0.7840 - val_r_square: -0.2279
# 2/2 [==============================] - 0s 94ms/step - loss: -0.7406 - MSE: 0.0388 - cosine_similarity: 0.7794 - r_square: -0.4351 - val_loss: -0.7452 - val_MSE: 0.0380 - val_cosine_similarity: 0.7832 - val_r_square: -0.2175
# Epoch 2
# 2/2 [==============================] - 0s 73ms/step - loss: -0.7548 - MSE: 0.0373 - cosine_similarity: 0.7920 - r_square: -0.3528 - val_loss: -0.7414 - val_MSE: 0.0387 - val_cosine_similarity: 0.7801 - val_r_square: -0.2313
# 2/2 [==============================] - 0s 71ms/step - loss: -0.7265 - MSE: 0.0420 - cosine_similarity: 0.7685 - r_square: -0.2641 - val_loss: -0.7424 - val_MSE: 0.0384 - val_cosine_similarity: 0.7808 - val_r_square: -0.2216
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7531 - MSE: 0.0355 - cosine_similarity: 0.7886 - r_square: -0.1821 - val_loss: -0.7437 - val_MSE: 0.0382 - val_cosine_similarity: 0.7820 - val_r_square: -0.2144
# 2/2 [==============================] - 0s 79ms/step - loss: -0.7492 - MSE: 0.0369 - cosine_similarity: 0.7861 - r_square: -0.4075 - val_loss: -0.7444 - val_MSE: 0.0381 - val_cosine_similarity: 0.7825 - val_r_square: -0.2096
# 2/2 [==============================] - 0s 74ms/step - loss: -0.7515 - MSE: 0.0386 - cosine_similarity: 0.7901 - r_square: -0.2593 - val_loss: -0.7445 - val_MSE: 0.0379 - val_cosine_similarity: 0.7824 - val_r_square: -0.2053
# 2/2 [==============================] - 0s 77ms/step - loss: -0.7278 - MSE: 0.0379 - cosine_similarity: 0.7657 - r_square: -0.2258 - val_loss: -0.7441 - val_MSE: 0.0379 - val_cosine_similarity: 0.7819 - val_r_square: -0.2036
# Epoch 3
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7478 - MSE: 0.0357 - cosine_similarity: 0.7834 - r_square: -0.2700 - val_loss: -0.7420 - val_MSE: 0.0377 - val_cosine_similarity: 0.7797 - val_r_square: -0.1966
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7246 - MSE: 0.0406 - cosine_similarity: 0.7652 - r_square: -0.2847 - val_loss: -0.7421 - val_MSE: 0.0376 - val_cosine_similarity: 0.7797 - val_r_square: -0.1957
# 2/2 [==============================] - 0s 73ms/step - loss: -0.7712 - MSE: 0.0329 - cosine_similarity: 0.8041 - r_square: -0.2066 - val_loss: -0.7415 - val_MSE: 0.0376 - val_cosine_similarity: 0.7791 - val_r_square: -0.1964
# 2/2 [==============================] - 0s 76ms/step - loss: -0.7202 - MSE: 0.0399 - cosine_similarity: 0.7601 - r_square: -0.2629 - val_loss: -0.7404 - val_MSE: 0.0377 - val_cosine_similarity: 0.7780 - val_r_square: -0.2010
# 2/2 [==============================] - 0s 76ms/step - loss: -0.7515 - MSE: 0.0368 - cosine_similarity: 0.7883 - r_square: -0.3822 - val_loss: -0.7410 - val_MSE: 0.0376 - val_cosine_similarity: 0.7786 - val_r_square: -0.1960
# 2/2 [==============================] - 0s 107ms/step - loss: -0.7441 - MSE: 0.0381 - cosine_similarity: 0.7822 - r_square: -0.1637 - val_loss: -0.7423 - val_MSE: 0.0374 - val_cosine_similarity: 0.7797 - val_r_square: -0.1898
# Epoch 4
# 2/2 [==============================] - 0s 74ms/step - loss: -0.7455 - MSE: 0.0348 - cosine_similarity: 0.7802 - r_square: -0.2283 - val_loss: -0.7393 - val_MSE: 0.0375 - val_cosine_similarity: 0.7768 - val_r_square: -0.1925
# 2/2 [==============================] - 0s 76ms/step - loss: -0.7650 - MSE: 0.0338 - cosine_similarity: 0.7988 - r_square: -0.3362 - val_loss: -0.7411 - val_MSE: 0.0373 - val_cosine_similarity: 0.7784 - val_r_square: -0.1859
# 2/2 [==============================] - 0s 73ms/step - loss: -0.7438 - MSE: 0.0394 - cosine_similarity: 0.7833 - r_square: -0.2701 - val_loss: -0.7426 - val_MSE: 0.0371 - val_cosine_similarity: 0.7797 - val_r_square: -0.1781
# 2/2 [==============================] - 0s 85ms/step - loss: -0.7411 - MSE: 0.0370 - cosine_similarity: 0.7781 - r_square: -0.1729 - val_loss: -0.7435 - val_MSE: 0.0369 - val_cosine_similarity: 0.7805 - val_r_square: -0.1686
# 2/2 [==============================] - 0s 77ms/step - loss: -0.7527 - MSE: 0.0365 - cosine_similarity: 0.7892 - r_square: -0.2060 - val_loss: -0.7440 - val_MSE: 0.0368 - val_cosine_similarity: 0.7808 - val_r_square: -0.1634
# 2/2 [==============================] - 0s 77ms/step - loss: -0.7188 - MSE: 0.0401 - cosine_similarity: 0.7589 - r_square: -0.2126 - val_loss: -0.7439 - val_MSE: 0.0367 - val_cosine_similarity: 0.7806 - val_r_square: -0.1579
# Epoch 5
# 2/2 [==============================] - 0s 77ms/step - loss: -0.7472 - MSE: 0.0356 - cosine_similarity: 0.7828 - r_square: -0.2391 - val_loss: -0.7515 - val_MSE: 0.0357 - val_cosine_similarity: 0.7872 - val_r_square: -0.1224
# 2/2 [==============================] - 0s 88ms/step - loss: -0.7470 - MSE: 0.0366 - cosine_similarity: 0.7837 - r_square: -0.1511 - val_loss: -0.7509 - val_MSE: 0.0357 - val_cosine_similarity: 0.7866 - val_r_square: -0.1192
# 2/2 [==============================] - 0s 79ms/step - loss: -0.7420 - MSE: 0.0379 - cosine_similarity: 0.7799 - r_square: -0.1105 - val_loss: -0.7505 - val_MSE: 0.0356 - val_cosine_similarity: 0.7861 - val_r_square: -0.1155
# 2/2 [==============================] - 0s 87ms/step - loss: -0.7388 - MSE: 0.0355 - cosine_similarity: 0.7743 - r_square: -0.2282 - val_loss: -0.7492 - val_MSE: 0.0357 - val_cosine_similarity: 0.7849 - val_r_square: -0.1168
# 2/2 [==============================] - 0s 98ms/step - loss: -0.7441 - MSE: 0.0372 - cosine_similarity: 0.7813 - r_square: -0.1833 - val_loss: -0.7484 - val_MSE: 0.0357 - val_cosine_similarity: 0.7841 - val_r_square: -0.1177
# 2/2 [==============================] - 0s 83ms/step - loss: -0.7680 - MSE: 0.0322 - cosine_similarity: 0.8002 - r_square: -0.1508 - val_loss: -0.7477 - val_MSE: 0.0358 - val_cosine_similarity: 0.7835 - val_r_square: -0.1175
# Epoch 6
# 2/2 [==============================] - 0s 75ms/step - loss: -0.7442 - MSE: 0.0367 - cosine_similarity: 0.7810 - r_square: -0.1567 - val_loss: -0.7452 - val_MSE: 0.0361 - val_cosine_similarity: 0.7813 - val_r_square: -0.1287
# 2/2 [==============================] - 0s 76ms/step - loss: -0.7506 - MSE: 0.0330 - cosine_similarity: 0.7836 - r_square: -0.1383 - val_loss: -0.7458 - val_MSE: 0.0359 - val_cosine_similarity: 0.7817 - val_r_square: -0.1234
# 2/2 [==============================] - 0s 73ms/step - loss: -0.7430 - MSE: 0.0384 - cosine_similarity: 0.7814 - r_square: -0.2428 - val_loss: -0.7455 - val_MSE: 0.0358 - val_cosine_similarity: 0.7813 - val_r_square: -0.1196
# 2/2 [==============================] - 0s 77ms/step - loss: -0.7228 - MSE: 0.0393 - cosine_similarity: 0.7620 - r_square: -0.2414 - val_loss: -0.7446 - val_MSE: 0.0359 - val_cosine_similarity: 0.7804 - val_r_square: -0.1214
# 2/2 [==============================] - 0s 87ms/step - loss: -0.7761 - MSE: 0.0322 - cosine_similarity: 0.8083 - r_square: -0.2204 - val_loss: -0.7444 - val_MSE: 0.0358 - val_cosine_similarity: 0.7802 - val_r_square: -0.1205
# 2/2 [==============================] - 0s 74ms/step - loss: -0.7508 - MSE: 0.0352 - cosine_similarity: 0.7860 - r_square: -0.1414 - val_loss: -0.7443 - val_MSE: 0.0358 - val_cosine_similarity: 0.7801 - val_r_square: -0.1203
# Epoch 7
# 2/2 [==============================] - 0s 75ms/step - loss: -0.7329 - MSE: 0.0368 - cosine_similarity: 0.7697 - r_square: -0.1979 - val_loss: -0.7412 - val_MSE: 0.0360 - val_cosine_similarity: 0.7772 - val_r_square: -0.1309
# 2/2 [==============================] - 0s 79ms/step - loss: -0.7597 - MSE: 0.0339 - cosine_similarity: 0.7937 - r_square: -0.1141 - val_loss: -0.7419 - val_MSE: 0.0360 - val_cosine_similarity: 0.7779 - val_r_square: -0.1294
# 2/2 [==============================] - 0s 76ms/step - loss: -0.7508 - MSE: 0.0356 - cosine_similarity: 0.7865 - r_square: -0.1840 - val_loss: -0.7429 - val_MSE: 0.0358 - val_cosine_similarity: 0.7788 - val_r_square: -0.1264
# 2/2 [==============================] - 0s 89ms/step - loss: -0.7407 - MSE: 0.0365 - cosine_similarity: 0.7771 - r_square: -0.1364 - val_loss: -0.7438 - val_MSE: 0.0357 - val_cosine_similarity: 0.7794 - val_r_square: -0.1213
# 2/2 [==============================] - 0s 78ms/step - loss: -0.7572 - MSE: 0.0345 - cosine_similarity: 0.7916 - r_square: -0.1427 - val_loss: -0.7445 - val_MSE: 0.0355 - val_cosine_similarity: 0.7800 - val_r_square: -0.1162
# 2/2 [==============================] - 0s 94ms/step - loss: -0.7495 - MSE: 0.0335 - cosine_similarity: 0.7830 - r_square: -0.1353 - val_loss: -0.7443 - val_MSE: 0.0355 - val_cosine_similarity: 0.7798 - val_r_square: -0.1136
# Epoch 8
# 2/2 [==============================] - 0s 74ms/step - loss: -0.7584 - MSE: 0.0337 - cosine_similarity: 0.7921 - r_square: -0.1556 - val_loss: -0.7454 - val_MSE: 0.0358 - val_cosine_similarity: 0.7811 - val_r_square: -0.1183
# 2/2 [==============================] - 0s 90ms/step - loss: -0.7272 - MSE: 0.0390 - cosine_similarity: 0.7662 - r_square: -0.0707 - val_loss: -0.7446 - val_MSE: 0.0358 - val_cosine_similarity: 0.7805 - val_r_square: -0.1211
# 2/2 [==============================] - 0s 78ms/step - loss: -0.7545 - MSE: 0.0326 - cosine_similarity: 0.7871 - r_square: -0.2099 - val_loss: -0.7445 - val_MSE: 0.0358 - val_cosine_similarity: 0.7803 - val_r_square: -0.1207
# 2/2 [==============================] - 0s 80ms/step - loss: -0.7521 - MSE: 0.0324 - cosine_similarity: 0.7845 - r_square: -0.2315 - val_loss: -0.7451 - val_MSE: 0.0357 - val_cosine_similarity: 0.7808 - val_r_square: -0.1172
# 2/2 [==============================] - 0s 77ms/step - loss: -0.7302 - MSE: 0.0381 - cosine_similarity: 0.7683 - r_square: -0.1434 - val_loss: -0.7461 - val_MSE: 0.0356 - val_cosine_similarity: 0.7817 - val_r_square: -0.1119
# 2/2 [==============================] - 0s 76ms/step - loss: -0.7601 - MSE: 0.0334 - cosine_similarity: 0.7935 - r_square: -0.0978 - val_loss: -0.7467 - val_MSE: 0.0355 - val_cosine_similarity: 0.7822 - val_r_square: -0.1086
# Epoch 9
# 2/2 [==============================] - 0s 71ms/step - loss: -0.7477 - MSE: 0.0348 - cosine_similarity: 0.7825 - r_square: -0.0844 - val_loss: -0.7535 - val_MSE: 0.0342 - val_cosine_similarity: 0.7877 - val_r_square: -0.0725
# 2/2 [==============================] - 0s 81ms/step - loss: -0.7367 - MSE: 0.0361 - cosine_similarity: 0.7728 - r_square: -0.0841 - val_loss: -0.7532 - val_MSE: 0.0342 - val_cosine_similarity: 0.7874 - val_r_square: -0.0705
# 2/2 [==============================] - 0s 75ms/step - loss: -0.7679 - MSE: 0.0322 - cosine_similarity: 0.8002 - r_square: -0.1271 - val_loss: -0.7518 - val_MSE: 0.0343 - val_cosine_similarity: 0.7861 - val_r_square: -0.0725
# 2/2 [==============================] - 0s 74ms/step - loss: -0.7453 - MSE: 0.0352 - cosine_similarity: 0.7805 - r_square: -0.2031 - val_loss: -0.7507 - val_MSE: 0.0344 - val_cosine_similarity: 0.7851 - val_r_square: -0.0746
# 2/2 [==============================] - 0s 90ms/step - loss: -0.7475 - MSE: 0.0344 - cosine_similarity: 0.7819 - r_square: -0.2330 - val_loss: -0.7517 - val_MSE: 0.0343 - val_cosine_similarity: 0.7860 - val_r_square: -0.0718
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7384 - MSE: 0.0359 - cosine_similarity: 0.7743 - r_square: -0.2024 - val_loss: -0.7532 - val_MSE: 0.0342 - val_cosine_similarity: 0.7874 - val_r_square: -0.0690
# Epoch 10
# 2/2 [==============================] - 0s 71ms/step - loss: -0.7430 - MSE: 0.0368 - cosine_similarity: 0.7798 - r_square: -0.0956 - val_loss: -0.7507 - val_MSE: 0.0350 - val_cosine_similarity: 0.7857 - val_r_square: -0.0894
# 2/2 [==============================] - 0s 71ms/step - loss: -0.7627 - MSE: 0.0326 - cosine_similarity: 0.7953 - r_square: -0.0951 - val_loss: -0.7505 - val_MSE: 0.0350 - val_cosine_similarity: 0.7855 - val_r_square: -0.0923
# 2/2 [==============================] - 0s 69ms/step - loss: -0.7527 - MSE: 0.0328 - cosine_similarity: 0.7855 - r_square: -0.2332 - val_loss: -0.7502 - val_MSE: 0.0351 - val_cosine_similarity: 0.7853 - val_r_square: -0.0936
# 2/2 [==============================] - 0s 81ms/step - loss: -0.7236 - MSE: 0.0412 - cosine_similarity: 0.7648 - r_square: -0.1007 - val_loss: -0.7498 - val_MSE: 0.0351 - val_cosine_similarity: 0.7849 - val_r_square: -0.0952
# 2/2 [==============================] - 0s 79ms/step - loss: -0.7624 - MSE: 0.0312 - cosine_similarity: 0.7936 - r_square: -0.0929 - val_loss: -0.7495 - val_MSE: 0.0351 - val_cosine_similarity: 0.7846 - val_r_square: -0.0954
# 2/2 [==============================] - 0s 71ms/step - loss: -0.7757 - MSE: 0.0308 - cosine_similarity: 0.8065 - r_square: -0.1121 - val_loss: -0.7494 - val_MSE: 0.0351 - val_cosine_similarity: 0.7845 - val_r_square: -0.0929
# Epoch 11
# 2/2 [==============================] - 0s 72ms/step - loss: -0.7240 - MSE: 0.0385 - cosine_similarity: 0.7625 - r_square: -0.0965 - val_loss: -0.7459 - val_MSE: 0.0346 - val_cosine_similarity: 0.7805 - val_r_square: -0.0864
# 2/2 [==============================] - 0s 78ms/step - loss: -0.7443 - MSE: 0.0350 - cosine_similarity: 0.7794 - r_square: -0.1061 - val_loss: -0.7461 - val_MSE: 0.0346 - val_cosine_similarity: 0.7806 - val_r_square: -0.0824
# 2/2 [==============================] - 0s 70ms/step - loss: -0.7583 - MSE: 0.0335 - cosine_similarity: 0.7918 - r_square: -0.0990 - val_loss: -0.7461 - val_MSE: 0.0345 - val_cosine_similarity: 0.7806 - val_r_square: -0.0794
# 2/2 [==============================] - 0s 75ms/step - loss: -0.7545 - MSE: 0.0329 - cosine_similarity: 0.7875 - r_square: -0.1677 - val_loss: -0.7458 - val_MSE: 0.0345 - val_cosine_similarity: 0.7803 - val_r_square: -0.0781
# 2/2 [==============================] - 0s 74ms/step - loss: -0.7710 - MSE: 0.0311 - cosine_similarity: 0.8021 - r_square: -0.1136 - val_loss: -0.7456 - val_MSE: 0.0345 - val_cosine_similarity: 0.7801 - val_r_square: -0.0775
# 2/2 [==============================] - 0s 78ms/step - loss: -0.7469 - MSE: 0.0341 - cosine_similarity: 0.7809 - r_square: -0.0784 - val_loss: -0.7457 - val_MSE: 0.0344 - val_cosine_similarity: 0.7801 - val_r_square: -0.0768
# Epoch 12
# 2/2 [==============================] - 0s 72ms/step - loss: -0.7452 - MSE: 0.0357 - cosine_similarity: 0.7809 - r_square: -0.1106 - val_loss: -0.7494 - val_MSE: 0.0342 - val_cosine_similarity: 0.7835 - val_r_square: -0.0660
# 2/2 [==============================] - 0s 73ms/step - loss: -0.7649 - MSE: 0.0314 - cosine_similarity: 0.7964 - r_square: -0.0730 - val_loss: -0.7493 - val_MSE: 0.0342 - val_cosine_similarity: 0.7834 - val_r_square: -0.0670
# 2/2 [==============================] - 0s 74ms/step - loss: -0.7664 - MSE: 0.0313 - cosine_similarity: 0.7977 - r_square: -0.0857 - val_loss: -0.7491 - val_MSE: 0.0342 - val_cosine_similarity: 0.7833 - val_r_square: -0.0693
# 2/2 [==============================] - 0s 86ms/step - loss: -0.7212 - MSE: 0.0408 - cosine_similarity: 0.7620 - r_square: -0.0816 - val_loss: -0.7486 - val_MSE: 0.0343 - val_cosine_similarity: 0.7828 - val_r_square: -0.0723
# 2/2 [==============================] - 0s 72ms/step - loss: -0.7651 - MSE: 0.0306 - cosine_similarity: 0.7957 - r_square: -0.1503 - val_loss: -0.7486 - val_MSE: 0.0343 - val_cosine_similarity: 0.7828 - val_r_square: -0.0724
# 2/2 [==============================] - 0s 75ms/step - loss: -0.7609 - MSE: 0.0328 - cosine_similarity: 0.7937 - r_square: -0.0714 - val_loss: -0.7489 - val_MSE: 0.0343 - val_cosine_similarity: 0.7831 - val_r_square: -0.0715
# Epoch 13
# 2/2 [==============================] - 0s 72ms/step - loss: -0.7707 - MSE: 0.0310 - cosine_similarity: 0.8017 - r_square: -0.0887 - val_loss: -0.7484 - val_MSE: 0.0348 - val_cosine_similarity: 0.7832 - val_r_square: -0.0888
# 2/2 [==============================] - 0s 82ms/step - loss: -0.7702 - MSE: 0.0323 - cosine_similarity: 0.8025 - r_square: -0.1318 - val_loss: -0.7486 - val_MSE: 0.0348 - val_cosine_similarity: 0.7833 - val_r_square: -0.0866
# 2/2 [==============================] - 0s 73ms/step - loss: -0.7577 - MSE: 0.0361 - cosine_similarity: 0.7938 - r_square: -0.0602 - val_loss: -0.7487 - val_MSE: 0.0347 - val_cosine_similarity: 0.7834 - val_r_square: -0.0841
# 2/2 [==============================] - 0s 72ms/step - loss: -0.7444 - MSE: 0.0352 - cosine_similarity: 0.7796 - r_square: -0.0785 - val_loss: -0.7486 - val_MSE: 0.0347 - val_cosine_similarity: 0.7833 - val_r_square: -0.0829
# 2/2 [==============================] - 0s 76ms/step - loss: -0.7371 - MSE: 0.0343 - cosine_similarity: 0.7714 - r_square: -0.1595 - val_loss: -0.7487 - val_MSE: 0.0347 - val_cosine_similarity: 0.7834 - val_r_square: -0.0828
# 2/2 [==============================] - 0s 78ms/step - loss: -0.7184 - MSE: 0.0363 - cosine_similarity: 0.7548 - r_square: -0.1920 - val_loss: -0.7489 - val_MSE: 0.0347 - val_cosine_similarity: 0.7837 - val_r_square: -0.0837
# Epoch 14
# 2/2 [==============================] - 0s 74ms/step - loss: -0.7660 - MSE: 0.0312 - cosine_similarity: 0.7972 - r_square: -0.0880 - val_loss: -0.7491 - val_MSE: 0.0346 - val_cosine_similarity: 0.7837 - val_r_square: -0.0762
# 2/2 [==============================] - 0s 76ms/step - loss: -0.7495 - MSE: 0.0344 - cosine_similarity: 0.7839 - r_square: -0.1780 - val_loss: -0.7490 - val_MSE: 0.0346 - val_cosine_similarity: 0.7836 - val_r_square: -0.0771
# 2/2 [==============================] - 0s 94ms/step - loss: -0.7372 - MSE: 0.0352 - cosine_similarity: 0.7724 - r_square: -0.1275 - val_loss: -0.7490 - val_MSE: 0.0347 - val_cosine_similarity: 0.7837 - val_r_square: -0.0787
# 2/2 [==============================] - 0s 78ms/step - loss: -0.7651 - MSE: 0.0309 - cosine_similarity: 0.7960 - r_square: -0.1484 - val_loss: -0.7486 - val_MSE: 0.0348 - val_cosine_similarity: 0.7834 - val_r_square: -0.0825
# 2/2 [==============================] - 0s 84ms/step - loss: -0.7618 - MSE: 0.0328 - cosine_similarity: 0.7947 - r_square: -0.0549 - val_loss: -0.7484 - val_MSE: 0.0349 - val_cosine_similarity: 0.7833 - val_r_square: -0.0858
# 2/2 [==============================] - 0s 77ms/step - loss: -0.7260 - MSE: 0.0401 - cosine_similarity: 0.7661 - r_square: -0.1228 - val_loss: -0.7486 - val_MSE: 0.0349 - val_cosine_similarity: 0.7835 - val_r_square: -0.0900
# Epoch 15
# 2/2 [==============================] - 0s 71ms/step - loss: -0.7737 - MSE: 0.0319 - cosine_similarity: 0.8055 - r_square: -0.0938 - val_loss: -0.7502 - val_MSE: 0.0344 - val_cosine_similarity: 0.7846 - val_r_square: -0.0770
# 2/2 [==============================] - 0s 81ms/step - loss: -0.7649 - MSE: 0.0316 - cosine_similarity: 0.7965 - r_square: -0.1507 - val_loss: -0.7506 - val_MSE: 0.0344 - val_cosine_similarity: 0.7850 - val_r_square: -0.0778
# 2/2 [==============================] - 0s 72ms/step - loss: -0.7413 - MSE: 0.0367 - cosine_similarity: 0.7780 - r_square: -0.0661 - val_loss: -0.7511 - val_MSE: 0.0343 - val_cosine_similarity: 0.7854 - val_r_square: -0.0781
# 2/2 [==============================] - 0s 74ms/step - loss: -0.7393 - MSE: 0.0361 - cosine_similarity: 0.7754 - r_square: -0.1131 - val_loss: -0.7517 - val_MSE: 0.0342 - val_cosine_similarity: 0.7859 - val_r_square: -0.0735
# 2/2 [==============================] - 0s 77ms/step - loss: -0.7489 - MSE: 0.0339 - cosine_similarity: 0.7828 - r_square: -0.1304 - val_loss: -0.7519 - val_MSE: 0.0341 - val_cosine_similarity: 0.7860 - val_r_square: -0.0662
# 2/2 [==============================] - 0s 78ms/step - loss: -0.7438 - MSE: 0.0353 - cosine_similarity: 0.7791 - r_square: -0.2705 - val_loss: -0.7524 - val_MSE: 0.0339 - val_cosine_similarity: 0.7863 - val_r_square: -0.0584
# Epoch 16
# 2/2 [==============================] - 0s 72ms/step - loss: -0.7656 - MSE: 0.0299 - cosine_similarity: 0.7955 - r_square: -0.0940 - val_loss: -0.7546 - val_MSE: 0.0336 - val_cosine_similarity: 0.7882 - val_r_square: -0.0545
# 2/2 [==============================] - 0s 73ms/step - loss: -0.7595 - MSE: 0.0326 - cosine_similarity: 0.7921 - r_square: -0.0580 - val_loss: -0.7549 - val_MSE: 0.0335 - val_cosine_similarity: 0.7884 - val_r_square: -0.0497
# 2/2 [==============================] - 0s 74ms/step - loss: -0.7352 - MSE: 0.0364 - cosine_similarity: 0.7717 - r_square: -0.1588 - val_loss: -0.7554 - val_MSE: 0.0334 - val_cosine_similarity: 0.7888 - val_r_square: -0.0469
# 2/2 [==============================] - 0s 80ms/step - loss: -0.7392 - MSE: 0.0369 - cosine_similarity: 0.7761 - r_square: -0.1076 - val_loss: -0.7564 - val_MSE: 0.0333 - val_cosine_similarity: 0.7898 - val_r_square: -0.0428
# 2/2 [==============================] - 0s 78ms/step - loss: -0.7404 - MSE: 0.0352 - cosine_similarity: 0.7755 - r_square: -0.0655 - val_loss: -0.7572 - val_MSE: 0.0332 - val_cosine_similarity: 0.7905 - val_r_square: -0.0396
# 2/2 [==============================] - 0s 71ms/step - loss: -0.7768 - MSE: 0.0310 - cosine_similarity: 0.8078 - r_square: -0.0676 - val_loss: -0.7578 - val_MSE: 0.0332 - val_cosine_similarity: 0.7910 - val_r_square: -0.0391
# Epoch 17
# 2/2 [==============================] - 0s 76ms/step - loss: -0.7589 - MSE: 0.0316 - cosine_similarity: 0.7904 - r_square: -0.0835 - val_loss: -0.7538 - val_MSE: 0.0336 - val_cosine_similarity: 0.7873 - val_r_square: -0.0511
# 2/2 [==============================] - 0s 77ms/step - loss: -0.7373 - MSE: 0.0355 - cosine_similarity: 0.7728 - r_square: -0.1310 - val_loss: -0.7537 - val_MSE: 0.0336 - val_cosine_similarity: 0.7874 - val_r_square: -0.0529
# 2/2 [==============================] - 0s 70ms/step - loss: -0.7677 - MSE: 0.0318 - cosine_similarity: 0.7995 - r_square: -0.0883 - val_loss: -0.7535 - val_MSE: 0.0337 - val_cosine_similarity: 0.7872 - val_r_square: -0.0554
# 2/2 [==============================] - 0s 71ms/step - loss: -0.7468 - MSE: 0.0366 - cosine_similarity: 0.7833 - r_square: -0.0674 - val_loss: -0.7536 - val_MSE: 0.0336 - val_cosine_similarity: 0.7872 - val_r_square: -0.0547
# 2/2 [==============================] - 0s 74ms/step - loss: -0.7621 - MSE: 0.0339 - cosine_similarity: 0.7960 - r_square: -0.1494 - val_loss: -0.7538 - val_MSE: 0.0336 - val_cosine_similarity: 0.7874 - val_r_square: -0.0529
# 2/2 [==============================] - 0s 81ms/step - loss: -0.7497 - MSE: 0.0334 - cosine_similarity: 0.7831 - r_square: -0.1588 - val_loss: -0.7538 - val_MSE: 0.0335 - val_cosine_similarity: 0.7874 - val_r_square: -0.0511
# Epoch 18
# 2/2 [==============================] - 0s 70ms/step - loss: -0.7511 - MSE: 0.0350 - cosine_similarity: 0.7862 - r_square: -0.0786 - val_loss: -0.7550 - val_MSE: 0.0337 - val_cosine_similarity: 0.7887 - val_r_square: -0.0517
# 2/2 [==============================] - 0s 71ms/step - loss: -0.7596 - MSE: 0.0311 - cosine_similarity: 0.7906 - r_square: -0.0800 - val_loss: -0.7539 - val_MSE: 0.0338 - val_cosine_similarity: 0.7877 - val_r_square: -0.0560
# 2/2 [==============================] - 0s 74ms/step - loss: -0.7427 - MSE: 0.0339 - cosine_similarity: 0.7766 - r_square: -0.0512 - val_loss: -0.7527 - val_MSE: 0.0340 - val_cosine_similarity: 0.7867 - val_r_square: -0.0621
# 2/2 [==============================] - 0s 78ms/step - loss: -0.7353 - MSE: 0.0374 - cosine_similarity: 0.7727 - r_square: -0.1216 - val_loss: -0.7519 - val_MSE: 0.0341 - val_cosine_similarity: 0.7860 - val_r_square: -0.0661
# 2/2 [==============================] - 0s 69ms/step - loss: -0.7393 - MSE: 0.0356 - cosine_similarity: 0.7749 - r_square: -0.1361 - val_loss: -0.7519 - val_MSE: 0.0341 - val_cosine_similarity: 0.7860 - val_r_square: -0.0642
# 2/2 [==============================] - 0s 77ms/step - loss: -0.7757 - MSE: 0.0312 - cosine_similarity: 0.8069 - r_square: -0.0998 - val_loss: -0.7526 - val_MSE: 0.0340 - val_cosine_similarity: 0.7866 - val_r_square: -0.0582
# Epoch 19
# 2/2 [==============================] - 0s 74ms/step - loss: -0.7516 - MSE: 0.0342 - cosine_similarity: 0.7858 - r_square: -0.0594 - val_loss: -0.7482 - val_MSE: 0.0344 - val_cosine_similarity: 0.7826 - val_r_square: -0.0688
# 2/2 [==============================] - 0s 116ms/step - loss: -0.7552 - MSE: 0.0314 - cosine_similarity: 0.7866 - r_square: -0.0978 - val_loss: -0.7485 - val_MSE: 0.0344 - val_cosine_similarity: 0.7829 - val_r_square: -0.0692
# 2/2 [==============================] - 0s 76ms/step - loss: -0.7379 - MSE: 0.0358 - cosine_similarity: 0.7738 - r_square: -0.0339 - val_loss: -0.7482 - val_MSE: 0.0346 - val_cosine_similarity: 0.7828 - val_r_square: -0.0735
# 2/2 [==============================] - 0s 74ms/step - loss: -0.7616 - MSE: 0.0330 - cosine_similarity: 0.7946 - r_square: -0.0949 - val_loss: -0.7479 - val_MSE: 0.0347 - val_cosine_similarity: 0.7826 - val_r_square: -0.0789
# 2/2 [==============================] - 0s 75ms/step - loss: -0.7477 - MSE: 0.0362 - cosine_similarity: 0.7839 - r_square: -0.1394 - val_loss: -0.7477 - val_MSE: 0.0347 - val_cosine_similarity: 0.7824 - val_r_square: -0.0789
# 2/2 [==============================] - 0s 74ms/step - loss: -0.7642 - MSE: 0.0320 - cosine_similarity: 0.7962 - r_square: -0.1104 - val_loss: -0.7478 - val_MSE: 0.0346 - val_cosine_similarity: 0.7824 - val_r_square: -0.0722

# %%
# %matplotlib inline

metrics = ["MSE", "cosine similarity", "r2"] #Choose between 'loss', 'MSE', 'cosine similarity', 'r2'

metrics_dict = {"loss": ["loss", "val_loss"], "MSE": ["MSE", "val_MSE"], 
                "cosine similarity": ["cosine_similarity", "val_cosine_similarity"],
               "r2" : ["r_square", "val_r_square"]}

import matplotlib.pyplot as plt
try: history_df = history_df.reset_index()
except: pass

for metric in metrics:
    fig, ax = plt.subplots(figsize=(15,4),nrows=1, ncols=1)
    ax.set_ylabel(f"{metric}")
    ax.set_xlabel("Training time")
    fig.suptitle(f"History of {metric} in training time")

    train_plot = history_df.plot(y=metrics_dict[metric][0], use_index=True, ax=ax, label="Training")
    val_plot = history_df.plot(y=metrics_dict[metric][1], use_index=True, ax=ax, label="Validation")

    plt.show()
# Out:
# Index(['index', 'loss', 'MSE', 'cosine_similarity', 'r_square', 'val_loss',
#        'val_MSE', 'val_cosine_similarity', 'val_r_square'],
#       dtype='object')

# %% [markdown]
# ---

# %%
val_ds = validation_dataset.shuffle(n_test).batch(n_test)
x_val, y_val = next(iter(val_ds))
x_val, y_val = slice_accordingly(x_val, y_val)
    

y_pred = model.predict(x_val)
y_true = y_val

# %%
def plot_epsilon_error(y_true, y_pred):
    
    N = len(y_true)
    
    cdf_abs_error = {}
    abs_error = np.abs(y_true - y_pred)
    
    fig, ax = plt.subplots(figsize=(12,6),nrows=1, ncols=2)
    ax[0].set_ylabel("Fraction of samples")
    ax[0].set_xlabel("Allowed absolute error")
    ax[0].set_title(f"CDF of the absolute error for different emotions")
    
    ax[0].set_ylim([0,1])
    
    for i, emotion in enumerate(emotions):
        abs_error_emotion = np.sort(abs_error[:,i])
        X2 = np.sort(abs_error_emotion)
        F2 = np.array(range(N))/(float(N))
        
        cdf_abs_error[emotion] = [X2, F2]
        
        ax[0].plot(X2, F2, label=emotion)
        
    ax[0].legend()
    ax[0].grid()
    
    cdf_cosine_sim = {}
    cos_sim = np.array([np.dot(y_true[i], y_pred[i])/(np.linalg.norm(y_true[i])*np.linalg.norm(y_pred[i])) for i in range(N)])
    cos_error = 1-cos_sim
    
    X2 = np.sort(cos_error)
    F2 = np.array(range(N))/(float(N))

    ax[1].set_ylabel(f"Fraction of samples", rotation=-90, labelpad=15)
    ax[1].yaxis.set_label_position("right")
    ax[1].yaxis.tick_right()
    ax[1].set_xlabel("Allowed cosine error")
    ax[1].set_title(f"CDF of the cosine error")
    ax[1].set_ylim([0,1])
    
    ax[1].plot(X2, F2)
    ax[1].grid()
    return cdf_abs_error

# %%
epsilon_error = plot_epsilon_error(y_true, y_pred)

x = epsilon_error["amazement"]
plt.show()

# %% [markdown]
# ## "Cross-Validation"
#
# The model is trained multiple times using different hold sets. Note that the model is initialized with random weights each time, thus this is not really cross-validation, and we also have some randomness due to initialization and shuffling of the data.

# %%
def custom_loss(y_true, y_pred):
    cos_sim = tf.keras.losses.CosineSimilarity() 
    MSE = tf.keras.losses.MeanSquaredError()
        
    return cos_sim(y_true, y_pred) + MSE(y_true, y_pred)

# %%
from sklearn.model_selection import KFold


n_splits = 5
kf = KFold(n_splits=n_splits)

predictions_and_labels = {}


count = 0
for train_index, test_index in kf.split(features_raw):
    
    print(f"Training K-fold {1+count} of {n_splits}")

    train_features, train_labels = features_raw[train_index], labels_raw[train_index]
    validation_features, validation_labels = features_raw[test_index], labels_raw[test_index]

    train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels))
    validation_dataset = tf.data.Dataset.from_tensor_slices((validation_features, validation_labels))

    sample_size = (3, 50, 1) # 50 corresponds to approximately 5 seconds. This parameter is arbitrary

    drop_out_rate = 0.4 #hyperparameter

    input_tensor = Input(sample_size)
    x = layers.Conv2D(16, (1, 10), padding="valid", activation="relu", strides=1)(input_tensor)
    x = layers.Flatten()(x)
    x = layers.Dropout(drop_out_rate)(x)
    output_tensor = layers.Dense(9, activation="sigmoid")(x)
    model = tf.keras.Model(input_tensor, output_tensor)

    model.compile(optimizer="adam",
                loss= custom_loss,
                metrics=["MSE", "cosine_similarity", tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))])
    
    n_epochs = 100
    batch_size = 50
    
    for epoch in range(n_epochs):
        train_ds = train_dataset.shuffle(n_train).batch(batch_size)
        for features, labels in train_ds:
            features, labels = slice_accordingly(features, labels)
            model.fit(features, labels, verbose=0)
            
    val_ds = validation_dataset.shuffle(n_test).batch(n_test)
    x_val, y_val = next(iter(val_ds))
    x_val, y_val = slice_accordingly(x_val, y_val)

            
    predictions_and_labels[count] = [model.predict(x_val), y_val]
    count = count+1
# Out:
# Training K-fold 1 of 5
# Training K-fold 2 of 5
# Training K-fold 3 of 5
# Training K-fold 4 of 5
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001903D40C730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Training K-fold 5 of 5
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019039757268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
predictions = []
labels = []

for i in range(max(predictions_and_labels.keys())+1):
    predictions.append(predictions_and_labels[i][0])
    labels.append(predictions_and_labels[i][1])

predictions = np.concatenate(predictions)
labels = np.concatenate(labels)
epsilon_error = plot_epsilon_error(labels, predictions)

plt.show()

# %%
cos_sim = []
r2 = []
MSE = []

cos_sim_function = tf.keras.metrics.CosineSimilarity() 
MSE_function = tf.keras.metrics.MeanSquaredError()
r2_function = tfa.metrics.RSquare(dtype=tf.float32, y_shape=(9,))

for i in range(max(predictions_and_labels.keys())+1):
    y_pred = predictions_and_labels[i][0]
    y_true = predictions_and_labels[i][1]
    
    cos_sim.append(cos_sim_function(y_true, y_pred).numpy())
    r2.append(r2_function(y_true, y_pred).numpy())
    MSE.append(MSE_function(y_true, y_pred).numpy())
    
print(f"The cosine similarity is approximately {100*np.mean(cos_sim):.2f}±{100*np.std(cos_sim):.2f}%")
print(f"The MSE is approximately {100*np.mean(MSE):.2f}±{100*np.std(MSE):.2f}%")
print(f"The R2 score is approximately {100*np.mean(r2):.2f}±{100*np.std(r2):.2f}%")
# Out:
# The cosine similarity is approximately 78.21±0.42%
# The MSE is approximately 3.37±0.08%
# The R2 score is approximately -3.77±0.36%
