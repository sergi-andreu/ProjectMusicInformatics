# %% [markdown]
# # extract_SimpleFeatures.ipynb
#
# Simple features are extracted from the audio samples: *ZC* (***zero crossings***), *SC* (***spectral centroid***), *SV* (***spectral variance***), *ST* (***static tempo***) using librosa (BPM). The data is restructured of the data and saving to the hard drive in [SimpleFeatures](./SimpleFeatures).
#
# Some data analysis on the features to see if they are seperable for genre classification.

# %%
import sys
import os
import numpy as np
import pydub
import pandas as pd
import librosa
import time

# %%
# Functions for (simple) feature extraction
# ZC zero crossings
# SC spectral centroid
# SV spectral variance
# ST static tempo using librosa (BPM). 1 number for entire song


def extractZC( data, windowsizeinsamples, windowhopinsamples ):
    totalnumberofwindows = np.floor((len(data)-windowsizeinsamples)/windowhopinsamples)
    numbersignchanges = []
    for ii in np.arange(totalnumberofwindows):
        windowstart = int(ii*windowhopinsamples)
        windowend = int(windowstart + windowhopinsamples)
        datasign = np.sign(data[windowstart:windowend])
        datasignderivative = datasign - np.roll(datasign,1)
        numbersignchanges.append(np.count_nonzero(datasignderivative[1:-1]))
    return np.array(numbersignchanges)

def extractSC( data, windowsizeinsamples, windowhopinsamples, samplerate ):
    totalnumberofwindows = np.floor((len(data)-windowsizeinsamples)/windowhopinsamples)
    centroid = []
    freqs = np.arange(np.ceil(windowsizeinsamples/2.0)+1)*samplerate/windowsizeinsamples
    for ii in np.arange(totalnumberofwindows):
        windowstart = int(ii*windowhopinsamples)
        windowend = int(windowstart + windowsizeinsamples)
        DATA = np.abs(np.fft.fft(data[windowstart:windowend]))
        centroid.append(np.sum(freqs*DATA[:int(np.ceil(windowsizeinsamples/2.0)+1)])/
                        np.sum(DATA[:int(np.ceil(windowsizeinsamples/2.0)+1)]))
    return np.array(centroid)

def extractSV( data, windowsizeinsamples, windowhopinsamples, samplerate ):
    totalnumberofwindows = np.floor((len(data)-windowsizeinsamples)/windowhopinsamples)
    variance = []
    freqs = np.arange(np.ceil(windowsizeinsamples/2.0)+1)*samplerate/windowsizeinsamples
    #freqs = np.power(freqs, trypower)
    for ii in np.arange(totalnumberofwindows):
        windowstart = int(ii*windowhopinsamples)
        windowend = int(windowstart + windowsizeinsamples)
        DATA = np.abs(np.fft.fft(data[windowstart:windowend]))  
        """ 
        centroid = np.sum(freqs*DATA[:int(np.ceil(windowsizeinsamples/2.0)+1)])/np.sum(DATA[:int(np.ceil(windowsizeinsamples/2.0)+1)])
            
        second_moment = np.sum(np.square(freqs)*DATA[:int(np.ceil(windowsizeinsamples/2.0)+1)])/np.sum(DATA[:int(np.ceil(windowsizeinsamples/2.0)+1)])
            
        variance.append( np.subtract(second_moment , centroid)
        """ 
        ind_max = int(np.ceil(windowsizeinsamples/2.0)+1) 
        centroid = np.sum(freqs*DATA[:ind_max])/np.sum(DATA[:ind_max])
        second_moment = np.sum(np.power(freqs, 2)*DATA[:ind_max])/np.sum(DATA[:ind_max])
        variance.append(second_moment - np.power(centroid,2))
    return np.array(variance)

def extractStaticTempo(data, sample_rate):
    data = np.array(data, dtype='float')
    onset_env = librosa.onset.onset_strength(y=data, sr=sample_rate)
    tempo = librosa.beat.tempo(onset_envelope=onset_env, sr=sample_rate)
    return tempo

# %%
# Extraction of all features. note: tempo extraction is computationally quite heavy

def extract_features(path,
                     ZCframe_size_seconds,
                     ZCwindow_hop_seconds,
                     SCframe_size_seconds,
                     SCwindow_hop_seconds,
                     SVframe_size_seconds,
                     SVwindow_hop_seconds,
                     do_tempoExtraction = False
                    ):
    """
    For some songs with shorter duration the arrays will be filled with -1's
    """
    duration = 60.02938776 # seconds per song. Shorter songs are accounted for later
    sample_rate = 44100
    staticTempo = 0   # initializer for switch
    ZCwindowsizeinsamples = ZCframe_size_seconds * sample_rate
    ZCwindowhopinsamples =  ZCwindow_hop_seconds * sample_rate   
    SCwindowsizeinsamples = SCframe_size_seconds * sample_rate
    SCwindowhopinsamples =  SCwindow_hop_seconds * sample_rate   
    SVwindowsizeinsamples = SVframe_size_seconds * sample_rate
    SVwindowhopinsamples =  SVwindow_hop_seconds * sample_rate   
    
    N_samples = 100
    ZC_frames = int(np.floor((duration*sample_rate-ZCwindowsizeinsamples)/ZCwindowhopinsamples))
    SC_frames = int(np.floor((duration*sample_rate-SCwindowsizeinsamples)/SCwindowhopinsamples))
    SV_frames = int(np.floor((duration*sample_rate-SVwindowsizeinsamples)/SVwindowhopinsamples))

    ZC_array = np.full((N_samples, ZC_frames), np.nan)
    SC_array = np.full((N_samples, SC_frames), np.nan)
    SV_array = np.full((N_samples, SV_frames), np.nan)
    staticTempo_array = np.full((N_samples), np.nan)
    

    for file in os.scandir(path):
            
        if file.path.endswith(".mp3"):
            print("analyzing ", file.name, file.path)

            int_track = int(file.name[:-4])
            
            start = time.time()
            sound = pydub.AudioSegment.from_file(path + "/" + file.name, format = "mp3")  
            samples = sound.get_array_of_samples()
            end = time.time() 
            print(f'import takes {end-start}')
            
            start = time.time()
            ZC = extractZC( samples, ZCwindowsizeinsamples, ZCwindowhopinsamples )  
            end = time.time()
            print(f'extracting ZC takes {end-start} per song')


            start = time.time()
            SC = extractSC( samples, SCwindowsizeinsamples, SCwindowhopinsamples, sample_rate )
            end = time.time()
            print(f'extracting SC takes {end-start} per song')

            start = time.time()
            SV = extractSV( samples, SVwindowsizeinsamples, SVwindowhopinsamples, sample_rate )
            end = time.time()
            print(f'extracting SV takes {end-start} per song')

            if do_tempoExtraction:
                start = time.time()
                staticTempo = extractStaticTempo(samples, sample_rate)
                end = time.time()
                print(f'extracting tempo takes {end-start} per song')
            
            if np.shape(ZC)[0] < ZC_frames:
                ZC = np.append(ZC, np.full((ZC_frames-np.shape(ZC)[0]), np.nan))
                            
            elif np.shape(ZC)[0] > ZC_frames:
                ZC = ZC[:ZC_frames]
             
            if np.shape(SC)[0] < SC_frames:
                SC = np.append(SC, np.full((SC_frames-np.shape(SC)[0]), np.nan))

            elif np.shape(SC)[0] > SC_frames:
                SC = SC[:SC_frames]
                
            if np.shape(SV)[0] < SV_frames:
                SV = np.append(SV, np.full((SV_frames-np.shape(SV)[0]), np.nan))

            elif np.shape(SV)[0] > SV_frames:
                SV = SV[:SV_frames]
                
            ZC_array[int_track-1, :] = ZC
            SC_array[int_track-1, :] = SC
            SV_array[int_track-1, :] = SV
            staticTempo_array[int_track-1] = staticTempo
    
    if do_tempoExtraction:
        return ZC_array, SC_array, SV_array, staticTempo_array
    return ZC_array, SC_array, SV_array

# %%
# Structuring data and saving

path = "../data/emotifymusic/"
genres = ["classical", "electronic", "pop", "rock"]

ZC = []
SC = []
SV = []
staticTempo = []


for genre in genres:
    ZC_array, SC_array, SV_array = extract_features(path+genre,
                                                    ZCframe_size_seconds=0.200,
                                                    ZCwindow_hop_seconds=0.100,
                                                    SCframe_size_seconds=0.200,
                                                    SCwindow_hop_seconds=0.100,
                                                    SVframe_size_seconds=0.200,
                                                    SVwindow_hop_seconds=0.100,
                                                    do_tempoExtraction=False
                                                    )
    ZC.append(ZC_array)
    SC.append(SC_array)
    SV.append(SV_array)
    #staticTempo.append(staticTempo_array)


# np.savez_compressed('zeroCrossings_frame100ms_hop50ms.npz', classical=ZC[0], electronic=ZC[1], pop=ZC[2], rock=ZC[3])
# np.savez_compressed('spectralCentroid_frame100ms_hop50ms.npz', classical=SC[0], electronic=SC[1], pop=SC[2], rock=SC[3])
# np.savez_compressed('spectralVariance_frame100ms_hop50ms.npz', classical=SV[0], electronic=SV[1], pop=SV[2], rock=SV[3])
# np.savez_compressed('staticTempoLibrosa.npz',
#                     classical=staticTempo[0], electronic=staticTempo[1], pop=staticTempo[2], rock=staticTempo[3])


ZC_reshape = np.reshape(ZC, (np.shape(ZC)[0]*np.shape(ZC)[1], np.shape(ZC)[2]))
SC_reshape = np.reshape(SC, (np.shape(SC)[0]*np.shape(SC)[1], np.shape(SC)[2]))
SV_reshape = np.reshape(SV, (np.shape(SV)[0]*np.shape(SV)[1], np.shape(SV)[2]))
staticTempo_reshape = np.reshape(staticTempo, (np.shape(staticTempo)[0]*np.shape(staticTempo)[1]))

np.save('zeroCrossings_frame200ms_hop100ms.npy', ZC_reshape)
np.save('spectralCentroid_frame200ms_hop100ms.npy', SC_reshape)
np.save('spectralVariance_frame200ms_hop100ms.npy', SV_reshape)

#np.save('zeroCrossings_frame100ms_hop50ms.npy', ZC_reshape)
#np.save('spectralCentroid_frame100ms_hop50ms.npy', SC_reshape)
#np.save('spectralVariance_frame5000ms_hop2500ms.npy', SV_reshape)
#np.save('staticTempoLibrosa.npy', staticTempo_reshape)
# Out:
# analyzing  1.mp3 ../data/emotifymusic/classical\1.mp3
# import takes 0.4676327705383301
# extracting ZC takes 0.09474802017211914 per song
# extracting SC takes 0.5026557445526123 per song
# extracting SV takes 0.8716669082641602 per song
# analyzing  10.mp3 ../data/emotifymusic/classical\10.mp3
# import takes 0.4546220302581787
# extracting ZC takes 0.08776473999023438 per song
# extracting SC takes 0.5056846141815186 per song
# extracting SV takes 0.8686776161193848 per song
# analyzing  100.mp3 ../data/emotifymusic/classical\100.mp3
# import takes 0.44479823112487793
# extracting ZC takes 0.0917518138885498 per song
# extracting SC takes 0.5156126022338867 per song
# extracting SV takes 0.8696739673614502 per song
# analyzing  11.mp3 ../data/emotifymusic/classical\11.mp3
# import takes 0.47154831886291504
# extracting ZC takes 0.12566328048706055 per song
# extracting SC takes 0.548569917678833 per song
# extracting SV takes 0.8766543865203857 per song
# analyzing  12.mp3 ../data/emotifymusic/classical\12.mp3
# import takes 0.4463067054748535
# extracting ZC takes 0.09873676300048828 per song
# extracting SC takes 0.5136630535125732 per song
# extracting SV takes 0.8736629486083984 per song
# analyzing  13.mp3 ../data/emotifymusic/classical\13.mp3
# import takes 0.4445006847381592
# extracting ZC takes 0.09774184226989746 per song
# extracting SC takes 0.5126276016235352 per song
# extracting SV takes 0.8717052936553955 per song
# analyzing  14.mp3 ../data/emotifymusic/classical\14.mp3
# import takes 0.4470384120941162
# extracting ZC takes 0.10276222229003906 per song
# extracting SC takes 0.5066103935241699 per song
# extracting SV takes 0.8736984729766846 per song
# analyzing  15.mp3 ../data/emotifymusic/classical\15.mp3
# import takes 0.44768524169921875
# extracting ZC takes 0.09279155731201172 per song
# extracting SC takes 0.5152647495269775 per song
# extracting SV takes 0.867713451385498 per song
# analyzing  16.mp3 ../data/emotifymusic/classical\16.mp3
# import takes 0.37526941299438477
# extracting ZC takes 0.06981325149536133 per song
# extracting SC takes 0.3630654811859131 per song
# extracting SV takes 0.6183464527130127 per song
# analyzing  17.mp3 ../data/emotifymusic/classical\17.mp3
# import takes 0.4463984966278076
# extracting ZC takes 0.08676266670227051 per song
# extracting SC takes 0.505650520324707 per song
# extracting SV takes 0.8706662654876709 per song
# analyzing  18.mp3 ../data/emotifymusic/classical\18.mp3
# import takes 0.4497103691101074
# extracting ZC takes 0.09873819351196289 per song
# extracting SC takes 0.5096714496612549 per song
# extracting SV takes 0.8776528835296631 per song
# analyzing  19.mp3 ../data/emotifymusic/classical\19.mp3
# import takes 0.44980573654174805
# extracting ZC takes 0.09578084945678711 per song
# extracting SC takes 0.5165815353393555 per song
# extracting SV takes 0.8736999034881592 per song
# analyzing  2.mp3 ../data/emotifymusic/classical\2.mp3
# import takes 0.44829487800598145
# extracting ZC takes 0.08976101875305176 per song
# extracting SC takes 0.500699520111084 per song
# extracting SV takes 0.8696742057800293 per song
# analyzing  20.mp3 ../data/emotifymusic/classical\20.mp3
# import takes 0.44754910469055176
# extracting ZC takes 0.09079480171203613 per song
# extracting SC takes 0.5016582012176514 per song
# extracting SV takes 0.8733792304992676 per song
# analyzing  21.mp3 ../data/emotifymusic/classical\21.mp3
# import takes 0.44841694831848145
# extracting ZC takes 0.09574627876281738 per song
# extracting SC takes 0.5036871433258057 per song
# extracting SV takes 0.8706760406494141 per song
# analyzing  22.mp3 ../data/emotifymusic/classical\22.mp3
# import takes 0.45101165771484375
# extracting ZC takes 0.08976054191589355 per song
# extracting SC takes 0.5115952491760254 per song
# extracting SV takes 0.8806450366973877 per song
# analyzing  23.mp3 ../data/emotifymusic/classical\23.mp3
# import takes 0.4542520046234131
# extracting ZC takes 0.09079480171203613 per song
# extracting SC takes 0.5026211738586426 per song
# extracting SV takes 0.9005899429321289 per song
# analyzing  24.mp3 ../data/emotifymusic/classical\24.mp3
# import takes 0.5131726264953613
# extracting ZC takes 0.09873557090759277 per song
# extracting SC takes 0.5245611667633057 per song
# extracting SV takes 0.8946411609649658 per song
# analyzing  25.mp3 ../data/emotifymusic/classical\25.mp3
# import takes 0.5323011875152588
# extracting ZC takes 0.11171150207519531 per song
# extracting SC takes 0.5664794445037842 per song
# extracting SV takes 0.9364957809448242 per song
# analyzing  26.mp3 ../data/emotifymusic/classical\26.mp3
# import takes 0.5108468532562256
# extracting ZC takes 0.1037135124206543 per song
# extracting SC takes 0.51865553855896 per song
# extracting SV takes 0.9085671901702881 per song
# analyzing  27.mp3 ../data/emotifymusic/classical\27.mp3
# import takes 0.4723930358886719
# extracting ZC takes 0.09378695487976074 per song
# extracting SC takes 0.5225646495819092 per song
# extracting SV takes 0.9005904197692871 per song
# analyzing  28.mp3 ../data/emotifymusic/classical\28.mp3
# import takes 0.48940134048461914
# extracting ZC takes 0.0987248420715332 per song
# extracting SC takes 0.5146350860595703 per song
# extracting SV takes 0.8816452026367188 per song
# analyzing  29.mp3 ../data/emotifymusic/classical\29.mp3
# import takes 0.47049522399902344
# extracting ZC takes 0.09075474739074707 per song
# extracting SC takes 0.5086395740509033 per song
# extracting SV takes 0.8636913299560547 per song
# analyzing  3.mp3 ../data/emotifymusic/classical\3.mp3
# import takes 0.4461383819580078
# extracting ZC takes 0.0897972583770752 per song
# extracting SC takes 0.5106344223022461 per song
# extracting SV takes 0.8674030303955078 per song
# analyzing  30.mp3 ../data/emotifymusic/classical\30.mp3
# import takes 0.44924354553222656
# extracting ZC takes 0.09181046485900879 per song
# extracting SC takes 0.5076234340667725 per song
# extracting SV takes 0.8701372146606445 per song
# analyzing  31.mp3 ../data/emotifymusic/classical\31.mp3
# import takes 0.44335079193115234
# extracting ZC takes 0.10073447227478027 per song
# extracting SC takes 0.5186502933502197 per song
# extracting SV takes 0.8696749210357666 per song
# analyzing  32.mp3 ../data/emotifymusic/classical\32.mp3
# import takes 0.4465217590332031
# extracting ZC takes 0.0937807559967041 per song
# extracting SC takes 0.5053362846374512 per song
# extracting SV takes 0.8706729412078857 per song
# analyzing  33.mp3 ../data/emotifymusic/classical\33.mp3
# import takes 0.44909048080444336
# extracting ZC takes 0.09275484085083008 per song
# extracting SC takes 0.5056860446929932 per song
# extracting SV takes 0.8875720500946045 per song
# analyzing  34.mp3 ../data/emotifymusic/classical\34.mp3
# import takes 0.447554349899292
# extracting ZC takes 0.09578108787536621 per song
# extracting SC takes 0.5186128616333008 per song
# extracting SV takes 0.8736300468444824 per song
# analyzing  35.mp3 ../data/emotifymusic/classical\35.mp3
# import takes 0.4558744430541992
# extracting ZC takes 0.08676433563232422 per song
# extracting SC takes 0.5076422691345215 per song
# extracting SV takes 0.8736679553985596 per song
# analyzing  36.mp3 ../data/emotifymusic/classical\36.mp3
# import takes 0.45031118392944336
# extracting ZC takes 0.08680486679077148 per song
# extracting SC takes 0.5090222358703613 per song
# extracting SV takes 0.8826394081115723 per song
# analyzing  37.mp3 ../data/emotifymusic/classical\37.mp3
# import takes 0.45482587814331055
# extracting ZC takes 0.08979678153991699 per song
# extracting SC takes 0.5046513080596924 per song
# extracting SV takes 0.8685529232025146 per song
# analyzing  38.mp3 ../data/emotifymusic/classical\38.mp3
# import takes 0.4484395980834961
# extracting ZC takes 0.09474921226501465 per song
# extracting SC takes 0.5156214237213135 per song
# extracting SV takes 0.8806443214416504 per song
# analyzing  39.mp3 ../data/emotifymusic/classical\39.mp3
# import takes 0.4582712650299072
# extracting ZC takes 0.09071040153503418 per song
# extracting SC takes 0.5116348266601562 per song
# extracting SV takes 0.8826401233673096 per song
# analyzing  4.mp3 ../data/emotifymusic/classical\4.mp3
# import takes 0.4482767581939697
# extracting ZC takes 0.08880805969238281 per song
# extracting SC takes 0.5135822296142578 per song
# extracting SV takes 0.8816421031951904 per song
# analyzing  40.mp3 ../data/emotifymusic/classical\40.mp3
# import takes 0.3805220127105713
# extracting ZC takes 0.05189657211303711 per song
# extracting SC takes 0.3041858673095703 per song
# extracting SV takes 0.512631893157959 per song
# analyzing  41.mp3 ../data/emotifymusic/classical\41.mp3
# import takes 0.446535587310791
# extracting ZC takes 0.08975863456726074 per song
# extracting SC takes 0.5156567096710205 per song
# extracting SV takes 0.887645959854126 per song
# analyzing  42.mp3 ../data/emotifymusic/classical\42.mp3
# import takes 0.48414015769958496
# extracting ZC takes 0.0977776050567627 per song
# extracting SC takes 0.5086414813995361 per song
# extracting SV takes 0.8806414604187012 per song
# analyzing  43.mp3 ../data/emotifymusic/classical\43.mp3
# import takes 0.44847655296325684
# extracting ZC takes 0.09175467491149902 per song
# extracting SC takes 0.5096402168273926 per song
# extracting SV takes 0.8677136898040771 per song
# analyzing  44.mp3 ../data/emotifymusic/classical\44.mp3
# import takes 0.4446847438812256
# extracting ZC takes 0.0907444953918457 per song
# extracting SC takes 0.5006630420684814 per song
# extracting SV takes 0.8895845413208008 per song
# analyzing  45.mp3 ../data/emotifymusic/classical\45.mp3
# import takes 0.45113468170166016
# extracting ZC takes 0.08879995346069336 per song
# extracting SC takes 0.5196096897125244 per song
# extracting SV takes 0.868675947189331 per song
# analyzing  46.mp3 ../data/emotifymusic/classical\46.mp3
# import takes 0.4496467113494873
# extracting ZC takes 0.0897970199584961 per song
# extracting SC takes 0.506608247756958 per song
# extracting SV takes 0.8806476593017578 per song
# analyzing  47.mp3 ../data/emotifymusic/classical\47.mp3
# import takes 0.4512600898742676
# extracting ZC takes 0.0897681713104248 per song
# extracting SC takes 0.5134754180908203 per song
# extracting SV takes 0.8756580352783203 per song
# analyzing  48.mp3 ../data/emotifymusic/classical\48.mp3
# import takes 0.44858431816101074
# extracting ZC takes 0.09179544448852539 per song
# extracting SC takes 0.5216012001037598 per song
# extracting SV takes 0.8806116580963135 per song
# analyzing  49.mp3 ../data/emotifymusic/classical\49.mp3
# import takes 0.4516434669494629
# extracting ZC takes 0.10272407531738281 per song
# extracting SC takes 0.5116720199584961 per song
# extracting SV takes 0.8786120414733887 per song
# analyzing  5.mp3 ../data/emotifymusic/classical\5.mp3
# import takes 0.4569551944732666
# extracting ZC takes 0.0868077278137207 per song
# extracting SC takes 0.5126247406005859 per song
# extracting SV takes 0.8676817417144775 per song
# analyzing  50.mp3 ../data/emotifymusic/classical\50.mp3
# import takes 0.45230793952941895
# extracting ZC takes 0.09175443649291992 per song
# extracting SC takes 0.5046882629394531 per song
# extracting SV takes 0.8736629486083984 per song
# analyzing  51.mp3 ../data/emotifymusic/classical\51.mp3
# import takes 0.44709134101867676
# extracting ZC takes 0.08681464195251465 per song
# extracting SC takes 0.5105910301208496 per song
# extracting SV takes 0.8786470890045166 per song
# analyzing  52.mp3 ../data/emotifymusic/classical\52.mp3
# import takes 0.45181989669799805
# extracting ZC takes 0.09070777893066406 per song
# C:\Users\sergi\AppData\Local\Temp/ipykernel_23148/4235397672.py:27: RuntimeWarning: invalid value encountered in double_scalars
#   centroid.append(np.sum(freqs*DATA[:int(np.ceil(windowsizeinsamples/2.0)+1)])/
# extracting SC takes 0.5206453800201416 per song
# C:\Users\sergi\AppData\Local\Temp/ipykernel_23148/4235397672.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   centroid = np.sum(freqs*DATA[:ind_max])/np.sum(DATA[:ind_max])
# C:\Users\sergi\AppData\Local\Temp/ipykernel_23148/4235397672.py:49: RuntimeWarning: invalid value encountered in double_scalars
#   second_moment = np.sum(np.power(freqs, 2)*DATA[:ind_max])/np.sum(DATA[:ind_max])
# extracting SV takes 0.8796103000640869 per song
# analyzing  53.mp3 ../data/emotifymusic/classical\53.mp3
# import takes 0.44800686836242676
# extracting ZC takes 0.10077786445617676 per song
# extracting SC takes 0.513582706451416 per song
# extracting SV takes 0.8727023601531982 per song
# analyzing  54.mp3 ../data/emotifymusic/classical\54.mp3
# import takes 0.4514131546020508
# extracting ZC takes 0.0927882194519043 per song
# extracting SC takes 0.5056502819061279 per song
# extracting SV takes 0.8656830787658691 per song
# analyzing  55.mp3 ../data/emotifymusic/classical\55.mp3
# import takes 0.44335436820983887
# extracting ZC takes 0.08776354789733887 per song
# extracting SC takes 0.5195753574371338 per song
# extracting SV takes 0.878650426864624 per song
# analyzing  56.mp3 ../data/emotifymusic/classical\56.mp3
# import takes 0.4463498592376709
# extracting ZC takes 0.08775520324707031 per song
# extracting SC takes 0.5036530494689941 per song
# extracting SV takes 0.8649888038635254 per song
# analyzing  57.mp3 ../data/emotifymusic/classical\57.mp3
# import takes 0.45660400390625
# extracting ZC takes 0.0897977352142334 per song
# extracting SC takes 0.504300594329834 per song
# extracting SV takes 0.8447446823120117 per song
# analyzing  58.mp3 ../data/emotifymusic/classical\58.mp3
# import takes 0.4466392993927002
# extracting ZC takes 0.10073375701904297 per song
# extracting SC takes 0.514660120010376 per song
# extracting SV takes 0.873661994934082 per song
# analyzing  59.mp3 ../data/emotifymusic/classical\59.mp3
# import takes 0.46093058586120605
# extracting ZC takes 0.08880090713500977 per song
# extracting SC takes 0.5205695629119873 per song
# extracting SV takes 0.885631799697876 per song
# analyzing  6.mp3 ../data/emotifymusic/classical\6.mp3
# import takes 0.4434788227081299
# extracting ZC takes 0.08780217170715332 per song
# extracting SC takes 0.5098202228546143 per song
# extracting SV takes 0.8786516189575195 per song
# analyzing  60.mp3 ../data/emotifymusic/classical\60.mp3
# import takes 0.44850826263427734
# extracting ZC takes 0.09973478317260742 per song
# extracting SC takes 0.507676362991333 per song
# extracting SV takes 0.8726682662963867 per song
# analyzing  61.mp3 ../data/emotifymusic/classical\61.mp3
# import takes 0.4502291679382324
# extracting ZC takes 0.08780264854431152 per song
# extracting SC takes 0.5172159671783447 per song
# extracting SV takes 0.8736615180969238 per song
# analyzing  62.mp3 ../data/emotifymusic/classical\62.mp3
# import takes 0.44378042221069336
# extracting ZC takes 0.0977015495300293 per song
# extracting SC takes 0.518613338470459 per song
# extracting SV takes 0.8766555786132812 per song
# analyzing  63.mp3 ../data/emotifymusic/classical\63.mp3
# import takes 0.44247889518737793
# extracting ZC takes 0.0877993106842041 per song
# extracting SC takes 0.5066475868225098 per song
# extracting SV takes 0.8686792850494385 per song
# analyzing  64.mp3 ../data/emotifymusic/classical\64.mp3
# import takes 0.4470522403717041
# extracting ZC takes 0.08676910400390625 per song
# extracting SC takes 0.5126309394836426 per song
# extracting SV takes 0.872666597366333 per song
# analyzing  65.mp3 ../data/emotifymusic/classical\65.mp3
# import takes 0.44175219535827637
# extracting ZC takes 0.0987386703491211 per song
# extracting SC takes 0.5086743831634521 per song
# extracting SV takes 0.8749299049377441 per song
# analyzing  66.mp3 ../data/emotifymusic/classical\66.mp3
# import takes 0.32343602180480957
# extracting ZC takes 0.038895606994628906 per song
# extracting SC takes 0.2293868064880371 per song
# extracting SV takes 0.3818647861480713 per song
# analyzing  67.mp3 ../data/emotifymusic/classical\67.mp3
# import takes 0.44798851013183594
# extracting ZC takes 0.09474945068359375 per song
# extracting SC takes 0.5176165103912354 per song
# extracting SV takes 0.8756558895111084 per song
# analyzing  68.mp3 ../data/emotifymusic/classical\68.mp3
# import takes 0.44365739822387695
# extracting ZC takes 0.09375143051147461 per song
# extracting SC takes 0.520606517791748 per song
# extracting SV takes 0.8786520957946777 per song
# analyzing  69.mp3 ../data/emotifymusic/classical\69.mp3
# import takes 0.447711706161499
# extracting ZC takes 0.09375119209289551 per song
# extracting SC takes 0.5056867599487305 per song
# extracting SV takes 0.8666982650756836 per song
# analyzing  7.mp3 ../data/emotifymusic/classical\7.mp3
# import takes 0.4471135139465332
# extracting ZC takes 0.08880090713500977 per song
# extracting SC takes 0.5119304656982422 per song
# extracting SV takes 0.8846347332000732 per song
# analyzing  70.mp3 ../data/emotifymusic/classical\70.mp3
# import takes 0.447967529296875
# extracting ZC takes 0.09378862380981445 per song
# extracting SC takes 0.5155856609344482 per song
# extracting SV takes 0.869375467300415 per song
# analyzing  71.mp3 ../data/emotifymusic/classical\71.mp3
# import takes 0.4623575210571289
# extracting ZC takes 0.09079599380493164 per song
# extracting SC takes 0.5145871639251709 per song
# extracting SV takes 0.8836374282836914 per song
# analyzing  72.mp3 ../data/emotifymusic/classical\72.mp3
# import takes 0.44559383392333984
# extracting ZC takes 0.09074687957763672 per song
# extracting SC takes 0.5086431503295898 per song
# extracting SV takes 0.8746604919433594 per song
# analyzing  73.mp3 ../data/emotifymusic/classical\73.mp3
# import takes 0.3496589660644531
# extracting ZC takes 0.044927120208740234 per song
# extracting SC takes 0.2592966556549072 per song
# extracting SV takes 0.4358360767364502 per song
# analyzing  74.mp3 ../data/emotifymusic/classical\74.mp3
# import takes 0.4425053596496582
# extracting ZC takes 0.09178876876831055 per song
# extracting SC takes 0.5032515525817871 per song
# extracting SV takes 0.8706679344177246 per song
# analyzing  75.mp3 ../data/emotifymusic/classical\75.mp3
# import takes 0.44340968132019043
# extracting ZC takes 0.09474992752075195 per song
# extracting SC takes 0.522601842880249 per song
# extracting SV takes 0.8846683502197266 per song
# analyzing  76.mp3 ../data/emotifymusic/classical\76.mp3
# import takes 0.44884181022644043
# extracting ZC takes 0.10372209548950195 per song
# extracting SC takes 0.5046877861022949 per song
# extracting SV takes 0.8706741333007812 per song
# analyzing  77.mp3 ../data/emotifymusic/classical\77.mp3
# import takes 0.4447512626647949
# extracting ZC takes 0.09079456329345703 per song
# extracting SC takes 0.5029346942901611 per song
# extracting SV takes 0.8686764240264893 per song
# analyzing  78.mp3 ../data/emotifymusic/classical\78.mp3
# import takes 0.44704675674438477
# extracting ZC takes 0.10372471809387207 per song
# extracting SC takes 0.52962327003479 per song
# extracting SV takes 0.8766534328460693 per song
# analyzing  79.mp3 ../data/emotifymusic/classical\79.mp3
# import takes 0.445357084274292
# extracting ZC takes 0.09275460243225098 per song
# extracting SC takes 0.5086371898651123 per song
# extracting SV takes 0.8826415538787842 per song
# analyzing  8.mp3 ../data/emotifymusic/classical\8.mp3
# import takes 0.447279691696167
# extracting ZC takes 0.09474873542785645 per song
# extracting SC takes 0.5166182518005371 per song
# extracting SV takes 0.8776838779449463 per song
# analyzing  80.mp3 ../data/emotifymusic/classical\80.mp3
# import takes 0.4548454284667969
# extracting ZC takes 0.09375238418579102 per song
# extracting SC takes 0.5066423416137695 per song
# extracting SV takes 0.877758264541626 per song
# analyzing  81.mp3 ../data/emotifymusic/classical\81.mp3
# import takes 0.44996047019958496
# extracting ZC takes 0.08879971504211426 per song
# extracting SC takes 0.5054810047149658 per song
# extracting SV takes 0.8726651668548584 per song
# analyzing  82.mp3 ../data/emotifymusic/classical\82.mp3
# import takes 0.4408562183380127
# extracting ZC takes 0.09378600120544434 per song
# extracting SC takes 0.5136282444000244 per song
# extracting SV takes 0.8726661205291748 per song
# analyzing  83.mp3 ../data/emotifymusic/classical\83.mp3
# import takes 0.4486827850341797
# extracting ZC takes 0.09574508666992188 per song
# extracting SC takes 0.514657735824585 per song
# extracting SV takes 0.8865947723388672 per song
# analyzing  84.mp3 ../data/emotifymusic/classical\84.mp3
# import takes 0.4493825435638428
# extracting ZC takes 0.08676338195800781 per song
# extracting SC takes 0.5118660926818848 per song
# extracting SV takes 0.8796842098236084 per song
# analyzing  85.mp3 ../data/emotifymusic/classical\85.mp3
# import takes 0.4469759464263916
# extracting ZC takes 0.10372543334960938 per song
# extracting SC takes 0.5066452026367188 per song
# extracting SV takes 0.8686771392822266 per song
# analyzing  86.mp3 ../data/emotifymusic/classical\86.mp3
# import takes 0.4452996253967285
# extracting ZC takes 0.09076118469238281 per song
# extracting SC takes 0.5126628875732422 per song
# extracting SV takes 0.8753538131713867 per song
# analyzing  87.mp3 ../data/emotifymusic/classical\87.mp3
# import takes 0.4516732692718506
# extracting ZC takes 0.08975934982299805 per song
# extracting SC takes 0.5096755027770996 per song
# extracting SV takes 0.8766565322875977 per song
# analyzing  88.mp3 ../data/emotifymusic/classical\88.mp3
# import takes 0.44533562660217285
# extracting ZC takes 0.09275174140930176 per song
# extracting SC takes 0.5056848526000977 per song
# extracting SV takes 0.872666597366333 per song
# analyzing  89.mp3 ../data/emotifymusic/classical\89.mp3
# import takes 0.4518146514892578
# extracting ZC takes 0.09275460243225098 per song
# extracting SC takes 0.512629508972168 per song
# extracting SV takes 0.8727030754089355 per song
# analyzing  9.mp3 ../data/emotifymusic/classical\9.mp3
# import takes 0.4539957046508789
# extracting ZC takes 0.09773826599121094 per song
# extracting SC takes 0.5144128799438477 per song
# extracting SV takes 0.8676779270172119 per song
# analyzing  90.mp3 ../data/emotifymusic/classical\90.mp3
# import takes 0.45598769187927246
# extracting ZC takes 0.10276556015014648 per song
# extracting SC takes 0.5059313774108887 per song
# extracting SV takes 0.8726663589477539 per song
# analyzing  91.mp3 ../data/emotifymusic/classical\91.mp3
# import takes 0.4537384510040283
# extracting ZC takes 0.1017305850982666 per song
# extracting SC takes 0.5136609077453613 per song
# extracting SV takes 0.8686802387237549 per song
# analyzing  92.mp3 ../data/emotifymusic/classical\92.mp3
# import takes 0.44895076751708984
# extracting ZC takes 0.09674406051635742 per song
# extracting SC takes 0.5106680393218994 per song
# extracting SV takes 0.8656470775604248 per song
# analyzing  93.mp3 ../data/emotifymusic/classical\93.mp3
# import takes 0.45098352432250977
# extracting ZC takes 0.08580756187438965 per song
# extracting SC takes 0.5378932952880859 per song
# extracting SV takes 0.8696739673614502 per song
# analyzing  94.mp3 ../data/emotifymusic/classical\94.mp3
# import takes 0.45551228523254395
# extracting ZC takes 0.0888056755065918 per song
# extracting SC takes 0.512484073638916 per song
# extracting SV takes 0.8756587505340576 per song
# analyzing  95.mp3 ../data/emotifymusic/classical\95.mp3
# import takes 0.451810359954834
# extracting ZC takes 0.08975982666015625 per song
# extracting SC takes 0.5006616115570068 per song
# extracting SV takes 0.8806076049804688 per song
# analyzing  96.mp3 ../data/emotifymusic/classical\96.mp3
# import takes 0.4482734203338623
# extracting ZC takes 0.08880233764648438 per song
# extracting SC takes 0.5112385749816895 per song
# extracting SV takes 0.877652645111084 per song
# analyzing  97.mp3 ../data/emotifymusic/classical\97.mp3
# import takes 0.46134328842163086
# extracting ZC takes 0.08880066871643066 per song
# extracting SC takes 0.5133645534515381 per song
# extracting SV takes 0.8766534328460693 per song
# analyzing  98.mp3 ../data/emotifymusic/classical\98.mp3
# import takes 0.4581327438354492
# extracting ZC takes 0.08776569366455078 per song
# extracting SC takes 0.5176184177398682 per song
# extracting SV takes 0.8816795349121094 per song
# analyzing  99.mp3 ../data/emotifymusic/classical\99.mp3
# import takes 0.45656585693359375
# extracting ZC takes 0.09075736999511719 per song
# extracting SC takes 0.5375626087188721 per song
# extracting SV takes 0.8769843578338623 per song
# analyzing  1.mp3 ../data/emotifymusic/electronic\1.mp3
# import takes 0.43998074531555176
# extracting ZC takes 0.0967414379119873 per song
# extracting SC takes 0.5136666297912598 per song
# extracting SV takes 0.8816392421722412 per song
# analyzing  10.mp3 ../data/emotifymusic/electronic\10.mp3
# import takes 0.44591546058654785
# extracting ZC takes 0.08681726455688477 per song
# extracting SC takes 0.5078368186950684 per song
# extracting SV takes 0.8766891956329346 per song
# analyzing  100.mp3 ../data/emotifymusic/electronic\100.mp3
# import takes 0.4529898166656494
# extracting ZC takes 0.0967862606048584 per song
# extracting SC takes 0.5115900039672852 per song
# extracting SV takes 0.8876631259918213 per song
# analyzing  11.mp3 ../data/emotifymusic/electronic\11.mp3
# import takes 0.4490983486175537
# extracting ZC takes 0.10376381874084473 per song
# extracting SC takes 0.5046486854553223 per song
# extracting SV takes 0.8676786422729492 per song
# analyzing  12.mp3 ../data/emotifymusic/electronic\12.mp3
# import takes 0.44651079177856445
# extracting ZC takes 0.09175443649291992 per song
# extracting SC takes 0.5056207180023193 per song
# extracting SV takes 0.8746609687805176 per song
# analyzing  13.mp3 ../data/emotifymusic/electronic\13.mp3
# import takes 0.44220995903015137
# extracting ZC takes 0.09869146347045898 per song
# extracting SC takes 0.5096375942230225 per song
# extracting SV takes 0.8846340179443359 per song
# analyzing  14.mp3 ../data/emotifymusic/electronic\14.mp3
# import takes 0.44658613204956055
# extracting ZC takes 0.09774136543273926 per song
# extracting SC takes 0.508673906326294 per song
# extracting SV takes 0.8786160945892334 per song
# analyzing  15.mp3 ../data/emotifymusic/electronic\15.mp3
# import takes 0.4467616081237793
# extracting ZC takes 0.09080696105957031 per song
# extracting SC takes 0.5315647125244141 per song
# extracting SV takes 0.874664306640625 per song
# analyzing  16.mp3 ../data/emotifymusic/electronic\16.mp3
# import takes 0.445239782333374
# extracting ZC takes 0.09175753593444824 per song
# extracting SC takes 0.517615795135498 per song
# extracting SV takes 0.8796472549438477 per song
# analyzing  17.mp3 ../data/emotifymusic/electronic\17.mp3
# import takes 0.4574902057647705
# extracting ZC takes 0.08880257606506348 per song
# extracting SC takes 0.5066092014312744 per song
# extracting SV takes 0.888620138168335 per song
# analyzing  18.mp3 ../data/emotifymusic/electronic\18.mp3
# import takes 0.4439682960510254
# extracting ZC takes 0.09474754333496094 per song
# extracting SC takes 0.5076448917388916 per song
# extracting SV takes 0.8717024326324463 per song
# analyzing  19.mp3 ../data/emotifymusic/electronic\19.mp3
# import takes 0.4564626216888428
# extracting ZC takes 0.0957331657409668 per song
# extracting SC takes 0.5136251449584961 per song
# extracting SV takes 0.8746209144592285 per song
# analyzing  2.mp3 ../data/emotifymusic/electronic\2.mp3
# import takes 0.4483969211578369
# extracting ZC takes 0.08980655670166016 per song
# extracting SC takes 0.5116937160491943 per song
# extracting SV takes 0.8746960163116455 per song
# analyzing  20.mp3 ../data/emotifymusic/electronic\20.mp3
# import takes 0.4529743194580078
# extracting ZC takes 0.09873723983764648 per song
# extracting SC takes 0.5066421031951904 per song
# extracting SV takes 0.8756611347198486 per song
# analyzing  21.mp3 ../data/emotifymusic/electronic\21.mp3
# import takes 0.4538307189941406
# extracting ZC takes 0.08975982666015625 per song
# extracting SC takes 0.5116691589355469 per song
# extracting SV takes 0.8766553401947021 per song
# analyzing  22.mp3 ../data/emotifymusic/electronic\22.mp3
# import takes 0.453418493270874
# extracting ZC takes 0.09174013137817383 per song
# extracting SC takes 0.5218138694763184 per song
# extracting SV takes 0.8676817417144775 per song
# analyzing  23.mp3 ../data/emotifymusic/electronic\23.mp3
# import takes 0.453305721282959
# extracting ZC takes 0.08876371383666992 per song
# extracting SC takes 0.5136263370513916 per song
# extracting SV takes 0.8646900653839111 per song
# analyzing  24.mp3 ../data/emotifymusic/electronic\24.mp3
# import takes 0.449582576751709
# extracting ZC takes 0.08880925178527832 per song
# extracting SC takes 0.5151066780090332 per song
# extracting SV takes 0.8697121143341064 per song
# analyzing  25.mp3 ../data/emotifymusic/electronic\25.mp3
# import takes 0.45481443405151367
# extracting ZC takes 0.10272502899169922 per song
# extracting SC takes 0.5096771717071533 per song
# extracting SV takes 0.869683027267456 per song
# analyzing  26.mp3 ../data/emotifymusic/electronic\26.mp3
# import takes 0.4565279483795166
# extracting ZC takes 0.0927886962890625 per song
# extracting SC takes 0.5175819396972656 per song
# extracting SV takes 0.885631799697876 per song
# analyzing  27.mp3 ../data/emotifymusic/electronic\27.mp3
# import takes 0.453902006149292
# extracting ZC takes 0.1017308235168457 per song
# extracting SC takes 0.5056817531585693 per song
# extracting SV takes 0.8656878471374512 per song
# analyzing  28.mp3 ../data/emotifymusic/electronic\28.mp3
# import takes 0.47722291946411133
# extracting ZC takes 0.09674358367919922 per song
# extracting SC takes 0.5096378326416016 per song
# extracting SV takes 0.8707053661346436 per song
# analyzing  29.mp3 ../data/emotifymusic/electronic\29.mp3
# import takes 0.48565030097961426
# extracting ZC takes 0.10272598266601562 per song
# extracting SC takes 0.5356032848358154 per song
# extracting SV takes 0.9295151233673096 per song
# analyzing  3.mp3 ../data/emotifymusic/electronic\3.mp3
# import takes 0.4603748321533203
# extracting ZC takes 0.09478402137756348 per song
# extracting SC takes 0.5143485069274902 per song
# extracting SV takes 0.8736684322357178 per song
# analyzing  30.mp3 ../data/emotifymusic/electronic\30.mp3
# import takes 0.4533882141113281
# extracting ZC takes 0.0917508602142334 per song
# extracting SC takes 0.511622428894043 per song
# extracting SV takes 0.8946435451507568 per song
# analyzing  31.mp3 ../data/emotifymusic/electronic\31.mp3
# import takes 0.47397851943969727
# extracting ZC takes 0.09174656867980957 per song
# extracting SC takes 0.5325746536254883 per song
# extracting SV takes 0.9617996215820312 per song
# analyzing  32.mp3 ../data/emotifymusic/electronic\32.mp3
# import takes 0.4742574691772461
# extracting ZC takes 0.09179115295410156 per song
# extracting SC takes 0.5106344223022461 per song
# extracting SV takes 0.9075331687927246 per song
# analyzing  33.mp3 ../data/emotifymusic/electronic\33.mp3
# import takes 0.4603583812713623
# extracting ZC takes 0.09773850440979004 per song
# extracting SC takes 0.5176527500152588 per song
# extracting SV takes 0.871671199798584 per song
# analyzing  34.mp3 ../data/emotifymusic/electronic\34.mp3
# import takes 0.45413661003112793
# extracting ZC takes 0.0987386703491211 per song
# extracting SC takes 0.5236337184906006 per song
# extracting SV takes 0.8826048374176025 per song
# analyzing  35.mp3 ../data/emotifymusic/electronic\35.mp3
# import takes 0.45571351051330566
# extracting ZC takes 0.08879947662353516 per song
# extracting SC takes 0.5037431716918945 per song
# extracting SV takes 0.8707098960876465 per song
# analyzing  36.mp3 ../data/emotifymusic/electronic\36.mp3
# import takes 0.45603346824645996
# extracting ZC takes 0.0967414379119873 per song
# extracting SC takes 0.5096745491027832 per song
# extracting SV takes 0.883601188659668 per song
# analyzing  37.mp3 ../data/emotifymusic/electronic\37.mp3
# import takes 0.4587101936340332
# extracting ZC takes 0.09179162979125977 per song
# extracting SC takes 0.5275917053222656 per song
# extracting SV takes 0.8906164169311523 per song
# analyzing  38.mp3 ../data/emotifymusic/electronic\38.mp3
# import takes 0.45217084884643555
# extracting ZC takes 0.08879947662353516 per song
# extracting SC takes 0.5096399784088135 per song
# extracting SV takes 0.8926103115081787 per song
# analyzing  39.mp3 ../data/emotifymusic/electronic\39.mp3
# import takes 0.46576547622680664
# extracting ZC takes 0.12071728706359863 per song
# extracting SC takes 0.5295813083648682 per song
# extracting SV takes 0.8906207084655762 per song
# analyzing  4.mp3 ../data/emotifymusic/electronic\4.mp3
# import takes 0.4595184326171875
# extracting ZC takes 0.08975934982299805 per song
# extracting SC takes 0.5086793899536133 per song
# extracting SV takes 0.8836343288421631 per song
# analyzing  40.mp3 ../data/emotifymusic/electronic\40.mp3
# import takes 0.4639396667480469
# extracting ZC takes 0.08875107765197754 per song
# extracting SC takes 0.5106348991394043 per song
# extracting SV takes 0.8955674171447754 per song
# analyzing  41.mp3 ../data/emotifymusic/electronic\41.mp3
# import takes 0.470778226852417
# extracting ZC takes 0.09075760841369629 per song
# extracting SC takes 0.5024635791778564 per song
# extracting SV takes 0.8945713043212891 per song
# analyzing  42.mp3 ../data/emotifymusic/electronic\42.mp3
# import takes 0.43889808654785156
# extracting ZC takes 0.08975839614868164 per song
# extracting SC takes 0.5125961303710938 per song
# extracting SV takes 0.8647205829620361 per song
# analyzing  43.mp3 ../data/emotifymusic/electronic\43.mp3
# import takes 0.44585371017456055
# extracting ZC takes 0.09574317932128906 per song
# extracting SC takes 0.5136656761169434 per song
# extracting SV takes 0.875657320022583 per song
# analyzing  44.mp3 ../data/emotifymusic/electronic\44.mp3
# import takes 0.44144201278686523
# extracting ZC takes 0.0847635269165039 per song
# extracting SC takes 0.5026557445526123 per song
# extracting SV takes 0.8686792850494385 per song
# analyzing  45.mp3 ../data/emotifymusic/electronic\45.mp3
# import takes 0.44307732582092285
# extracting ZC takes 0.08974647521972656 per song
# extracting SC takes 0.5065207481384277 per song
# extracting SV takes 0.8667163848876953 per song
# analyzing  46.mp3 ../data/emotifymusic/electronic\46.mp3
# import takes 0.44081926345825195
# extracting ZC takes 0.08677077293395996 per song
# extracting SC takes 0.505648136138916 per song
# extracting SV takes 0.8856995105743408 per song
# analyzing  47.mp3 ../data/emotifymusic/electronic\47.mp3
# import takes 0.4485158920288086
# extracting ZC takes 0.09075450897216797 per song
# extracting SC takes 0.5136287212371826 per song
# extracting SV takes 0.9095656871795654 per song
# analyzing  48.mp3 ../data/emotifymusic/electronic\48.mp3
# import takes 0.4490625858306885
# extracting ZC takes 0.09174227714538574 per song
# extracting SC takes 0.5285518169403076 per song
# extracting SV takes 0.9056127071380615 per song
# analyzing  49.mp3 ../data/emotifymusic/electronic\49.mp3
# import takes 0.4627399444580078
# extracting ZC takes 0.09873604774475098 per song
# extracting SC takes 0.5535569190979004 per song
# extracting SV takes 0.8915822505950928 per song
# analyzing  5.mp3 ../data/emotifymusic/electronic\5.mp3
# import takes 0.4587852954864502
# extracting ZC takes 0.08776497840881348 per song
# extracting SC takes 0.5136263370513916 per song
# extracting SV takes 0.8687057495117188 per song
# analyzing  50.mp3 ../data/emotifymusic/electronic\50.mp3
# import takes 0.4712858200073242
# extracting ZC takes 0.09080195426940918 per song
# extracting SC takes 0.5176084041595459 per song
# extracting SV takes 0.8816466331481934 per song
# analyzing  51.mp3 ../data/emotifymusic/electronic\51.mp3
# import takes 0.454240083694458
# extracting ZC takes 0.09175348281860352 per song
# extracting SC takes 0.707111120223999 per song
# extracting SV takes 1.374323844909668 per song
# analyzing  52.mp3 ../data/emotifymusic/electronic\52.mp3
# import takes 0.7220673561096191
# extracting ZC takes 0.13364410400390625 per song
# extracting SC takes 1.2715997695922852 per song
# extracting SV takes 1.5917437076568604 per song
# analyzing  53.mp3 ../data/emotifymusic/electronic\53.mp3
# import takes 0.6472690105438232
# extracting ZC takes 0.17353558540344238 per song
# extracting SC takes 0.7799990177154541 per song
# extracting SV takes 1.408238410949707 per song
# analyzing  54.mp3 ../data/emotifymusic/electronic\54.mp3
# import takes 0.6133599281311035
# extracting ZC takes 0.1685488224029541 per song
# extracting SC takes 0.9743943214416504 per song
# extracting SV takes 1.6964640617370605 per song
# analyzing  55.mp3 ../data/emotifymusic/electronic\55.mp3
# import takes 0.6791856288909912
# extracting ZC takes 0.18550848960876465 per song
# extracting SC takes 0.9354913234710693 per song
# extracting SV takes 1.6475937366485596 per song
# analyzing  56.mp3 ../data/emotifymusic/electronic\56.mp3
# import takes 0.6692099571228027
# extracting ZC takes 0.1705467700958252 per song
# extracting SC takes 1.0192701816558838 per song
# extracting SV takes 1.5169436931610107 per song
# analyzing  57.mp3 ../data/emotifymusic/electronic\57.mp3
# import takes 0.6532540321350098
# extracting ZC takes 0.176497220993042 per song
# extracting SC takes 1.0442087650299072 per song
# extracting SV takes 1.2945375442504883 per song
# analyzing  58.mp3 ../data/emotifymusic/electronic\58.mp3
# import takes 0.6033861637115479
# extracting ZC takes 0.11569046974182129 per song
# extracting SC takes 0.9793825149536133 per song
# extracting SV takes 1.345400333404541 per song
# analyzing  59.mp3 ../data/emotifymusic/electronic\59.mp3
# import takes 0.49770617485046387
# extracting ZC takes 0.08976030349731445 per song
# extracting SC takes 0.5614633560180664 per song
# extracting SV takes 1.0102953910827637 per song
# analyzing  6.mp3 ../data/emotifymusic/electronic\6.mp3
# import takes 0.5226035118103027
# extracting ZC takes 0.11569452285766602 per song
# extracting SC takes 0.5565073490142822 per song
# extracting SV takes 1.0332391262054443 per song
# analyzing  60.mp3 ../data/emotifymusic/electronic\60.mp3
# import takes 0.5096361637115479
# extracting ZC takes 0.1545872688293457 per song
# extracting SC takes 0.7290527820587158 per song
# extracting SV takes 1.2386868000030518 per song
# analyzing  61.mp3 ../data/emotifymusic/electronic\61.mp3
# import takes 0.6632263660430908
# extracting ZC takes 0.19148826599121094 per song
# extracting SC takes 1.082106590270996 per song
# extracting SV takes 1.61468505859375 per song
# analyzing  62.mp3 ../data/emotifymusic/electronic\62.mp3
# import takes 0.6263246536254883
# extracting ZC takes 0.15956926345825195 per song
# extracting SC takes 1.0023221969604492 per song
# extracting SV takes 1.632631540298462 per song
# analyzing  63.mp3 ../data/emotifymusic/electronic\63.mp3
# import takes 0.647268533706665
# extracting ZC takes 0.18949317932128906 per song
# extracting SC takes 0.9973325729370117 per song
# extracting SV takes 1.4870197772979736 per song
# analyzing  64.mp3 ../data/emotifymusic/electronic\64.mp3
# import takes 0.8108317852020264
# extracting ZC takes 0.28324151039123535 per song
# extracting SC takes 1.320469856262207 per song
# extracting SV takes 1.510958194732666 per song
# analyzing  65.mp3 ../data/emotifymusic/electronic\65.mp3
# import takes 0.6123623847961426
# extracting ZC takes 0.1735386848449707 per song
# extracting SC takes 0.8786475658416748 per song
# extracting SV takes 1.493006944656372 per song
# analyzing  66.mp3 ../data/emotifymusic/electronic\66.mp3
# import takes 0.713092565536499
# extracting ZC takes 0.19049620628356934 per song
# extracting SC takes 1.1100256443023682 per song
# extracting SV takes 1.654576063156128 per song
# analyzing  67.mp3 ../data/emotifymusic/electronic\67.mp3
# import takes 0.6741952896118164
# extracting ZC takes 0.18849563598632812 per song
# extracting SC takes 1.007305383682251 per song
# extracting SV takes 1.5428709983825684 per song
# analyzing  68.mp3 ../data/emotifymusic/electronic\68.mp3
# import takes 0.636298418045044
# extracting ZC takes 0.17154359817504883 per song
# extracting SC takes 0.938488245010376 per song
# extracting SV takes 1.7592942714691162 per song
# analyzing  69.mp3 ../data/emotifymusic/electronic\69.mp3
# import takes 0.6861653327941895
# extracting ZC takes 0.18350934982299805 per song
# extracting SC takes 1.058171272277832 per song
# extracting SV takes 1.6565687656402588 per song
# analyzing  7.mp3 ../data/emotifymusic/electronic\7.mp3
# import takes 0.6662178039550781
# extracting ZC takes 0.17553043365478516 per song
# extracting SC takes 0.9414865970611572 per song
# extracting SV takes 1.4351589679718018 per song
# analyzing  70.mp3 ../data/emotifymusic/electronic\70.mp3
# import takes 0.6333057880401611
# extracting ZC takes 0.15059828758239746 per song
# extracting SC takes 0.8926119804382324 per song
# extracting SV takes 1.3723349571228027 per song
# analyzing  71.mp3 ../data/emotifymusic/electronic\71.mp3
# import takes 0.5934076309204102
# extracting ZC takes 0.1266615390777588 per song
# extracting SC takes 0.7629604339599609 per song
# extracting SV takes 1.3404185771942139 per song
# analyzing  72.mp3 ../data/emotifymusic/electronic\72.mp3
# import takes 0.5764586925506592
# extracting ZC takes 0.15458416938781738 per song
# extracting SC takes 0.7210724353790283 per song
# extracting SV takes 1.3304424285888672 per song
# analyzing  73.mp3 ../data/emotifymusic/electronic\73.mp3
# import takes 0.5854353904724121
# extracting ZC takes 0.13064885139465332 per song
# extracting SC takes 0.7529897689819336 per song
# extracting SV takes 1.270599365234375 per song
# analyzing  74.mp3 ../data/emotifymusic/electronic\74.mp3
# import takes 0.5834393501281738
# extracting ZC takes 0.15858030319213867 per song
# extracting SC takes 0.783900260925293 per song
# extracting SV takes 1.2546460628509521 per song
# analyzing  75.mp3 ../data/emotifymusic/electronic\75.mp3
# import takes 0.581446647644043
# extracting ZC takes 0.1466059684753418 per song
# extracting SC takes 0.7699432373046875 per song
# extracting SV takes 1.2686057090759277 per song
# analyzing  76.mp3 ../data/emotifymusic/electronic\76.mp3
# import takes 0.6213383674621582
# extracting ZC takes 0.11170172691345215 per song
# extracting SC takes 0.7190744876861572 per song
# extracting SV takes 1.3025169372558594 per song
# analyzing  77.mp3 ../data/emotifymusic/electronic\77.mp3
# import takes 0.575463056564331
# extracting ZC takes 0.11469388008117676 per song
# extracting SC takes 0.7280576229095459 per song
# extracting SV takes 1.2476587295532227 per song
# analyzing  78.mp3 ../data/emotifymusic/electronic\78.mp3
# import takes 0.5595052242279053
# extracting ZC takes 0.15358805656433105 per song
# extracting SC takes 0.7480013370513916 per song
# extracting SV takes 1.3085014820098877 per song
# analyzing  79.mp3 ../data/emotifymusic/electronic\79.mp3
# import takes 0.5754666328430176
# extracting ZC takes 0.1466081142425537 per song
# extracting SC takes 0.7968664169311523 per song
# extracting SV takes 1.1150169372558594 per song
# analyzing  8.mp3 ../data/emotifymusic/electronic\8.mp3
# import takes 0.5235996246337891
# extracting ZC takes 0.1096796989440918 per song
# extracting SC takes 0.657243013381958 per song
# extracting SV takes 1.0831031799316406 per song
# analyzing  80.mp3 ../data/emotifymusic/electronic\80.mp3
# import takes 0.5206074714660645
# extracting ZC takes 0.12267518043518066 per song
# extracting SC takes 0.6353039741516113 per song
# extracting SV takes 1.101050615310669 per song
# analyzing  81.mp3 ../data/emotifymusic/electronic\81.mp3
# import takes 0.542550802230835
# extracting ZC takes 0.11369538307189941 per song
# extracting SC takes 0.6921486854553223 per song
# extracting SV takes 1.1389594078063965 per song
# analyzing  82.mp3 ../data/emotifymusic/electronic\82.mp3
# import takes 0.5734624862670898
# extracting ZC takes 0.1466071605682373 per song
# extracting SC takes 0.7250628471374512 per song
# extracting SV takes 1.0671501159667969 per song
# analyzing  83.mp3 ../data/emotifymusic/electronic\83.mp3
# import takes 0.5644898414611816
# extracting ZC takes 0.11768627166748047 per song
# extracting SC takes 0.6492636203765869 per song
# extracting SV takes 1.1000559329986572 per song
# analyzing  84.mp3 ../data/emotifymusic/electronic\84.mp3
# import takes 0.5595037937164307
# extracting ZC takes 0.13863062858581543 per song
# extracting SC takes 0.712094783782959 per song
# extracting SV takes 1.0152854919433594 per song
# analyzing  85.mp3 ../data/emotifymusic/electronic\85.mp3
# import takes 0.5505268573760986
# extracting ZC takes 0.13364386558532715 per song
# extracting SC takes 0.6163520812988281 per song
# extracting SV takes 1.0182781219482422 per song
# analyzing  86.mp3 ../data/emotifymusic/electronic\86.mp3
# import takes 0.5196096897125244
# extracting ZC takes 0.10775017738342285 per song
# extracting SC takes 0.6452386379241943 per song
# extracting SV takes 0.9923825263977051 per song
# analyzing  87.mp3 ../data/emotifymusic/electronic\87.mp3
# import takes 0.5046155452728271
# extracting ZC takes 0.09274721145629883 per song
# extracting SC takes 0.677191972732544 per song
# extracting SV takes 1.0511887073516846 per song
# analyzing  88.mp3 ../data/emotifymusic/electronic\88.mp3
# import takes 1.313448429107666
# extracting ZC takes 0.12466788291931152 per song
# extracting SC takes 0.611365556716919 per song
# extracting SV takes 1.1210050582885742 per song
# analyzing  89.mp3 ../data/emotifymusic/electronic\89.mp3
# import takes 0.526587724685669
# extracting ZC takes 0.11867928504943848 per song
# extracting SC takes 0.6233289241790771 per song
# extracting SV takes 1.1269872188568115 per song
# analyzing  9.mp3 ../data/emotifymusic/electronic\9.mp3
# import takes 0.5265915393829346
# extracting ZC takes 0.1077125072479248 per song
# extracting SC takes 0.5964057445526123 per song
# extracting SV takes 1.129976511001587 per song
# analyzing  90.mp3 ../data/emotifymusic/electronic\90.mp3
# import takes 0.5206077098846436
# extracting ZC takes 0.11071038246154785 per song
# extracting SC takes 0.6851630210876465 per song
# extracting SV takes 1.0910801887512207 per song
# analyzing  91.mp3 ../data/emotifymusic/electronic\91.mp3
# import takes 0.5305807590484619
# extracting ZC takes 0.12366795539855957 per song
# extracting SC takes 0.6203470230102539 per song
# extracting SV takes 1.0611577033996582 per song
# analyzing  92.mp3 ../data/emotifymusic/electronic\92.mp3
# import takes 0.5186100006103516
# extracting ZC takes 0.13963055610656738 per song
# extracting SC takes 0.6143515110015869 per song
# extracting SV takes 1.0302443504333496 per song
# analyzing  93.mp3 ../data/emotifymusic/electronic\93.mp3
# import takes 0.48669886589050293
# extracting ZC takes 0.11070394515991211 per song
# extracting SC takes 0.5984001159667969 per song
# extracting SV takes 0.9903576374053955 per song
# analyzing  94.mp3 ../data/emotifymusic/electronic\94.mp3
# import takes 0.5076408386230469
# extracting ZC takes 0.1376323699951172 per song
# extracting SC takes 0.6542868614196777 per song
# extracting SV takes 1.0341980457305908 per song
# analyzing  95.mp3 ../data/emotifymusic/electronic\95.mp3
# import takes 0.5146236419677734
# extracting ZC takes 0.09076309204101562 per song
# extracting SC takes 0.6722047328948975 per song
# extracting SV takes 1.1588962078094482 per song
# analyzing  96.mp3 ../data/emotifymusic/electronic\96.mp3
# import takes 0.5285835266113281
# extracting ZC takes 0.09973526000976562 per song
# extracting SC takes 0.6113629341125488 per song
# extracting SV takes 1.0352396965026855 per song
# analyzing  97.mp3 ../data/emotifymusic/electronic\97.mp3
# import takes 0.5026521682739258
# extracting ZC takes 0.09178471565246582 per song
# extracting SC takes 0.545546293258667 per song
# extracting SV takes 0.9434387683868408 per song
# analyzing  98.mp3 ../data/emotifymusic/electronic\98.mp3
# import takes 0.5126280784606934
# extracting ZC takes 0.10571861267089844 per song
# extracting SC takes 0.6263246536254883 per song
# extracting SV takes 1.0811076164245605 per song
# analyzing  99.mp3 ../data/emotifymusic/electronic\99.mp3
# import takes 0.5265922546386719
# extracting ZC takes 0.1266617774963379 per song
# extracting SC takes 0.6143543720245361 per song
# extracting SV takes 1.0132896900177002 per song
# analyzing  1.mp3 ../data/emotifymusic/pop\1.mp3
# import takes 0.5096380710601807
# extracting ZC takes 0.11269927024841309 per song
# extracting SC takes 0.5964057445526123 per song
# extracting SV takes 0.9195759296417236 per song
# analyzing  10.mp3 ../data/emotifymusic/pop\10.mp3
# import takes 0.49466800689697266
# extracting ZC takes 0.10172772407531738 per song
# extracting SC takes 0.6283211708068848 per song
# extracting SV takes 1.0362281799316406 per song
# analyzing  100.mp3 ../data/emotifymusic/pop\100.mp3
# import takes 0.5315804481506348
# extracting ZC takes 0.18151473999023438 per song
# extracting SC takes 0.599421501159668 per song
# extracting SV takes 1.267594575881958 per song
# analyzing  11.mp3 ../data/emotifymusic/pop\11.mp3
# import takes 0.5278816223144531
# ...
# extracting SC takes 0.508636474609375 per song
# extracting SV takes 0.8636934757232666 per song
# analyzing  39.mp3 ../data/emotifymusic/rock\39.mp3
# import takes 0.48914241790771484
# extracting ZC takes 0.10272622108459473 per song
# extracting SC takes 0.5106325149536133 per song
# extracting SV takes 0.8747007846832275 per song
# analyzing  4.mp3 ../data/emotifymusic/rock\4.mp3
# import takes 0.4510676860809326
# extracting ZC takes 0.08980774879455566 per song
# extracting SC takes 0.510624885559082 per song
# extracting SV takes 0.8676614761352539 per song
# analyzing  40.mp3 ../data/emotifymusic/rock\40.mp3
# import takes 0.44902706146240234
# extracting ZC takes 0.09774088859558105 per song
# extracting SC takes 0.5116698741912842 per song
# extracting SV takes 0.8955693244934082 per song
# analyzing  41.mp3 ../data/emotifymusic/rock\41.mp3
# import takes 0.45386624336242676
# extracting ZC takes 0.08976197242736816 per song
# extracting SC takes 0.5143799781799316 per song
# extracting SV takes 0.872704029083252 per song
# analyzing  42.mp3 ../data/emotifymusic/rock\42.mp3
# import takes 0.4498300552368164
# extracting ZC takes 0.0937509536743164 per song
# extracting SC takes 0.5814435482025146 per song
# extracting SV takes 1.1758942604064941 per song
# analyzing  43.mp3 ../data/emotifymusic/rock\43.mp3
# import takes 0.4543449878692627
# extracting ZC takes 0.09977126121520996 per song
# extracting SC takes 0.5056469440460205 per song
# extracting SV takes 0.8916139602661133 per song
# analyzing  44.mp3 ../data/emotifymusic/rock\44.mp3
# import takes 0.4522240161895752
# extracting ZC takes 0.0927891731262207 per song
# extracting SC takes 0.5026557445526123 per song
# extracting SV takes 0.8701417446136475 per song
# analyzing  45.mp3 ../data/emotifymusic/rock\45.mp3
# import takes 0.4543159008026123
# extracting ZC takes 0.08876204490661621 per song
# extracting SC takes 0.5036516189575195 per song
# extracting SV takes 0.8697099685668945 per song
# analyzing  46.mp3 ../data/emotifymusic/rock\46.mp3
# import takes 0.4559049606323242
# extracting ZC takes 0.0937490463256836 per song
# extracting SC takes 0.5017008781433105 per song
# extracting SV takes 0.8766524791717529 per song
# analyzing  47.mp3 ../data/emotifymusic/rock\47.mp3
# import takes 0.45020341873168945
# extracting ZC takes 0.1037602424621582 per song
# extracting SC takes 0.5137333869934082 per song
# extracting SV takes 0.8746612071990967 per song
# analyzing  48.mp3 ../data/emotifymusic/rock\48.mp3
# import takes 0.4644012451171875
# extracting ZC takes 0.10372471809387207 per song
# extracting SC takes 0.5126636028289795 per song
# extracting SV takes 0.8706731796264648 per song
# analyzing  49.mp3 ../data/emotifymusic/rock\49.mp3
# import takes 0.4596719741821289
# extracting ZC takes 0.08880090713500977 per song
# extracting SC takes 0.5086045265197754 per song
# extracting SV takes 0.8736610412597656 per song
# analyzing  5.mp3 ../data/emotifymusic/rock\5.mp3
# import takes 0.4711191654205322
# extracting ZC takes 0.09275150299072266 per song
# extracting SC takes 0.512669563293457 per song
# extracting SV takes 0.8746242523193359 per song
# analyzing  50.mp3 ../data/emotifymusic/rock\50.mp3
# import takes 0.45690441131591797
# extracting ZC takes 0.08680462837219238 per song
# extracting SC takes 0.5086033344268799 per song
# extracting SV takes 0.8816423416137695 per song
# analyzing  51.mp3 ../data/emotifymusic/rock\51.mp3
# import takes 0.458329439163208
# extracting ZC takes 0.09578156471252441 per song
# extracting SC takes 0.5070765018463135 per song
# extracting SV takes 0.8806455135345459 per song
# analyzing  52.mp3 ../data/emotifymusic/rock\52.mp3
# import takes 0.45563602447509766
# extracting ZC takes 0.09275102615356445 per song
# extracting SC takes 0.5106348991394043 per song
# extracting SV takes 0.8792862892150879 per song
# analyzing  53.mp3 ../data/emotifymusic/rock\53.mp3
# import takes 0.45880770683288574
# extracting ZC takes 0.09271764755249023 per song
# extracting SC takes 0.508673906326294 per song
# extracting SV takes 0.894934892654419 per song
# analyzing  54.mp3 ../data/emotifymusic/rock\54.mp3
# import takes 0.45864439010620117
# extracting ZC takes 0.09275484085083008 per song
# extracting SC takes 0.5076761245727539 per song
# extracting SV takes 0.8713033199310303 per song
# analyzing  55.mp3 ../data/emotifymusic/rock\55.mp3
# import takes 0.48639535903930664
# extracting ZC takes 0.08879971504211426 per song
# extracting SC takes 0.5126321315765381 per song
# extracting SV takes 0.8746547698974609 per song
# analyzing  56.mp3 ../data/emotifymusic/rock\56.mp3
# import takes 0.4411904811859131
# extracting ZC takes 0.09179186820983887 per song
# extracting SC takes 0.5206539630889893 per song
# extracting SV takes 0.8776905536651611 per song
# analyzing  57.mp3 ../data/emotifymusic/rock\57.mp3
# import takes 0.4451944828033447
# extracting ZC takes 0.09473204612731934 per song
# extracting SC takes 0.5126340389251709 per song
# extracting SV takes 0.8706722259521484 per song
# analyzing  58.mp3 ../data/emotifymusic/rock\58.mp3
# import takes 0.45285940170288086
# extracting ZC takes 0.09373855590820312 per song
# extracting SC takes 0.5155837535858154 per song
# extracting SV takes 0.8716721534729004 per song
# analyzing  59.mp3 ../data/emotifymusic/rock\59.mp3
# import takes 0.4507162570953369
# extracting ZC takes 0.09474420547485352 per song
# extracting SC takes 0.5096683502197266 per song
# extracting SV takes 0.8726663589477539 per song
# analyzing  6.mp3 ../data/emotifymusic/rock\6.mp3
# import takes 0.45023679733276367
# extracting ZC takes 0.08780169486999512 per song
# extracting SC takes 0.510664701461792 per song
# extracting SV takes 0.8836350440979004 per song
# analyzing  60.mp3 ../data/emotifymusic/rock\60.mp3
# import takes 0.4462268352508545
# extracting ZC takes 0.08879971504211426 per song
# extracting SC takes 0.5136260986328125 per song
# extracting SV takes 0.8706347942352295 per song
# analyzing  61.mp3 ../data/emotifymusic/rock\61.mp3
# import takes 0.4487600326538086
# extracting ZC takes 0.08875083923339844 per song
# extracting SC takes 0.5076091289520264 per song
# extracting SV takes 0.8856692314147949 per song
# analyzing  62.mp3 ../data/emotifymusic/rock\62.mp3
# import takes 0.4538304805755615
# extracting ZC takes 0.09578418731689453 per song
# extracting SC takes 0.514620304107666 per song
# extracting SV takes 0.881645917892456 per song
# analyzing  63.mp3 ../data/emotifymusic/rock\63.mp3
# import takes 0.45749783515930176
# extracting ZC takes 0.08979463577270508 per song
# extracting SC takes 0.5176181793212891 per song
# extracting SV takes 0.875497579574585 per song
# analyzing  64.mp3 ../data/emotifymusic/rock\64.mp3
# import takes 0.457988977432251
# extracting ZC takes 0.09674429893493652 per song
# extracting SC takes 0.508638858795166 per song
# extracting SV takes 0.9096028804779053 per song
# analyzing  65.mp3 ../data/emotifymusic/rock\65.mp3
# import takes 0.4774606227874756
# extracting ZC takes 0.09674191474914551 per song
# extracting SC takes 0.5315806865692139 per song
# extracting SV takes 0.9355294704437256 per song
# analyzing  66.mp3 ../data/emotifymusic/rock\66.mp3
# import takes 0.4766373634338379
# extracting ZC takes 0.09271478652954102 per song
# extracting SC takes 0.5245974063873291 per song
# extracting SV takes 0.8826427459716797 per song
# analyzing  67.mp3 ../data/emotifymusic/rock\67.mp3
# import takes 0.4914226531982422
# extracting ZC takes 0.0927886962890625 per song
# extracting SC takes 0.5236718654632568 per song
# extracting SV takes 0.8766531944274902 per song
# analyzing  68.mp3 ../data/emotifymusic/rock\68.mp3
# import takes 0.45658302307128906
# extracting ZC takes 0.0937037467956543 per song
# extracting SC takes 0.5046849250793457 per song
# extracting SV takes 0.8925783634185791 per song
# analyzing  69.mp3 ../data/emotifymusic/rock\69.mp3
# import takes 0.4492490291595459
# extracting ZC takes 0.09474897384643555 per song
# extracting SC takes 0.5146214962005615 per song
# extracting SV takes 0.8776187896728516 per song
# analyzing  7.mp3 ../data/emotifymusic/rock\7.mp3
# import takes 0.45374536514282227
# extracting ZC takes 0.08972501754760742 per song
# extracting SC takes 0.5196104049682617 per song
# extracting SV takes 0.8846340179443359 per song
# analyzing  70.mp3 ../data/emotifymusic/rock\70.mp3
# import takes 0.45497798919677734
# extracting ZC takes 0.09074640274047852 per song
# extracting SC takes 0.5082406997680664 per song
# extracting SV takes 0.8696744441986084 per song
# analyzing  71.mp3 ../data/emotifymusic/rock\71.mp3
# import takes 0.4477207660675049
# extracting ZC takes 0.09375214576721191 per song
# extracting SC takes 0.5076420307159424 per song
# extracting SV takes 0.8886594772338867 per song
# analyzing  72.mp3 ../data/emotifymusic/rock\72.mp3
# import takes 0.4478025436401367
# extracting ZC takes 0.09474611282348633 per song
# extracting SC takes 0.5145895481109619 per song
# extracting SV takes 0.8776524066925049 per song
# analyzing  73.mp3 ../data/emotifymusic/rock\73.mp3
# import takes 0.453876256942749
# extracting ZC takes 0.09270262718200684 per song
# extracting SC takes 0.5066819190979004 per song
# extracting SV takes 0.8755884170532227 per song
# analyzing  74.mp3 ../data/emotifymusic/rock\74.mp3
# import takes 0.4538235664367676
# extracting ZC takes 0.09473299980163574 per song
# extracting SC takes 0.5245625972747803 per song
# extracting SV takes 0.8856315612792969 per song
# analyzing  75.mp3 ../data/emotifymusic/rock\75.mp3
# import takes 0.45576977729797363
# extracting ZC takes 0.09877324104309082 per song
# extracting SC takes 0.5106337070465088 per song
# extracting SV takes 0.8766217231750488 per song
# analyzing  76.mp3 ../data/emotifymusic/rock\76.mp3
# import takes 0.4573342800140381
# extracting ZC takes 0.09075713157653809 per song
# extracting SC takes 0.509676456451416 per song
# extracting SV takes 0.8846218585968018 per song
# analyzing  77.mp3 ../data/emotifymusic/rock\77.mp3
# import takes 0.46364831924438477
# extracting ZC takes 0.09078311920166016 per song
# extracting SC takes 0.5206186771392822 per song
# extracting SV takes 0.8657257556915283 per song
# analyzing  78.mp3 ../data/emotifymusic/rock\78.mp3
# import takes 0.45427370071411133
# extracting ZC takes 0.09574389457702637 per song
# extracting SC takes 0.5156571865081787 per song
# extracting SV takes 0.9205408096313477 per song
# analyzing  79.mp3 ../data/emotifymusic/rock\79.mp3
# import takes 0.44484996795654297
# extracting ZC takes 0.09275197982788086 per song
# extracting SC takes 0.5196473598480225 per song
# extracting SV takes 0.8836367130279541 per song
# analyzing  8.mp3 ../data/emotifymusic/rock\8.mp3
# import takes 0.45096349716186523
# extracting ZC takes 0.09674453735351562 per song
# extracting SC takes 0.5206413269042969 per song
# extracting SV takes 0.8794207572937012 per song
# analyzing  80.mp3 ../data/emotifymusic/rock\80.mp3
# import takes 0.47901439666748047
# extracting ZC takes 0.09968733787536621 per song
# extracting SC takes 0.5345685482025146 per song
# extracting SV takes 0.8996376991271973 per song
# analyzing  81.mp3 ../data/emotifymusic/rock\81.mp3
# import takes 0.47569918632507324
# extracting ZC takes 0.09175634384155273 per song
# extracting SC takes 0.514662504196167 per song
# extracting SV takes 0.8936102390289307 per song
# analyzing  82.mp3 ../data/emotifymusic/rock\82.mp3
# import takes 0.47272634506225586
# extracting ZC takes 0.09774112701416016 per song
# extracting SC takes 0.5445420742034912 per song
# extracting SV takes 0.8956058025360107 per song
# analyzing  83.mp3 ../data/emotifymusic/rock\83.mp3
# import takes 0.4647400379180908
# extracting ZC takes 0.09271526336669922 per song
# extracting SC takes 0.5295865535736084 per song
# extracting SV takes 0.8806445598602295 per song
# analyzing  84.mp3 ../data/emotifymusic/rock\84.mp3
# import takes 0.4486696720123291
# extracting ZC takes 0.09079337120056152 per song
# extracting SC takes 0.51558518409729 per song
# extracting SV takes 0.8786876201629639 per song
# analyzing  85.mp3 ../data/emotifymusic/rock\85.mp3
# import takes 0.45598769187927246
# extracting ZC takes 0.09675216674804688 per song
# extracting SC takes 0.5111570358276367 per song
# extracting SV takes 0.9305107593536377 per song
# analyzing  86.mp3 ../data/emotifymusic/rock\86.mp3
# import takes 0.5239772796630859
# extracting ZC takes 0.1147301197052002 per song
# extracting SC takes 0.9574034214019775 per song
# extracting SV takes 1.7164089679718018 per song
# analyzing  87.mp3 ../data/emotifymusic/rock\87.mp3
# import takes 0.5445449352264404
# extracting ZC takes 0.13164806365966797 per song
# extracting SC takes 0.6502590179443359 per song
# extracting SV takes 1.063157081604004 per song
# analyzing  88.mp3 ../data/emotifymusic/rock\88.mp3
# import takes 0.47669219970703125
# extracting ZC takes 0.10272693634033203 per song
# extracting SC takes 0.5405945777893066 per song
# extracting SV takes 0.9005515575408936 per song
# analyzing  89.mp3 ../data/emotifymusic/rock\89.mp3
# import takes 0.4879617691040039
# extracting ZC takes 0.12271261215209961 per song
# extracting SC takes 0.5215997695922852 per song
# extracting SV takes 0.9065749645233154 per song
# analyzing  9.mp3 ../data/emotifymusic/rock\9.mp3
# import takes 0.44973301887512207
# extracting ZC takes 0.09578108787536621 per song
# extracting SC takes 0.5146262645721436 per song
# extracting SV takes 0.877854585647583 per song
# analyzing  90.mp3 ../data/emotifymusic/rock\90.mp3
# import takes 0.4648599624633789
# extracting ZC takes 0.10073041915893555 per song
# extracting SC takes 0.5166568756103516 per song
# extracting SV takes 0.8936090469360352 per song
# analyzing  91.mp3 ../data/emotifymusic/rock\91.mp3
# import takes 0.4458651542663574
# extracting ZC takes 0.09574604034423828 per song
# extracting SC takes 0.5126297473907471 per song
# extracting SV takes 0.8736996650695801 per song
# analyzing  92.mp3 ../data/emotifymusic/rock\92.mp3
# import takes 0.45140552520751953
# extracting ZC takes 0.08976221084594727 per song
# extracting SC takes 0.5366024971008301 per song
# extracting SV takes 0.907569408416748 per song
# analyzing  93.mp3 ../data/emotifymusic/rock\93.mp3
# import takes 0.44709229469299316
# extracting ZC takes 0.08876252174377441 per song
# extracting SC takes 0.510634183883667 per song
# extracting SV takes 0.8806450366973877 per song
# analyzing  94.mp3 ../data/emotifymusic/rock\94.mp3
# import takes 0.4420759677886963
# extracting ZC takes 0.10272812843322754 per song
# extracting SC takes 0.5316140651702881 per song
# extracting SV takes 0.9055807590484619 per song
# analyzing  95.mp3 ../data/emotifymusic/rock\95.mp3
# import takes 0.47272753715515137
# extracting ZC takes 0.09179019927978516 per song
# extracting SC takes 0.5285844802856445 per song
# extracting SV takes 0.907538652420044 per song
# analyzing  96.mp3 ../data/emotifymusic/rock\96.mp3
# import takes 0.44925427436828613
# extracting ZC takes 0.09074687957763672 per song
# extracting SC takes 0.5125946998596191 per song
# extracting SV takes 0.9075703620910645 per song
# analyzing  97.mp3 ../data/emotifymusic/rock\97.mp3
# import takes 0.4573543071746826
# extracting ZC takes 0.09079098701477051 per song
# extracting SC takes 0.5255599021911621 per song
# extracting SV takes 0.8966388702392578 per song
# analyzing  98.mp3 ../data/emotifymusic/rock\98.mp3
# import takes 0.47620320320129395
# extracting ZC takes 0.10372352600097656 per song
# extracting SC takes 0.5196077823638916 per song
# extracting SV takes 0.8677170276641846 per song
# analyzing  99.mp3 ../data/emotifymusic/rock\99.mp3
# import takes 0.44600796699523926
# extracting ZC takes 0.0947866439819336 per song
# extracting SC takes 0.5205700397491455 per song
# extracting SV takes 0.8887925148010254 per song
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23148/4270545963.py in <module>
#      36 SC_reshape = np.reshape(SC, (np.shape(SC)[0]*np.shape(SC)[1], np.shape(SC)[2]))
#      37 SV_reshape = np.reshape(SV, (np.shape(SV)[0]*np.shape(SV)[1], np.shape(SV)[2]))
# ---> 38 staticTempo_reshape = np.reshape(staticTempo, (np.shape(staticTempo)[0]*np.shape(staticTempo)[1]))
#      39
#      40 np.save('zeroCrossings_frame200ms_hop100ms.npy', ZC_reshape)
#
# IndexError: tuple index out of range

# %%
np.save('zeroCrossings_frame200ms_hop100ms.npy', ZC_reshape)
np.save('spectralCentroid_frame200ms_hop100ms.npy', SC_reshape)
np.save('spectralVariance_frame200ms_hop100ms.npy', SV_reshape)

# %%
# Loading previous data
# Some data is saved as npz file, containing 4 arrays for every genre. Then use the loop to unpack
# Later data was saved as 400 x ... as npy file

genres = ["classical", "electronic", "pop", "rock"]

ZCnpz = np.load('zeroCrossings_frame100ms_hop50ms.npz')
SCnpz = np.load('spectralCentroid_frame100ms_hop50ms.npz')
SVnpz = np.load('spectralVariance_frame100ms_hop50ms.npz')
STnpz = np.load('staticTempoLibrosa.npz')

ZC = []
SC = []
SV = []
staticTempo = []

for genre in genres:
    ZC.append(ZCnpz[genre])
    SC.append(SCnpz[genre])
    SV.append(SVnpz[genre])
    staticTempo.append(STnpz[genre])

# %%
# Reshaping lists containing one array per genre to a single array of dimension 400 x . 

ZC_reshape = np.reshape(ZC, (np.shape(ZC)[0]*np.shape(ZC)[1], np.shape(ZC)[2]))
SC_reshape = np.reshape(SC, (np.shape(SC)[0]*np.shape(SC)[1], np.shape(SC)[2]))
SV_reshape = np.reshape(SV, (np.shape(SV)[0]*np.shape(SV)[1], np.shape(SV)[2]))
staticTempo_reshape = np.reshape(staticTempo, (np.shape(staticTempo)[0]*np.shape(staticTempo)[1]))

# %% [markdown]
# ----------------------------

# %%
# Scatter plots for feature exploration

import matplotlib.pyplot as plt

fig,ax = plt.subplots()
ax.scatter(ZC[0].flatten(), SV[0].flatten(), marker='x', alpha=0.1)
# ax.scatter(ZC[1].flatten(), SC[1].flatten(), marker='o', alpha=0.1)
# ax.scatter(ZC[2].flatten(), SC[2].flatten(), marker='^', alpha=0.1)
ax.scatter(ZC[3].flatten(), SV[3].flatten(), marker='*', alpha=0.1)


# ax.set_xlim(0,10000)
# ax.set_ylim(0,20000)

# %%
fig,ax = plt.subplots()
ax.scatter(np.mean(ZC[0], axis=1), staticTempo[0], marker='x', alpha=0.5)
ax.scatter(np.mean(ZC[1], axis=1), staticTempo[1], marker='o', alpha=0.5)
ax.scatter(np.mean(ZC[2], axis=1), staticTempo[2], marker='^', alpha=0.5)
ax.scatter(np.mean(ZC[3], axis=1), staticTempo[3], marker='*', alpha=0.5)


# ax.set_xlim(0,10000)
# ax.set_ylim(0,20000)

# %%
# From top to bottom: genre
# From left to right: zero crossings, spectral centroid, spectral variance, static tempo extimation by librosa
# For the first three the mean is taken over all windows (can be changed!)


fig, [[ax1, ax2, ax3, ax4], [ax5, ax6, ax7, ax8], [ax9, ax10, ax11, ax12], [ax13, ax14, ax15, ax16]] = plt.subplots(4,4, figsize=(14,14))

# fig, [[ax1, ax2, ax3], [ax4, ax5, ax6]] = plt.subplots(2,3)


ax1.hist(np.mean(ZC[0], axis=1),  bins=50, density=True, color='blue')
ax2.hist(np.mean(SC[0], axis=1),  bins=50, density=True, color='blue')
ax3.hist(np.mean(SV[0], axis=1),  bins=50, density=True, color='blue')
ax4.hist(staticTempo[0] ,  bins=50, density=True, color='blue')


ax5.hist(np.mean(ZC[1], axis=1), bins=50, density=True, color='orange')
ax6.hist(np.mean(SC[1], axis=1), bins=50, density=True, color='orange')
ax7.hist(np.mean(SV[1], axis=1), bins=50, density=True, color='orange')
ax8.hist(staticTempo[1],  bins=50, density=True, color='orange')


ax9.hist(np.mean(ZC[2], axis=1),  bins=50, density=True, color='red')
ax10.hist(np.mean(SC[2], axis=1), bins=50, density=True, color='red')
ax11.hist(np.mean(SV[2], axis=1), bins=50, density=True, color='red')
ax12.hist(staticTempo[2],  bins=50, density=True, color='red')


ax13.hist(np.mean(ZC[3], axis=1), bins=50, density=True, color='green')
ax14.hist(np.mean(SC[3], axis=1), bins=50, density=True, color='green')
ax15.hist(np.mean(SV[3], axis=1), bins=50, density=True, color='green')
ax16.hist(staticTempo[3],  bins=50, density=True, color='green')


ax1.set_xlim((0,2000))
ax5.set_xlim((0,2000))
ax9.set_xlim((0,2000))
ax13.set_xlim((0,2000))

ax2.set_xlim((0,15000))
ax6.set_xlim((0,15000))
ax10.set_xlim((0,15000))
ax14.set_xlim((0,15000))

ax3.set_xlim((0,1.5e8))
ax7.set_xlim((0,1.5e8))
ax11.set_xlim((0,1.5e8))
ax15.set_xlim((0,1.5e8))

ax4.set_xlim((80,175))
ax8.set_xlim((80,175))
ax12.set_xlim((80,175))
ax16.set_xlim((80,175))

# %%
# From top to bottom: genre
# From left to right: zero crossings, spectral centroid, spectral variance, static tempo extimation by librosa
# No mean taken


fig, [[ax1, ax2, ax3, ax4], [ax5, ax6, ax7, ax8], [ax9, ax10, ax11, ax12], [ax13, ax14, ax15, ax16]] = plt.subplots(4,4, figsize=(14,14))

# fig, [[ax1, ax2, ax3], [ax4, ax5, ax6]] = plt.subplots(2,3)


ax1.hist(ZC[0].flatten(),  bins=50, density=True, color='blue')
ax2.hist(SC[0].flatten(),  bins=50, density=True, color='blue')
ax3.hist(SV[0].flatten(),  bins=50, density=True, color='blue')
ax4.hist(staticTempo[0] ,  bins=50, density=True, color='blue')


ax5.hist(ZC[1].flatten(), bins=50, density=True, color='orange')
ax6.hist(SC[1].flatten(), bins=50, density=True, color='orange')
ax7.hist(SV[1].flatten(), bins=50, density=True, color='orange')
ax8.hist(staticTempo[1],  bins=50, density=True, color='orange')


ax9.hist(ZC[2].flatten(),  bins=50, density=True, color='red')
ax10.hist(SC[2].flatten(), bins=50, density=True, color='red')
ax11.hist(SV[2].flatten(), bins=50, density=True, color='red')
ax12.hist(staticTempo[2],  bins=50, density=True, color='red')


ax13.hist(ZC[3].flatten(), bins=50, density=True, color='green')
ax14.hist(SC[3].flatten(), bins=50, density=True, color='green')
ax15.hist(SV[3].flatten(), bins=50, density=True, color='green')
ax16.hist(staticTempo[3],  bins=50, density=True, color='green')


ax1.set_xlim((0,2000))
ax5.set_xlim((0,2000))
ax9.set_xlim((0,2000))
ax13.set_xlim((0,2000))

ax2.set_xlim((0,15000))
ax6.set_xlim((0,15000))
ax10.set_xlim((0,15000))
ax14.set_xlim((0,15000))

ax3.set_xlim((0,1.5e8))
ax7.set_xlim((0,1.5e8))
ax11.set_xlim((0,1.5e8))
ax15.set_xlim((0,1.5e8))

ax4.set_xlim((80,175))
ax8.set_xlim((80,175))
ax12.set_xlim((80,175))
ax16.set_xlim((80,175))

# %%
# fig, [[ax1, ax2, ax3], [ax4, ax5, ax6], [ax7, ax8, ax9], [ax10, ax11, ax12]] = plt.subplots(4,3, figsize=(10,10))

fig, [[ax1, ax2, ax3], [ax4, ax5, ax6]] = plt.subplots(2,3,  figsize=(10,10))


ax1.hist(ZC_5_2[0].flatten(),  bins=50, density=True, color='blue')
ax2.hist(SC_5_2[0].flatten(),  bins=50, density=True, color='blue')
ax3.hist(SV_5_2[0].flatten(),  bins=50, density=True, color='blue')

ax4.hist(ZC_5_2[1].flatten(), bins=50, density=True, color='orange')
ax5.hist(SC_5_2[1].flatten(), bins=50, density=True, color='orange')
ax6.hist(SV_5_2[1].flatten(), bins=50, density=True, color='orange')

# ax7.hist(ZC_5_2[2].flatten(),  bins=50, density=True, color='red')
# ax8.hist(SC_5_2[2].flatten(),  bins=50, density=True, color='red')
# ax9.hist(SV_5_2[2].flatten(),  bins=50, density=True, color='red')

# ax10.hist(ZC_5_2[3].flatten(), bins=50, density=True, color='green')
# ax11.hist(SC_5_2[3].flatten(), bins=50, density=True, color='green')
# ax12.hist(SV_5_2[3].flatten(), bins=50, density=True, color='green')

ax1.set_xlim((0,80000))
ax4.set_xlim((0,80000))
ax2.set_xlim((0,15000))
ax5.set_xlim((0,15000))
ax3.set_xlim((0,1.5e8))
ax6.set_xlim((0,1.5e8))

# %%
fig, [[ax1, ax2, ax3], [ax4, ax5, ax6]] = plt.subplots(2,3,  figsize=(10,10))


ZC_means0 = np.mean(ZC[0], axis=1)
ZC_means1 = np.mean(ZC[1], axis=1)

SC_means0 = np.mean(SC[0], axis=1)
SC_means1 = np.mean(SC[1], axis=1)

SV_means0 = np.mean(SV[0], axis=1)
SV_means1 = np.mean(SV[1], axis=1)


ax1.hist(ZC_means0,  bins=50, density=True, color='blue')
ax2.hist(SC_means0,  bins=50, density=True, color='blue')
ax3.hist(SV_means0,  bins=50, density=True, color='blue')

ax4.hist(ZC_means1, bins=50, density=True, color='orange')
ax5.hist(SC_means1, bins=50, density=True, color='orange')
ax6.hist(SV_means1, bins=50, density=True, color='orange')


# ax2.hist(SC[0][song,:],  bins=50, density=True, color='blue')
# ax3.hist(SV[0][song,:],  bins=50, density=True, color='blue')

# ax4.hist(ZC_means1, bins=50, density=True, color='orange')
# ax5.hist(SC[1][song,:], bins=50, density=True, color='orange')
# ax6.hist(SV[1][song,:], bins=50, density=True, color='orange')

ax1.set_xlim((0,2000))
ax4.set_xlim((0,2000))
ax2.set_xlim((0,15000))
ax5.set_xlim((0,15000))
ax3.set_xlim((0,1.5e8))
ax6.set_xlim((0,1.5e8))

# %% [markdown]
# --------------------------

# %%
# Dataframes for further feature exploration

d = {'ZC': ZC_reshape, 'SC': SC_reshape, 'SV': SV_reshape, 'StaticTempo': staticTempo_reshape}
features_dict_means = {'ZC': np.nanmean(ZC_reshape, axis=1),
           'SC': np.nanmean(SC_reshape, axis=1),
           'SV': np.nanmean(SV_reshape, axis=1),
           'StaticTempo': staticTempo_reshape}
features_df = pd.DataFrame(data=features_dict_means)
features_df

# %%
ones = np.ones(100, dtype='int')
labels_dict = {'label': np.concatenate((ones, ones*2, ones*3, ones*4))}
labels_df = pd.DataFrame(labels_dict)
labels_df

# %%
# All features in a scatter matrix

from matplotlib import colors
cmap = colors.ListedColormap(['k', 'g', 'b', 'orange'], 4)

F = features_df
C = labels_df.to_numpy()

pd.plotting.scatter_matrix(F, c=C, cmap=cmap, alpha=1, figsize=(15,15), diagonal = 'hist')
plt.legend('classical')

# %%
# All features in a scatter matrix for classical and rock. They seem seperable to some extent!!

cmap = colors.ListedColormap(['k', 'g', 'b', 'orange'], 4)

F = features_df[(labels_df['label'] == 1) | (labels_df['label'] == 4)]
C = labels_df[(labels_df['label'] == 1) | (labels_df['label'] == 4)].to_numpy()

pd.plotting.scatter_matrix(F, c=C, cmap=cmap, alpha=1, figsize=(15,15), diagonal = 'hist')
plt.legend('classical')
